# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=512, filter2=4096, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        self.conv_c = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_cc = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)
        self.W_cc = nn.Linear(filter2 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        c = self.relu(self.conv_c(x))
        aa = self.flatten(self.relu(self.conv_aa(a)))
        ab = self.flatten(self.relu(self.conv_ab(a)))
        ba = self.flatten(self.relu(self.conv_ba(b)))
        bb = self.flatten(self.relu(self.conv_bb(b)))
        cc = self.flatten(self.relu(self.conv_cc(c)))
        out = self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) + self.W_cc(cc)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y) / 2
            last_loss = loss.item()
            loss.backward()
            optimizer.step()
            model.eval()
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 1e-3
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)
    
def load_model(model, optimizer, filename, model_only = False):
    checkpoint_path = os.path.join(experiment_dir, filename)
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    if not model_only:
        optimizer.load_state_dict(ckpt_dict['optimizer'])
        epoch = ckpt_dict['epoch']
        running_mean = ckpt_dict['running_mean']
    else:
        epoch = None
        running_mean = None
    return model, optimizer, epoch, running_mean

# %%
import copy

num_epochs = 1000
best_model = None

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
    ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean or epoch % 500 == 0:
            running_mean = sum(ls) / 10
            name = epoch if epoch % 500 == 0 else epoch // 100
            filename = "model_score_"+str(name)+".pth.tar"
            save_model({
                'epoch': epoch,
                'running_mean': running_mean,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            model.cuda()
            best_model = copy.deepcopy(model)
            
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  169 Max score  128 Game score  1536
# Game #  2 Game length  109 Max score  64 Game score  796
# Game #  3 Game length  92 Max score  64 Game score  636
# Game #  4 Game length  220 Max score  128 Game score  2024
# Game #  5 Game length  234 Max score  256 Game score  2568
# Game #  6 Game length  256 Max score  128 Game score  2576
# Game #  7 Game length  353 Max score  256 Game score  3944
# Game #  8 Game length  216 Max score  256 Game score  2364
# Game #  9 Game length  214 Max score  128 Game score  2092
# Game #  10 Game length  193 Max score  128 Game score  1808
# Game #  11 Game length  115 Max score  64 Game score  852
# Game #  12 Game length  340 Max score  256 Game score  3936
# Game #  13 Game length  220 Max score  128 Game score  2192
# Game #  14 Game length  419 Max score  512 Game score  5596
# Game #  15 Game length  375 Max score  256 Game score  4316
# Game #  16 Game length  488 Max score  512 Game score  6656
# Game #  17 Game length  228 Max score  256 Game score  2524
# Game #  18 Game length  535 Max score  512 Game score  7196
# Game #  19 Game length  586 Max score  512 Game score  8224
# Game #  20 Game length  509 Max score  512 Game score  6912
# Game #  21 Game length  496 Max score  512 Game score  6796
# Game #  22 Game length  477 Max score  512 Game score  6576
# Game #  23 Game length  253 Max score  256 Game score  2896
# Game #  24 Game length  430 Max score  512 Game score  5676
# Game #  25 Game length  665 Max score  512 Game score  9128
# Game #  26 Game length  538 Max score  512 Game score  7320
# Game #  27 Game length  310 Max score  256 Game score  3500
# Game #  28 Game length  564 Max score  512 Game score  7628
# Game #  29 Game length  444 Max score  256 Game score  5376
# Game #  30 Game length  1026 Max score  1024 Game score  16172
# Game #  31 Game length  670 Max score  512 Game score  9700
# Game #  32 Game length  333 Max score  256 Game score  3776
# Game #  33 Game length  442 Max score  512 Game score  5864
# Game #  34 Game length  744 Max score  512 Game score  10784
# Game #  35 Game length  736 Max score  1024 Game score  11724
# Game #  36 Game length  1208 Max score  2048 Game score  22236
# Game #  37 Game length  468 Max score  512 Game score  6240
# Game #  38 Game length  522 Max score  512 Game score  7200
# Game #  39 Game length  775 Max score  1024 Game score  12268
# Game #  40 Game length  546 Max score  512 Game score  7388
# Game #  41 Game length  845 Max score  1024 Game score  13124
# Game #  42 Game length  787 Max score  1024 Game score  12380
# Game #  43 Game length  950 Max score  1024 Game score  15060
# Game #  44 Game length  581 Max score  512 Game score  7936
# Game #  45 Game length  574 Max score  512 Game score  7872
# Game #  46 Game length  591 Max score  512 Game score  8012
# Game #  47 Game length  542 Max score  512 Game score  7356
# Game #  48 Game length  905 Max score  1024 Game score  14620
# Game #  49 Game length  483 Max score  512 Game score  6620
# Game #  50 Game length  923 Max score  1024 Game score  14764
# Game #  51 Game length  799 Max score  1024 Game score  12492
# Game #  52 Game length  528 Max score  512 Game score  7244
# Game #  53 Game length  537 Max score  512 Game score  7304
# Game #  54 Game length  640 Max score  512 Game score  8852
# Game #  55 Game length  919 Max score  1024 Game score  14236
# Game #  56 Game length  830 Max score  1024 Game score  12936
# Game #  57 Game length  851 Max score  1024 Game score  13900
# Game #  58 Game length  488 Max score  512 Game score  6648
# Game #  59 Game length  744 Max score  1024 Game score  11776
# Game #  60 Game length  786 Max score  1024 Game score  12376
# Game #  61 Game length  281 Max score  256 Game score  3200
# Game #  62 Game length  410 Max score  512 Game score  5536
# Game #  63 Game length  1038 Max score  1024 Game score  16444
# Game #  64 Game length  981 Max score  1024 Game score  15728
# Game #  65 Game length  790 Max score  1024 Game score  12432
# Game #  66 Game length  554 Max score  512 Game score  7528
# Game #  67 Game length  544 Max score  512 Game score  7376
# Game #  68 Game length  543 Max score  512 Game score  7372
# Game #  69 Game length  662 Max score  512 Game score  9084
# Game #  70 Game length  789 Max score  1024 Game score  12428
# Game #  71 Game length  838 Max score  1024 Game score  13072
# Game #  72 Game length  561 Max score  512 Game score  7576
# Game #  73 Game length  1035 Max score  1024 Game score  16428
# Game #  74 Game length  672 Max score  1024 Game score  10700
# Game #  75 Game length  821 Max score  1024 Game score  12728
# Game #  76 Game length  509 Max score  512 Game score  7024
# Game #  77 Game length  484 Max score  512 Game score  6712
# Game #  78 Game length  1046 Max score  1024 Game score  16536
# Game #  79 Game length  530 Max score  512 Game score  7256
# Game #  80 Game length  579 Max score  512 Game score  7852
# Game #  81 Game length  544 Max score  512 Game score  7376
# Game #  82 Game length  1054 Max score  1024 Game score  16588
# Game #  83 Game length  572 Max score  512 Game score  7680
# Game #  84 Game length  575 Max score  512 Game score  7700
# Game #  85 Game length  555 Max score  512 Game score  7532
# Game #  86 Game length  566 Max score  512 Game score  7640
# Game #  87 Game length  811 Max score  1024 Game score  12652
# Game #  88 Game length  662 Max score  512 Game score  9616
# Game #  89 Game length  737 Max score  1024 Game score  11728
# Game #  90 Game length  313 Max score  256 Game score  3552
# Game #  91 Game length  533 Max score  512 Game score  7308
# Game #  92 Game length  1065 Max score  1024 Game score  16864
# Game #  93 Game length  811 Max score  1024 Game score  12652
# Game #  94 Game length  829 Max score  1024 Game score  12976
# Game #  95 Game length  1057 Max score  1024 Game score  16664
# Game #  96 Game length  591 Max score  512 Game score  8012
# Game #  97 Game length  1247 Max score  1024 Game score  20940
# Game #  98 Game length  796 Max score  1024 Game score  12476
# Game #  99 Game length  908 Max score  1024 Game score  14636
# Game #  100 Game length  1052 Max score  1024 Game score  16576
# Game #  101 Game length  922 Max score  1024 Game score  14760
# Game #  102 Game length  443 Max score  512 Game score  5880
# Game #  103 Game length  927 Max score  1024 Game score  14796
# Game #  104 Game length  570 Max score  512 Game score  7784
# Game #  105 Game length  922 Max score  1024 Game score  14760
# Game #  106 Game length  855 Max score  1024 Game score  13436
# Game #  107 Game length  617 Max score  512 Game score  8460
# Game #  108 Game length  902 Max score  1024 Game score  14060
# Game #  109 Game length  578 Max score  512 Game score  7896
# Game #  110 Game length  578 Max score  512 Game score  7920
# Game #  111 Game length  1038 Max score  1024 Game score  16456
# Game #  112 Game length  559 Max score  512 Game score  7564
# Game #  113 Game length  1020 Max score  1024 Game score  16240
# Game #  114 Game length  1047 Max score  1024 Game score  16600
# Game #  115 Game length  502 Max score  512 Game score  6840
# Game #  116 Game length  976 Max score  1024 Game score  15692
# Game #  117 Game length  812 Max score  1024 Game score  12608
# Game #  118 Game length  1165 Max score  1024 Game score  18752
# Game #  119 Game length  607 Max score  512 Game score  8396
# Game #  120 Game length  1049 Max score  1024 Game score  16552
# Game #  121 Game length  549 Max score  512 Game score  7404
# Game #  122 Game length  992 Max score  1024 Game score  15824
# Game #  123 Game length  791 Max score  1024 Game score  12412
# Game #  124 Game length  1039 Max score  1024 Game score  16460
# Game #  125 Game length  1134 Max score  1024 Game score  18424
# Game #  126 Game length  1302 Max score  2048 Game score  23696
# Game #  127 Game length  661 Max score  1024 Game score  10592
# Game #  128 Game length  1050 Max score  1024 Game score  16568
# Game #  129 Game length  1288 Max score  1024 Game score  21532
# Game #  130 Game length  781 Max score  1024 Game score  12336
# Game #  131 Game length  298 Max score  256 Game score  3340
# Game #  132 Game length  1540 Max score  2048 Game score  27616
# Game #  133 Game length  923 Max score  1024 Game score  14764
# Game #  134 Game length  1593 Max score  2048 Game score  28140
# Game #  135 Game length  586 Max score  512 Game score  7852
# Game #  136 Game length  1027 Max score  1024 Game score  16348
# Game #  137 Game length  548 Max score  512 Game score  7400
# Game #  138 Game length  1042 Max score  1024 Game score  16476
# Game #  139 Game length  1784 Max score  2048 Game score  32484
# Game #  140 Game length  558 Max score  512 Game score  7584
# Game #  141 Game length  1332 Max score  2048 Game score  24348
# Game #  142 Game length  466 Max score  512 Game score  6480
# Game #  143 Game length  809 Max score  1024 Game score  12556
# Game #  144 Game length  540 Max score  512 Game score  7356
# Game #  145 Game length  536 Max score  512 Game score  7300
# Game #  146 Game length  1033 Max score  1024 Game score  16416
# Game #  147 Game length  412 Max score  256 Game score  5040
# Game #  148 Game length  878 Max score  1024 Game score  13644
# Game #  149 Game length  1080 Max score  1024 Game score  16872
# Game #  150 Game length  1174 Max score  1024 Game score  18824
# Game #  151 Game length  970 Max score  1024 Game score  15648
# Game #  152 Game length  1017 Max score  1024 Game score  16272
# Game #  153 Game length  537 Max score  512 Game score  7304
# Game #  154 Game length  1302 Max score  2048 Game score  23660
# Game #  155 Game length  559 Max score  512 Game score  7564
# Game #  156 Game length  1032 Max score  1024 Game score  16412
# Game #  157 Game length  911 Max score  1024 Game score  14664
# Game #  158 Game length  754 Max score  512 Game score  11056
# Game #  159 Game length  923 Max score  1024 Game score  14824
# Game #  160 Game length  1035 Max score  1024 Game score  16428
# Game #  161 Game length  527 Max score  512 Game score  7228
# Game #  162 Game length  995 Max score  1024 Game score  16024
# Game #  163 Game length  1143 Max score  1024 Game score  18492
# Game #  164 Game length  1549 Max score  2048 Game score  27712
# Game #  165 Game length  1027 Max score  1024 Game score  16348
# Game #  166 Game length  1132 Max score  1024 Game score  18288
# Game #  169 Game length  1015 Max score  1024 Game score  16188
# Game #  170 Game length  1172 Max score  1024 Game score  19808
# Game #  171 Game length  1021 Max score  1024 Game score  16304
# Game #  172 Game length  1811 Max score  2048 Game score  32876
# Game #  173 Game length  978 Max score  1024 Game score  15704
# Game #  174 Game length  936 Max score  1024 Game score  14856
# Game #  175 Game length  943 Max score  1024 Game score  14988
# Game #  176 Game length  1056 Max score  1024 Game score  16656
# Game #  177 Game length  1559 Max score  2048 Game score  27804
# Game #  178 Game length  1299 Max score  2048 Game score  23644
# Game #  179 Game length  925 Max score  1024 Game score  14760
# Game #  180 Game length  421 Max score  512 Game score  5644
# Game #  181 Game length  545 Max score  512 Game score  7384
# Game #  182 Game length  1054 Max score  1024 Game score  16588
# Game #  183 Game length  1451 Max score  2048 Game score  26220
# Game #  184 Game length  1052 Max score  1024 Game score  16568
# Game #  185 Game length  1547 Max score  2048 Game score  27692
# Game #  186 Game length  1162 Max score  1024 Game score  18220
# Game #  187 Game length  2007 Max score  2048 Game score  36252
# Game #  188 Game length  781 Max score  1024 Game score  12336
# Game #  189 Game length  1305 Max score  2048 Game score  23712
# Game #  190 Game length  559 Max score  512 Game score  7676
# Game #  191 Game length  701 Max score  1024 Game score  10984
# Game #  192 Game length  581 Max score  512 Game score  8128
# Game #  193 Game length  554 Max score  512 Game score  7468
# Game #  194 Game length  1032 Max score  1024 Game score  16412
# Game #  195 Game length  1040 Max score  1024 Game score  16408
# Game #  196 Game length  1550 Max score  2048 Game score  27720
# Game #  197 Game length  1823 Max score  2048 Game score  32980
# Game #  198 Game length  982 Max score  1024 Game score  15512
# Game #  199 Game length  737 Max score  1024 Game score  11740
# Game #  200 Game length  610 Max score  512 Game score  8436
# Game #  201 Game length  1749 Max score  2048 Game score  31864
# Game #  202 Game length  1039 Max score  1024 Game score  16460
# Game #  203 Game length  1560 Max score  2048 Game score  27784
# Game #  204 Game length  1218 Max score  1024 Game score  19624
# Game #  205 Game length  774 Max score  1024 Game score  12260
# Game #  206 Game length  1635 Max score  2048 Game score  30456
# Game #  207 Game length  1085 Max score  1024 Game score  16968
# Game #  208 Game length  1850 Max score  2048 Game score  33400
# Game #  209 Game length  1463 Max score  2048 Game score  26668
# Game #  210 Game length  805 Max score  1024 Game score  12536
# Game #  211 Game length  854 Max score  1024 Game score  13208
# Game #  212 Game length  852 Max score  1024 Game score  13916
# Game #  213 Game length  540 Max score  512 Game score  7344
# Game #  214 Game length  538 Max score  512 Game score  7344
# Game #  215 Game length  550 Max score  512 Game score  7420
# Game #  216 Game length  1059 Max score  1024 Game score  16700
# Game #  217 Game length  1523 Max score  2048 Game score  27420
# Game #  218 Game length  802 Max score  1024 Game score  12508
# Game #  219 Game length  1928 Max score  2048 Game score  35072
# Game #  220 Game length  1504 Max score  2048 Game score  27088
# Game #  221 Game length  798 Max score  512 Game score  11468
# Game #  222 Game length  1047 Max score  1024 Game score  16528
# Game #  223 Game length  1050 Max score  1024 Game score  16556
# Game #  224 Game length  1811 Max score  2048 Game score  32876
# Game #  225 Game length  1595 Max score  2048 Game score  28500
# Game #  226 Game length  1080 Max score  1024 Game score  17244
# Game #  227 Game length  726 Max score  1024 Game score  11632
# Game #  228 Game length  1551 Max score  2048 Game score  27724
# Game #  229 Game length  1007 Max score  1024 Game score  15772
# Game #  230 Game length  1054 Max score  1024 Game score  16588
# Game #  231 Game length  1084 Max score  1024 Game score  16904
# Game #  232 Game length  1529 Max score  2048 Game score  27464
# Game #  233 Game length  717 Max score  1024 Game score  11312
# Game #  234 Game length  829 Max score  1024 Game score  12808
# Game #  235 Game length  676 Max score  512 Game score  9208
# Game #  236 Game length  1828 Max score  2048 Game score  33016
# Game #  237 Game length  1026 Max score  1024 Game score  16344
# Game #  238 Game length  1045 Max score  1024 Game score  16504
# Game #  239 Game length  1184 Max score  1024 Game score  19920
# Game #  240 Game length  1011 Max score  1024 Game score  16156
# Game #  241 Game length  1494 Max score  2048 Game score  27024
# Game #  242 Game length  1598 Max score  2048 Game score  28360
# Game #  243 Game length  2061 Max score  2048 Game score  36936
# Game #  244 Game length  1931 Max score  2048 Game score  35068
# Game #  245 Game length  1595 Max score  2048 Game score  28160
# Game #  246 Game length  1810 Max score  2048 Game score  32860
# Game #  247 Game length  1014 Max score  1024 Game score  16256
# Game #  248 Game length  683 Max score  512 Game score  9304
# Game #  249 Game length  1526 Max score  2048 Game score  27472
# Game #  250 Game length  1797 Max score  2048 Game score  32780
# Game #  251 Game length  1055 Max score  1024 Game score  16652
# Game #  252 Game length  1036 Max score  1024 Game score  16444
# Game #  253 Game length  2727 Max score  4096 Game score  55868
# Game #  254 Game length  1042 Max score  1024 Game score  16476
# Game #  255 Game length  1967 Max score  2048 Game score  35596
# Game #  256 Game length  541 Max score  512 Game score  7360
# Game #  257 Game length  1499 Max score  2048 Game score  27052
# Game #  258 Game length  1652 Max score  2048 Game score  30624
# Game #  259 Game length  1077 Max score  1024 Game score  16976
# Game #  260 Game length  947 Max score  1024 Game score  15132
# Game #  261 Game length  997 Max score  1024 Game score  15880
# Game #  262 Game length  1128 Max score  1024 Game score  17464
# Game #  263 Game length  1544 Max score  2048 Game score  27676
# Game #  264 Game length  1165 Max score  1024 Game score  18248
# Game #  265 Game length  1580 Max score  2048 Game score  28036
# Game #  266 Game length  1556 Max score  2048 Game score  27752
# Game #  267 Game length  1756 Max score  2048 Game score  31168
# Game #  268 Game length  1936 Max score  2048 Game score  35156
# Game #  269 Game length  1330 Max score  2048 Game score  23916
# Game #  270 Game length  1800 Max score  2048 Game score  32796
# Game #  271 Game length  1075 Max score  1024 Game score  16844
# Game #  272 Game length  1501 Max score  2048 Game score  27036
# Game #  273 Game length  2990 Max score  4096 Game score  60044
# Game #  274 Game length  979 Max score  1024 Game score  15708
# Game #  275 Game length  1042 Max score  1024 Game score  16476
# Game #  276 Game length  1013 Max score  1024 Game score  16044
# Game #  277 Game length  1340 Max score  2048 Game score  24056
# Game #  278 Game length  1689 Max score  2048 Game score  29372
# Game #  279 Game length  1813 Max score  2048 Game score  32888
# Game #  280 Game length  2068 Max score  2048 Game score  37012
# Game #  281 Game length  921 Max score  1024 Game score  14728
# Game #  282 Game length  2578 Max score  4096 Game score  52316
# Game #  283 Game length  1550 Max score  2048 Game score  27720
# Game #  284 Game length  2052 Max score  2048 Game score  36840
# Game #  285 Game length  1058 Max score  1024 Game score  16620
# Game #  286 Game length  944 Max score  1024 Game score  14992
# Game #  287 Game length  1568 Max score  2048 Game score  27864
# Game #  288 Game length  1555 Max score  2048 Game score  27744
# Game #  289 Game length  529 Max score  512 Game score  7260
# Game #  290 Game length  1015 Max score  1024 Game score  16188
# Game #  291 Game length  1179 Max score  1024 Game score  18876
# Game #  292 Game length  1833 Max score  2048 Game score  33080
# Game #  293 Game length  2033 Max score  2048 Game score  36632
# Game #  294 Game length  1937 Max score  2048 Game score  35160
# Game #  295 Game length  1821 Max score  2048 Game score  32968
# Game #  296 Game length  2010 Max score  2048 Game score  36244
# Game #  297 Game length  1089 Max score  1024 Game score  17064
# Game #  298 Game length  1964 Max score  2048 Game score  35400
# Game #  299 Game length  1309 Max score  2048 Game score  23748
# Game #  300 Game length  1279 Max score  1024 Game score  20428
# Game #  301 Game length  1554 Max score  2048 Game score  27752
# Game #  302 Game length  1795 Max score  2048 Game score  31740
# Game #  303 Game length  1934 Max score  2048 Game score  35144
# Game #  304 Game length  1037 Max score  1024 Game score  16448
# Game #  305 Game length  2010 Max score  2048 Game score  36280
# Game #  306 Game length  760 Max score  1024 Game score  11968
# Game #  307 Game length  950 Max score  1024 Game score  15064
# Game #  308 Game length  1396 Max score  2048 Game score  25504
# Game #  309 Game length  2093 Max score  2048 Game score  37260
# Game #  310 Game length  1039 Max score  1024 Game score  16460
# Game #  311 Game length  1134 Max score  1024 Game score  17556
# Game #  312 Game length  1567 Max score  2048 Game score  27916
# Game #  313 Game length  2059 Max score  2048 Game score  36924
# Game #  314 Game length  2053 Max score  2048 Game score  36884
# Game #  315 Game length  1047 Max score  1024 Game score  16540
# Game #  316 Game length  1076 Max score  1024 Game score  16848
# Game #  317 Game length  2031 Max score  2048 Game score  36620
# Game #  318 Game length  548 Max score  512 Game score  7400
# Game #  319 Game length  855 Max score  1024 Game score  13212
# Game #  320 Game length  2013 Max score  2048 Game score  36268
# Game #  321 Game length  1036 Max score  1024 Game score  16432
# Game #  322 Game length  1579 Max score  2048 Game score  28028
# Game #  323 Game length  1097 Max score  1024 Game score  17068
# Game #  324 Game length  1326 Max score  1024 Game score  21004
# Game #  325 Game length  1550 Max score  2048 Game score  27720
# Game #  326 Game length  1527 Max score  2048 Game score  27452
# Game #  327 Game length  1746 Max score  2048 Game score  32084
# Game #  328 Game length  528 Max score  512 Game score  7244
# Game #  329 Game length  1945 Max score  2048 Game score  35296
# Game #  330 Game length  2208 Max score  2048 Game score  42448
# Game #  331 Game length  2111 Max score  2048 Game score  37612
# Game #  332 Game length  2448 Max score  4096 Game score  50448
# Game #  333 Game length  1629 Max score  2048 Game score  28556
# Game #  334 Game length  1614 Max score  2048 Game score  28492
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-2d4dd1522a55> in <module>
#      24             best_model = copy.deepcopy(model)
#      25
# ---> 26 train(model, optimizer, loss)
#
# <ipython-input-8-2d4dd1522a55> in train(model, optimizer, loss, epoch, running_mean)
#       8     while epoch != num_epochs:
#       9         epoch += 1
# ---> 10         game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
#      11         print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
#      12         ls.pop(0)
#
# <ipython-input-5-a59ad20aa8c4> in gen_sample_and_learn(model, optimizer, loss_fn, is_train, explorationProb)
#      26         if board_list:
#      27             boards = np.array([make_input(g) for g,m,s in board_list])
# ---> 28             p = model(torch.from_numpy(boards).cuda()).flatten().detach()
#      29             game_len += 1
#      30             best_v = None
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# <ipython-input-2-9c762393a967> in forward(self, x)
#      25     def forward(self, x):
#      26         x = x.float()
# ---> 27         a = self.relu(self.conv_a(x))
#      28         b = self.relu(self.conv_b(x))
#      29         c = self.relu(self.conv_c(x))
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     341
#     342     def forward(self, input):
# --> 343         return self.conv2d_forward(input, self.weight)
#     344
#     345 class Conv3d(_ConvNd):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     338                             _pair(0), self.dilation, self.groups)
#     339         return F.conv2d(input, weight, self.bias, self.stride,
# --> 340                         self.padding, self.dilation, self.groups)
#     341
#     342     def forward(self, input):
#
# RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

# %%
test(model)

# %%
test(best_model)
