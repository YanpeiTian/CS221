# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=512, filter2=4096, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        self.conv_c = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_cc = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)
        self.W_cc = nn.Linear(filter2 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        c = self.relu(self.conv_c(x))
        aa = self.flatten(self.relu(self.conv_aa(a)))
        ab = self.flatten(self.relu(self.conv_ab(a)))
        ba = self.flatten(self.relu(self.conv_ba(b)))
        bb = self.flatten(self.relu(self.conv_bb(b)))
        cc = self.flatten(self.relu(self.conv_cc(c)))
        out = self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) + self.W_cc(cc)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y) / 2
            last_loss = loss.item()
            loss.backward()
            optimizer.step()
            model.eval()
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 5e-4
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)
    
def load_model(model, optimizer, checkpoint_path, model_only = False):
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    if not model_only:
        optimizer.load_state_dict(ckpt_dict['optimizer'])
        epoch = ckpt_dict['epoch']
        running_mean = ckpt_dict['running_mean']
    else:
        epoch = None
        running_mean = None
    return model, optimizer, epoch, running_mean

# %%
num_epochs = 1500
best_model = None

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
    ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean:
            running_mean = sum(ls) / 10
            filename = "model_score_"+str(epoch // 100)+".pth.tar"
            save_model({
                'epoch': epoch,
                'running_mean': running_mean,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            best_model, _, _, _ = load_model(model, optimizer, filename, True)
            model.cuda()
            
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  208 Max score  128 Game score  2108
# Game #  2 Game length  324 Max score  256 Game score  3828
# Game #  3 Game length  360 Max score  256 Game score  4104
# Game #  4 Game length  483 Max score  512 Game score  6676
# Game #  5 Game length  128 Max score  128 Game score  1116
# Game #  6 Game length  376 Max score  256 Game score  4320
# Game #  7 Game length  472 Max score  512 Game score  6272
# Game #  8 Game length  310 Max score  256 Game score  3500
# Game #  9 Game length  774 Max score  1024 Game score  12108
# Game #  10 Game length  378 Max score  256 Game score  4640
# Game #  11 Game length  525 Max score  512 Game score  7216
# Game #  12 Game length  321 Max score  256 Game score  3664
# Game #  13 Game length  529 Max score  512 Game score  6912
# Game #  14 Game length  236 Max score  128 Game score  2412
# Game #  15 Game length  276 Max score  128 Game score  2744
# Game #  16 Game length  261 Max score  256 Game score  2856
# Game #  17 Game length  394 Max score  256 Game score  4356
# Game #  18 Game length  529 Max score  512 Game score  7192
# Game #  19 Game length  174 Max score  128 Game score  1632
# Game #  20 Game length  329 Max score  256 Game score  3660
# Game #  21 Game length  680 Max score  512 Game score  9288
# Game #  22 Game length  233 Max score  256 Game score  2560
# Game #  23 Game length  514 Max score  512 Game score  6940
# Game #  24 Game length  709 Max score  1024 Game score  11064
# Game #  25 Game length  576 Max score  512 Game score  7828
# Game #  26 Game length  380 Max score  256 Game score  4344
# Game #  27 Game length  326 Max score  256 Game score  3644
# Game #  28 Game length  483 Max score  512 Game score  6648
# Game #  29 Game length  512 Max score  512 Game score  7052
# Game #  30 Game length  494 Max score  512 Game score  6524
# Game #  31 Game length  562 Max score  512 Game score  7532
# Game #  32 Game length  375 Max score  256 Game score  4316
# Game #  33 Game length  300 Max score  256 Game score  3436
# Game #  34 Game length  546 Max score  512 Game score  7448
# Game #  35 Game length  631 Max score  512 Game score  8476
# Game #  36 Game length  535 Max score  512 Game score  7320
# Game #  37 Game length  891 Max score  1024 Game score  14316
# Game #  38 Game length  1441 Max score  2048 Game score  26072
# Game #  39 Game length  1363 Max score  2048 Game score  24668
# Game #  40 Game length  696 Max score  512 Game score  9208
# Game #  41 Game length  785 Max score  1024 Game score  12368
# Game #  42 Game length  547 Max score  512 Game score  7452
# Game #  43 Game length  609 Max score  512 Game score  8168
# Game #  44 Game length  567 Max score  512 Game score  7644
# Game #  45 Game length  846 Max score  1024 Game score  13116
# Game #  46 Game length  1018 Max score  1024 Game score  16232
# Game #  47 Game length  469 Max score  512 Game score  6496
# Game #  48 Game length  715 Max score  512 Game score  9788
# Game #  49 Game length  917 Max score  1024 Game score  14732
# Game #  50 Game length  323 Max score  256 Game score  3628
# Game #  51 Game length  895 Max score  1024 Game score  13964
# Game #  52 Game length  565 Max score  512 Game score  7608
# Game #  53 Game length  836 Max score  1024 Game score  13052
# Game #  54 Game length  567 Max score  512 Game score  7644
# Game #  55 Game length  662 Max score  512 Game score  9112
# Game #  56 Game length  538 Max score  512 Game score  7308
# Game #  57 Game length  1300 Max score  1024 Game score  20624
# Game #  58 Game length  848 Max score  1024 Game score  13136
# Game #  59 Game length  970 Max score  1024 Game score  14892
# Game #  60 Game length  1010 Max score  1024 Game score  16152
# Game #  61 Game length  845 Max score  1024 Game score  13120
# Game #  62 Game length  1099 Max score  1024 Game score  17452
# Game #  63 Game length  597 Max score  512 Game score  8044
# Game #  64 Game length  1024 Max score  1024 Game score  16332
# Game #  65 Game length  674 Max score  512 Game score  9196
# Game #  66 Game length  721 Max score  512 Game score  10576
# Game #  67 Game length  1831 Max score  2048 Game score  33116
# Game #  68 Game length  1076 Max score  1024 Game score  16972
# Game #  69 Game length  684 Max score  512 Game score  9456
# Game #  70 Game length  1596 Max score  2048 Game score  28168
# Game #  71 Game length  1513 Max score  2048 Game score  27356
# Game #  72 Game length  1051 Max score  1024 Game score  16620
# Game #  73 Game length  1248 Max score  1024 Game score  20108
# Game #  74 Game length  1068 Max score  1024 Game score  16768
# Game #  75 Game length  660 Max score  512 Game score  8728
# Game #  76 Game length  852 Max score  512 Game score  12152
# Game #  77 Game length  982 Max score  1024 Game score  15484
# Game #  78 Game length  958 Max score  1024 Game score  14792
# Game #  79 Game length  1520 Max score  1024 Game score  25000
# Game #  80 Game length  1061 Max score  1024 Game score  16844
# Game #  81 Game length  542 Max score  512 Game score  7368
# Game #  82 Game length  1686 Max score  2048 Game score  31084
# Game #  83 Game length  755 Max score  512 Game score  11036
# Game #  84 Game length  450 Max score  512 Game score  6124
# Game #  85 Game length  1009 Max score  1024 Game score  15304
# Game #  86 Game length  1832 Max score  2048 Game score  33120
# Game #  87 Game length  1196 Max score  1024 Game score  18688
# Game #  88 Game length  1084 Max score  1024 Game score  16904
# Game #  89 Game length  1093 Max score  1024 Game score  17160
# Game #  90 Game length  1803 Max score  2048 Game score  32812
# Game #  91 Game length  1838 Max score  2048 Game score  33164
# Game #  92 Game length  1261 Max score  1024 Game score  19976
# Game #  93 Game length  786 Max score  1024 Game score  12364
# Game #  94 Game length  1118 Max score  1024 Game score  17420
# Game #  95 Game length  964 Max score  1024 Game score  15340
# Game #  96 Game length  1008 Max score  1024 Game score  16020
# Game #  97 Game length  2329 Max score  2048 Game score  42168
# Game #  98 Game length  1116 Max score  1024 Game score  17352
# Game #  99 Game length  902 Max score  1024 Game score  13916
# Game #  100 Game length  1628 Max score  2048 Game score  28616
# Game #  101 Game length  2183 Max score  2048 Game score  39048
# Game #  102 Game length  721 Max score  1024 Game score  11596
# Game #  103 Game length  1375 Max score  1024 Game score  21508
# Game #  104 Game length  2223 Max score  2048 Game score  40592
# Game #  105 Game length  603 Max score  512 Game score  8112
# Game #  106 Game length  1020 Max score  1024 Game score  16120
# Game #  107 Game length  954 Max score  1024 Game score  14760
# Game #  108 Game length  1300 Max score  2048 Game score  23648
# Game #  109 Game length  1822 Max score  2048 Game score  32972
# Game #  110 Game length  936 Max score  1024 Game score  14856
# Game #  111 Game length  931 Max score  1024 Game score  14324
# Game #  112 Game length  1566 Max score  2048 Game score  27852
# Game #  113 Game length  1059 Max score  1024 Game score  16652
# Game #  114 Game length  1226 Max score  1024 Game score  18948
# Game #  115 Game length  1042 Max score  1024 Game score  16512
# Game #  116 Game length  2001 Max score  2048 Game score  36208
# Game #  117 Game length  923 Max score  1024 Game score  14260
# Game #  118 Game length  1698 Max score  2048 Game score  29756
# Game #  119 Game length  1125 Max score  1024 Game score  17496
# Game #  120 Game length  1468 Max score  2048 Game score  26372
# Game #  121 Game length  1236 Max score  1024 Game score  19852
# Game #  122 Game length  2016 Max score  2048 Game score  36368
# Game #  123 Game length  1616 Max score  2048 Game score  28408
# Game #  124 Game length  934 Max score  1024 Game score  14928
# Game #  125 Game length  1242 Max score  1024 Game score  19884
# Game #  126 Game length  1720 Max score  2048 Game score  30812
# Game #  127 Game length  1139 Max score  1024 Game score  19356
# Game #  128 Game length  1441 Max score  1024 Game score  24040
# Game #  129 Game length  989 Max score  1024 Game score  15860
# Game #  130 Game length  1776 Max score  2048 Game score  32344
# Game #  131 Game length  593 Max score  512 Game score  7688
# Game #  132 Game length  952 Max score  1024 Game score  14568
# Game #  133 Game length  1291 Max score  1024 Game score  20540
# Game #  134 Game length  1843 Max score  2048 Game score  32212
# Game #  135 Game length  1290 Max score  1024 Game score  20524
# Game #  136 Game length  1310 Max score  1024 Game score  20692
# Game #  137 Game length  469 Max score  512 Game score  6332
# Game #  138 Game length  1306 Max score  1024 Game score  20716
# Game #  139 Game length  986 Max score  1024 Game score  15784
# Game #  140 Game length  1693 Max score  2048 Game score  31144
# Game #  141 Game length  640 Max score  512 Game score  8824
# Game #  142 Game length  1445 Max score  2048 Game score  26104
# Game #  143 Game length  1818 Max score  2048 Game score  31932
# Game #  144 Game length  966 Max score  1024 Game score  15376
# Game #  145 Game length  1180 Max score  1024 Game score  18376
# Game #  146 Game length  1817 Max score  2048 Game score  31928
# Game #  147 Game length  2689 Max score  4096 Game score  53580
# Game #  148 Game length  1764 Max score  2048 Game score  30552
# Game #  149 Game length  1920 Max score  2048 Game score  34512
# Game #  150 Game length  1098 Max score  1024 Game score  17196
# Game #  151 Game length  1255 Max score  1024 Game score  21164
# Game #  152 Game length  1074 Max score  1024 Game score  16812
# Game #  153 Game length  2926 Max score  4096 Game score  59392
# Game #  154 Game length  1359 Max score  1024 Game score  21612
# Game #  155 Game length  1140 Max score  1024 Game score  17624
# Game #  156 Game length  1612 Max score  2048 Game score  28480
# Game #  157 Game length  1173 Max score  1024 Game score  18832
# Game #  158 Game length  1145 Max score  1024 Game score  17664
# Game #  159 Game length  1152 Max score  1024 Game score  17796
# Game #  160 Game length  658 Max score  512 Game score  9080
# Game #  161 Game length  1520 Max score  2048 Game score  27224
# Game #  162 Game length  796 Max score  1024 Game score  12476
# Game #  163 Game length  1422 Max score  1024 Game score  23868
# Game #  164 Game length  1130 Max score  1024 Game score  17896
# Game #  165 Game length  1550 Max score  2048 Game score  27660
# Game #  166 Game length  1196 Max score  1024 Game score  18568
# Game #  167 Game length  351 Max score  256 Game score  4044
# Game #  168 Game length  557 Max score  512 Game score  7496
# Game #  169 Game length  1831 Max score  2048 Game score  33116
# Game #  170 Game length  1464 Max score  2048 Game score  25832
# Game #  171 Game length  2073 Max score  2048 Game score  37036
# Game #  172 Game length  1311 Max score  2048 Game score  23756
# Game #  173 Game length  2069 Max score  2048 Game score  37016
# Game #  174 Game length  1991 Max score  2048 Game score  35868
# Game #  175 Game length  1589 Max score  2048 Game score  28972
# Game #  176 Game length  2084 Max score  2048 Game score  37176
# Game #  177 Game length  2504 Max score  4096 Game score  50720
# Game #  178 Game length  1057 Max score  1024 Game score  16616
# Game #  179 Game length  1159 Max score  1024 Game score  18036
# Game #  180 Game length  1503 Max score  2048 Game score  26836
# Game #  181 Game length  1674 Max score  2048 Game score  29484
# Game #  182 Game length  3143 Max score  4096 Game score  62244
# Game #  183 Game length  894 Max score  1024 Game score  13960
# Game #  184 Game length  1888 Max score  2048 Game score  34008
# Game #  185 Game length  810 Max score  1024 Game score  12572
# Game #  186 Game length  602 Max score  512 Game score  8168
# Game #  187 Game length  1137 Max score  1024 Game score  17820
# Game #  188 Game length  1259 Max score  1024 Game score  20204
# Game #  189 Game length  1117 Max score  1024 Game score  17384
# Game #  190 Game length  1048 Max score  1024 Game score  16544
# Game #  191 Game length  3244 Max score  4096 Game score  64160
# Game #  192 Game length  2112 Max score  2048 Game score  36488
# Game #  193 Game length  2375 Max score  2048 Game score  43036
# Game #  194 Game length  1656 Max score  2048 Game score  28920
# Game #  195 Game length  1080 Max score  1024 Game score  16872
# Game #  196 Game length  638 Max score  512 Game score  8476
# Game #  197 Game length  1068 Max score  1024 Game score  16768
# Game #  198 Game length  312 Max score  256 Game score  3524
# Game #  199 Game length  901 Max score  1024 Game score  14008
# Game #  200 Game length  824 Max score  1024 Game score  13116
# Game #  201 Game length  1650 Max score  2048 Game score  28876
# Game #  202 Game length  1491 Max score  2048 Game score  26972
# Game #  203 Game length  2472 Max score  4096 Game score  50696
# Game #  204 Game length  1288 Max score  2048 Game score  23576
# Game #  205 Game length  1920 Max score  2048 Game score  35020
# Game #  206 Game length  1816 Max score  2048 Game score  32988
# Game #  207 Game length  520 Max score  512 Game score  6760
# Game #  208 Game length  2369 Max score  2048 Game score  41708
# Game #  209 Game length  918 Max score  1024 Game score  13860
# Game #  210 Game length  949 Max score  1024 Game score  14552
# Game #  211 Game length  1200 Max score  1024 Game score  18712
# Game #  212 Game length  966 Max score  1024 Game score  14452
# Game #  213 Game length  1872 Max score  2048 Game score  32616
# Game #  214 Game length  1596 Max score  2048 Game score  28224
# Game #  215 Game length  2906 Max score  4096 Game score  59048
# Game #  216 Game length  2903 Max score  4096 Game score  58524
# Game #  217 Game length  2029 Max score  2048 Game score  36488
# Game #  218 Game length  1136 Max score  1024 Game score  19340
# Game #  219 Game length  1871 Max score  2048 Game score  33868
# Game #  220 Game length  1083 Max score  1024 Game score  17020
# Game #  221 Game length  2354 Max score  2048 Game score  41428
# Game #  222 Game length  1596 Max score  2048 Game score  28168
# Game #  223 Game length  3038 Max score  4096 Game score  61056
# Game #  224 Game length  1167 Max score  1024 Game score  18260
# Game #  225 Game length  2126 Max score  2048 Game score  37964
# Game #  226 Game length  1304 Max score  1024 Game score  20648
# Game #  227 Game length  1560 Max score  1024 Game score  25768
# Game #  228 Game length  1667 Max score  2048 Game score  29436
# Game #  229 Game length  1174 Max score  1024 Game score  18332
# Game #  230 Game length  1147 Max score  1024 Game score  17672
# Game #  231 Game length  1105 Max score  1024 Game score  17256
# Game #  232 Game length  802 Max score  1024 Game score  12508
# Game #  233 Game length  1937 Max score  2048 Game score  35160
# Game #  234 Game length  3016 Max score  4096 Game score  60400
# Game #  235 Game length  1266 Max score  1024 Game score  20252
# Game #  236 Game length  851 Max score  1024 Game score  13180
# Game #  237 Game length  742 Max score  512 Game score  10076
# Game #  238 Game length  1147 Max score  1024 Game score  18596
# Game #  239 Game length  833 Max score  1024 Game score  12896
# Game #  240 Game length  1117 Max score  1024 Game score  17356
# Game #  241 Game length  1150 Max score  1024 Game score  17940
# Game #  242 Game length  1300 Max score  1024 Game score  20624
# Game #  243 Game length  2072 Max score  2048 Game score  37032
# Game #  244 Game length  2296 Max score  2048 Game score  40696
# Game #  245 Game length  2142 Max score  2048 Game score  38148
# Game #  246 Game length  1268 Max score  1024 Game score  19928
# Game #  247 Game length  613 Max score  512 Game score  8272
# Game #  248 Game length  2196 Max score  2048 Game score  39312
# Game #  249 Game length  1904 Max score  2048 Game score  32968
# Game #  250 Game length  1060 Max score  1024 Game score  16632
# Game #  251 Game length  1374 Max score  2048 Game score  25280
# Game #  252 Game length  1541 Max score  1024 Game score  25620
# Game #  253 Game length  1054 Max score  1024 Game score  16588
# Game #  254 Game length  2366 Max score  4096 Game score  48652
# Game #  255 Game length  1117 Max score  1024 Game score  17356
# Game #  256 Game length  987 Max score  1024 Game score  15772
# Game #  257 Game length  1665 Max score  2048 Game score  29276
# Game #  258 Game length  2171 Max score  2048 Game score  38588
# Game #  259 Game length  744 Max score  1024 Game score  11776
# Game #  260 Game length  2006 Max score  2048 Game score  36220
# Game #  261 Game length  1308 Max score  1024 Game score  20680
# Game #  262 Game length  1977 Max score  2048 Game score  35996
# Game #  263 Game length  1945 Max score  2048 Game score  34744
# Game #  264 Game length  1055 Max score  1024 Game score  16592
# Game #  265 Game length  2413 Max score  2048 Game score  43528
# Game #  266 Game length  2145 Max score  2048 Game score  37948
# Game #  267 Game length  1953 Max score  2048 Game score  35724
# Game #  268 Game length  1629 Max score  2048 Game score  28632
# Game #  269 Game length  2030 Max score  2048 Game score  36616
# Game #  270 Game length  2174 Max score  2048 Game score  39052
# Game #  271 Game length  1163 Max score  1024 Game score  18140
# Game #  272 Game length  584 Max score  512 Game score  8156
# Game #  273 Game length  1977 Max score  2048 Game score  35068
# Game #  274 Game length  2845 Max score  4096 Game score  57544
# Game #  275 Game length  1956 Max score  2048 Game score  35404
# Game #  276 Game length  706 Max score  1024 Game score  11036
# Game #  277 Game length  1059 Max score  1024 Game score  16684
# Game #  278 Game length  851 Max score  1024 Game score  13164
# Game #  279 Game length  525 Max score  512 Game score  7216
# Game #  280 Game length  1695 Max score  2048 Game score  31180
# Game #  281 Game length  2493 Max score  4096 Game score  50952
# Game #  282 Game length  1436 Max score  2048 Game score  26032
# Game #  283 Game length  1825 Max score  2048 Game score  32988
# Game #  284 Game length  2066 Max score  2048 Game score  36972
# Game #  285 Game length  1588 Max score  2048 Game score  28236
# Game #  286 Game length  2792 Max score  4096 Game score  56924
# Game #  287 Game length  1884 Max score  2048 Game score  33736
# Game #  288 Game length  955 Max score  1024 Game score  15044
# Game #  289 Game length  694 Max score  512 Game score  9436
# Game #  290 Game length  1956 Max score  2048 Game score  35528
# Game #  291 Game length  1140 Max score  1024 Game score  17624
# Game #  292 Game length  1636 Max score  2048 Game score  28696
# Game #  293 Game length  1748 Max score  2048 Game score  32108
# Game #  294 Game length  1308 Max score  1024 Game score  20708
# Game #  295 Game length  2079 Max score  2048 Game score  37136
# Game #  296 Game length  969 Max score  1024 Game score  15368
# Game #  297 Game length  1806 Max score  2048 Game score  32780
# Game #  298 Game length  1568 Max score  1024 Game score  26252
# Game #  299 Game length  1390 Max score  2048 Game score  24716
# Game #  300 Game length  1117 Max score  1024 Game score  17608
# Game #  301 Game length  970 Max score  1024 Game score  14904
# Game #  302 Game length  777 Max score  512 Game score  10428
# Game #  303 Game length  1277 Max score  1024 Game score  20236
# Game #  304 Game length  1165 Max score  1024 Game score  18248
# Game #  305 Game length  2060 Max score  2048 Game score  36932
# Game #  306 Game length  633 Max score  512 Game score  8428
# Game #  307 Game length  1537 Max score  1024 Game score  25584
# Game #  308 Game length  1682 Max score  2048 Game score  31064
# Game #  309 Game length  1808 Max score  2048 Game score  32848
# Game #  310 Game length  2423 Max score  2048 Game score  46044
# Game #  311 Game length  1206 Max score  1024 Game score  18660
# Game #  312 Game length  2687 Max score  4096 Game score  54288
# Game #  313 Game length  1778 Max score  2048 Game score  32412
# Game #  314 Game length  1535 Max score  1024 Game score  25548
# Game #  315 Game length  581 Max score  512 Game score  7768
# Game #  316 Game length  1843 Max score  2048 Game score  33204
# Game #  317 Game length  1134 Max score  1024 Game score  17916
# Game #  318 Game length  772 Max score  1024 Game score  12192
# Game #  319 Game length  1678 Max score  2048 Game score  31032
# Game #  320 Game length  1030 Max score  1024 Game score  16364
# Game #  321 Game length  1831 Max score  2048 Game score  33060
# Game #  322 Game length  1826 Max score  2048 Game score  33032
# Game #  323 Game length  1934 Max score  2048 Game score  35140
# Game #  324 Game length  1334 Max score  2048 Game score  23996
# Game #  325 Game length  1800 Max score  2048 Game score  32796
# Game #  326 Game length  1132 Max score  1024 Game score  17916
# Game #  327 Game length  1058 Max score  1024 Game score  16692
# Game #  328 Game length  1514 Max score  2048 Game score  27360
# Game #  329 Game length  2038 Max score  2048 Game score  36572
# Game #  330 Game length  1256 Max score  1024 Game score  21084
# Game #  331 Game length  1643 Max score  2048 Game score  28744
# Game #  332 Game length  2120 Max score  2048 Game score  37680
# Game #  333 Game length  2989 Max score  4096 Game score  60400
# Game #  334 Game length  2064 Max score  2048 Game score  36952
# Game #  335 Game length  1936 Max score  2048 Game score  35156
# Game #  336 Game length  3127 Max score  4096 Game score  62108
# Game #  337 Game length  1552 Max score  2048 Game score  27728
# Game #  338 Game length  2060 Max score  2048 Game score  36956
# Game #  339 Game length  1280 Max score  2048 Game score  23316
# Game #  340 Game length  1047 Max score  1024 Game score  16540
# Game #  341 Game length  1713 Max score  2048 Game score  31384
# Game #  342 Game length  2040 Max score  2048 Game score  36764
# Game #  343 Game length  2041 Max score  2048 Game score  36712
# Game #  344 Game length  2142 Max score  2048 Game score  37932
# Game #  345 Game length  1528 Max score  1024 Game score  25500
# Game #  346 Game length  803 Max score  1024 Game score  12516
# Game #  347 Game length  3090 Max score  4096 Game score  61548
# Game #  348 Game length  2044 Max score  2048 Game score  36736
# Game #  349 Game length  2620 Max score  2048 Game score  48776
# Game #  350 Game length  2641 Max score  4096 Game score  54860
# Game #  351 Game length  1925 Max score  2048 Game score  35072
# Game #  352 Game length  2060 Max score  2048 Game score  36932
# Game #  353 Game length  1791 Max score  2048 Game score  32652
# Game #  354 Game length  1859 Max score  2048 Game score  33336
# Game #  355 Game length  1006 Max score  1024 Game score  16008
# Game #  356 Game length  983 Max score  1024 Game score  15740
# Game #  357 Game length  1108 Max score  1024 Game score  17272
# Game #  358 Game length  1145 Max score  1024 Game score  17660
# Game #  359 Game length  2917 Max score  4096 Game score  59308
# Game #  360 Game length  1832 Max score  2048 Game score  33064
# Game #  361 Game length  1780 Max score  2048 Game score  31528
# Game #  362 Game length  1704 Max score  2048 Game score  31324
# Game #  363 Game length  938 Max score  1024 Game score  14924
# Game #  364 Game length  1532 Max score  2048 Game score  27508
# Game #  365 Game length  1560 Max score  1024 Game score  25768
# Game #  366 Game length  2091 Max score  2048 Game score  37360
# Game #  367 Game length  1838 Max score  2048 Game score  33164
# Game #  368 Game length  1569 Max score  2048 Game score  27880
# Game #  369 Game length  2084 Max score  2048 Game score  37176
# Game #  370 Game length  1626 Max score  2048 Game score  30368
# Game #  371 Game length  1659 Max score  2048 Game score  30700
# Game #  372 Game length  1058 Max score  1024 Game score  16668
# Game #  373 Game length  1590 Max score  2048 Game score  28248
# Game #  374 Game length  2028 Max score  2048 Game score  36232
# Game #  375 Game length  2028 Max score  2048 Game score  36480
# Game #  376 Game length  1757 Max score  2048 Game score  32364
# Game #  377 Game length  2355 Max score  4096 Game score  48500
# Game #  378 Game length  1887 Max score  2048 Game score  34508
# Game #  379 Game length  1088 Max score  1024 Game score  16936
# Game #  380 Game length  2832 Max score  4096 Game score  57428
# Game #  381 Game length  1507 Max score  2048 Game score  27116
# Game #  382 Game length  511 Max score  512 Game score  6924
# Game #  383 Game length  1713 Max score  2048 Game score  30376
# Game #  384 Game length  1889 Max score  2048 Game score  33800
# Game #  385 Game length  1440 Max score  2048 Game score  26068
# Game #  386 Game length  1307 Max score  2048 Game score  23724
# Game #  387 Game length  2060 Max score  2048 Game score  36928
# Game #  388 Game length  1142 Max score  1024 Game score  17636
# Game #  389 Game length  360 Max score  256 Game score  4104
# Game #  390 Game length  2664 Max score  4096 Game score  55044
# Game #  391 Game length  2076 Max score  2048 Game score  37148
# Game #  392 Game length  1538 Max score  2048 Game score  27548
# Game #  393 Game length  992 Max score  1024 Game score  15884
# Game #  394 Game length  3008 Max score  4096 Game score  60200
# Game #  395 Game length  2026 Max score  2048 Game score  36580
# Game #  396 Game length  1810 Max score  2048 Game score  32860
# Game #  397 Game length  1946 Max score  2048 Game score  35244
# Game #  398 Game length  1025 Max score  1024 Game score  16348
# Game #  399 Game length  2024 Max score  2048 Game score  36572
# Game #  400 Game length  1540 Max score  1024 Game score  25612
# Game #  401 Game length  1296 Max score  1024 Game score  20568
# Game #  402 Game length  2920 Max score  4096 Game score  59228
# Game #  403 Game length  1296 Max score  2048 Game score  23628
# Game #  404 Game length  2157 Max score  2048 Game score  38156
# Game #  405 Game length  488 Max score  256 Game score  5864
# Game #  406 Game length  685 Max score  512 Game score  9352
# Game #  407 Game length  1265 Max score  1024 Game score  20124
# Game #  408 Game length  1979 Max score  2048 Game score  35588
# Game #  409 Game length  2930 Max score  4096 Game score  59416
# Game #  410 Game length  2092 Max score  2048 Game score  37256
# Game #  411 Game length  2056 Max score  2048 Game score  36896
# Game #  412 Game length  1148 Max score  1024 Game score  18096
# Game #  413 Game length  2031 Max score  2048 Game score  36620
# Game #  414 Game length  1008 Max score  1024 Game score  16044
# Game #  415 Game length  2921 Max score  4096 Game score  59232
# Game #  416 Game length  1652 Max score  2048 Game score  28888
# Game #  417 Game length  1257 Max score  1024 Game score  20204
# Game #  418 Game length  2014 Max score  2048 Game score  36108
# Game #  419 Game length  1390 Max score  2048 Game score  24716
# Game #  420 Game length  1177 Max score  1024 Game score  18360
# Game #  421 Game length  1848 Max score  2048 Game score  33256
# Game #  422 Game length  2047 Max score  2048 Game score  36812
# Game #  423 Game length  1807 Max score  2048 Game score  32844
# Game #  424 Game length  2059 Max score  2048 Game score  36924
# Game #  425 Game length  1576 Max score  2048 Game score  28124
# Game #  426 Game length  1552 Max score  2048 Game score  27672
# Game #  427 Game length  2074 Max score  2048 Game score  37052
# Game #  428 Game length  2061 Max score  2048 Game score  36936
# Game #  429 Game length  1597 Max score  2048 Game score  28172
# Game #  430 Game length  1077 Max score  1024 Game score  16828
# Game #  431 Game length  1891 Max score  2048 Game score  33868
# Game #  432 Game length  2018 Max score  2048 Game score  36332
# Game #  433 Game length  1292 Max score  2048 Game score  23596
# Game #  434 Game length  1680 Max score  2048 Game score  29564
# Game #  435 Game length  2244 Max score  2048 Game score  39956
# Game #  436 Game length  2055 Max score  2048 Game score  36892
# Game #  437 Game length  1965 Max score  2048 Game score  35464
# Game #  438 Game length  1565 Max score  2048 Game score  27848
# Game #  439 Game length  2281 Max score  2048 Game score  40556
# Game #  440 Game length  1038 Max score  1024 Game score  16456
# Game #  441 Game length  2061 Max score  2048 Game score  36936
# Game #  442 Game length  1063 Max score  1024 Game score  16732
# Game #  443 Game length  957 Max score  1024 Game score  15112
# Game #  444 Game length  2068 Max score  2048 Game score  36984
# Game #  445 Game length  1500 Max score  2048 Game score  27056
# Game #  446 Game length  1369 Max score  2048 Game score  25244
# Game #  447 Game length  1905 Max score  2048 Game score  34832
# Game #  448 Game length  1770 Max score  2048 Game score  32312
# Game #  449 Game length  2697 Max score  4096 Game score  54056
# Game #  450 Game length  1197 Max score  1024 Game score  18600
# Game #  451 Game length  2089 Max score  2048 Game score  37228
# Game #  452 Game length  1107 Max score  1024 Game score  17144
# Game #  453 Game length  3823 Max score  4096 Game score  77580
# Game #  454 Game length  1028 Max score  1024 Game score  16352
# Game #  455 Game length  2055 Max score  2048 Game score  36892
# Game #  456 Game length  1961 Max score  2048 Game score  35804
# Game #  457 Game length  1691 Max score  2048 Game score  31144
# Game #  458 Game length  2396 Max score  4096 Game score  48968
# Game #  459 Game length  2590 Max score  4096 Game score  52428
# Game #  460 Game length  3137 Max score  4096 Game score  62088
# Game #  461 Game length  1236 Max score  1024 Game score  19576
# Game #  462 Game length  1116 Max score  1024 Game score  17352
# Game #  463 Game length  1607 Max score  2048 Game score  28264
# Game #  464 Game length  1811 Max score  2048 Game score  32952
# Game #  465 Game length  1574 Max score  2048 Game score  28112
# Game #  466 Game length  1975 Max score  2048 Game score  35652
# Game #  467 Game length  1949 Max score  2048 Game score  35272
# Game #  468 Game length  805 Max score  1024 Game score  12536
# Game #  469 Game length  1806 Max score  2048 Game score  32840
# Game #  470 Game length  1061 Max score  1024 Game score  16664
# Game #  471 Game length  2264 Max score  2048 Game score  41140
# Game #  472 Game length  1530 Max score  2048 Game score  27480
# Game #  473 Game length  2893 Max score  4096 Game score  58940
# Game #  474 Game length  1630 Max score  2048 Game score  28684
# Game #  475 Game length  1624 Max score  2048 Game score  28568
# Game #  476 Game length  1745 Max score  2048 Game score  30824
# Game #  477 Game length  1552 Max score  2048 Game score  27732
# Game #  478 Game length  1250 Max score  2048 Game score  23000
# Game #  479 Game length  2034 Max score  2048 Game score  36524
# Game #  480 Game length  2985 Max score  4096 Game score  60140
# Game #  481 Game length  2233 Max score  4096 Game score  46792
# Game #  482 Game length  2108 Max score  2048 Game score  37448
# Game #  483 Game length  1915 Max score  2048 Game score  34056
# Game #  484 Game length  1067 Max score  1024 Game score  16764
# Game #  485 Game length  1635 Max score  2048 Game score  29120
# Game #  486 Game length  1895 Max score  2048 Game score  34564
# Game #  487 Game length  2839 Max score  4096 Game score  57500
# Game #  488 Game length  1450 Max score  2048 Game score  26188
# Game #  489 Game length  1762 Max score  2048 Game score  32232
# Game #  490 Game length  2018 Max score  2048 Game score  36348
# Game #  491 Game length  1949 Max score  2048 Game score  35272
# Game #  492 Game length  3266 Max score  4096 Game score  67760
# Game #  493 Game length  2096 Max score  2048 Game score  37288
# Game #  494 Game length  1689 Max score  2048 Game score  31136
# Game #  495 Game length  1779 Max score  2048 Game score  32540
# Game #  496 Game length  2573 Max score  4096 Game score  52168
# Game #  497 Game length  2335 Max score  2048 Game score  44328
# Game #  498 Game length  1485 Max score  2048 Game score  26928
# Game #  499 Game length  1060 Max score  1024 Game score  16632
# Game #  500 Game length  1932 Max score  2048 Game score  35120
# Game #  501 Game length  1538 Max score  1024 Game score  25564
# Game #  502 Game length  1927 Max score  2048 Game score  35096
# Game #  503 Game length  3089 Max score  4096 Game score  61544
# Game #  504 Game length  2092 Max score  2048 Game score  37256
# Game #  505 Game length  2021 Max score  2048 Game score  36184
# Game #  506 Game length  2115 Max score  2048 Game score  38308
# Game #  507 Game length  1327 Max score  1024 Game score  21908
# Game #  508 Game length  1866 Max score  2048 Game score  34336
# Game #  509 Game length  3131 Max score  4096 Game score  61960
# Game #  510 Game length  1736 Max score  2048 Game score  31996
# Game #  511 Game length  996 Max score  1024 Game score  16028
# Game #  512 Game length  2037 Max score  2048 Game score  36328
# Game #  513 Game length  1668 Max score  2048 Game score  29080
# Game #  514 Game length  3124 Max score  4096 Game score  61912
# Game #  515 Game length  1401 Max score  1024 Game score  23032
# Game #  516 Game length  1359 Max score  1024 Game score  21372
# Game #  517 Game length  2104 Max score  2048 Game score  37368
# Game #  518 Game length  807 Max score  1024 Game score  12548
# Game #  519 Game length  1529 Max score  2048 Game score  27368
# Game #  520 Game length  2047 Max score  2048 Game score  36812
# Game #  521 Game length  2193 Max score  2048 Game score  38792
# Game #  522 Game length  2919 Max score  4096 Game score  59332
# Game #  523 Game length  1430 Max score  2048 Game score  25976
# Game #  524 Game length  1046 Max score  1024 Game score  16508
# Game #  525 Game length  1572 Max score  2048 Game score  27896
# Game #  526 Game length  2977 Max score  4096 Game score  59928
# Game #  527 Game length  2031 Max score  2048 Game score  36620
# Game #  528 Game length  2390 Max score  2048 Game score  45016
# Game #  529 Game length  3122 Max score  4096 Game score  62072
# Game #  530 Game length  1719 Max score  2048 Game score  31800
# Game #  531 Game length  1240 Max score  2048 Game score  22908
# Game #  532 Game length  1558 Max score  2048 Game score  27772
# Game #  533 Game length  1811 Max score  2048 Game score  32868
# Game #  534 Game length  2008 Max score  2048 Game score  36232
# Game #  535 Game length  2607 Max score  4096 Game score  52652
# Game #  536 Game length  1539 Max score  2048 Game score  27616
# Game #  537 Game length  1426 Max score  2048 Game score  25940
# Game #  538 Game length  2083 Max score  2048 Game score  37140
# Game #  539 Game length  1756 Max score  2048 Game score  30920
# Game #  540 Game length  2107 Max score  2048 Game score  37384
# Game #  541 Game length  1596 Max score  2048 Game score  28168
# Game #  542 Game length  1700 Max score  2048 Game score  31208
# Game #  543 Game length  1905 Max score  2048 Game score  34736
# Game #  544 Game length  2011 Max score  2048 Game score  36284
# Game #  545 Game length  2062 Max score  2048 Game score  36940
# Game #  546 Game length  3334 Max score  4096 Game score  65564
# Game #  547 Game length  2631 Max score  4096 Game score  53020
# Game #  548 Game length  1793 Max score  2048 Game score  32720
# Game #  549 Game length  2181 Max score  2048 Game score  38680
# Game #  550 Game length  2698 Max score  4096 Game score  54060
# Game #  551 Game length  2016 Max score  2048 Game score  36312
# Game #  552 Game length  1632 Max score  2048 Game score  28648
# Game #  553 Game length  1044 Max score  1024 Game score  15896
# Game #  554 Game length  1945 Max score  2048 Game score  35240
# Game #  555 Game length  1580 Max score  1024 Game score  25992
# Game #  556 Game length  999 Max score  1024 Game score  15900
# Game #  557 Game length  2082 Max score  2048 Game score  37156
# Game #  558 Game length  2179 Max score  2048 Game score  38668
# Game #  559 Game length  1770 Max score  2048 Game score  32360
# Game #  560 Game length  2104 Max score  2048 Game score  37536
# Game #  561 Game length  1962 Max score  2048 Game score  35808
# Game #  562 Game length  879 Max score  1024 Game score  14156
# Game #  563 Game length  1059 Max score  1024 Game score  16652
# Game #  564 Game length  3105 Max score  4096 Game score  61736
# Game #  565 Game length  1573 Max score  2048 Game score  27984
# Game #  566 Game length  1979 Max score  2048 Game score  36008
# Game #  567 Game length  1101 Max score  1024 Game score  17224
# Game #  568 Game length  2036 Max score  2048 Game score  36660
# Game #  569 Game length  830 Max score  512 Game score  11796
# Game #  570 Game length  2152 Max score  2048 Game score  41732
# Game #  571 Game length  1950 Max score  2048 Game score  35276
# Game #  572 Game length  2074 Max score  2048 Game score  37052
# Game #  573 Game length  2139 Max score  2048 Game score  38588
# Game #  574 Game length  3151 Max score  4096 Game score  62332
# Game #  575 Game length  2005 Max score  2048 Game score  36216
# Game #  576 Game length  3120 Max score  4096 Game score  61976
# Game #  577 Game length  3391 Max score  4096 Game score  68028
# Game #  578 Game length  3053 Max score  4096 Game score  61184
# Game #  579 Game length  2486 Max score  4096 Game score  50892
# Game #  580 Game length  3216 Max score  4096 Game score  66892
# Game #  581 Game length  3310 Max score  4096 Game score  68352
# Game #  582 Game length  1611 Max score  2048 Game score  28296
# Game #  583 Game length  2098 Max score  2048 Game score  37324
# Game #  584 Game length  2880 Max score  4096 Game score  58008
# Game #  585 Game length  2107 Max score  2048 Game score  37384
# Game #  586 Game length  1071 Max score  1024 Game score  16812
# Game #  587 Game length  2055 Max score  2048 Game score  36892
# Game #  588 Game length  2048 Max score  2048 Game score  36816
# Game #  589 Game length  1786 Max score  2048 Game score  32504
# Game #  590 Game length  1662 Max score  2048 Game score  29204
# Game #  591 Game length  1474 Max score  1024 Game score  24732
# Game #  592 Game length  1652 Max score  2048 Game score  29224
# Game #  593 Game length  1956 Max score  2048 Game score  35740
# Game #  594 Game length  1460 Max score  2048 Game score  25812
# Game #  595 Game length  1584 Max score  2048 Game score  28056
# Game #  596 Game length  2828 Max score  4096 Game score  57404
# Game #  597 Game length  2454 Max score  4096 Game score  50492
# Game #  598 Game length  1928 Max score  2048 Game score  35100
# Game #  599 Game length  1804 Max score  2048 Game score  32828
# Game #  600 Game length  2194 Max score  2048 Game score  38796
# Game #  601 Game length  2071 Max score  2048 Game score  37208
# Game #  602 Game length  3064 Max score  4096 Game score  60920
# Game #  603 Game length  1054 Max score  1024 Game score  16588
# Game #  604 Game length  1563 Max score  2048 Game score  27836
# Game #  605 Game length  2108 Max score  2048 Game score  37512
# Game #  606 Game length  1757 Max score  2048 Game score  32184
# Game #  607 Game length  1801 Max score  2048 Game score  32632
# Game #  608 Game length  1928 Max score  2048 Game score  35100
# Game #  609 Game length  2119 Max score  2048 Game score  37640
# Game #  610 Game length  1106 Max score  1024 Game score  17252
# Game #  611 Game length  1748 Max score  2048 Game score  32108
# Game #  612 Game length  3171 Max score  4096 Game score  66448
# Game #  613 Game length  1071 Max score  1024 Game score  16756
# Game #  614 Game length  1835 Max score  2048 Game score  33136
# Game #  615 Game length  1958 Max score  2048 Game score  34884
# Game #  616 Game length  1134 Max score  1024 Game score  17580
# Game #  617 Game length  705 Max score  512 Game score  9724
# Game #  618 Game length  2038 Max score  2048 Game score  36548
# Game #  619 Game length  948 Max score  1024 Game score  15016
# Game #  620 Game length  1819 Max score  2048 Game score  32984
# Game #  621 Game length  1440 Max score  2048 Game score  25560
# Game #  622 Game length  2278 Max score  4096 Game score  47680
# Game #  623 Game length  1690 Max score  2048 Game score  29628
# Game #  624 Game length  1394 Max score  1024 Game score  23068
# Game #  625 Game length  1756 Max score  2048 Game score  32176
# Game #  626 Game length  1594 Max score  2048 Game score  28156
# Game #  627 Game length  2013 Max score  2048 Game score  36296
# Game #  628 Game length  1163 Max score  1024 Game score  18236
# Game #  629 Game length  2075 Max score  2048 Game score  37060
# Game #  630 Game length  2852 Max score  4096 Game score  57676
# Game #  631 Game length  2071 Max score  2048 Game score  37028
# Game #  632 Game length  2107 Max score  2048 Game score  37384
# Game #  633 Game length  1431 Max score  2048 Game score  25980
# Game #  634 Game length  1923 Max score  2048 Game score  35036
# Game #  635 Game length  2804 Max score  4096 Game score  55384
# Game #  636 Game length  1579 Max score  2048 Game score  28028
# Game #  637 Game length  1931 Max score  2048 Game score  35116
# Game #  638 Game length  2677 Max score  4096 Game score  55216
# Game #  639 Game length  1598 Max score  2048 Game score  28180
# Game #  640 Game length  1988 Max score  2048 Game score  35672
# Game #  641 Game length  1863 Max score  2048 Game score  33564
# Game #  642 Game length  1939 Max score  2048 Game score  35168
# Game #  643 Game length  1818 Max score  2048 Game score  32940
# Game #  644 Game length  1050 Max score  1024 Game score  16568
# Game #  645 Game length  2060 Max score  2048 Game score  36928
# Game #  646 Game length  1821 Max score  2048 Game score  32968
# Game #  647 Game length  1806 Max score  2048 Game score  32840
# Game #  648 Game length  1496 Max score  1024 Game score  24968
# Game #  649 Game length  1684 Max score  2048 Game score  31084
# Game #  650 Game length  900 Max score  1024 Game score  14556
# Game #  651 Game length  1993 Max score  2048 Game score  35768
# Game #  652 Game length  2773 Max score  4096 Game score  56680
# Game #  653 Game length  1534 Max score  2048 Game score  27528
# Game #  654 Game length  911 Max score  1024 Game score  14664
# Game #  655 Game length  2014 Max score  2048 Game score  36468
# Game #  656 Game length  2211 Max score  4096 Game score  46556
# Game #  657 Game length  1625 Max score  2048 Game score  30364
# Game #  658 Game length  1433 Max score  2048 Game score  25992
# Game #  659 Game length  990 Max score  1024 Game score  15788
# Game #  660 Game length  1885 Max score  2048 Game score  33740
# Game #  661 Game length  2054 Max score  2048 Game score  36888
# Game #  662 Game length  2049 Max score  2048 Game score  36848
# Game #  663 Game length  1074 Max score  1024 Game score  16804
# Game #  664 Game length  1668 Max score  2048 Game score  30768
# Game #  665 Game length  1869 Max score  2048 Game score  33608
# Game #  666 Game length  878 Max score  1024 Game score  14320
# Game #  667 Game length  2059 Max score  2048 Game score  36924
# Game #  668 Game length  1579 Max score  2048 Game score  28028
# Game #  669 Game length  2134 Max score  2048 Game score  39544
# Game #  670 Game length  1044 Max score  1024 Game score  16524
# Game #  671 Game length  1818 Max score  2048 Game score  32940
# Game #  672 Game length  1873 Max score  2048 Game score  33640
# Game #  673 Game length  1936 Max score  2048 Game score  35180
# Game #  674 Game length  2064 Max score  2048 Game score  36952
# Game #  675 Game length  1756 Max score  2048 Game score  32188
# Game #  676 Game length  2309 Max score  2048 Game score  44032
# Game #  677 Game length  2154 Max score  2048 Game score  38020
# Game #  678 Game length  2786 Max score  4096 Game score  56856
# Game #  679 Game length  1932 Max score  2048 Game score  34568
# Game #  680 Game length  2551 Max score  4096 Game score  52056
# Game #  681 Game length  2144 Max score  2048 Game score  38616
# Game #  682 Game length  1812 Max score  2048 Game score  32908
# Game #  683 Game length  1642 Max score  2048 Game score  28740
# Game #  684 Game length  1098 Max score  1024 Game score  17028
# Game #  685 Game length  1748 Max score  2048 Game score  32108
# Game #  686 Game length  1488 Max score  2048 Game score  26956
# Game #  687 Game length  1830 Max score  2048 Game score  33052
# Game #  688 Game length  3285 Max score  4096 Game score  67952
# Game #  689 Game length  2830 Max score  4096 Game score  57416
# Game #  690 Game length  788 Max score  1024 Game score  12364
# Game #  691 Game length  1759 Max score  2048 Game score  32204
# Game #  692 Game length  1527 Max score  2048 Game score  27480
# Game #  693 Game length  1340 Max score  2048 Game score  24064
# Game #  694 Game length  1929 Max score  2048 Game score  35104
# Game #  695 Game length  596 Max score  512 Game score  8040
# Game #  696 Game length  1140 Max score  1024 Game score  17624
# Game #  697 Game length  1989 Max score  2048 Game score  35776
# Game #  698 Game length  2635 Max score  4096 Game score  53052
# Game #  699 Game length  2008 Max score  2048 Game score  36256
# Game #  700 Game length  1250 Max score  2048 Game score  23000
# Game #  701 Game length  1860 Max score  2048 Game score  34268
# Game #  702 Game length  1802 Max score  2048 Game score  32804
# Game #  703 Game length  2057 Max score  2048 Game score  36904
# Game #  704 Game length  3073 Max score  4096 Game score  61424
# Game #  705 Game length  787 Max score  1024 Game score  12380
# Game #  706 Game length  1946 Max score  2048 Game score  35256
# Game #  707 Game length  1426 Max score  2048 Game score  25100
# Game #  708 Game length  1904 Max score  2048 Game score  34828
# Game #  709 Game length  1842 Max score  2048 Game score  33224
# Game #  710 Game length  953 Max score  1024 Game score  14680
# Game #  711 Game length  1928 Max score  2048 Game score  35100
# Game #  712 Game length  1993 Max score  2048 Game score  36104
# Game #  713 Game length  2017 Max score  2048 Game score  36152
# Game #  714 Game length  2058 Max score  2048 Game score  36920
# Game #  715 Game length  2200 Max score  2048 Game score  38840
# Game #  716 Game length  1696 Max score  2048 Game score  31184
# Game #  717 Game length  2006 Max score  2048 Game score  36236
# Game #  718 Game length  2517 Max score  2048 Game score  47256
# Game #  719 Game length  2810 Max score  4096 Game score  57068
# Game #  720 Game length  1933 Max score  2048 Game score  35136
# Game #  721 Game length  1715 Max score  2048 Game score  31768
# Game #  722 Game length  1813 Max score  2048 Game score  32888
# Game #  723 Game length  392 Max score  256 Game score  4456
# Game #  724 Game length  1623 Max score  2048 Game score  28552
# Game #  725 Game length  1795 Max score  2048 Game score  32732
# Game #  726 Game length  1436 Max score  2048 Game score  26044
# Game #  727 Game length  2107 Max score  2048 Game score  37384
# Game #  728 Game length  2775 Max score  4096 Game score  56700
# Game #  729 Game length  977 Max score  1024 Game score  15696
# Game #  730 Game length  2015 Max score  2048 Game score  36488
# Game #  731 Game length  1130 Max score  1024 Game score  17896
# Game #  732 Game length  1970 Max score  2048 Game score  35516
# Game #  733 Game length  1864 Max score  2048 Game score  34324
# Game #  734 Game length  1875 Max score  2048 Game score  34396
# Game #  735 Game length  1537 Max score  2048 Game score  27544
# Game #  736 Game length  872 Max score  1024 Game score  13412
# Game #  737 Game length  2771 Max score  4096 Game score  56668
# Game #  738 Game length  1755 Max score  2048 Game score  31932
# Game #  739 Game length  1505 Max score  2048 Game score  27096
# Game #  740 Game length  1950 Max score  2048 Game score  35324
# Game #  741 Game length  1983 Max score  2048 Game score  35788
# Game #  742 Game length  1555 Max score  2048 Game score  27744
# Game #  743 Game length  1581 Max score  2048 Game score  28040
# Game #  744 Game length  2045 Max score  2048 Game score  36792
# Game #  745 Game length  668 Max score  1024 Game score  10640
# Game #  746 Game length  1864 Max score  2048 Game score  33400
# Game #  747 Game length  1821 Max score  2048 Game score  32968
# Game #  748 Game length  1030 Max score  1024 Game score  16376
# Game #  749 Game length  1939 Max score  2048 Game score  35180
# Game #  750 Game length  1815 Max score  2048 Game score  32900
# Game #  751 Game length  2054 Max score  2048 Game score  36888
# Game #  752 Game length  1790 Max score  2048 Game score  32704
# Game #  753 Game length  739 Max score  512 Game score  10060
# Game #  754 Game length  1954 Max score  2048 Game score  35356
# Game #  755 Game length  2076 Max score  2048 Game score  37064
# Game #  756 Game length  1785 Max score  2048 Game score  32488
# ...
# Game #  1833 Game length  1644 Max score  2048 Game score  30692
# Game #  1834 Game length  1579 Max score  2048 Game score  28028
# Game #  1835 Game length  1710 Max score  2048 Game score  31308
# Game #  1836 Game length  1543 Max score  2048 Game score  27588
# Game #  1837 Game length  1005 Max score  1024 Game score  16112
# Game #  1838 Game length  1432 Max score  2048 Game score  26072
# Game #  1839 Game length  867 Max score  1024 Game score  14224
# Game #  1840 Game length  379 Max score  512 Game score  5092
# Game #  1841 Game length  1324 Max score  2048 Game score  23932
# Game #  1842 Game length  1551 Max score  2048 Game score  27724
# Game #  1843 Game length  1657 Max score  2048 Game score  30688
# Game #  1844 Game length  1068 Max score  1024 Game score  16880
# Game #  1845 Game length  1519 Max score  2048 Game score  27400
# Game #  1846 Game length  1704 Max score  2048 Game score  30652
# Game #  1847 Game length  927 Max score  1024 Game score  14796
# Game #  1848 Game length  1414 Max score  2048 Game score  25720
# Game #  1849 Game length  1427 Max score  2048 Game score  25960
# Game #  1850 Game length  280 Max score  256 Game score  3196
# Game #  1851 Game length  1979 Max score  2048 Game score  35588
# Game #  1852 Game length  1046 Max score  1024 Game score  16508
# Game #  1853 Game length  1041 Max score  1024 Game score  16472
# Game #  1854 Game length  1548 Max score  2048 Game score  27708
# Game #  1855 Game length  1059 Max score  1024 Game score  16688
# Game #  1856 Game length  993 Max score  1024 Game score  15832
# Game #  1857 Game length  1046 Max score  1024 Game score  16524
# Game #  1858 Game length  1549 Max score  2048 Game score  27656
# Game #  1859 Game length  1037 Max score  1024 Game score  16448
# Game #  1860 Game length  561 Max score  512 Game score  7528
# Game #  1861 Game length  1031 Max score  1024 Game score  16404
# Game #  1862 Game length  1016 Max score  1024 Game score  16192
# Game #  1863 Game length  1040 Max score  1024 Game score  16464
# Game #  1864 Game length  867 Max score  1024 Game score  14044
# Game #  1865 Game length  928 Max score  1024 Game score  14800
# Game #  1866 Game length  587 Max score  512 Game score  7868
# Game #  1867 Game length  845 Max score  1024 Game score  13868
# Game #  1868 Game length  837 Max score  1024 Game score  12860
# Game #  1869 Game length  928 Max score  1024 Game score  14860
# Game #  1870 Game length  1521 Max score  2048 Game score  27312
# Game #  1871 Game length  1605 Max score  2048 Game score  30112
# Game #  1872 Game length  1031 Max score  1024 Game score  16404
# Game #  1873 Game length  1316 Max score  2048 Game score  23868
# Game #  1874 Game length  975 Max score  1024 Game score  15676
# Game #  1875 Game length  786 Max score  1024 Game score  12376
# Game #  1876 Game length  918 Max score  1024 Game score  14712
# Game #  1877 Game length  1495 Max score  2048 Game score  26780
# Game #  1878 Game length  1044 Max score  1024 Game score  16500
# Game #  1879 Game length  1053 Max score  1024 Game score  16584
# Game #  1880 Game length  523 Max score  512 Game score  7208
# Game #  1881 Game length  974 Max score  1024 Game score  15672
# Game #  1882 Game length  1112 Max score  1024 Game score  17376
# Game #  1883 Game length  1040 Max score  1024 Game score  16476
# Game #  1884 Game length  1403 Max score  2048 Game score  25748
# Game #  1885 Game length  1683 Max score  2048 Game score  31020
# Game #  1886 Game length  774 Max score  1024 Game score  12264
# Game #  1887 Game length  1555 Max score  2048 Game score  27756
# Game #  1888 Game length  927 Max score  1024 Game score  14796
# Game #  1889 Game length  1114 Max score  1024 Game score  17388
# Game #  1890 Game length  1034 Max score  1024 Game score  16424
# Game #  1891 Game length  1450 Max score  2048 Game score  26132
# Game #  1892 Game length  1058 Max score  1024 Game score  16692
# Game #  1893 Game length  756 Max score  1024 Game score  12060
# Game #  1894 Game length  1309 Max score  2048 Game score  23744
# Game #  1895 Game length  1116 Max score  1024 Game score  17352
# Game #  1896 Game length  1011 Max score  1024 Game score  16156
# Game #  1897 Game length  1533 Max score  2048 Game score  27520
# Game #  1898 Game length  1192 Max score  1024 Game score  20060
# Game #  1899 Game length  972 Max score  1024 Game score  15632
# Game #  1900 Game length  509 Max score  512 Game score  7008
# Game #  1901 Game length  1072 Max score  1024 Game score  16792
# Game #  1902 Game length  933 Max score  1024 Game score  14864
# Game #  1903 Game length  923 Max score  1024 Game score  14764
# Game #  1904 Game length  951 Max score  1024 Game score  15068
# Game #  1905 Game length  1014 Max score  1024 Game score  16060
# Game #  1906 Game length  1575 Max score  2048 Game score  27996
# Game #  1907 Game length  1065 Max score  1024 Game score  16744
# Game #  1908 Game length  766 Max score  1024 Game score  12136
# Game #  1909 Game length  783 Max score  1024 Game score  12360
# Game #  1910 Game length  1268 Max score  2048 Game score  23228
# Game #  1911 Game length  805 Max score  1024 Game score  12524
# Game #  1912 Game length  1315 Max score  2048 Game score  23788
# Game #  1913 Game length  1715 Max score  2048 Game score  31404
# Game #  1914 Game length  804 Max score  1024 Game score  12700
# Game #  1915 Game length  780 Max score  1024 Game score  12332
# Game #  1916 Game length  266 Max score  256 Game score  3016
# Game #  1917 Game length  1539 Max score  2048 Game score  27612
# Game #  1918 Game length  555 Max score  512 Game score  7532
# Game #  1919 Game length  1550 Max score  2048 Game score  27720
# Game #  1920 Game length  828 Max score  1024 Game score  12828
# Game #  1921 Game length  1607 Max score  2048 Game score  28324
# Game #  1922 Game length  1368 Max score  2048 Game score  25212
# Game #  1923 Game length  802 Max score  1024 Game score  12508
# Game #  1924 Game length  1042 Max score  1024 Game score  16476
# Game #  1925 Game length  979 Max score  1024 Game score  15708
# Game #  1926 Game length  1045 Max score  1024 Game score  16528
# Game #  1927 Game length  921 Max score  1024 Game score  14752
# Game #  1928 Game length  1032 Max score  1024 Game score  16384
# Game #  1929 Game length  1699 Max score  2048 Game score  31260
# Game #  1930 Game length  756 Max score  1024 Game score  12060
# Game #  1931 Game length  1425 Max score  2048 Game score  25936
# Game #  1932 Game length  1053 Max score  1024 Game score  16584
# Game #  1933 Game length  1528 Max score  2048 Game score  27364
# Game #  1934 Game length  1043 Max score  1024 Game score  16492
# Game #  1935 Game length  1034 Max score  1024 Game score  16424
# Game #  1936 Game length  1005 Max score  1024 Game score  16112
# Game #  1937 Game length  1579 Max score  2048 Game score  28016
# Game #  1938 Game length  1572 Max score  2048 Game score  27896
# Game #  1939 Game length  1036 Max score  1024 Game score  16444
# Game #  1940 Game length  1046 Max score  1024 Game score  16508
# Game #  1941 Game length  1015 Max score  1024 Game score  16188
# Game #  1942 Game length  1019 Max score  1024 Game score  16236
# Game #  1943 Game length  1018 Max score  1024 Game score  16204
# Game #  1944 Game length  1541 Max score  2048 Game score  27632
# Game #  1945 Game length  801 Max score  1024 Game score  12560
# Game #  1946 Game length  798 Max score  1024 Game score  12484
# Game #  1947 Game length  774 Max score  1024 Game score  12272
# Game #  1948 Game length  990 Max score  1024 Game score  15816
# Game #  1949 Game length  1008 Max score  1024 Game score  16140
# Game #  1950 Game length  599 Max score  512 Game score  8092
# Game #  1951 Game length  965 Max score  1024 Game score  15584
# Game #  1952 Game length  868 Max score  1024 Game score  14060
# Game #  1953 Game length  969 Max score  1024 Game score  15632
# Game #  1954 Game length  725 Max score  1024 Game score  11616
# Game #  1955 Game length  979 Max score  1024 Game score  15708
# Game #  1956 Game length  769 Max score  1024 Game score  12180
# Game #  1957 Game length  1401 Max score  2048 Game score  25544
# Game #  1958 Game length  946 Max score  1024 Game score  15004
# Game #  1959 Game length  1031 Max score  1024 Game score  16408
# Game #  1960 Game length  1017 Max score  1024 Game score  16200
# Game #  1961 Game length  1538 Max score  2048 Game score  27548
# Game #  1962 Game length  973 Max score  1024 Game score  15664
# Game #  1963 Game length  1037 Max score  1024 Game score  16448
# Game #  1964 Game length  1502 Max score  2048 Game score  27080
# Game #  1965 Game length  384 Max score  256 Game score  4400
# Game #  1966 Game length  1071 Max score  1024 Game score  16908
# Game #  1967 Game length  1690 Max score  2048 Game score  31144
# Game #  1968 Game length  920 Max score  1024 Game score  14748
# Game #  1969 Game length  1039 Max score  1024 Game score  16460
# Game #  1970 Game length  1030 Max score  1024 Game score  16400
# Game #  1971 Game length  921 Max score  1024 Game score  14728
# Game #  1972 Game length  1425 Max score  2048 Game score  25936
# Game #  1973 Game length  1240 Max score  2048 Game score  22740
# Game #  1974 Game length  1665 Max score  2048 Game score  30864
# Game #  1975 Game length  337 Max score  256 Game score  3920
# Game #  1976 Game length  815 Max score  1024 Game score  12684
# Game #  1977 Game length  1039 Max score  1024 Game score  16460
# Game #  1978 Game length  993 Max score  1024 Game score  15592
# Game #  1979 Game length  846 Max score  1024 Game score  13376
# Game #  1980 Game length  507 Max score  512 Game score  6652
# Game #  1981 Game length  927 Max score  1024 Game score  14796
# Game #  1982 Game length  1093 Max score  1024 Game score  17420
# Game #  1983 Game length  1475 Max score  2048 Game score  26780
# Game #  1984 Game length  1031 Max score  1024 Game score  16380
# Game #  1985 Game length  1535 Max score  2048 Game score  27592
# Game #  1986 Game length  688 Max score  1024 Game score  10892
# Game #  1987 Game length  1316 Max score  2048 Game score  23796
# Game #  1988 Game length  782 Max score  1024 Game score  12352
# Game #  1989 Game length  785 Max score  1024 Game score  12368
# Game #  1990 Game length  1037 Max score  1024 Game score  16448
# Game #  1991 Game length  1111 Max score  1024 Game score  17316
# Game #  1992 Game length  610 Max score  512 Game score  8412
# Game #  1993 Game length  1047 Max score  1024 Game score  16512
# Game #  1994 Game length  1336 Max score  2048 Game score  24008
# Game #  1995 Game length  526 Max score  512 Game score  7224
# Game #  1996 Game length  788 Max score  1024 Game score  12384
# Game #  1997 Game length  793 Max score  1024 Game score  12424
# Game #  1998 Game length  399 Max score  512 Game score  5440
# Game #  1999 Game length  799 Max score  1024 Game score  12492
# Game #  2000 Game length  1069 Max score  1024 Game score  16776
# Game #  2001 Game length  1016 Max score  1024 Game score  16084
# Game #  2002 Game length  509 Max score  512 Game score  7036
# Game #  2003 Game length  1038 Max score  1024 Game score  16456
# Game #  2004 Game length  985 Max score  1024 Game score  15788
# Game #  2005 Game length  787 Max score  1024 Game score  12380
# Game #  2006 Game length  958 Max score  1024 Game score  15488
# Game #  2007 Game length  1027 Max score  1024 Game score  16376
# Game #  2008 Game length  930 Max score  1024 Game score  14756
# Game #  2009 Game length  574 Max score  512 Game score  7692
# Game #  2010 Game length  1064 Max score  1024 Game score  16748
# Game #  2011 Game length  918 Max score  1024 Game score  14712
# Game #  2012 Game length  1041 Max score  1024 Game score  16472
# Game #  2013 Game length  948 Max score  1024 Game score  15136
# Game #  2014 Game length  1049 Max score  1024 Game score  16552
# Game #  2015 Game length  1035 Max score  1024 Game score  16428
# Game #  2016 Game length  1045 Max score  1024 Game score  16504
# Game #  2017 Game length  738 Max score  512 Game score  10776
# Game #  2018 Game length  1167 Max score  1024 Game score  18764
# Game #  2019 Game length  999 Max score  1024 Game score  16072
# Game #  2020 Game length  1054 Max score  1024 Game score  16588
# Game #  2021 Game length  536 Max score  512 Game score  7324
# Game #  2022 Game length  809 Max score  1024 Game score  12640
# Game #  2023 Game length  992 Max score  1024 Game score  16008
# Game #  2024 Game length  530 Max score  512 Game score  7256
# Game #  2025 Game length  1172 Max score  1024 Game score  18792
# Game #  2026 Game length  591 Max score  512 Game score  8012
# Game #  2027 Game length  806 Max score  1024 Game score  12624
# Game #  2028 Game length  560 Max score  512 Game score  7568
# Game #  2029 Game length  356 Max score  256 Game score  4072
# Game #  2030 Game length  934 Max score  1024 Game score  14844
# Game #  2031 Game length  760 Max score  1024 Game score  12092
# Game #  2032 Game length  499 Max score  512 Game score  6812
# Game #  2033 Game length  1032 Max score  1024 Game score  16408
# Game #  2034 Game length  917 Max score  1024 Game score  14696
# Game #  2035 Game length  458 Max score  512 Game score  6428
# Game #  2036 Game length  819 Max score  1024 Game score  12660
# Game #  2037 Game length  1042 Max score  1024 Game score  16476
# Game #  2038 Game length  980 Max score  1024 Game score  15740
# Game #  2039 Game length  1515 Max score  2048 Game score  27244
# Game #  2040 Game length  967 Max score  1024 Game score  15548
# Game #  2041 Game length  1003 Max score  1024 Game score  16076
# Game #  2042 Game length  977 Max score  1024 Game score  15696
# Game #  2043 Game length  1018 Max score  1024 Game score  15868
# Game #  2044 Game length  664 Max score  1024 Game score  10620
# Game #  2045 Game length  1039 Max score  1024 Game score  16460
# Game #  2046 Game length  467 Max score  512 Game score  6484
# Game #  2047 Game length  978 Max score  1024 Game score  15452
# Game #  2048 Game length  724 Max score  1024 Game score  11360
# Game #  2049 Game length  987 Max score  1024 Game score  15788
# Game #  2050 Game length  1052 Max score  1024 Game score  16580
# Game #  2051 Game length  753 Max score  1024 Game score  12044
# Game #  2052 Game length  924 Max score  1024 Game score  14780
# Game #  2053 Game length  974 Max score  1024 Game score  15680
# Game #  2054 Game length  1016 Max score  1024 Game score  16220
# Game #  2055 Game length  264 Max score  256 Game score  3060
# Game #  2056 Game length  525 Max score  512 Game score  7228
# Game #  2057 Game length  971 Max score  1024 Game score  15652
# Game #  2058 Game length  766 Max score  1024 Game score  11788
# Game #  2059 Game length  436 Max score  512 Game score  5820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d09840c55e1f> in <module>
#      17
#      18
# ---> 19 train(model, optimizer, loss)
#
# <ipython-input-9-d09840c55e1f> in train(model, optimizer, loss)
#       5     while epoch != num_epochs:
#       6         epoch += 1
# ----> 7         game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
#       8         print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
#       9         if epoch % 500 == 0:
#
# <ipython-input-5-7afa3361de1a> in gen_sample_and_learn(model, optimizer, loss_fn, is_train, explorationProb)
#      53             loss.backward()
#      54 #             nn.utils.clip_grad_norm_(model.parameters(), 10.0) #
# ---> 55             optimizer.step()
#      56             model.eval()
#      57 #             if game_len % 50 == 0:
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#      99                     denom = max_exp_avg_sq.sqrt().add_(group['eps'])
#     100                 else:
# --> 101                     denom = exp_avg_sq.sqrt().add_(group['eps'])
#     102
#     103                 bias_correction1 = 1 - beta1 ** state['step']
#
# KeyboardInterrupt:

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
# Out:
# Game #  1 Game length  831 Max score  1024 Game score  12940
# Game #  2 Game length  908 Max score  1024 Game score  14636
# Game #  3 Game length  924 Max score  1024 Game score  14744
# Game #  4 Game length  1028 Max score  1024 Game score  16352
# Game #  5 Game length  929 Max score  1024 Game score  14808
# Game #  6 Game length  551 Max score  512 Game score  7452
# Game #  7 Game length  547 Max score  512 Game score  7392
# Game #  8 Game length  1010 Max score  1024 Game score  16028
# Game #  9 Game length  534 Max score  512 Game score  7288
# Game #  10 Game length  693 Max score  1024 Game score  10872
# Game #  11 Game length  1033 Max score  1024 Game score  16360
# Game #  12 Game length  800 Max score  1024 Game score  12440
# Game #  13 Game length  562 Max score  512 Game score  7532
# Game #  14 Game length  1316 Max score  2048 Game score  23796
# Game #  15 Game length  795 Max score  1024 Game score  12460
# Game #  16 Game length  1029 Max score  1024 Game score  16384
# Game #  17 Game length  810 Max score  1024 Game score  12564
# Game #  18 Game length  512 Max score  512 Game score  7016
# Game #  19 Game length  1049 Max score  1024 Game score  16524
# Game #  20 Game length  853 Max score  1024 Game score  13416
# Game #  21 Game length  1023 Max score  1024 Game score  16268
# Game #  22 Game length  1056 Max score  1024 Game score  16600
# Game #  23 Game length  914 Max score  1024 Game score  14680
# Game #  24 Game length  513 Max score  512 Game score  7032
# Game #  25 Game length  913 Max score  1024 Game score  14672
# Game #  26 Game length  949 Max score  1024 Game score  15032
# Game #  27 Game length  1040 Max score  1024 Game score  16464
# Game #  28 Game length  678 Max score  1024 Game score  10744
# Game #  29 Game length  1300 Max score  2048 Game score  23648
# Game #  30 Game length  542 Max score  512 Game score  7356
# Game #  31 Game length  819 Max score  1024 Game score  12828
# Game #  32 Game length  739 Max score  1024 Game score  11740
# Game #  33 Game length  574 Max score  512 Game score  7816
# Game #  34 Game length  961 Max score  1024 Game score  15256
# Game #  35 Game length  869 Max score  1024 Game score  14056
# Game #  36 Game length  1048 Max score  1024 Game score  16548
# Game #  37 Game length  985 Max score  1024 Game score  15776
# Game #  38 Game length  943 Max score  1024 Game score  14988
# Game #  39 Game length  868 Max score  1024 Game score  14048
# Game #  40 Game length  567 Max score  512 Game score  7644
# Game #  41 Game length  516 Max score  512 Game score  7072
# Game #  42 Game length  736 Max score  1024 Game score  11476
# Game #  43 Game length  910 Max score  1024 Game score  14660
# Game #  44 Game length  487 Max score  512 Game score  6640
# Game #  45 Game length  537 Max score  512 Game score  7312
# Game #  46 Game length  524 Max score  512 Game score  7184
# Game #  47 Game length  842 Max score  1024 Game score  13764
# Game #  48 Game length  275 Max score  256 Game score  2988
# Game #  49 Game length  1059 Max score  1024 Game score  16652
# Game #  50 Game length  1033 Max score  1024 Game score  16392
# Game #  51 Game length  521 Max score  512 Game score  7072
# Game #  52 Game length  535 Max score  512 Game score  7292
# Game #  53 Game length  916 Max score  1024 Game score  14692
# Game #  54 Game length  735 Max score  1024 Game score  11708
# Game #  55 Game length  859 Max score  1024 Game score  13916
# Game #  56 Game length  1004 Max score  1024 Game score  15856
# Game #  57 Game length  985 Max score  1024 Game score  15748
# Game #  58 Game length  802 Max score  1024 Game score  12520
# Game #  59 Game length  817 Max score  1024 Game score  12816
# Game #  60 Game length  986 Max score  1024 Game score  15756
# Game #  61 Game length  710 Max score  1024 Game score  11428
# Game #  62 Game length  540 Max score  512 Game score  7356
# Game #  63 Game length  1060 Max score  1024 Game score  16632
# Game #  64 Game length  846 Max score  1024 Game score  13060
# Game #  65 Game length  859 Max score  1024 Game score  13244
# Game #  66 Game length  950 Max score  1024 Game score  15036
# Game #  67 Game length  928 Max score  1024 Game score  14800
# Game #  68 Game length  1044 Max score  1024 Game score  16496
# Game #  69 Game length  830 Max score  1024 Game score  12840
# Game #  70 Game length  892 Max score  1024 Game score  13576
# Game #  71 Game length  931 Max score  1024 Game score  14828
# Game #  72 Game length  1047 Max score  1024 Game score  16540
# Game #  73 Game length  1071 Max score  1024 Game score  16908
# Game #  74 Game length  519 Max score  512 Game score  7100
# Game #  75 Game length  967 Max score  1024 Game score  15548
# Game #  76 Game length  799 Max score  1024 Game score  12492
# Game #  77 Game length  313 Max score  256 Game score  3528
# Game #  78 Game length  1296 Max score  2048 Game score  23628
# Game #  79 Game length  283 Max score  256 Game score  3152
# Game #  80 Game length  770 Max score  1024 Game score  12240
# Game #  81 Game length  811 Max score  1024 Game score  12604
# Game #  82 Game length  1071 Max score  1024 Game score  16908
# Game #  83 Game length  943 Max score  1024 Game score  14988
# Game #  84 Game length  991 Max score  1024 Game score  15820
# Game #  85 Game length  1036 Max score  1024 Game score  16444
# Game #  86 Game length  743 Max score  1024 Game score  11772
# Game #  87 Game length  1003 Max score  1024 Game score  15980
# Game #  88 Game length  1316 Max score  2048 Game score  23820
# Game #  89 Game length  539 Max score  512 Game score  7340
# Game #  90 Game length  1057 Max score  1024 Game score  16640
# Game #  91 Game length  915 Max score  1024 Game score  14684
# Game #  92 Game length  1042 Max score  1024 Game score  16444
# Game #  93 Game length  814 Max score  1024 Game score  12620
# Game #  94 Game length  959 Max score  1024 Game score  15484
# Game #  95 Game length  825 Max score  1024 Game score  12776
# Game #  96 Game length  993 Max score  1024 Game score  16000
# Game #  97 Game length  996 Max score  1024 Game score  15860
# Game #  98 Game length  1034 Max score  1024 Game score  16396
# Game #  99 Game length  929 Max score  1024 Game score  14808
# Game #  100 Game length  805 Max score  1024 Game score  12620

# %%
test(model)

# %%
test(best_model)
