# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=128, filter2=512, filter3=1024, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)

        self.conv_aaa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_aab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_aba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_abb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)

        self.conv_baa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_bba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bbb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_x = nn.Linear(input_size * 16, 1)
        self.W_a = nn.Linear(filter1 * 12, 1)
        self.W_b = nn.Linear(filter1 * 12, 1)

        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)

        self.W_aaa = nn.Linear(filter3 * 4, 1)
        self.W_aab = nn.Linear(filter3 * 6, 1)
        self.W_aba = nn.Linear(filter3 * 6, 1)
        self.W_abb = nn.Linear(filter3 * 6, 1)
        self.W_baa = nn.Linear(filter3 * 6, 1)
        self.W_bab = nn.Linear(filter3 * 6, 1)
        self.W_bba = nn.Linear(filter3 * 6, 1)
        self.W_bbb = nn.Linear(filter3 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        aa = self.relu(self.conv_aa(a))
        ab = self.relu(self.conv_ab(a))
        ba = self.relu(self.conv_ba(b))
        bb = self.relu(self.conv_bb(b))

        aaa = self.flatten(self.relu(self.conv_aaa(aa)))
        aab = self.flatten(self.relu(self.conv_aab(aa)))
        aba = self.flatten(self.relu(self.conv_aba(ab)))
        abb = self.flatten(self.relu(self.conv_abb(ab)))
        baa = self.flatten(self.relu(self.conv_baa(ba)))
        bab = self.flatten(self.relu(self.conv_bab(ba)))
        bba = self.flatten(self.relu(self.conv_bba(bb)))
        bbb = self.flatten(self.relu(self.conv_bbb(bb)))
        x = self.flatten(x)
        a = self.flatten(a)
        b = self.flatten(b)
        aa = self.flatten(aa)
        ab = self.flatten(ab)
        ba = self.flatten(ba)
        bb = self.flatten(bb)

        out = self.W_x(x) + self.W_a(a) + self.W_b(b) \
              + self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) \
              +  self.W_aaa(aaa) + self.W_aab(aab) + self.W_aba(aba) + self.W_abb(abb) \
              + self.W_baa(baa) + self.W_bab(bab) + self.W_bba(bba) + self.W_bbb(bbb)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y)
            last_loss = loss.item()
            loss.backward()
            optimizer.step()
            model.eval()
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 5e-4
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)
    
def load_model(model, optimizer, filename, model_only = False):
    checkpoint_path = os.path.join(experiment_dir, filename)
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    if not model_only:
        optimizer.load_state_dict(ckpt_dict['optimizer'])
        epoch = ckpt_dict['epoch']
        running_mean = ckpt_dict['running_mean']
    else:
        epoch = None
        running_mean = None
    return model, optimizer, epoch, running_mean

# %%
num_epochs = 1500
best_model = None

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
    ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean:
            running_mean = sum(ls) / 10
            filename = "model2_score_"+str(epoch // 100)+".pth.tar"
            save_model({
                'epoch': epoch,
                'running_mean': running_mean,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            best_model, _, _, _ = load_model(model, optimizer, filename, True)
            model.cuda()
            
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  141 Max score  128 Game score  1288
# Game #  2 Game length  239 Max score  256 Game score  2592
# Game #  3 Game length  297 Max score  256 Game score  3336
# Game #  4 Game length  201 Max score  128 Game score  1804
# Game #  5 Game length  232 Max score  128 Game score  2388
# Game #  6 Game length  506 Max score  512 Game score  6888
# Game #  7 Game length  368 Max score  256 Game score  4364
# Game #  8 Game length  275 Max score  256 Game score  3156
# Game #  9 Game length  385 Max score  512 Game score  5260
# Game #  10 Game length  325 Max score  256 Game score  3664
# Game #  11 Game length  390 Max score  512 Game score  5172
# Game #  12 Game length  267 Max score  256 Game score  2924
# Game #  13 Game length  234 Max score  128 Game score  2220
# Game #  14 Game length  321 Max score  256 Game score  3776
# Game #  15 Game length  272 Max score  256 Game score  3132
# Game #  16 Game length  429 Max score  512 Game score  5744
# Game #  17 Game length  286 Max score  256 Game score  3256
# Game #  18 Game length  387 Max score  512 Game score  5260
# Game #  19 Game length  241 Max score  256 Game score  2640
# Game #  20 Game length  252 Max score  256 Game score  2796
# Game #  21 Game length  438 Max score  512 Game score  5816
# Game #  22 Game length  295 Max score  256 Game score  3384
# Game #  23 Game length  477 Max score  512 Game score  6216
# Game #  24 Game length  451 Max score  512 Game score  5932
# Game #  25 Game length  286 Max score  256 Game score  3228
# Game #  26 Game length  538 Max score  512 Game score  7212
# Game #  27 Game length  271 Max score  256 Game score  2956
# Game #  28 Game length  568 Max score  512 Game score  7660
# Game #  29 Game length  191 Max score  128 Game score  1788
# Game #  30 Game length  325 Max score  256 Game score  3628
# Game #  31 Game length  378 Max score  256 Game score  4556
# Game #  32 Game length  465 Max score  512 Game score  6104
# Game #  33 Game length  234 Max score  256 Game score  2568
# Game #  34 Game length  414 Max score  512 Game score  5508
# Game #  35 Game length  266 Max score  256 Game score  2892
# Game #  36 Game length  302 Max score  256 Game score  3400
# Game #  37 Game length  444 Max score  512 Game score  5884
# Game #  38 Game length  543 Max score  512 Game score  7420
# Game #  39 Game length  307 Max score  256 Game score  3484
# Game #  40 Game length  460 Max score  512 Game score  6064
# Game #  41 Game length  440 Max score  512 Game score  5852
# Game #  42 Game length  317 Max score  256 Game score  3560
# Game #  43 Game length  322 Max score  256 Game score  3612
# Game #  44 Game length  360 Max score  256 Game score  4128
# Game #  45 Game length  525 Max score  512 Game score  7216
# Game #  46 Game length  409 Max score  512 Game score  5504
# Game #  47 Game length  544 Max score  512 Game score  7376
# Game #  48 Game length  298 Max score  256 Game score  3424
# Game #  49 Game length  540 Max score  512 Game score  7356
# Game #  50 Game length  553 Max score  512 Game score  7464
# Game #  51 Game length  462 Max score  512 Game score  6448
# Game #  52 Game length  536 Max score  512 Game score  7300
# Game #  53 Game length  499 Max score  512 Game score  6812
# Game #  54 Game length  585 Max score  512 Game score  7968
# Game #  55 Game length  429 Max score  512 Game score  5696
# Game #  56 Game length  784 Max score  1024 Game score  12364
# Game #  57 Game length  603 Max score  512 Game score  8364
# Game #  58 Game length  758 Max score  512 Game score  10940
# Game #  59 Game length  282 Max score  256 Game score  3208
# Game #  60 Game length  542 Max score  512 Game score  7368
# Game #  61 Game length  562 Max score  512 Game score  7580
# Game #  62 Game length  687 Max score  1024 Game score  10828
# Game #  63 Game length  531 Max score  512 Game score  7260
# Game #  64 Game length  362 Max score  256 Game score  4200
# Game #  65 Game length  562 Max score  512 Game score  7592
# Game #  66 Game length  195 Max score  128 Game score  1820
# Game #  67 Game length  312 Max score  256 Game score  3520
# Game #  68 Game length  576 Max score  512 Game score  7824
# Game #  69 Game length  243 Max score  256 Game score  2712
# Game #  70 Game length  671 Max score  512 Game score  9676
# Game #  71 Game length  801 Max score  1024 Game score  12504
# Game #  72 Game length  559 Max score  512 Game score  7564
# Game #  73 Game length  625 Max score  512 Game score  8720
# Game #  74 Game length  285 Max score  256 Game score  3224
# Game #  75 Game length  679 Max score  1024 Game score  10748
# Game #  76 Game length  199 Max score  128 Game score  1852
# Game #  77 Game length  497 Max score  512 Game score  6804
# Game #  78 Game length  530 Max score  512 Game score  7256
# Game #  79 Game length  542 Max score  512 Game score  7364
# Game #  80 Game length  526 Max score  512 Game score  7232
# Game #  81 Game length  623 Max score  512 Game score  8336
# Game #  82 Game length  476 Max score  512 Game score  6544
# Game #  83 Game length  465 Max score  512 Game score  6476
# Game #  84 Game length  943 Max score  1024 Game score  15100
# Game #  85 Game length  522 Max score  512 Game score  7200
# Game #  86 Game length  738 Max score  1024 Game score  11736
# Game #  87 Game length  350 Max score  256 Game score  4028
# Game #  88 Game length  557 Max score  512 Game score  7552
# Game #  89 Game length  501 Max score  512 Game score  6956
# Game #  90 Game length  543 Max score  512 Game score  7372
# Game #  91 Game length  801 Max score  1024 Game score  12504
# Game #  92 Game length  504 Max score  512 Game score  6848
# Game #  93 Game length  536 Max score  512 Game score  7324
# Game #  94 Game length  541 Max score  512 Game score  7360
# Game #  95 Game length  820 Max score  1024 Game score  12720
# Game #  96 Game length  535 Max score  512 Game score  7292
# Game #  97 Game length  536 Max score  512 Game score  7300
# Game #  98 Game length  1444 Max score  2048 Game score  26096
# Game #  99 Game length  536 Max score  512 Game score  7324
# Game #  100 Game length  542 Max score  512 Game score  7368
# Game #  101 Game length  782 Max score  1024 Game score  12352
# Game #  102 Game length  542 Max score  512 Game score  7368
# Game #  103 Game length  1038 Max score  1024 Game score  16480
# Game #  104 Game length  769 Max score  1024 Game score  12176
# Game #  105 Game length  817 Max score  1024 Game score  12696
# Game #  106 Game length  852 Max score  1024 Game score  13168
# Game #  107 Game length  453 Max score  512 Game score  6064
# Game #  108 Game length  796 Max score  1024 Game score  12476
# Game #  109 Game length  557 Max score  512 Game score  7552
# Game #  110 Game length  504 Max score  512 Game score  6876
# Game #  111 Game length  289 Max score  256 Game score  3280
# Game #  112 Game length  752 Max score  1024 Game score  11856
# Game #  113 Game length  314 Max score  256 Game score  3532
# Game #  114 Game length  415 Max score  256 Game score  5068
# Game #  115 Game length  992 Max score  1024 Game score  15884
# Game #  116 Game length  770 Max score  1024 Game score  12240
# Game #  117 Game length  532 Max score  512 Game score  7276
# Game #  118 Game length  783 Max score  512 Game score  11340
# Game #  119 Game length  733 Max score  512 Game score  10688
# Game #  120 Game length  782 Max score  1024 Game score  12340
# Game #  121 Game length  1039 Max score  1024 Game score  16460
# Game #  122 Game length  810 Max score  1024 Game score  12600
# Game #  123 Game length  1101 Max score  1024 Game score  17980
# Game #  124 Game length  974 Max score  1024 Game score  15672
# Game #  125 Game length  799 Max score  1024 Game score  12576
# Game #  126 Game length  173 Max score  128 Game score  1584
# Game #  127 Game length  923 Max score  1024 Game score  14764
# Game #  128 Game length  522 Max score  512 Game score  7176
# Game #  129 Game length  741 Max score  1024 Game score  11760
# Game #  130 Game length  1050 Max score  1024 Game score  16612
# Game #  131 Game length  598 Max score  512 Game score  8312
# Game #  132 Game length  1021 Max score  1024 Game score  16316
# Game #  133 Game length  1240 Max score  2048 Game score  22656
# Game #  134 Game length  571 Max score  512 Game score  7788
# Game #  135 Game length  772 Max score  1024 Game score  12204
# Game #  136 Game length  593 Max score  512 Game score  8024
# Game #  137 Game length  591 Max score  512 Game score  8204
# Game #  138 Game length  813 Max score  1024 Game score  12664
# Game #  139 Game length  890 Max score  1024 Game score  13900
# Game #  140 Game length  538 Max score  512 Game score  7336
# Game #  141 Game length  477 Max score  512 Game score  6336
# Game #  142 Game length  468 Max score  512 Game score  6492
# Game #  143 Game length  545 Max score  512 Game score  7384
# Game #  144 Game length  1006 Max score  1024 Game score  16008
# Game #  145 Game length  978 Max score  1024 Game score  15700
# Game #  146 Game length  279 Max score  256 Game score  3192
# Game #  147 Game length  377 Max score  512 Game score  5056
# Game #  148 Game length  1281 Max score  1024 Game score  21460
# Game #  149 Game length  158 Max score  128 Game score  1440
# Game #  150 Game length  1014 Max score  1024 Game score  16060
# Game #  151 Game length  805 Max score  1024 Game score  12536
# Game #  152 Game length  536 Max score  512 Game score  7324
# Game #  153 Game length  855 Max score  1024 Game score  13464
# Game #  154 Game length  820 Max score  1024 Game score  13084
# Game #  155 Game length  916 Max score  1024 Game score  14700
# Game #  156 Game length  914 Max score  1024 Game score  14680
# Game #  157 Game length  586 Max score  512 Game score  7984
# Game #  158 Game length  1034 Max score  1024 Game score  16420
# Game #  159 Game length  1424 Max score  2048 Game score  25932
# Game #  160 Game length  335 Max score  256 Game score  3912
# Game #  161 Game length  579 Max score  512 Game score  7936
# Game #  162 Game length  426 Max score  512 Game score  5728
# Game #  163 Game length  277 Max score  256 Game score  3168
# Game #  164 Game length  678 Max score  512 Game score  9424
# Game #  165 Game length  1003 Max score  1024 Game score  16104
# Game #  166 Game length  553 Max score  512 Game score  7520
# Game #  167 Game length  919 Max score  1024 Game score  14716
# Game #  168 Game length  1057 Max score  1024 Game score  16664
# Game #  169 Game length  654 Max score  512 Game score  9032
# Game #  170 Game length  1612 Max score  2048 Game score  28720
# Game #  171 Game length  309 Max score  256 Game score  3868
# Game #  172 Game length  1276 Max score  2048 Game score  23376
# Game #  173 Game length  920 Max score  1024 Game score  14720
# Game #  174 Game length  1311 Max score  2048 Game score  23816
# Game #  175 Game length  738 Max score  1024 Game score  11732
# Game #  176 Game length  1004 Max score  1024 Game score  16108
# Game #  177 Game length  581 Max score  512 Game score  7768
# Game #  178 Game length  593 Max score  512 Game score  8024
# Game #  179 Game length  554 Max score  512 Game score  7648
# Game #  180 Game length  281 Max score  256 Game score  3228
# Game #  181 Game length  820 Max score  1024 Game score  12868
# Game #  182 Game length  1032 Max score  1024 Game score  16412
# Game #  183 Game length  907 Max score  1024 Game score  14628
# Game #  184 Game length  1110 Max score  1024 Game score  17532
# Game #  185 Game length  231 Max score  256 Game score  2540
# Game #  186 Game length  816 Max score  1024 Game score  12812
# Game #  187 Game length  1053 Max score  1024 Game score  16584
# Game #  188 Game length  990 Max score  1024 Game score  15816
# Game #  189 Game length  461 Max score  512 Game score  6444
# Game #  190 Game length  478 Max score  512 Game score  6592
# Game #  191 Game length  699 Max score  1024 Game score  10988
# Game #  192 Game length  794 Max score  1024 Game score  12456
# Game #  193 Game length  540 Max score  512 Game score  7344
# Game #  194 Game length  936 Max score  1024 Game score  15036
# Game #  195 Game length  999 Max score  1024 Game score  15652
# Game #  196 Game length  972 Max score  1024 Game score  15660
# Game #  197 Game length  930 Max score  1024 Game score  14812
# Game #  198 Game length  289 Max score  256 Game score  3280
# Game #  199 Game length  490 Max score  512 Game score  6504
# Game #  200 Game length  1562 Max score  2048 Game score  27832
# Game #  201 Game length  558 Max score  512 Game score  7560
# Game #  202 Game length  557 Max score  512 Game score  7640
# Game #  203 Game length  563 Max score  512 Game score  7596
# Game #  204 Game length  1033 Max score  1024 Game score  16428
# Game #  205 Game length  921 Max score  1024 Game score  14752
# Game #  206 Game length  771 Max score  1024 Game score  12244
# Game #  207 Game length  733 Max score  1024 Game score  11696
# Game #  208 Game length  1065 Max score  1024 Game score  16840
# Game #  209 Game length  789 Max score  1024 Game score  12400
# Game #  210 Game length  527 Max score  512 Game score  7240
# Game #  211 Game length  1040 Max score  1024 Game score  16464
# Game #  212 Game length  1295 Max score  1024 Game score  21580
# Game #  213 Game length  1037 Max score  1024 Game score  16448
# Game #  214 Game length  589 Max score  512 Game score  8000
# Game #  215 Game length  585 Max score  512 Game score  8220
# Game #  216 Game length  765 Max score  1024 Game score  12024
# Game #  217 Game length  1066 Max score  1024 Game score  17120
# Game #  218 Game length  787 Max score  1024 Game score  12392
# Game #  219 Game length  886 Max score  1024 Game score  13772
# Game #  220 Game length  533 Max score  512 Game score  7280
# Game #  221 Game length  645 Max score  512 Game score  8936
# Game #  222 Game length  540 Max score  512 Game score  7356
# Game #  223 Game length  1290 Max score  2048 Game score  23584
# Game #  224 Game length  676 Max score  1024 Game score  10732
# Game #  225 Game length  1096 Max score  1024 Game score  17408
# Game #  226 Game length  994 Max score  1024 Game score  16016
# Game #  227 Game length  1061 Max score  1024 Game score  16664
# Game #  228 Game length  909 Max score  1024 Game score  14640
# Game #  229 Game length  559 Max score  512 Game score  7564
# Game #  230 Game length  1139 Max score  1024 Game score  17964
# Game #  231 Game length  610 Max score  512 Game score  8592
# Game #  232 Game length  542 Max score  512 Game score  7368
# Game #  233 Game length  1617 Max score  2048 Game score  29264
# Game #  234 Game length  1533 Max score  2048 Game score  27400
# Game #  235 Game length  1497 Max score  2048 Game score  27040
# Game #  236 Game length  408 Max score  256 Game score  4992
# Game #  237 Game length  1804 Max score  2048 Game score  32828
# Game #  238 Game length  1659 Max score  2048 Game score  30796
# Game #  239 Game length  1368 Max score  2048 Game score  25212
# Game #  240 Game length  1035 Max score  1024 Game score  16428
# Game #  241 Game length  1102 Max score  1024 Game score  17468
# Game #  242 Game length  785 Max score  1024 Game score  12368
# Game #  243 Game length  996 Max score  1024 Game score  16028
# Game #  244 Game length  1067 Max score  1024 Game score  16876
# Game #  245 Game length  969 Max score  1024 Game score  15644
# Game #  246 Game length  1093 Max score  1024 Game score  17408
# Game #  247 Game length  1020 Max score  1024 Game score  16300
# Game #  248 Game length  1012 Max score  1024 Game score  16160
# Game #  249 Game length  411 Max score  512 Game score  5540
# Game #  250 Game length  542 Max score  512 Game score  7368
# Game #  251 Game length  603 Max score  512 Game score  8364
# Game #  252 Game length  1303 Max score  2048 Game score  23676
# Game #  253 Game length  1336 Max score  1024 Game score  20984
# Game #  254 Game length  531 Max score  512 Game score  7260
# Game #  255 Game length  604 Max score  512 Game score  8132
# Game #  256 Game length  745 Max score  1024 Game score  11784
# Game #  257 Game length  1535 Max score  2048 Game score  27532
# Game #  258 Game length  1278 Max score  2048 Game score  23424
# Game #  259 Game length  951 Max score  1024 Game score  14564
# Game #  260 Game length  1054 Max score  1024 Game score  16588
# Game #  261 Game length  1287 Max score  1024 Game score  20508
# Game #  262 Game length  1554 Max score  2048 Game score  27752
# Game #  263 Game length  945 Max score  1024 Game score  15120
# Game #  264 Game length  1047 Max score  1024 Game score  16516
# Game #  265 Game length  1662 Max score  2048 Game score  29832
# Game #  266 Game length  936 Max score  1024 Game score  14940
# Game #  267 Game length  315 Max score  256 Game score  3564
# Game #  268 Game length  605 Max score  512 Game score  8136
# Game #  269 Game length  1590 Max score  2048 Game score  28124
# Game #  270 Game length  540 Max score  512 Game score  7356
# Game #  271 Game length  967 Max score  1024 Game score  15324
# Game #  272 Game length  1105 Max score  1024 Game score  17244
# Game #  273 Game length  938 Max score  1024 Game score  15072
# Game #  274 Game length  553 Max score  512 Game score  7464
# Game #  275 Game length  1721 Max score  2048 Game score  31836
# Game #  276 Game length  528 Max score  512 Game score  7244
# Game #  277 Game length  997 Max score  1024 Game score  16032
# Game #  278 Game length  969 Max score  1024 Game score  15644
# Game #  279 Game length  1743 Max score  2048 Game score  31820
# Game #  280 Game length  991 Max score  1024 Game score  15820
# Game #  281 Game length  1080 Max score  1024 Game score  16872
# Game #  282 Game length  1760 Max score  2048 Game score  32212
# Game #  283 Game length  1016 Max score  1024 Game score  16220
# Game #  284 Game length  1527 Max score  2048 Game score  27480
# Game #  285 Game length  791 Max score  1024 Game score  12440
# Game #  286 Game length  887 Max score  1024 Game score  13512
# Game #  287 Game length  1070 Max score  1024 Game score  16780
# Game #  288 Game length  1310 Max score  2048 Game score  23724
# Game #  289 Game length  1004 Max score  1024 Game score  15996
# Game #  290 Game length  517 Max score  512 Game score  7164
# Game #  291 Game length  823 Max score  1024 Game score  12740
# Game #  292 Game length  539 Max score  512 Game score  7340
# Game #  293 Game length  763 Max score  1024 Game score  12136
# Game #  294 Game length  970 Max score  1024 Game score  15204
# Game #  295 Game length  1056 Max score  1024 Game score  16600
# Game #  296 Game length  908 Max score  1024 Game score  14636
# Game #  297 Game length  1030 Max score  1024 Game score  16364
# Game #  298 Game length  558 Max score  512 Game score  7560
# Game #  299 Game length  583 Max score  512 Game score  7780
# Game #  300 Game length  1173 Max score  1024 Game score  19824
# Game #  301 Game length  589 Max score  512 Game score  8004
# Game #  302 Game length  547 Max score  512 Game score  7392
# Game #  303 Game length  1057 Max score  1024 Game score  16604
# Game #  304 Game length  550 Max score  512 Game score  7468
# Game #  305 Game length  974 Max score  1024 Game score  15668
# Game #  306 Game length  1159 Max score  1024 Game score  18684
# Game #  307 Game length  700 Max score  1024 Game score  11340
# Game #  308 Game length  1003 Max score  1024 Game score  15232
# Game #  309 Game length  1019 Max score  1024 Game score  16236
# Game #  310 Game length  941 Max score  1024 Game score  15340
# Game #  311 Game length  571 Max score  512 Game score  7676
# Game #  312 Game length  1068 Max score  1024 Game score  16712
# Game #  313 Game length  572 Max score  512 Game score  7804
# Game #  314 Game length  1178 Max score  2048 Game score  21920
# Game #  315 Game length  575 Max score  512 Game score  7724
# Game #  316 Game length  2462 Max score  4096 Game score  50632
# Game #  317 Game length  531 Max score  512 Game score  7260
# Game #  318 Game length  546 Max score  512 Game score  7388
# Game #  319 Game length  915 Max score  1024 Game score  14684
# Game #  320 Game length  1320 Max score  2048 Game score  23844
# Game #  321 Game length  851 Max score  1024 Game score  13068
# Game #  322 Game length  1049 Max score  1024 Game score  16536
# Game #  323 Game length  828 Max score  1024 Game score  12776
# Game #  324 Game length  652 Max score  512 Game score  9516
# Game #  325 Game length  1023 Max score  1024 Game score  16268
# Game #  326 Game length  528 Max score  512 Game score  7232
# Game #  327 Game length  1495 Max score  2048 Game score  27004
# Game #  328 Game length  997 Max score  1024 Game score  16032
# Game #  329 Game length  1039 Max score  1024 Game score  16460
# Game #  330 Game length  895 Max score  1024 Game score  14024
# Game #  331 Game length  1048 Max score  1024 Game score  16544
# Game #  332 Game length  624 Max score  512 Game score  8344
# Game #  333 Game length  1796 Max score  2048 Game score  32736
# Game #  334 Game length  972 Max score  1024 Game score  15660
# Game #  335 Game length  995 Max score  1024 Game score  15900
# Game #  336 Game length  1533 Max score  2048 Game score  27568
# Game #  337 Game length  1124 Max score  1024 Game score  18332
# Game #  338 Game length  517 Max score  512 Game score  6968
# Game #  339 Game length  1332 Max score  1024 Game score  20952
# Game #  340 Game length  1099 Max score  1024 Game score  17212
# Game #  341 Game length  530 Max score  512 Game score  7264
# Game #  342 Game length  923 Max score  1024 Game score  14764
# Game #  343 Game length  1058 Max score  1024 Game score  16704
# Game #  344 Game length  1519 Max score  2048 Game score  27276
# Game #  345 Game length  1837 Max score  2048 Game score  33280
# Game #  346 Game length  1820 Max score  2048 Game score  33020
# Game #  347 Game length  1544 Max score  2048 Game score  27676
# Game #  348 Game length  487 Max score  512 Game score  6820
# Game #  349 Game length  914 Max score  1024 Game score  14676
# Game #  350 Game length  1090 Max score  1024 Game score  16972
# Game #  351 Game length  1125 Max score  1024 Game score  18336
# Game #  352 Game length  1230 Max score  2048 Game score  22832
# Game #  353 Game length  1095 Max score  1024 Game score  17180
# Game #  354 Game length  320 Max score  256 Game score  3576
# Game #  355 Game length  2366 Max score  2048 Game score  44924
# Game #  356 Game length  1026 Max score  1024 Game score  16344
# Game #  357 Game length  1702 Max score  2048 Game score  31228
# Game #  358 Game length  1021 Max score  1024 Game score  16136
# Game #  359 Game length  1045 Max score  1024 Game score  16528
# Game #  360 Game length  2366 Max score  4096 Game score  48652
# Game #  361 Game length  922 Max score  1024 Game score  14732
# Game #  362 Game length  1685 Max score  2048 Game score  31080
# Game #  363 Game length  790 Max score  1024 Game score  12408
# Game #  364 Game length  1148 Max score  1024 Game score  18432
# Game #  365 Game length  931 Max score  1024 Game score  14828
# Game #  366 Game length  880 Max score  1024 Game score  13500
# Game #  367 Game length  1554 Max score  2048 Game score  27740
# Game #  368 Game length  969 Max score  1024 Game score  15268
# Game #  369 Game length  1303 Max score  2048 Game score  23676
# Game #  370 Game length  1797 Max score  2048 Game score  32768
# Game #  371 Game length  919 Max score  1024 Game score  14716
# Game #  372 Game length  1027 Max score  1024 Game score  16348
# Game #  373 Game length  641 Max score  512 Game score  8856
# Game #  374 Game length  519 Max score  512 Game score  7100
# Game #  375 Game length  1291 Max score  2048 Game score  23592
# Game #  376 Game length  1139 Max score  1024 Game score  17964
# Game #  377 Game length  1027 Max score  1024 Game score  16300
# Game #  378 Game length  1467 Max score  2048 Game score  25860
# Game #  379 Game length  1745 Max score  2048 Game score  32080
# Game #  380 Game length  573 Max score  512 Game score  7688
# Game #  381 Game length  1042 Max score  1024 Game score  16476
# Game #  382 Game length  543 Max score  512 Game score  7372
# Game #  383 Game length  1035 Max score  1024 Game score  16440
# Game #  384 Game length  854 Max score  1024 Game score  13180
# Game #  385 Game length  1053 Max score  1024 Game score  16584
# Game #  386 Game length  1360 Max score  2048 Game score  24232
# Game #  387 Game length  1217 Max score  1024 Game score  19416
# Game #  388 Game length  1042 Max score  1024 Game score  16476
# Game #  389 Game length  925 Max score  1024 Game score  14788
# Game #  390 Game length  1050 Max score  1024 Game score  16556
# Game #  391 Game length  1034 Max score  1024 Game score  16424
# Game #  392 Game length  1300 Max score  2048 Game score  23648
# Game #  393 Game length  957 Max score  1024 Game score  15136
# Game #  394 Game length  1801 Max score  2048 Game score  32800
# Game #  395 Game length  1248 Max score  1024 Game score  20944
# Game #  396 Game length  1075 Max score  1024 Game score  16844
# Game #  397 Game length  1582 Max score  2048 Game score  28168
# Game #  398 Game length  1287 Max score  1024 Game score  21516
# Game #  399 Game length  928 Max score  1024 Game score  14800
# Game #  400 Game length  1162 Max score  1024 Game score  18232
# Game #  401 Game length  1628 Max score  2048 Game score  28520
# Game #  402 Game length  1582 Max score  2048 Game score  28044
# Game #  403 Game length  1034 Max score  1024 Game score  16424
# Game #  404 Game length  594 Max score  512 Game score  8028
# Game #  405 Game length  1948 Max score  2048 Game score  35256
# Game #  406 Game length  1562 Max score  2048 Game score  27820
# Game #  407 Game length  1683 Max score  2048 Game score  31068
# Game #  408 Game length  1495 Max score  2048 Game score  27004
# Game #  409 Game length  911 Max score  1024 Game score  14652
# Game #  410 Game length  1910 Max score  2048 Game score  34392
# Game #  411 Game length  928 Max score  1024 Game score  14800
# Game #  412 Game length  801 Max score  1024 Game score  12588
# Game #  413 Game length  1522 Max score  2048 Game score  27416
# Game #  414 Game length  596 Max score  512 Game score  7896
# Game #  415 Game length  1092 Max score  1024 Game score  17164
# Game #  416 Game length  1183 Max score  1024 Game score  18392
# Game #  417 Game length  1963 Max score  2048 Game score  35452
# Game #  418 Game length  801 Max score  512 Game score  11484
# Game #  419 Game length  658 Max score  1024 Game score  10576
# Game #  420 Game length  1684 Max score  2048 Game score  30080
# Game #  421 Game length  2049 Max score  2048 Game score  36848
# Game #  422 Game length  551 Max score  512 Game score  7452
# Game #  423 Game length  1048 Max score  1024 Game score  16604
# Game #  424 Game length  1011 Max score  1024 Game score  16044
# Game #  425 Game length  1511 Max score  2048 Game score  27128
# Game #  426 Game length  1104 Max score  1024 Game score  17996
# Game #  427 Game length  418 Max score  512 Game score  5564
# Game #  428 Game length  593 Max score  512 Game score  8024
# Game #  429 Game length  1524 Max score  2048 Game score  26584
# Game #  430 Game length  1110 Max score  1024 Game score  17308
# Game #  431 Game length  1035 Max score  1024 Game score  16428
# Game #  432 Game length  1065 Max score  1024 Game score  16696
# Game #  433 Game length  1840 Max score  2048 Game score  33176
# Game #  434 Game length  1644 Max score  2048 Game score  28832
# Game #  435 Game length  987 Max score  1024 Game score  15760
# Game #  436 Game length  725 Max score  512 Game score  9880
# Game #  437 Game length  1958 Max score  2048 Game score  34908
# Game #  438 Game length  1578 Max score  2048 Game score  28012
# Game #  439 Game length  930 Max score  1024 Game score  14812
# Game #  440 Game length  1100 Max score  1024 Game score  17456
# Game #  441 Game length  1658 Max score  2048 Game score  29292
# Game #  442 Game length  571 Max score  512 Game score  7772
# Game #  443 Game length  1686 Max score  2048 Game score  29596
# Game #  444 Game length  1234 Max score  1024 Game score  19816
# Game #  445 Game length  1020 Max score  1024 Game score  16300
# Game #  446 Game length  975 Max score  1024 Game score  15688
# Game #  447 Game length  1513 Max score  2048 Game score  27148
# Game #  448 Game length  1104 Max score  1024 Game score  17264
# Game #  449 Game length  538 Max score  512 Game score  7308
# Game #  450 Game length  2017 Max score  2048 Game score  36328
# Game #  451 Game length  2094 Max score  2048 Game score  37292
# Game #  452 Game length  1047 Max score  1024 Game score  16540
# Game #  453 Game length  1369 Max score  2048 Game score  24736
# Game #  454 Game length  2686 Max score  4096 Game score  55484
# Game #  455 Game length  965 Max score  1024 Game score  15344
# Game #  456 Game length  1542 Max score  2048 Game score  27584
# Game #  457 Game length  1455 Max score  2048 Game score  26252
# Game #  458 Game length  813 Max score  1024 Game score  12648
# Game #  459 Game length  499 Max score  512 Game score  6924
# Game #  460 Game length  1076 Max score  1024 Game score  16824
# Game #  461 Game length  979 Max score  1024 Game score  15708
# Game #  462 Game length  1043 Max score  1024 Game score  16492
# Game #  463 Game length  1035 Max score  1024 Game score  16428
# Game #  464 Game length  959 Max score  1024 Game score  15244
# Game #  465 Game length  989 Max score  1024 Game score  15560
# Game #  466 Game length  815 Max score  1024 Game score  12600
# Game #  467 Game length  1059 Max score  1024 Game score  16796
# Game #  468 Game length  1042 Max score  1024 Game score  16476
# Game #  469 Game length  570 Max score  512 Game score  7720
# Game #  470 Game length  1818 Max score  2048 Game score  32952
# Game #  471 Game length  1332 Max score  2048 Game score  23976
# Game #  472 Game length  1577 Max score  2048 Game score  28380
# Game #  473 Game length  529 Max score  512 Game score  7248
# Game #  474 Game length  1098 Max score  1024 Game score  17196
# Game #  475 Game length  882 Max score  1024 Game score  14172
# Game #  476 Game length  930 Max score  1024 Game score  14896
# Game #  477 Game length  1554 Max score  2048 Game score  27752
# Game #  478 Game length  1047 Max score  1024 Game score  16540
# Game #  479 Game length  1003 Max score  1024 Game score  15932
# Game #  480 Game length  543 Max score  512 Game score  7372
# Game #  481 Game length  1033 Max score  1024 Game score  16416
# Game #  482 Game length  1117 Max score  1024 Game score  17440
# Game #  483 Game length  1663 Max score  2048 Game score  29388
# Game #  484 Game length  1651 Max score  2048 Game score  28856
# Game #  485 Game length  1095 Max score  1024 Game score  17432
# Game #  486 Game length  708 Max score  512 Game score  9560
# Game #  487 Game length  840 Max score  1024 Game score  12904
# Game #  488 Game length  1814 Max score  2048 Game score  32892
# Game #  489 Game length  1033 Max score  1024 Game score  16416
# Game #  490 Game length  1042 Max score  1024 Game score  16476
# Game #  491 Game length  1557 Max score  2048 Game score  27768
# Game #  492 Game length  1296 Max score  2048 Game score  23628
# Game #  493 Game length  1037 Max score  1024 Game score  16448
# Game #  494 Game length  1003 Max score  1024 Game score  15740
# Game #  495 Game length  1004 Max score  1024 Game score  16108
# Game #  496 Game length  1777 Max score  2048 Game score  32528
# Game #  497 Game length  1088 Max score  1024 Game score  16936
# Game #  498 Game length  1807 Max score  2048 Game score  32844
# Game #  499 Game length  1152 Max score  1024 Game score  18128
# Game #  500 Game length  1454 Max score  2048 Game score  26608
# Game #  501 Game length  1610 Max score  2048 Game score  28460
# Game #  502 Game length  675 Max score  512 Game score  9276
# Game #  503 Game length  1047 Max score  1024 Game score  16600
# Game #  504 Game length  1007 Max score  1024 Game score  16136
# Game #  505 Game length  1612 Max score  2048 Game score  28732
# Game #  506 Game length  642 Max score  512 Game score  8920
# Game #  507 Game length  1144 Max score  1024 Game score  17656
# Game #  508 Game length  1037 Max score  1024 Game score  16448
# Game #  509 Game length  1101 Max score  1024 Game score  17968
# Game #  510 Game length  1193 Max score  1024 Game score  19144
# Game #  511 Game length  2935 Max score  4096 Game score  59452
# Game #  512 Game length  2401 Max score  4096 Game score  49368
# Game #  513 Game length  801 Max score  1024 Game score  12512
# Game #  514 Game length  1695 Max score  2048 Game score  31180
# Game #  515 Game length  1043 Max score  1024 Game score  16492
# Game #  516 Game length  1552 Max score  2048 Game score  27728
# Game #  517 Game length  1535 Max score  2048 Game score  27532
# Game #  518 Game length  1099 Max score  1024 Game score  17116
# Game #  519 Game length  1302 Max score  1024 Game score  21656
# Game #  520 Game length  1023 Max score  1024 Game score  16268
# Game #  521 Game length  1440 Max score  2048 Game score  26064
# Game #  522 Game length  1051 Max score  1024 Game score  16620
# Game #  523 Game length  1074 Max score  1024 Game score  16756
# Game #  524 Game length  1387 Max score  2048 Game score  25388
# Game #  525 Game length  1054 Max score  1024 Game score  16588
# Game #  526 Game length  1099 Max score  1024 Game score  17404
# Game #  527 Game length  2357 Max score  4096 Game score  48592
# Game #  528 Game length  918 Max score  1024 Game score  14700
# Game #  529 Game length  1046 Max score  1024 Game score  16508
# Game #  530 Game length  1961 Max score  2048 Game score  35384
# Game #  531 Game length  1066 Max score  1024 Game score  16700
# Game #  532 Game length  1293 Max score  1024 Game score  21568
# Game #  533 Game length  583 Max score  512 Game score  7752
# Game #  534 Game length  658 Max score  512 Game score  9052
# Game #  535 Game length  1099 Max score  1024 Game score  17212
# Game #  536 Game length  1974 Max score  2048 Game score  35548
# Game #  537 Game length  2138 Max score  2048 Game score  37884
# Game #  538 Game length  980 Max score  1024 Game score  15712
# Game #  539 Game length  1041 Max score  1024 Game score  16508
# Game #  540 Game length  543 Max score  512 Game score  7372
# Game #  541 Game length  785 Max score  1024 Game score  12356
# Game #  542 Game length  1955 Max score  2048 Game score  35736
# Game #  543 Game length  2024 Max score  2048 Game score  36572
# Game #  544 Game length  2031 Max score  2048 Game score  36620
# Game #  545 Game length  1760 Max score  2048 Game score  32212
# Game #  546 Game length  1202 Max score  1024 Game score  19060
# Game #  547 Game length  1143 Max score  1024 Game score  17640
# Game #  548 Game length  1298 Max score  1024 Game score  20580
# Game #  549 Game length  1943 Max score  2048 Game score  35228
# Game #  550 Game length  1432 Max score  2048 Game score  25988
# Game #  551 Game length  1940 Max score  2048 Game score  35212
# Game #  552 Game length  1814 Max score  2048 Game score  32892
# Game #  553 Game length  1561 Max score  2048 Game score  27824
# Game #  554 Game length  1033 Max score  1024 Game score  16416
# Game #  555 Game length  2062 Max score  2048 Game score  36940
# Game #  556 Game length  1548 Max score  2048 Game score  27708
# Game #  557 Game length  1956 Max score  2048 Game score  35320
# Game #  558 Game length  1053 Max score  1024 Game score  16584
# Game #  559 Game length  478 Max score  512 Game score  6580
# Game #  560 Game length  597 Max score  512 Game score  8296
# Game #  561 Game length  1310 Max score  1024 Game score  20748
# Game #  562 Game length  874 Max score  1024 Game score  13252
# Game #  563 Game length  1744 Max score  2048 Game score  32076
# Game #  564 Game length  1011 Max score  1024 Game score  16156
# Game #  565 Game length  1060 Max score  1024 Game score  16632
# Game #  566 Game length  1569 Max score  2048 Game score  27952
# Game #  567 Game length  1021 Max score  1024 Game score  16304
# Game #  568 Game length  1032 Max score  1024 Game score  16412
# Game #  569 Game length  1989 Max score  2048 Game score  36072
# Game #  570 Game length  796 Max score  1024 Game score  12524
# Game #  571 Game length  2213 Max score  2048 Game score  40444
# Game #  572 Game length  676 Max score  1024 Game score  10720
# Game #  573 Game length  1064 Max score  1024 Game score  16736
# Game #  574 Game length  952 Max score  1024 Game score  15444
# Game #  575 Game length  1039 Max score  1024 Game score  16460
# Game #  576 Game length  732 Max score  1024 Game score  11664
# Game #  577 Game length  1042 Max score  1024 Game score  16476
# Game #  578 Game length  2056 Max score  2048 Game score  36896
# Game #  579 Game length  1935 Max score  2048 Game score  35148
# Game #  580 Game length  1844 Max score  2048 Game score  33208
# Game #  581 Game length  2060 Max score  2048 Game score  36928
# Game #  582 Game length  1610 Max score  2048 Game score  28712
# Game #  583 Game length  1043 Max score  1024 Game score  16492
# Game #  584 Game length  2074 Max score  2048 Game score  37052
# Game #  585 Game length  1060 Max score  1024 Game score  16716
# Game #  586 Game length  1052 Max score  1024 Game score  16576
# Game #  587 Game length  1005 Max score  1024 Game score  16124
# Game #  588 Game length  1041 Max score  1024 Game score  16472
# Game #  589 Game length  642 Max score  512 Game score  8500
# Game #  590 Game length  1049 Max score  1024 Game score  16524
# Game #  591 Game length  560 Max score  512 Game score  7568
# Game #  592 Game length  1755 Max score  2048 Game score  32172
# Game #  593 Game length  1741 Max score  2048 Game score  32060
# Game #  594 Game length  1884 Max score  2048 Game score  34480
# Game #  595 Game length  1845 Max score  2048 Game score  33240
# Game #  596 Game length  1408 Max score  2048 Game score  25740
# Game #  597 Game length  1042 Max score  1024 Game score  16512
# Game #  598 Game length  1077 Max score  1024 Game score  16968
# Game #  599 Game length  2062 Max score  2048 Game score  36968
# Game #  600 Game length  1032 Max score  1024 Game score  16412
# Game #  601 Game length  811 Max score  1024 Game score  12652
# Game #  602 Game length  1890 Max score  2048 Game score  34028
# Game #  603 Game length  1913 Max score  2048 Game score  34408
# Game #  604 Game length  1042 Max score  1024 Game score  16476
# Game #  605 Game length  2323 Max score  4096 Game score  48220
# Game #  606 Game length  1997 Max score  2048 Game score  36160
# Game #  607 Game length  1666 Max score  2048 Game score  30872
# Game #  608 Game length  1817 Max score  2048 Game score  32936
# Game #  609 Game length  1047 Max score  1024 Game score  16540
# Game #  610 Game length  927 Max score  1024 Game score  14772
# Game #  611 Game length  1999 Max score  2048 Game score  36172
# Game #  612 Game length  1588 Max score  2048 Game score  28088
# Game #  613 Game length  932 Max score  1024 Game score  14916
# Game #  614 Game length  819 Max score  1024 Game score  12704
# Game #  615 Game length  957 Max score  1024 Game score  15456
# Game #  616 Game length  1598 Max score  2048 Game score  28300
# Game #  617 Game length  1041 Max score  1024 Game score  16424
# Game #  618 Game length  660 Max score  1024 Game score  10588
# Game #  619 Game length  1042 Max score  1024 Game score  16476
# Game #  620 Game length  531 Max score  512 Game score  7260
# Game #  621 Game length  928 Max score  1024 Game score  14296
# Game #  622 Game length  1576 Max score  2048 Game score  28012
# Game #  623 Game length  1488 Max score  2048 Game score  26944
# Game #  624 Game length  556 Max score  512 Game score  7548
# Game #  625 Game length  537 Max score  512 Game score  7388
# Game #  626 Game length  587 Max score  512 Game score  7980
# Game #  627 Game length  544 Max score  512 Game score  7404
# Game #  628 Game length  1161 Max score  1024 Game score  18720
# Game #  629 Game length  1042 Max score  1024 Game score  16476
# Game #  630 Game length  1574 Max score  2048 Game score  28076
# Game #  631 Game length  976 Max score  1024 Game score  15692
# Game #  632 Game length  694 Max score  1024 Game score  10876
# Game #  633 Game length  565 Max score  512 Game score  7608
# Game #  634 Game length  1038 Max score  1024 Game score  16456
# Game #  635 Game length  1237 Max score  1024 Game score  19860
# Game #  636 Game length  927 Max score  1024 Game score  14796
# Game #  637 Game length  3021 Max score  4096 Game score  60736
# Game #  638 Game length  1534 Max score  2048 Game score  27576
# Game #  639 Game length  976 Max score  1024 Game score  15680
# Game #  640 Game length  1048 Max score  1024 Game score  16544
# Game #  641 Game length  1527 Max score  2048 Game score  27356
# Game #  642 Game length  543 Max score  512 Game score  7372
# Game #  643 Game length  1520 Max score  2048 Game score  27404
# Game #  644 Game length  1528 Max score  2048 Game score  27484
# Game #  645 Game length  838 Max score  1024 Game score  12988
# Game #  646 Game length  1442 Max score  2048 Game score  26076
# Game #  647 Game length  1836 Max score  2048 Game score  33152
# Game #  648 Game length  2101 Max score  2048 Game score  37520
# Game #  649 Game length  1515 Max score  2048 Game score  27368
# Game #  650 Game length  1756 Max score  2048 Game score  32188
# Game #  651 Game length  588 Max score  512 Game score  7816
# Game #  652 Game length  1493 Max score  2048 Game score  26648
# Game #  653 Game length  994 Max score  1024 Game score  15836
# Game #  654 Game length  561 Max score  512 Game score  7700
# Game #  655 Game length  1697 Max score  2048 Game score  31164
# Game #  656 Game length  927 Max score  1024 Game score  14796
# Game #  657 Game length  1557 Max score  2048 Game score  27792
# Game #  658 Game length  2072 Max score  2048 Game score  37032
# Game #  659 Game length  2648 Max score  4096 Game score  54908
# Game #  660 Game length  1035 Max score  1024 Game score  16412
# Game #  661 Game length  1072 Max score  1024 Game score  16792
# Game #  662 Game length  1057 Max score  1024 Game score  16632
# Game #  663 Game length  780 Max score  1024 Game score  12332
# Game #  664 Game length  1571 Max score  1024 Game score  25896
# Game #  665 Game length  2059 Max score  2048 Game score  36924
# Game #  666 Game length  934 Max score  1024 Game score  14904
# Game #  667 Game length  1045 Max score  1024 Game score  16532
# Game #  668 Game length  1202 Max score  1024 Game score  19228
# Game #  669 Game length  782 Max score  1024 Game score  12340
# Game #  670 Game length  1959 Max score  2048 Game score  35420
# Game #  671 Game length  1572 Max score  2048 Game score  27980
# Game #  672 Game length  854 Max score  1024 Game score  13936
# Game #  673 Game length  1053 Max score  1024 Game score  16584
# Game #  674 Game length  1907 Max score  2048 Game score  34844
# Game #  675 Game length  2038 Max score  2048 Game score  36668
# Game #  676 Game length  1947 Max score  2048 Game score  35248
# Game #  677 Game length  1548 Max score  2048 Game score  27696
# Game #  678 Game length  529 Max score  512 Game score  7248
# Game #  679 Game length  1997 Max score  2048 Game score  36160
# Game #  680 Game length  3056 Max score  4096 Game score  61200
# Game #  681 Game length  1803 Max score  2048 Game score  32812
# Game #  682 Game length  1536 Max score  2048 Game score  27596
# Game #  683 Game length  1110 Max score  1024 Game score  17616
# Game #  684 Game length  2770 Max score  4096 Game score  56672
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-28e1ea1759da> in <module>
#      22             model.cuda()
#      23
# ---> 24 train(model, optimizer, loss)
#
# <ipython-input-8-28e1ea1759da> in train(model, optimizer, loss, epoch, running_mean)
#      19                 'optimizer': optimizer.state_dict(),
#      20             }, filename)
# ---> 21             best_model, _, _, _ = load_model(model, optimizer, filename, True)
#      22             model.cuda()
#      23
#
# <ipython-input-7-36844a382121> in load_model(model, optimizer, checkpoint_path, model_only)
#       7
#       8 def load_model(model, optimizer, checkpoint_path, model_only = False):
# ----> 9     ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")
#      10
#      11     model.load_state_dict(ckpt_dict['state_dict'])
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     379             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     380         new_fd = True
# --> 381         f = open(f, 'rb')
#     382     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     383         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model2_score_6.pth.tar'

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

# %%
test(model)

# %%
test(best_model)
