# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=128, filter2=512, filter3=1024, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)

        self.conv_aaa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_aab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_aba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_abb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)

        self.conv_baa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_bba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bbb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_x = nn.Linear(input_size * 16, 1)
        self.W_a = nn.Linear(filter1 * 12, 1)
        self.W_b = nn.Linear(filter1 * 12, 1)

        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)

        self.W_aaa = nn.Linear(filter3 * 4, 1)
        self.W_aab = nn.Linear(filter3 * 6, 1)
        self.W_aba = nn.Linear(filter3 * 6, 1)
        self.W_abb = nn.Linear(filter3 * 6, 1)
        self.W_baa = nn.Linear(filter3 * 6, 1)
        self.W_bab = nn.Linear(filter3 * 6, 1)
        self.W_bba = nn.Linear(filter3 * 6, 1)
        self.W_bbb = nn.Linear(filter3 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        aa = self.relu(self.conv_aa(a))
        ab = self.relu(self.conv_ab(a))
        ba = self.relu(self.conv_ba(b))
        bb = self.relu(self.conv_bb(b))

        aaa = self.flatten(self.relu(self.conv_aaa(aa)))
        aab = self.flatten(self.relu(self.conv_aab(aa)))
        aba = self.flatten(self.relu(self.conv_aba(ab)))
        abb = self.flatten(self.relu(self.conv_abb(ab)))
        baa = self.flatten(self.relu(self.conv_baa(ba)))
        bab = self.flatten(self.relu(self.conv_bab(ba)))
        bba = self.flatten(self.relu(self.conv_bba(bb)))
        bbb = self.flatten(self.relu(self.conv_bbb(bb)))
        x = self.flatten(x)
        a = self.flatten(a)
        b = self.flatten(b)
        aa = self.flatten(aa)
        ab = self.flatten(ab)
        ba = self.flatten(ba)
        bb = self.flatten(bb)

        out = self.W_x(x) + self.W_a(a) + self.W_b(b) \
              + self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) \
              +  self.W_aaa(aaa) + self.W_aab(aab) + self.W_aba(aba) + self.W_abb(abb) \
              + self.W_baa(baa) + self.W_bab(bab) + self.W_bba(bba) + self.W_bbb(bbb)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def add_two_boards(board):
    indexs=np.argwhere(board==0)
    boards = []
    for index in indexs:
        new_board = board.copy()
        new_board[tuple(index)] = 1
        boards.append(new_board)
    return boards

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:     
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                new_board_list = add_two_boards(g)
                boards = np.array([make_input(b) for b in new_board_list])
                p = torch.mean(model(torch.from_numpy(boards).cuda())).detach() 
                v = (s - game_score) + p.item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = g
                    
        else:
            best_v = 0
            best_grid1 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y)
            last_loss = loss.item()
            loss.backward()
            optimizer.step()
            model.eval()
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = make_input(last_grid1)
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = make_input(last_grid1)
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 1e-3
weight_decay = 0
beta1 = 0.5

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)

# %%
def load_model(model, optimizer, checkpoint_path):
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    optimizer.load_state_dict(ckpt_dict['optimizer'])
    epoch = ckpt_dict['epoch']
    running_mean = ckpt_dict['running_mean']
    return model, optimizer, epoch, running_mean

# model, optimizer, epoch, running_mean = load_model(model, optimizer, "model/model7_2_12.pth.tar")

# %%
num_epochs = 3000

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
#     ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
#         ls.pop(0)
#         ls.append(max_score)
#         if sum(ls) / 10 > running_mean:
#             running_mean = sum(ls) / 10
#             filename = "model7_2_"+str(epoch // 100)+".pth.tar"
#             save_model({
#                 'epoch': epoch,
#                 'running_mean': running_mean,
#                 'state_dict': model.cpu().state_dict(),
#                 'optimizer': optimizer.state_dict(),
#             }, filename)
#             model.cuda()
    
    
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  90 Max score  32 Game score  576
# Game #  2 Game length  70 Max score  32 Game score  412
# Game #  3 Game length  71 Max score  32 Game score  416
# Game #  4 Game length  85 Max score  64 Game score  572
# Game #  5 Game length  161 Max score  128 Game score  1484
# Game #  6 Game length  59 Max score  32 Game score  316
# Game #  7 Game length  53 Max score  16 Game score  244
# Game #  8 Game length  70 Max score  32 Game score  412
# Game #  9 Game length  102 Max score  64 Game score  736
# Game #  10 Game length  141 Max score  128 Game score  1232
# Game #  11 Game length  176 Max score  128 Game score  1640
# Game #  12 Game length  260 Max score  256 Game score  2944
# Game #  13 Game length  293 Max score  256 Game score  3372
# Game #  14 Game length  316 Max score  256 Game score  3580
# Game #  15 Game length  92 Max score  64 Game score  644
# Game #  16 Game length  204 Max score  128 Game score  2060
# Game #  17 Game length  382 Max score  512 Game score  5092
# Game #  18 Game length  194 Max score  128 Game score  1936
# Game #  19 Game length  192 Max score  128 Game score  1916
# Game #  20 Game length  172 Max score  128 Game score  1600
# Game #  21 Game length  281 Max score  256 Game score  3188
# Game #  22 Game length  250 Max score  256 Game score  2760
# Game #  23 Game length  149 Max score  128 Game score  1340
# Game #  24 Game length  264 Max score  256 Game score  3020
# Game #  25 Game length  164 Max score  128 Game score  1500
# Game #  26 Game length  241 Max score  256 Game score  2700
# Game #  27 Game length  246 Max score  128 Game score  2512
# Game #  28 Game length  161 Max score  128 Game score  1456
# Game #  29 Game length  347 Max score  256 Game score  3988
# Game #  30 Game length  265 Max score  256 Game score  3008
# Game #  31 Game length  327 Max score  256 Game score  3736
# Game #  32 Game length  151 Max score  128 Game score  1380
# Game #  33 Game length  184 Max score  128 Game score  1712
# Game #  34 Game length  318 Max score  256 Game score  3592
# Game #  35 Game length  102 Max score  64 Game score  736
# Game #  36 Game length  277 Max score  256 Game score  3168
# Game #  37 Game length  233 Max score  256 Game score  2560
# Game #  38 Game length  176 Max score  128 Game score  1584
# Game #  39 Game length  552 Max score  512 Game score  7516
# Game #  40 Game length  448 Max score  256 Game score  5208
# Game #  41 Game length  117 Max score  64 Game score  920
# Game #  42 Game length  325 Max score  256 Game score  3640
# Game #  43 Game length  237 Max score  128 Game score  2416
# Game #  44 Game length  155 Max score  128 Game score  1412
# Game #  45 Game length  589 Max score  512 Game score  7820
# Game #  46 Game length  159 Max score  128 Game score  1460
# Game #  47 Game length  83 Max score  64 Game score  572
# Game #  48 Game length  186 Max score  128 Game score  1760
# Game #  49 Game length  253 Max score  256 Game score  2812
# Game #  50 Game length  315 Max score  256 Game score  3744
# Game #  51 Game length  134 Max score  64 Game score  1100
# Game #  52 Game length  113 Max score  64 Game score  832
# Game #  53 Game length  422 Max score  512 Game score  5612
# Game #  54 Game length  167 Max score  64 Game score  1416
# Game #  55 Game length  605 Max score  512 Game score  8136
# Game #  56 Game length  105 Max score  64 Game score  764
# Game #  57 Game length  545 Max score  512 Game score  7384
# Game #  58 Game length  480 Max score  512 Game score  6412
# Game #  59 Game length  497 Max score  256 Game score  6056
# Game #  60 Game length  705 Max score  1024 Game score  11028
# Game #  61 Game length  644 Max score  512 Game score  8536
# Game #  62 Game length  520 Max score  512 Game score  7188
# Game #  63 Game length  584 Max score  512 Game score  7964
# Game #  64 Game length  669 Max score  512 Game score  9160
# Game #  65 Game length  754 Max score  512 Game score  10524
# Game #  66 Game length  527 Max score  512 Game score  7240
# Game #  67 Game length  907 Max score  1024 Game score  14124
# Game #  68 Game length  620 Max score  512 Game score  8684
# Game #  69 Game length  981 Max score  1024 Game score  15728
# Game #  70 Game length  787 Max score  1024 Game score  12380
# Game #  71 Game length  986 Max score  1024 Game score  15756
# Game #  72 Game length  480 Max score  512 Game score  6604
# Game #  73 Game length  421 Max score  512 Game score  5608
# Game #  74 Game length  531 Max score  512 Game score  7260
# Game #  75 Game length  301 Max score  256 Game score  3392
# Game #  76 Game length  525 Max score  512 Game score  7228
# Game #  77 Game length  316 Max score  256 Game score  3628
# Game #  78 Game length  485 Max score  512 Game score  6640
# Game #  79 Game length  958 Max score  1024 Game score  15116
# Game #  80 Game length  1035 Max score  1024 Game score  16440
# Game #  81 Game length  529 Max score  512 Game score  7248
# Game #  82 Game length  933 Max score  1024 Game score  14840
# Game #  83 Game length  544 Max score  512 Game score  7388
# Game #  84 Game length  528 Max score  512 Game score  7244
# Game #  85 Game length  985 Max score  1024 Game score  15776
# Game #  86 Game length  567 Max score  512 Game score  7644
# Game #  87 Game length  846 Max score  1024 Game score  13128
# Game #  88 Game length  485 Max score  512 Game score  6392
# Game #  89 Game length  577 Max score  512 Game score  7720
# Game #  90 Game length  532 Max score  512 Game score  7264
# Game #  91 Game length  788 Max score  1024 Game score  12420
# Game #  92 Game length  986 Max score  1024 Game score  15840
# Game #  93 Game length  426 Max score  512 Game score  5644
# Game #  94 Game length  194 Max score  128 Game score  1936
# Game #  95 Game length  473 Max score  512 Game score  6528
# Game #  96 Game length  163 Max score  128 Game score  1492
# Game #  97 Game length  535 Max score  512 Game score  7292
# Game #  98 Game length  857 Max score  1024 Game score  13220
# Game #  99 Game length  280 Max score  256 Game score  3196
# Game #  100 Game length  534 Max score  512 Game score  7312
# Game #  101 Game length  585 Max score  512 Game score  7968
# Game #  102 Game length  958 Max score  1024 Game score  15536
# Game #  103 Game length  249 Max score  256 Game score  2864
# Game #  104 Game length  780 Max score  1024 Game score  12332
# Game #  105 Game length  918 Max score  1024 Game score  14700
# Game #  106 Game length  523 Max score  512 Game score  7208
# Game #  107 Game length  937 Max score  1024 Game score  14896
# Game #  108 Game length  563 Max score  512 Game score  7708
# Game #  109 Game length  799 Max score  1024 Game score  12492
# Game #  110 Game length  800 Max score  1024 Game score  12556
# Game #  111 Game length  543 Max score  512 Game score  7372
# Game #  112 Game length  481 Max score  512 Game score  6608
# Game #  113 Game length  526 Max score  512 Game score  7232
# Game #  114 Game length  1206 Max score  1024 Game score  19164
# Game #  115 Game length  539 Max score  512 Game score  7340
# Game #  116 Game length  977 Max score  1024 Game score  15472
# Game #  117 Game length  547 Max score  512 Game score  7404
# Game #  118 Game length  1010 Max score  1024 Game score  16028
# Game #  119 Game length  323 Max score  256 Game score  3620
# Game #  120 Game length  939 Max score  1024 Game score  14956
# Game #  121 Game length  1054 Max score  1024 Game score  16588
# Game #  122 Game length  1040 Max score  1024 Game score  16464
# Game #  123 Game length  813 Max score  1024 Game score  12660
# Game #  124 Game length  525 Max score  512 Game score  7216
# Game #  125 Game length  927 Max score  1024 Game score  14796
# Game #  126 Game length  555 Max score  512 Game score  7532
# Game #  127 Game length  859 Max score  1024 Game score  13244
# Game #  128 Game length  537 Max score  512 Game score  7328
# Game #  129 Game length  908 Max score  1024 Game score  14636
# Game #  130 Game length  534 Max score  512 Game score  7288
# Game #  131 Game length  522 Max score  512 Game score  7200
# Game #  132 Game length  1065 Max score  1024 Game score  16696
# Game #  133 Game length  850 Max score  1024 Game score  13904
# Game #  134 Game length  1420 Max score  2048 Game score  25840
# Game #  135 Game length  541 Max score  512 Game score  7360
# Game #  136 Game length  532 Max score  512 Game score  7264
# Game #  137 Game length  551 Max score  512 Game score  7452
# Game #  138 Game length  789 Max score  1024 Game score  12400
# Game #  139 Game length  525 Max score  512 Game score  7216
# Game #  140 Game length  516 Max score  512 Game score  7132
# Game #  143 Game length  1037 Max score  1024 Game score  16440
# Game #  144 Game length  785 Max score  1024 Game score  12368
# Game #  145 Game length  1437 Max score  2048 Game score  26048
# Game #  146 Game length  1422 Max score  2048 Game score  25920
# Game #  147 Game length  305 Max score  256 Game score  3596
# Game #  148 Game length  796 Max score  1024 Game score  12464
# Game #  149 Game length  1492 Max score  2048 Game score  26736
# Game #  150 Game length  583 Max score  512 Game score  7872
# Game #  151 Game length  1293 Max score  2048 Game score  23600
# Game #  152 Game length  793 Max score  1024 Game score  12424
# Game #  153 Game length  547 Max score  512 Game score  7396
# Game #  154 Game length  536 Max score  512 Game score  7324
# Game #  155 Game length  807 Max score  1024 Game score  12604
# Game #  156 Game length  869 Max score  1024 Game score  14064
# Game #  157 Game length  915 Max score  1024 Game score  14684
# Game #  158 Game length  1032 Max score  1024 Game score  16412
# Game #  159 Game length  1039 Max score  1024 Game score  16460
# Game #  160 Game length  1000 Max score  1024 Game score  15964
# Game #  161 Game length  324 Max score  512 Game score  4500
# Game #  162 Game length  305 Max score  256 Game score  3412
# Game #  163 Game length  807 Max score  1024 Game score  12604
# Game #  164 Game length  559 Max score  512 Game score  7676
# Game #  165 Game length  546 Max score  512 Game score  7388
# Game #  166 Game length  796 Max score  1024 Game score  12476
# Game #  167 Game length  1081 Max score  1024 Game score  16888
# Game #  168 Game length  1042 Max score  1024 Game score  16476
# Game #  169 Game length  535 Max score  512 Game score  7292
# Game #  170 Game length  1039 Max score  1024 Game score  16460
# Game #  171 Game length  1070 Max score  1024 Game score  16808
# Game #  172 Game length  997 Max score  1024 Game score  15920
# Game #  173 Game length  443 Max score  512 Game score  5964
# Game #  174 Game length  491 Max score  512 Game score  6880
# Game #  175 Game length  667 Max score  1024 Game score  10636
# Game #  176 Game length  1045 Max score  1024 Game score  16532
# Game #  177 Game length  636 Max score  512 Game score  8792
# Game #  178 Game length  1016 Max score  1024 Game score  16220
# Game #  179 Game length  1044 Max score  1024 Game score  16488
# Game #  180 Game length  824 Max score  1024 Game score  12768
# Game #  181 Game length  532 Max score  512 Game score  7276
# Game #  182 Game length  819 Max score  1024 Game score  12744
# Game #  183 Game length  556 Max score  512 Game score  7548
# Game #  184 Game length  944 Max score  1024 Game score  15116
# Game #  185 Game length  1034 Max score  1024 Game score  16424
# Game #  186 Game length  797 Max score  1024 Game score  12480
# Game #  187 Game length  1440 Max score  2048 Game score  26068
# Game #  188 Game length  856 Max score  1024 Game score  13948
# Game #  189 Game length  410 Max score  512 Game score  5512
# Game #  190 Game length  466 Max score  512 Game score  6480
# Game #  191 Game length  863 Max score  1024 Game score  13996
# Game #  192 Game length  1034 Max score  1024 Game score  16396
# Game #  193 Game length  531 Max score  512 Game score  7260
# Game #  194 Game length  480 Max score  512 Game score  6604
# Game #  195 Game length  1040 Max score  1024 Game score  16492
# Game #  196 Game length  858 Max score  1024 Game score  13960
# Game #  197 Game length  1004 Max score  1024 Game score  16080
# Game #  198 Game length  1039 Max score  1024 Game score  16460
# Game #  199 Game length  1035 Max score  1024 Game score  16428
# Game #  200 Game length  539 Max score  512 Game score  7340
# Game #  201 Game length  535 Max score  512 Game score  7292
# Game #  202 Game length  550 Max score  512 Game score  7480
# Game #  203 Game length  835 Max score  1024 Game score  13212
# Game #  204 Game length  782 Max score  1024 Game score  12352
# Game #  205 Game length  282 Max score  256 Game score  3208
# Game #  206 Game length  425 Max score  512 Game score  5640
# Game #  207 Game length  1008 Max score  1024 Game score  16140
# Game #  208 Game length  504 Max score  512 Game score  6972
# Game #  209 Game length  1036 Max score  1024 Game score  16432
# Game #  210 Game length  540 Max score  512 Game score  7356
# Game #  211 Game length  588 Max score  512 Game score  8740
# Game #  212 Game length  1013 Max score  1024 Game score  16080
# Game #  213 Game length  1032 Max score  1024 Game score  16412
# Game #  214 Game length  668 Max score  1024 Game score  10640
# Game #  215 Game length  1569 Max score  2048 Game score  27880
# Game #  216 Game length  405 Max score  512 Game score  5472
# Game #  217 Game length  721 Max score  1024 Game score  11344
# Game #  218 Game length  1012 Max score  1024 Game score  16160
# Game #  219 Game length  131 Max score  64 Game score  1020
# Game #  220 Game length  130 Max score  128 Game score  1152
# Game #  221 Game length  124 Max score  64 Game score  960
# Game #  222 Game length  160 Max score  128 Game score  1468
# Game #  223 Game length  118 Max score  64 Game score  904
# Game #  224 Game length  143 Max score  128 Game score  1244
# Game #  225 Game length  130 Max score  64 Game score  1040
# Game #  226 Game length  132 Max score  64 Game score  1052
# Game #  227 Game length  120 Max score  64 Game score  940
# Game #  228 Game length  221 Max score  256 Game score  2448
# Game #  229 Game length  286 Max score  256 Game score  3312
# Game #  230 Game length  162 Max score  64 Game score  1368
# Game #  231 Game length  258 Max score  128 Game score  2672
# Game #  232 Game length  249 Max score  256 Game score  2752
# Game #  233 Game length  162 Max score  64 Game score  1364
# Game #  234 Game length  555 Max score  512 Game score  7532
# Game #  235 Game length  164 Max score  128 Game score  1556
# Game #  236 Game length  197 Max score  128 Game score  1832
# Game #  237 Game length  258 Max score  256 Game score  2840
# Game #  238 Game length  128 Max score  64 Game score  1020
# Game #  239 Game length  178 Max score  128 Game score  1680
# Game #  240 Game length  208 Max score  128 Game score  1996
# Game #  241 Game length  146 Max score  64 Game score  1176
# Game #  242 Game length  200 Max score  128 Game score  1884
# Game #  243 Game length  197 Max score  128 Game score  1900
# Game #  244 Game length  143 Max score  64 Game score  1180
# Game #  245 Game length  125 Max score  64 Game score  1004
# Game #  246 Game length  179 Max score  128 Game score  1712
# Game #  247 Game length  240 Max score  256 Game score  2692
# Game #  248 Game length  186 Max score  256 Game score  2096
# Game #  249 Game length  158 Max score  64 Game score  1336
# Game #  250 Game length  162 Max score  64 Game score  1392
# Game #  251 Game length  772 Max score  512 Game score  11064
# Game #  252 Game length  679 Max score  1024 Game score  10928
# Game #  253 Game length  801 Max score  1024 Game score  12504
# Game #  254 Game length  625 Max score  512 Game score  8600
# Game #  255 Game length  524 Max score  512 Game score  7212
# Game #  256 Game length  797 Max score  1024 Game score  12472
# Game #  257 Game length  888 Max score  1024 Game score  14300
# Game #  258 Game length  702 Max score  1024 Game score  11004
# Game #  259 Game length  136 Max score  128 Game score  1196
# Game #  260 Game length  206 Max score  256 Game score  2336
# Game #  261 Game length  149 Max score  128 Game score  1360
# Game #  262 Game length  301 Max score  256 Game score  3564
# Game #  263 Game length  547 Max score  512 Game score  7452
# Game #  264 Game length  385 Max score  512 Game score  5260
# Game #  265 Game length  278 Max score  256 Game score  3200
# Game #  266 Game length  259 Max score  256 Game score  2956
# Game #  267 Game length  316 Max score  256 Game score  3572
# Game #  268 Game length  305 Max score  256 Game score  3472
# Game #  269 Game length  302 Max score  256 Game score  3400
# Game #  270 Game length  478 Max score  512 Game score  6368
# Game #  271 Game length  758 Max score  1024 Game score  11984
# Game #  272 Game length  671 Max score  1024 Game score  10684
# Game #  273 Game length  477 Max score  512 Game score  6576
# Game #  274 Game length  190 Max score  256 Game score  2128
# Game #  275 Game length  283 Max score  256 Game score  3236
# Game #  276 Game length  166 Max score  128 Game score  1512
# Game #  277 Game length  479 Max score  512 Game score  6588
# Game #  278 Game length  908 Max score  1024 Game score  14636
# Game #  279 Game length  797 Max score  512 Game score  11464
# Game #  280 Game length  516 Max score  512 Game score  7132
# Game #  281 Game length  399 Max score  512 Game score  5428
# Game #  282 Game length  476 Max score  512 Game score  6572
# Game #  283 Game length  525 Max score  512 Game score  7216
# Game #  284 Game length  527 Max score  512 Game score  7228
# Game #  285 Game length  596 Max score  512 Game score  8796
# Game #  286 Game length  738 Max score  1024 Game score  11736
# Game #  287 Game length  724 Max score  1024 Game score  11612
# Game #  288 Game length  466 Max score  512 Game score  6480
# Game #  289 Game length  274 Max score  256 Game score  3152
# Game #  290 Game length  513 Max score  512 Game score  7056
# Game #  291 Game length  309 Max score  256 Game score  3496
# Game #  292 Game length  430 Max score  512 Game score  5872
# Game #  293 Game length  529 Max score  512 Game score  7248
# Game #  294 Game length  656 Max score  512 Game score  9536
# Game #  295 Game length  724 Max score  1024 Game score  11360
# Game #  296 Game length  491 Max score  512 Game score  6760
# Game #  297 Game length  401 Max score  512 Game score  5452
# Game #  298 Game length  529 Max score  512 Game score  7248
# Game #  299 Game length  443 Max score  512 Game score  5852
# Game #  301 Game length  928 Max score  1024 Game score  14800
# Game #  302 Game length  542 Max score  512 Game score  7368
# Game #  303 Game length  369 Max score  512 Game score  5116
# Game #  304 Game length  640 Max score  1024 Game score  10364
# Game #  305 Game length  658 Max score  1024 Game score  10576
# Game #  306 Game length  161 Max score  128 Game score  1484
# Game #  307 Game length  488 Max score  512 Game score  6836
# Game #  308 Game length  512 Max score  512 Game score  7052
# Game #  309 Game length  528 Max score  512 Game score  7244
# Game #  310 Game length  1007 Max score  1024 Game score  16124
# Game #  311 Game length  538 Max score  512 Game score  7336
# Game #  312 Game length  785 Max score  1024 Game score  12380
# Game #  313 Game length  927 Max score  1024 Game score  14796
# Game #  314 Game length  599 Max score  512 Game score  8092
# Game #  315 Game length  954 Max score  1024 Game score  15196
# Game #  316 Game length  521 Max score  512 Game score  7196
# Game #  317 Game length  1552 Max score  2048 Game score  27728
# Game #  318 Game length  1038 Max score  1024 Game score  16456
# Game #  319 Game length  502 Max score  512 Game score  6960
# Game #  320 Game length  517 Max score  512 Game score  7136
# Game #  321 Game length  975 Max score  1024 Game score  15436
# Game #  322 Game length  1494 Max score  2048 Game score  27000
# Game #  323 Game length  546 Max score  512 Game score  7388
# Game #  324 Game length  829 Max score  1024 Game score  12808
# Game #  325 Game length  1427 Max score  2048 Game score  25948
# Game #  326 Game length  1015 Max score  1024 Game score  16092
# Game #  327 Game length  1487 Max score  2048 Game score  26952
# Game #  328 Game length  944 Max score  1024 Game score  14992
# Game #  329 Game length  524 Max score  512 Game score  7212
# Game #  330 Game length  771 Max score  1024 Game score  12188
# Game #  331 Game length  782 Max score  1024 Game score  12352
# Game #  332 Game length  591 Max score  512 Game score  8012
# Game #  335 Game length  1432 Max score  2048 Game score  26012
# Game #  336 Game length  548 Max score  512 Game score  7436
# Game #  337 Game length  531 Max score  512 Game score  7260
# Game #  338 Game length  814 Max score  1024 Game score  12680
# Game #  339 Game length  926 Max score  1024 Game score  14792
# Game #  340 Game length  1007 Max score  1024 Game score  16124
# Game #  341 Game length  939 Max score  1024 Game score  14956
# Game #  342 Game length  918 Max score  512 Game score  13188
# Game #  343 Game length  800 Max score  1024 Game score  12556
# Game #  344 Game length  1010 Max score  1024 Game score  16152
# Game #  345 Game length  965 Max score  1024 Game score  15612
# Game #  346 Game length  824 Max score  1024 Game score  12772
# Game #  347 Game length  1295 Max score  2048 Game score  23612
# Game #  348 Game length  1008 Max score  1024 Game score  16140
# Game #  349 Game length  1551 Max score  2048 Game score  27724
# Game #  350 Game length  958 Max score  1024 Game score  15488
# Game #  351 Game length  279 Max score  256 Game score  3180
# Game #  352 Game length  819 Max score  1024 Game score  12656
# Game #  353 Game length  799 Max score  1024 Game score  12492
# Game #  354 Game length  947 Max score  1024 Game score  15036
# Game #  355 Game length  515 Max score  512 Game score  7068
# Game #  356 Game length  464 Max score  512 Game score  6468
# Game #  357 Game length  498 Max score  512 Game score  6928
# Game #  358 Game length  981 Max score  1024 Game score  15480
# Game #  359 Game length  1022 Max score  1024 Game score  16140
# Game #  360 Game length  541 Max score  512 Game score  7360
# Game #  361 Game length  1533 Max score  2048 Game score  27512
# Game #  362 Game length  1814 Max score  2048 Game score  32892
# Game #  363 Game length  515 Max score  512 Game score  7068
# Game #  364 Game length  1048 Max score  1024 Game score  16520
# Game #  365 Game length  1998 Max score  2048 Game score  36168
# Game #  366 Game length  2344 Max score  2048 Game score  42356
# Game #  367 Game length  1095 Max score  1024 Game score  17180
# Game #  368 Game length  927 Max score  1024 Game score  14796
# Game #  369 Game length  1408 Max score  2048 Game score  25740
# Game #  370 Game length  813 Max score  1024 Game score  12664
# Game #  371 Game length  1737 Max score  2048 Game score  32028
# Game #  372 Game length  1461 Max score  2048 Game score  26656
# Game #  373 Game length  1556 Max score  2048 Game score  27760
# Game #  374 Game length  1050 Max score  1024 Game score  16616
# Game #  375 Game length  520 Max score  512 Game score  7188
# Game #  376 Game length  893 Max score  1024 Game score  14448
# Game #  377 Game length  739 Max score  1024 Game score  11740
# Game #  378 Game length  726 Max score  1024 Game score  11620
# Game #  379 Game length  972 Max score  1024 Game score  15660
# Game #  380 Game length  1576 Max score  2048 Game score  28000
# Game #  381 Game length  1225 Max score  1024 Game score  19744
# Game #  382 Game length  984 Max score  1024 Game score  15744
# Game #  383 Game length  753 Max score  1024 Game score  11920
# Game #  384 Game length  1079 Max score  1024 Game score  16988
# Game #  385 Game length  994 Max score  1024 Game score  15836
# Game #  386 Game length  953 Max score  1024 Game score  15080
# Game #  387 Game length  672 Max score  1024 Game score  10688
# Game #  388 Game length  684 Max score  512 Game score  9096
# Game #  389 Game length  823 Max score  1024 Game score  12764
# Game #  390 Game length  1009 Max score  1024 Game score  16148
# Game #  391 Game length  862 Max score  1024 Game score  13260
# Game #  392 Game length  660 Max score  512 Game score  9088
# Game #  393 Game length  520 Max score  512 Game score  7188
# Game #  394 Game length  759 Max score  1024 Game score  11964
# Game #  395 Game length  683 Max score  512 Game score  9676
# Game #  396 Game length  1073 Max score  1024 Game score  16824
# Game #  397 Game length  974 Max score  1024 Game score  15680
# Game #  398 Game length  754 Max score  1024 Game score  12036
# Game #  399 Game length  378 Max score  512 Game score  5184
# Game #  400 Game length  409 Max score  256 Game score  5024
# Game #  401 Game length  413 Max score  256 Game score  5048
# Game #  402 Game length  228 Max score  256 Game score  2524
# Game #  403 Game length  502 Max score  512 Game score  6948
# Game #  404 Game length  405 Max score  512 Game score  5472
# Game #  405 Game length  522 Max score  512 Game score  7200
# Game #  406 Game length  514 Max score  512 Game score  7064
# Game #  407 Game length  397 Max score  256 Game score  4912
# Game #  408 Game length  444 Max score  512 Game score  5996
# Game #  409 Game length  786 Max score  1024 Game score  12400
# Game #  410 Game length  1000 Max score  1024 Game score  15964
# Game #  411 Game length  875 Max score  1024 Game score  13676
# Game #  412 Game length  1320 Max score  1024 Game score  20876
# Game #  413 Game length  529 Max score  512 Game score  7240
# Game #  414 Game length  1021 Max score  1024 Game score  16304
# Game #  415 Game length  879 Max score  1024 Game score  14336
# Game #  416 Game length  790 Max score  1024 Game score  12408
# Game #  417 Game length  727 Max score  1024 Game score  11628
# Game #  418 Game length  459 Max score  256 Game score  5924
# Game #  419 Game length  414 Max score  256 Game score  5052
# Game #  420 Game length  520 Max score  512 Game score  7104
# Game #  421 Game length  517 Max score  512 Game score  7136
# Game #  422 Game length  557 Max score  512 Game score  7552
# Game #  423 Game length  544 Max score  512 Game score  7380
# Game #  424 Game length  818 Max score  1024 Game score  12700
# Game #  425 Game length  855 Max score  1024 Game score  13212
# Game #  426 Game length  778 Max score  1024 Game score  12284
# Game #  427 Game length  922 Max score  1024 Game score  14816
# Game #  428 Game length  784 Max score  512 Game score  11344
# Game #  429 Game length  1303 Max score  2048 Game score  23676
# Game #  430 Game length  588 Max score  512 Game score  7816
# Game #  431 Game length  94 Max score  64 Game score  656
# Game #  432 Game length  240 Max score  256 Game score  2636
# Game #  433 Game length  87 Max score  64 Game score  596
# Game #  434 Game length  121 Max score  64 Game score  944
# Game #  435 Game length  125 Max score  64 Game score  976
# Game #  436 Game length  111 Max score  64 Game score  796
# Game #  437 Game length  152 Max score  128 Game score  1396
# Game #  438 Game length  110 Max score  64 Game score  788
# Game #  439 Game length  186 Max score  128 Game score  1856
# Game #  440 Game length  162 Max score  128 Game score  1488
# Game #  441 Game length  165 Max score  128 Game score  1504
# Game #  442 Game length  187 Max score  128 Game score  1680
# Game #  443 Game length  163 Max score  128 Game score  1484
# Game #  444 Game length  189 Max score  128 Game score  1704
# Game #  445 Game length  295 Max score  256 Game score  3312
# Game #  446 Game length  276 Max score  256 Game score  3164
# Game #  447 Game length  541 Max score  512 Game score  7352
# Game #  448 Game length  224 Max score  128 Game score  2128
# Game #  449 Game length  503 Max score  512 Game score  6836
# Game #  450 Game length  278 Max score  256 Game score  3088
# Game #  451 Game length  306 Max score  256 Game score  3468
# Game #  452 Game length  390 Max score  512 Game score  5296
# Game #  453 Game length  186 Max score  128 Game score  1732
# Game #  454 Game length  282 Max score  256 Game score  3108
# Game #  455 Game length  430 Max score  512 Game score  5752
# Game #  456 Game length  229 Max score  256 Game score  2528
# Game #  457 Game length  279 Max score  256 Game score  3216
# Game #  458 Game length  173 Max score  128 Game score  1644
# Game #  459 Game length  223 Max score  128 Game score  2236
# Game #  460 Game length  317 Max score  256 Game score  3672
# Game #  461 Game length  157 Max score  128 Game score  1424
# Game #  462 Game length  185 Max score  128 Game score  1756
# Game #  463 Game length  391 Max score  256 Game score  4508
# Game #  464 Game length  192 Max score  128 Game score  1804
# Game #  465 Game length  182 Max score  128 Game score  1824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-9c034cc52181> in <module>
#      21
#      22
# ---> 23 train(model, optimizer, loss)
#
# <ipython-input-18-9c034cc52181> in train(model, optimizer, loss, epoch, running_mean)
#       5     while epoch != num_epochs:
#       6         epoch += 1
# ----> 7         game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
#       8         print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
#       9 #         ls.pop(0)
#
# <ipython-input-16-22e586078473> in gen_sample_and_learn(model, optimizer, loss_fn, is_train, explorationProb)
#      51             last_loss = loss.item()
#      52             loss.backward()
# ---> 53             optimizer.step()
#      54             model.eval()
#      55
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     105                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     106
# --> 107                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     108
#     109         return loss
#
# KeyboardInterrupt:

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

test(model)
# Out:
# Game #  1 Game length  1653 Max score  2048 Game score  28892
# Game #  2 Game length  1581 Max score  2048 Game score  28040
# Game #  3 Game length  3463 Max score  4096 Game score  70908
# Game #  4 Game length  2184 Max score  2048 Game score  40220
# Game #  5 Game length  3940 Max score  4096 Game score  79608
# Game #  6 Game length  3555 Max score  4096 Game score  70220
# Game #  7 Game length  2075 Max score  2048 Game score  37060
# Game #  8 Game length  571 Max score  512 Game score  7676
# Game #  9 Game length  2077 Max score  2048 Game score  37072
# Game #  10 Game length  2354 Max score  2048 Game score  44460
# Game #  11 Game length  1844 Max score  2048 Game score  33236
# Game #  12 Game length  2076 Max score  2048 Game score  37064
# Game #  13 Game length  2148 Max score  2048 Game score  37976
# Game #  14 Game length  1862 Max score  2048 Game score  33436
# Game #  15 Game length  2057 Max score  2048 Game score  36904
# Game #  16 Game length  2149 Max score  2048 Game score  39672
# Game #  17 Game length  2221 Max score  2048 Game score  39180
# Game #  18 Game length  1801 Max score  1024 Game score  29740
# Game #  19 Game length  1415 Max score  2048 Game score  25340
# Game #  20 Game length  1965 Max score  2048 Game score  35464
# Game #  21 Game length  2050 Max score  2048 Game score  36828
# Game #  22 Game length  3499 Max score  4096 Game score  71236
# Game #  23 Game length  2610 Max score  2048 Game score  48588
# Game #  24 Game length  2118 Max score  2048 Game score  37660
# Game #  25 Game length  2070 Max score  2048 Game score  37020
# Game #  26 Game length  2963 Max score  4096 Game score  59756
# Game #  27 Game length  2964 Max score  4096 Game score  59752
# Game #  28 Game length  2035 Max score  2048 Game score  36652
# Game #  29 Game length  2124 Max score  2048 Game score  37704
# Game #  30 Game length  2093 Max score  2048 Game score  37260
# Game #  31 Game length  2154 Max score  2048 Game score  38020
# Game #  32 Game length  558 Max score  512 Game score  7560
# Game #  33 Game length  1610 Max score  2048 Game score  28472
# Game #  34 Game length  2939 Max score  4096 Game score  58632
# Game #  35 Game length  2307 Max score  2048 Game score  41784
# Game #  36 Game length  3106 Max score  4096 Game score  61768
# Game #  37 Game length  1807 Max score  2048 Game score  32844
# Game #  38 Game length  2925 Max score  4096 Game score  59240
# Game #  39 Game length  1957 Max score  2048 Game score  35412
# Game #  40 Game length  2032 Max score  2048 Game score  36628
# Game #  41 Game length  3001 Max score  4096 Game score  60572
# Game #  42 Game length  2061 Max score  2048 Game score  36936
# Game #  43 Game length  1961 Max score  2048 Game score  35432
# Game #  44 Game length  1569 Max score  2048 Game score  27880
# Game #  45 Game length  3080 Max score  4096 Game score  61476
# Game #  46 Game length  2092 Max score  2048 Game score  37256
# Game #  47 Game length  763 Max score  512 Game score  10248
# Game #  48 Game length  2098 Max score  2048 Game score  37324
# Game #  49 Game length  2171 Max score  2048 Game score  38616
# Game #  50 Game length  2017 Max score  2048 Game score  36316
# Game #  51 Game length  2063 Max score  2048 Game score  36944
# Game #  52 Game length  3640 Max score  4096 Game score  73208
# Game #  53 Game length  2180 Max score  2048 Game score  38424
# Game #  54 Game length  1855 Max score  2048 Game score  33484
# Game #  55 Game length  2311 Max score  2048 Game score  42012
# Game #  56 Game length  1995 Max score  2048 Game score  36140
# Game #  57 Game length  2182 Max score  2048 Game score  39192
# Game #  58 Game length  2086 Max score  2048 Game score  37212
# Game #  59 Game length  1864 Max score  2048 Game score  33820
# Game #  60 Game length  3382 Max score  4096 Game score  69180
# Game #  61 Game length  1801 Max score  2048 Game score  32800
# Game #  62 Game length  1989 Max score  2048 Game score  36108
# Game #  63 Game length  2074 Max score  2048 Game score  37052
# Game #  64 Game length  1678 Max score  2048 Game score  29180
# Game #  65 Game length  2009 Max score  2048 Game score  36264
# Game #  66 Game length  2094 Max score  2048 Game score  37388
# Game #  67 Game length  1147 Max score  1024 Game score  17672
# Game #  68 Game length  1504 Max score  2048 Game score  27088
# Game #  69 Game length  1976 Max score  2048 Game score  35932
# Game #  70 Game length  1380 Max score  1024 Game score  21592
# Game #  71 Game length  3861 Max score  4096 Game score  77976
# Game #  72 Game length  2213 Max score  2048 Game score  39004
# Game #  73 Game length  2268 Max score  2048 Game score  40392
# Game #  74 Game length  1561 Max score  2048 Game score  27816
# Game #  75 Game length  1847 Max score  2048 Game score  33248
# Game #  76 Game length  3280 Max score  4096 Game score  64136
# Game #  77 Game length  1966 Max score  2048 Game score  35468
# Game #  78 Game length  2106 Max score  2048 Game score  37380
# Game #  79 Game length  1957 Max score  2048 Game score  35408
# Game #  80 Game length  2057 Max score  2048 Game score  36904
# Game #  81 Game length  2604 Max score  2048 Game score  48520
# Game #  82 Game length  3286 Max score  4096 Game score  64924
# Game #  83 Game length  2041 Max score  2048 Game score  36712
# Game #  84 Game length  2058 Max score  2048 Game score  36908
# Game #  85 Game length  1133 Max score  1024 Game score  17800
# Game #  86 Game length  2983 Max score  4096 Game score  59968
# Game #  87 Game length  2016 Max score  2048 Game score  36312
# Game #  88 Game length  1352 Max score  2048 Game score  24224
# Game #  89 Game length  2054 Max score  2048 Game score  36888
# Game #  90 Game length  1575 Max score  2048 Game score  27996
# Game #  91 Game length  1656 Max score  2048 Game score  28920
# Game #  92 Game length  3640 Max score  4096 Game score  73208
# Game #  93 Game length  1681 Max score  2048 Game score  31056
# Game #  94 Game length  3096 Max score  4096 Game score  61608
# Game #  95 Game length  2644 Max score  2048 Game score  50784
# Game #  96 Game length  2296 Max score  2048 Game score  40696
# Game #  97 Game length  2594 Max score  4096 Game score  52476
# Game #  98 Game length  2212 Max score  2048 Game score  39000
# Game #  99 Game length  2988 Max score  4096 Game score  59976
# Game #  100 Game length  736 Max score  512 Game score  9960

# %%
for i in range(4, 12):
    if i != 9:
        model, optimizer, epoch, running_mean = load_model(model, optimizer, "model/model7_2_"+str(i)+".pth.tar")
        print("model #", i)
        test(model)
# Out:
# model # 4
# Game #  1 Game length  2034 Max score  2048 Game score  36636
# Game #  2 Game length  1836 Max score  2048 Game score  33096
# Game #  3 Game length  1480 Max score  2048 Game score  26472
# Game #  4 Game length  1136 Max score  1024 Game score  17768
# Game #  5 Game length  1147 Max score  1024 Game score  18092
# Game #  6 Game length  1882 Max score  2048 Game score  33964
# Game #  7 Game length  1514 Max score  2048 Game score  27212
# Game #  8 Game length  2031 Max score  2048 Game score  36620
# Game #  9 Game length  1967 Max score  2048 Game score  35596
# Game #  10 Game length  1935 Max score  2048 Game score  35148
# Game #  11 Game length  770 Max score  1024 Game score  12240
# Game #  12 Game length  1039 Max score  1024 Game score  16460
# Game #  13 Game length  766 Max score  1024 Game score  12152
# Game #  14 Game length  657 Max score  512 Game score  9552
# Game #  15 Game length  1113 Max score  1024 Game score  17576
# Game #  16 Game length  2031 Max score  2048 Game score  36620
# Game #  17 Game length  2113 Max score  2048 Game score  37596
# Game #  18 Game length  1561 Max score  2048 Game score  27816
# Game #  19 Game length  1824 Max score  2048 Game score  32984
# Game #  20 Game length  2940 Max score  4096 Game score  59516
# Game #  21 Game length  1035 Max score  1024 Game score  16428
# Game #  22 Game length  511 Max score  512 Game score  7096
# Game #  23 Game length  940 Max score  1024 Game score  14904
# Game #  24 Game length  1040 Max score  1024 Game score  16464
# Game #  25 Game length  1328 Max score  1024 Game score  20920
# Game #  26 Game length  674 Max score  1024 Game score  10712
# Game #  27 Game length  1083 Max score  1024 Game score  16900
# Game #  28 Game length  1920 Max score  2048 Game score  34840
# Game #  29 Game length  2023 Max score  2048 Game score  36444
# Game #  30 Game length  1083 Max score  1024 Game score  16840
# Game #  31 Game length  1611 Max score  2048 Game score  28328
# Game #  32 Game length  1636 Max score  2048 Game score  29088
# Game #  33 Game length  1166 Max score  1024 Game score  18748
# Game #  34 Game length  2108 Max score  2048 Game score  37808
# Game #  35 Game length  2106 Max score  2048 Game score  37548
# Game #  36 Game length  1990 Max score  2048 Game score  35836
# Game #  37 Game length  1534 Max score  2048 Game score  27528
# Game #  38 Game length  2510 Max score  4096 Game score  51148
# Game #  39 Game length  1137 Max score  1024 Game score  17940
# Game #  40 Game length  1167 Max score  1024 Game score  18764
# Game #  41 Game length  1165 Max score  1024 Game score  18248
# Game #  42 Game length  926 Max score  1024 Game score  14284
# Game #  43 Game length  661 Max score  1024 Game score  10592
# Game #  44 Game length  1195 Max score  1024 Game score  19068
# Game #  45 Game length  1544 Max score  2048 Game score  27676
# Game #  46 Game length  1611 Max score  2048 Game score  28296
# Game #  47 Game length  2260 Max score  2048 Game score  40984
# Game #  48 Game length  1064 Max score  1024 Game score  16736
# Game #  49 Game length  1782 Max score  2048 Game score  31548
# Game #  50 Game length  1426 Max score  2048 Game score  25940
# Game #  51 Game length  892 Max score  1024 Game score  14444
# Game #  52 Game length  1713 Max score  2048 Game score  31504
# Game #  53 Game length  980 Max score  1024 Game score  15712
# Game #  54 Game length  1380 Max score  1024 Game score  21592
# Game #  55 Game length  1315 Max score  1024 Game score  20728
# Game #  56 Game length  2590 Max score  4096 Game score  52428
# Game #  57 Game length  1302 Max score  1024 Game score  21628
# Game #  58 Game length  571 Max score  512 Game score  7724
# Game #  59 Game length  461 Max score  512 Game score  6444
# Game #  60 Game length  1288 Max score  1024 Game score  20512
# Game #  61 Game length  1804 Max score  2048 Game score  32816
# Game #  62 Game length  1086 Max score  1024 Game score  16916
# Game #  63 Game length  1569 Max score  2048 Game score  27880
# Game #  64 Game length  2542 Max score  2048 Game score  45836
# Game #  65 Game length  1204 Max score  1024 Game score  18660
# Game #  66 Game length  2489 Max score  2048 Game score  44796
# Game #  67 Game length  528 Max score  512 Game score  7244
# Game #  68 Game length  1740 Max score  1024 Game score  28996
# Game #  69 Game length  1232 Max score  2048 Game score  22852
# Game #  70 Game length  2027 Max score  2048 Game score  36168
# Game #  71 Game length  1040 Max score  1024 Game score  16476
# Game #  72 Game length  975 Max score  1024 Game score  15676
# Game #  73 Game length  1948 Max score  2048 Game score  34760
# Game #  74 Game length  2662 Max score  4096 Game score  53592
# Game #  75 Game length  2115 Max score  2048 Game score  37560
# Game #  76 Game length  949 Max score  1024 Game score  15032
# Game #  77 Game length  1504 Max score  2048 Game score  27088
# Game #  78 Game length  1546 Max score  2048 Game score  27688
# Game #  79 Game length  2715 Max score  4096 Game score  55724
# Game #  80 Game length  1745 Max score  2048 Game score  31064
# Game #  81 Game length  1039 Max score  1024 Game score  16460
# Game #  82 Game length  1032 Max score  1024 Game score  16412
# Game #  83 Game length  474 Max score  512 Game score  6532
# Game #  84 Game length  1736 Max score  2048 Game score  30248
# Game #  85 Game length  823 Max score  1024 Game score  12764
# Game #  86 Game length  2360 Max score  2048 Game score  42488
# Game #  87 Game length  1041 Max score  1024 Game score  16472
# Game #  88 Game length  2010 Max score  2048 Game score  36280
# Game #  89 Game length  682 Max score  1024 Game score  10848
# Game #  90 Game length  1737 Max score  2048 Game score  31596
# Game #  91 Game length  1041 Max score  1024 Game score  16484
# Game #  92 Game length  531 Max score  512 Game score  7260
# Game #  93 Game length  936 Max score  1024 Game score  14856
# Game #  94 Game length  667 Max score  512 Game score  8776
# Game #  95 Game length  1862 Max score  2048 Game score  33560
# Game #  96 Game length  1050 Max score  1024 Game score  16556
# Game #  97 Game length  1190 Max score  2048 Game score  22024
# Game #  98 Game length  1759 Max score  2048 Game score  30936
# Game #  99 Game length  1813 Max score  2048 Game score  31896
# Game #  100 Game length  1177 Max score  1024 Game score  18360
# model # 5
# Game #  1 Game length  1542 Max score  2048 Game score  27640
# Game #  2 Game length  1775 Max score  2048 Game score  32508
# Game #  3 Game length  1787 Max score  2048 Game score  31660
# Game #  4 Game length  1045 Max score  1024 Game score  16504
# Game #  5 Game length  921 Max score  1024 Game score  14728
# Game #  6 Game length  923 Max score  1024 Game score  14764
# Game #  7 Game length  895 Max score  1024 Game score  14444
# Game #  8 Game length  2025 Max score  2048 Game score  36576
# Game #  9 Game length  1886 Max score  2048 Game score  34504
# Game #  10 Game length  1013 Max score  1024 Game score  16168
# Game #  11 Game length  1060 Max score  1024 Game score  16632
# Game #  12 Game length  1572 Max score  2048 Game score  27896
# Game #  13 Game length  1580 Max score  2048 Game score  28032
# Game #  14 Game length  1744 Max score  2048 Game score  32076
# Game #  15 Game length  1051 Max score  1024 Game score  16536
# Game #  16 Game length  800 Max score  1024 Game score  12496
# Game #  17 Game length  1994 Max score  2048 Game score  36136
# Game #  18 Game length  2020 Max score  2048 Game score  36524
# Game #  19 Game length  1069 Max score  1024 Game score  16776
# Game #  20 Game length  915 Max score  1024 Game score  14684
# Game #  21 Game length  1036 Max score  1024 Game score  16436
# Game #  22 Game length  1024 Max score  1024 Game score  16284
# Game #  23 Game length  1914 Max score  2048 Game score  34976
# Game #  24 Game length  1604 Max score  2048 Game score  29148
# Game #  25 Game length  1303 Max score  2048 Game score  23676
# Game #  26 Game length  1580 Max score  2048 Game score  28036
# Game #  27 Game length  921 Max score  1024 Game score  14752
# Game #  28 Game length  1822 Max score  2048 Game score  32972
# Game #  29 Game length  1850 Max score  2048 Game score  33276
# Game #  30 Game length  1852 Max score  2048 Game score  33288
# Game #  31 Game length  1995 Max score  2048 Game score  36140
# Game #  32 Game length  1746 Max score  2048 Game score  32096
# Game #  33 Game length  1995 Max score  2048 Game score  36140
# Game #  34 Game length  1561 Max score  2048 Game score  27816
# Game #  35 Game length  1035 Max score  1024 Game score  16428
# Game #  36 Game length  1039 Max score  1024 Game score  16460
# Game #  37 Game length  837 Max score  1024 Game score  12888
# Game #  38 Game length  1098 Max score  1024 Game score  17952
# Game #  39 Game length  1040 Max score  1024 Game score  16492
# Game #  40 Game length  1927 Max score  2048 Game score  35096
# Game #  41 Game length  1428 Max score  2048 Game score  25964
# Game #  42 Game length  1603 Max score  2048 Game score  29140
# Game #  43 Game length  1051 Max score  1024 Game score  16620
# Game #  44 Game length  1641 Max score  2048 Game score  28792
# Game #  45 Game length  833 Max score  1024 Game score  12840
# Game #  46 Game length  915 Max score  1024 Game score  14684
# Game #  47 Game length  1478 Max score  2048 Game score  26892
# Game #  48 Game length  2045 Max score  2048 Game score  36744
# Game #  49 Game length  1540 Max score  2048 Game score  27620
# Game #  50 Game length  1868 Max score  2048 Game score  34348
# Game #  51 Game length  1525 Max score  2048 Game score  27516
# Game #  52 Game length  416 Max score  512 Game score  5568
# Game #  53 Game length  1066 Max score  1024 Game score  16872
# Game #  54 Game length  1020 Max score  1024 Game score  16244
# Game #  55 Game length  533 Max score  512 Game score  7296
# Game #  56 Game length  1718 Max score  2048 Game score  31448
# Game #  57 Game length  1047 Max score  1024 Game score  16540
# Game #  58 Game length  534 Max score  512 Game score  7288
# Game #  59 Game length  1806 Max score  2048 Game score  32864
# Game #  60 Game length  1045 Max score  1024 Game score  16532
# Game #  61 Game length  1931 Max score  2048 Game score  35116
# Game #  62 Game length  1545 Max score  2048 Game score  27680
# Game #  63 Game length  2929 Max score  4096 Game score  59420
# Game #  64 Game length  1269 Max score  2048 Game score  23328
# Game #  65 Game length  912 Max score  1024 Game score  14668
# Game #  66 Game length  1262 Max score  2048 Game score  23112
# Game #  67 Game length  1789 Max score  2048 Game score  31684
# Game #  68 Game length  1085 Max score  1024 Game score  17340
# Game #  69 Game length  1017 Max score  1024 Game score  16284
# Game #  70 Game length  808 Max score  512 Game score  11740
# Game #  71 Game length  1037 Max score  1024 Game score  16448
# Game #  72 Game length  999 Max score  1024 Game score  15900
# Game #  73 Game length  1057 Max score  1024 Game score  16700
# Game #  74 Game length  1925 Max score  2048 Game score  35056
# Game #  75 Game length  984 Max score  1024 Game score  15772
# Game #  76 Game length  1818 Max score  2048 Game score  32940
# Game #  77 Game length  1896 Max score  2048 Game score  34624
# Game #  78 Game length  899 Max score  1024 Game score  14492
# Game #  79 Game length  1032 Max score  1024 Game score  16412
# Game #  80 Game length  1562 Max score  2048 Game score  27820
# Game #  81 Game length  1017 Max score  1024 Game score  16200
# Game #  82 Game length  1006 Max score  1024 Game score  16116
# Game #  83 Game length  1812 Max score  2048 Game score  32880
# Game #  84 Game length  1581 Max score  2048 Game score  28040
# Game #  85 Game length  1936 Max score  2048 Game score  35164
# Game #  86 Game length  610 Max score  512 Game score  8892
# Game #  87 Game length  1813 Max score  2048 Game score  32888
# Game #  88 Game length  1041 Max score  1024 Game score  16472
# Game #  89 Game length  975 Max score  1024 Game score  15660
# Game #  90 Game length  2037 Max score  2048 Game score  36664
# Game #  91 Game length  1998 Max score  2048 Game score  36168
# Game #  92 Game length  1873 Max score  2048 Game score  33668
# Game #  93 Game length  886 Max score  1024 Game score  14376
# Game #  94 Game length  554 Max score  512 Game score  7452
# Game #  95 Game length  1041 Max score  1024 Game score  16472
# Game #  96 Game length  1944 Max score  2048 Game score  35244
# Game #  97 Game length  2958 Max score  4096 Game score  59720
# Game #  98 Game length  2055 Max score  2048 Game score  36892
# Game #  99 Game length  1531 Max score  2048 Game score  27560
# Game #  100 Game length  1008 Max score  1024 Game score  16140
# model # 6
# Game #  1 Game length  1624 Max score  2048 Game score  28892
# Game #  2 Game length  1583 Max score  2048 Game score  28060
# Game #  3 Game length  922 Max score  1024 Game score  14732
# Game #  4 Game length  1798 Max score  2048 Game score  32748
# Game #  5 Game length  1431 Max score  2048 Game score  25444
# Game #  6 Game length  1936 Max score  2048 Game score  35152
# Game #  7 Game length  2357 Max score  2048 Game score  44476
# Game #  8 Game length  1319 Max score  2048 Game score  24736
# Game #  9 Game length  932 Max score  1024 Game score  15004
# Game #  10 Game length  1030 Max score  1024 Game score  16344
# Game #  11 Game length  1832 Max score  2048 Game score  33048
# Game #  12 Game length  1012 Max score  1024 Game score  16160
# Game #  13 Game length  976 Max score  1024 Game score  15692
# Game #  14 Game length  1051 Max score  1024 Game score  16620
# Game #  15 Game length  971 Max score  1024 Game score  15656
# Game #  16 Game length  1057 Max score  1024 Game score  16616
# Game #  17 Game length  894 Max score  1024 Game score  14428
# Game #  18 Game length  1055 Max score  1024 Game score  16620
# Game #  19 Game length  1665 Max score  2048 Game score  30864
# Game #  20 Game length  578 Max score  512 Game score  7716
# Game #  21 Game length  1866 Max score  2048 Game score  34336
# Game #  22 Game length  929 Max score  1024 Game score  14808
# Game #  23 Game length  1044 Max score  1024 Game score  16524
# Game #  24 Game length  1302 Max score  2048 Game score  23696
# Game #  25 Game length  1808 Max score  2048 Game score  32876
# Game #  26 Game length  1509 Max score  2048 Game score  27128
# Game #  27 Game length  1065 Max score  1024 Game score  16864
# Game #  28 Game length  1328 Max score  2048 Game score  23956
# Game #  29 Game length  1915 Max score  2048 Game score  34056
# Game #  30 Game length  543 Max score  512 Game score  7336
# Game #  31 Game length  1917 Max score  2048 Game score  34944
# Game #  32 Game length  1935 Max score  2048 Game score  35148
# Game #  33 Game length  1291 Max score  1024 Game score  21548
# Game #  34 Game length  1035 Max score  1024 Game score  16428
# Game #  35 Game length  1038 Max score  1024 Game score  16540
# Game #  36 Game length  1524 Max score  2048 Game score  27436
# Game #  37 Game length  1662 Max score  2048 Game score  30824
# Game #  38 Game length  1812 Max score  2048 Game score  32872
# Game #  39 Game length  1013 Max score  1024 Game score  16176
# Game #  40 Game length  1053 Max score  1024 Game score  16584
# Game #  41 Game length  919 Max score  1024 Game score  14744
# Game #  42 Game length  721 Max score  1024 Game score  11584
# Game #  43 Game length  1332 Max score  2048 Game score  23928
# Game #  44 Game length  748 Max score  1024 Game score  11884
# Game #  45 Game length  1011 Max score  1024 Game score  16156
# Game #  46 Game length  1026 Max score  1024 Game score  16344
# Game #  47 Game length  949 Max score  1024 Game score  15032
# Game #  48 Game length  1024 Max score  1024 Game score  16272
# Game #  49 Game length  1588 Max score  2048 Game score  28116
# Game #  50 Game length  1202 Max score  1024 Game score  19240
# Game #  51 Game length  791 Max score  1024 Game score  12412
# Game #  52 Game length  572 Max score  512 Game score  7804
# Game #  53 Game length  1466 Max score  2048 Game score  26360
# Game #  54 Game length  1040 Max score  1024 Game score  16464
# Game #  55 Game length  1486 Max score  2048 Game score  26944
# Game #  56 Game length  1569 Max score  2048 Game score  27928
# Game #  57 Game length  899 Max score  1024 Game score  14516
# Game #  58 Game length  770 Max score  512 Game score  11248
# Game #  59 Game length  1508 Max score  2048 Game score  27120
# Game #  60 Game length  1799 Max score  2048 Game score  32788
# Game #  61 Game length  825 Max score  1024 Game score  12776
# Game #  62 Game length  1050 Max score  1024 Game score  16564
# Game #  63 Game length  1763 Max score  2048 Game score  32236
# Game #  64 Game length  730 Max score  512 Game score  9964
# Game #  65 Game length  1982 Max score  2048 Game score  36032
# Game #  66 Game length  1543 Max score  2048 Game score  27644
# Game #  67 Game length  1321 Max score  2048 Game score  23904
# Game #  68 Game length  1084 Max score  1024 Game score  16988
# Game #  69 Game length  1069 Max score  1024 Game score  16896
# Game #  70 Game length  578 Max score  512 Game score  7836
# Game #  71 Game length  3531 Max score  4096 Game score  71980
# Game #  72 Game length  1920 Max score  2048 Game score  35020
# Game #  73 Game length  979 Max score  1024 Game score  15708
# Game #  74 Game length  993 Max score  1024 Game score  15888
# Game #  75 Game length  1560 Max score  2048 Game score  27784
# Game #  76 Game length  1021 Max score  1024 Game score  16304
# Game #  77 Game length  994 Max score  1024 Game score  15836
# Game #  78 Game length  912 Max score  1024 Game score  14668
# Game #  79 Game length  996 Max score  1024 Game score  15932
# Game #  80 Game length  1038 Max score  1024 Game score  16456
# Game #  81 Game length  1051 Max score  1024 Game score  16560
# Game #  82 Game length  2047 Max score  2048 Game score  36840
# Game #  83 Game length  1579 Max score  2048 Game score  28028
# Game #  84 Game length  1095 Max score  1024 Game score  17180
# Game #  85 Game length  560 Max score  512 Game score  7568
# Game #  86 Game length  2138 Max score  2048 Game score  37828
# Game #  87 Game length  1105 Max score  1024 Game score  17280
# Game #  88 Game length  1347 Max score  2048 Game score  24980
# Game #  89 Game length  1051 Max score  1024 Game score  16572
# Game #  90 Game length  1116 Max score  1024 Game score  17352
# Game #  91 Game length  2573 Max score  4096 Game score  52288
# Game #  92 Game length  727 Max score  1024 Game score  11628
# Game #  93 Game length  1033 Max score  1024 Game score  16420
# Game #  94 Game length  584 Max score  512 Game score  7784
# Game #  95 Game length  950 Max score  1024 Game score  14980
# Game #  96 Game length  809 Max score  1024 Game score  12556
# Game #  97 Game length  552 Max score  512 Game score  7628
# Game #  98 Game length  1032 Max score  1024 Game score  16412
# Game #  99 Game length  924 Max score  1024 Game score  14768
# Game #  100 Game length  1573 Max score  1024 Game score  25944
# model # 7
# Game #  1 Game length  4114 Max score  4096 Game score  82036
# Game #  2 Game length  1603 Max score  2048 Game score  28216
# Game #  3 Game length  1982 Max score  2048 Game score  36032
# Game #  4 Game length  1956 Max score  2048 Game score  35320
# Game #  5 Game length  1980 Max score  2048 Game score  35964
# Game #  6 Game length  2079 Max score  2048 Game score  37080
# Game #  7 Game length  1652 Max score  2048 Game score  28888
# Game #  8 Game length  2017 Max score  2048 Game score  36352
# Game #  9 Game length  2073 Max score  2048 Game score  37096
# Game #  10 Game length  1840 Max score  2048 Game score  33128
# Game #  11 Game length  3870 Max score  4096 Game score  78092
# Game #  12 Game length  2254 Max score  2048 Game score  40268
# Game #  13 Game length  1050 Max score  1024 Game score  16532
# Game #  14 Game length  2853 Max score  4096 Game score  57596
# Game #  15 Game length  2007 Max score  2048 Game score  35976
# Game #  16 Game length  1095 Max score  1024 Game score  17404
# Game #  17 Game length  2324 Max score  2048 Game score  41112
# Game #  18 Game length  1344 Max score  1024 Game score  21064
# Game #  19 Game length  1842 Max score  2048 Game score  33308
# Game #  20 Game length  1799 Max score  2048 Game score  31772
# Game #  21 Game length  2664 Max score  2048 Game score  47592
# Game #  22 Game length  2911 Max score  4096 Game score  57348
# Game #  23 Game length  1608 Max score  2048 Game score  28448
# Game #  24 Game length  2575 Max score  4096 Game score  52120
# Game #  25 Game length  2031 Max score  2048 Game score  36608
# Game #  26 Game length  1654 Max score  2048 Game score  28908
# Game #  27 Game length  1821 Max score  2048 Game score  32968
# Game #  28 Game length  2007 Max score  2048 Game score  36252
# Game #  29 Game length  2222 Max score  2048 Game score  39100
# Game #  30 Game length  1312 Max score  1024 Game score  21720
# Game #  31 Game length  2102 Max score  2048 Game score  37528
# Game #  32 Game length  1063 Max score  1024 Game score  16732
# Game #  33 Game length  2168 Max score  2048 Game score  38264
# Game #  34 Game length  2188 Max score  2048 Game score  38728
# Game #  35 Game length  1880 Max score  2048 Game score  33704
# Game #  36 Game length  3131 Max score  4096 Game score  61960
# Game #  37 Game length  1030 Max score  1024 Game score  16316
# Game #  38 Game length  1280 Max score  1024 Game score  20376
# Game #  39 Game length  1555 Max score  2048 Game score  27576
# Game #  40 Game length  1945 Max score  2048 Game score  35240
# Game #  41 Game length  3123 Max score  4096 Game score  61908
# Game #  42 Game length  2100 Max score  2048 Game score  37336
# Game #  43 Game length  2138 Max score  2048 Game score  37828
# Game #  44 Game length  3097 Max score  4096 Game score  61624
# Game #  45 Game length  3114 Max score  4096 Game score  61820
# Game #  46 Game length  1069 Max score  1024 Game score  17644
# Game #  47 Game length  2488 Max score  4096 Game score  50912
# Game #  48 Game length  1714 Max score  2048 Game score  31388
# Game #  49 Game length  2323 Max score  4096 Game score  48220
# Game #  50 Game length  1259 Max score  1024 Game score  19844
# Game #  51 Game length  1964 Max score  2048 Game score  35580
# Game #  52 Game length  1574 Max score  2048 Game score  27932
# Game #  53 Game length  2095 Max score  2048 Game score  37272
# Game #  54 Game length  2175 Max score  2048 Game score  39144
# Game #  55 Game length  2084 Max score  2048 Game score  37144
# Game #  56 Game length  582 Max score  512 Game score  7952
# Game #  57 Game length  1837 Max score  2048 Game score  33160
# Game #  58 Game length  2104 Max score  2048 Game score  37368
# Game #  59 Game length  2077 Max score  2048 Game score  37068
# Game #  60 Game length  984 Max score  1024 Game score  15744
# Game #  61 Game length  1420 Max score  2048 Game score  25900
# Game #  62 Game length  1669 Max score  2048 Game score  30776
# Game #  63 Game length  2040 Max score  2048 Game score  36344
# Game #  64 Game length  2010 Max score  2048 Game score  36268
# Game #  65 Game length  3085 Max score  4096 Game score  61512
# Game #  66 Game length  1492 Max score  2048 Game score  26952
# Game #  67 Game length  1530 Max score  2048 Game score  27356
# Game #  68 Game length  1132 Max score  1024 Game score  17916
# Game #  69 Game length  1005 Max score  1024 Game score  15752
# Game #  70 Game length  3010 Max score  4096 Game score  60236
# Game #  71 Game length  3621 Max score  4096 Game score  73048
# Game #  72 Game length  1123 Max score  1024 Game score  17400
# Game #  73 Game length  2103 Max score  2048 Game score  37724
# Game #  74 Game length  2055 Max score  2048 Game score  36892
# Game #  75 Game length  2064 Max score  2048 Game score  36988
# Game #  76 Game length  3477 Max score  4096 Game score  71056
# Game #  77 Game length  1648 Max score  2048 Game score  29080
# Game #  78 Game length  2423 Max score  4096 Game score  50232
# Game #  79 Game length  1586 Max score  2048 Game score  28020
# Game #  80 Game length  1716 Max score  2048 Game score  31352
# Game #  81 Game length  1928 Max score  2048 Game score  35100
# Game #  82 Game length  1279 Max score  1024 Game score  20428
# Game #  83 Game length  2929 Max score  4096 Game score  59288
# Game #  84 Game length  2026 Max score  2048 Game score  36584
# Game #  85 Game length  574 Max score  512 Game score  7692
# Game #  86 Game length  2507 Max score  2048 Game score  45148
# Game #  87 Game length  2152 Max score  2048 Game score  38008
# Game #  88 Game length  1006 Max score  1024 Game score  15264
# Game #  89 Game length  1574 Max score  2048 Game score  27932
# Game #  90 Game length  1563 Max score  1024 Game score  25852
# Game #  91 Game length  1892 Max score  2048 Game score  33816
# Game #  92 Game length  2196 Max score  2048 Game score  38808
# Game #  93 Game length  1789 Max score  2048 Game score  32688
# Game #  94 Game length  1609 Max score  2048 Game score  28284
# Game #  95 Game length  3086 Max score  4096 Game score  61516
# Game #  96 Game length  1213 Max score  1024 Game score  20204
# Game #  97 Game length  1000 Max score  1024 Game score  15544
# Game #  98 Game length  1914 Max score  2048 Game score  34892
# Game #  99 Game length  1369 Max score  1024 Game score  22184
# Game #  100 Game length  1907 Max score  2048 Game score  34004
# model # 8
# Game #  1 Game length  1042 Max score  1024 Game score  16512
# Game #  2 Game length  1994 Max score  2048 Game score  36136
# Game #  3 Game length  1332 Max score  2048 Game score  24096
# Game #  4 Game length  1630 Max score  2048 Game score  28684
# Game #  5 Game length  1153 Max score  1024 Game score  18460
# Game #  6 Game length  2949 Max score  4096 Game score  59480
# Game #  7 Game length  1424 Max score  1024 Game score  23384
# Game #  8 Game length  942 Max score  1024 Game score  15344
# Game #  9 Game length  1992 Max score  2048 Game score  36124
# Game #  10 Game length  1925 Max score  2048 Game score  35000
# Game #  11 Game length  1090 Max score  1024 Game score  17308
# Game #  12 Game length  3623 Max score  4096 Game score  73060
# Game #  13 Game length  796 Max score  1024 Game score  12468
# Game #  14 Game length  1537 Max score  2048 Game score  27628
# Game #  15 Game length  1588 Max score  2048 Game score  28088
# Game #  16 Game length  3940 Max score  4096 Game score  78936
# Game #  17 Game length  3038 Max score  4096 Game score  60876
# Game #  18 Game length  2111 Max score  2048 Game score  37612
# Game #  19 Game length  3110 Max score  4096 Game score  61788
# Game #  20 Game length  1242 Max score  1024 Game score  19548
# Game #  21 Game length  1535 Max score  2048 Game score  27532
# Game #  22 Game length  2070 Max score  2048 Game score  37020
# Game #  23 Game length  2062 Max score  2048 Game score  36940
# Game #  24 Game length  3244 Max score  4096 Game score  65096
# Game #  25 Game length  2066 Max score  2048 Game score  36972
# Game #  26 Game length  709 Max score  1024 Game score  11484
# Game #  27 Game length  993 Max score  1024 Game score  15832
# Game #  28 Game length  999 Max score  1024 Game score  15708
# Game #  29 Game length  2989 Max score  4096 Game score  60040
# Game #  30 Game length  1163 Max score  1024 Game score  18236
# Game #  31 Game length  1865 Max score  2048 Game score  34332
# Game #  32 Game length  1051 Max score  1024 Game score  16572
# Game #  33 Game length  1897 Max score  2048 Game score  34160
# Game #  34 Game length  1742 Max score  2048 Game score  32064
# Game #  35 Game length  1078 Max score  1024 Game score  16860
# Game #  36 Game length  1420 Max score  2048 Game score  25900
# Game #  37 Game length  907 Max score  1024 Game score  14632
# Game #  38 Game length  3429 Max score  4096 Game score  69720
# Game #  39 Game length  1030 Max score  1024 Game score  16316
# Game #  40 Game length  1718 Max score  2048 Game score  31420
# Game #  41 Game length  1040 Max score  1024 Game score  16468
# Game #  42 Game length  546 Max score  512 Game score  7388
# Game #  43 Game length  3556 Max score  4096 Game score  72184
# Game #  44 Game length  1694 Max score  2048 Game score  31176
# Game #  45 Game length  1611 Max score  2048 Game score  28476
# Game #  46 Game length  1140 Max score  1024 Game score  17624
# Game #  47 Game length  1560 Max score  2048 Game score  27784
# Game #  48 Game length  2041 Max score  2048 Game score  36684
# Game #  49 Game length  1624 Max score  1024 Game score  26552
# Game #  50 Game length  1862 Max score  2048 Game score  34304
# Game #  51 Game length  1926 Max score  2048 Game score  35004
# Game #  52 Game length  1313 Max score  2048 Game score  23768
# Game #  53 Game length  1919 Max score  2048 Game score  34928
# Game #  54 Game length  2075 Max score  2048 Game score  37060
# Game #  55 Game length  3853 Max score  4096 Game score  77896
# Game #  56 Game length  910 Max score  1024 Game score  14644
# Game #  57 Game length  1012 Max score  1024 Game score  16076
# Game #  58 Game length  1621 Max score  2048 Game score  30304
# Game #  59 Game length  2067 Max score  2048 Game score  36980
# Game #  60 Game length  2030 Max score  2048 Game score  36616
# Game #  61 Game length  1690 Max score  2048 Game score  31116
# Game #  62 Game length  2055 Max score  2048 Game score  36892
# Game #  63 Game length  2100 Max score  2048 Game score  37336
# Game #  64 Game length  1133 Max score  1024 Game score  17576
# Game #  65 Game length  1676 Max score  2048 Game score  31020
# Game #  66 Game length  1958 Max score  2048 Game score  35416
# Game #  67 Game length  1040 Max score  1024 Game score  16464
# Game #  68 Game length  1009 Max score  1024 Game score  16024
# Game #  69 Game length  1821 Max score  2048 Game score  32968
# Game #  70 Game length  1946 Max score  2048 Game score  35244
# Game #  71 Game length  1028 Max score  1024 Game score  15960
# Game #  72 Game length  1944 Max score  2048 Game score  35208
# Game #  73 Game length  1739 Max score  1024 Game score  28988
# Game #  74 Game length  1054 Max score  1024 Game score  16588
# Game #  75 Game length  1995 Max score  2048 Game score  36140
# Game #  76 Game length  796 Max score  1024 Game score  12476
# Game #  77 Game length  2040 Max score  2048 Game score  36708
# Game #  78 Game length  835 Max score  1024 Game score  12852
# Game #  79 Game length  1143 Max score  1024 Game score  17640
# Game #  80 Game length  1692 Max score  2048 Game score  31152
# Game #  81 Game length  988 Max score  1024 Game score  15804
# Game #  82 Game length  946 Max score  1024 Game score  14956
# Game #  83 Game length  1801 Max score  2048 Game score  32812
# Game #  84 Game length  1798 Max score  2048 Game score  32604
# Game #  85 Game length  1052 Max score  1024 Game score  16624
# Game #  86 Game length  1458 Max score  2048 Game score  26392
# Game #  87 Game length  1279 Max score  1024 Game score  21268
# Game #  88 Game length  2013 Max score  2048 Game score  36072
# Game #  89 Game length  1956 Max score  2048 Game score  35320
# Game #  90 Game length  1999 Max score  2048 Game score  36172
# Game #  91 Game length  2054 Max score  2048 Game score  36804
# Game #  92 Game length  1951 Max score  2048 Game score  35700
# Game #  93 Game length  2113 Max score  2048 Game score  37872
# Game #  94 Game length  1689 Max score  2048 Game score  29624
# Game #  95 Game length  1328 Max score  1024 Game score  21912
# Game #  96 Game length  1071 Max score  1024 Game score  16908
# Game #  97 Game length  1538 Max score  1024 Game score  25532
# Game #  98 Game length  1561 Max score  2048 Game score  27816
# Game #  99 Game length  1882 Max score  2048 Game score  33752
# Game #  100 Game length  1894 Max score  2048 Game score  34752
# model # 10
# Game #  1 Game length  2208 Max score  2048 Game score  40828
# Game #  2 Game length  3390 Max score  4096 Game score  70016
# Game #  3 Game length  1062 Max score  1024 Game score  16652
# Game #  4 Game length  579 Max score  512 Game score  7900
# Game #  5 Game length  2077 Max score  2048 Game score  37068
# Game #  6 Game length  1772 Max score  2048 Game score  32380
# Game #  7 Game length  1066 Max score  1024 Game score  16760
# Game #  8 Game length  2077 Max score  2048 Game score  37128
# Game #  9 Game length  1513 Max score  2048 Game score  26924
# Game #  10 Game length  2112 Max score  2048 Game score  38288
# Game #  11 Game length  2181 Max score  2048 Game score  38680
# Game #  12 Game length  2031 Max score  2048 Game score  36704
# Game #  13 Game length  2148 Max score  2048 Game score  38340
# Game #  14 Game length  4168 Max score  4096 Game score  82984
# Game #  15 Game length  2001 Max score  2048 Game score  35848
# Game #  16 Game length  1756 Max score  2048 Game score  32188
# Game #  17 Game length  2589 Max score  2048 Game score  48392
# Game #  18 Game length  1818 Max score  2048 Game score  32940
# Game #  19 Game length  1828 Max score  1024 Game score  30040
# Game #  20 Game length  1075 Max score  1024 Game score  16844
# Game #  21 Game length  2094 Max score  2048 Game score  37292
# Game #  22 Game length  2072 Max score  2048 Game score  37032
# Game #  23 Game length  1637 Max score  2048 Game score  30464
# Game #  24 Game length  2024 Max score  2048 Game score  36572
# Game #  25 Game length  2123 Max score  2048 Game score  37724
# Game #  26 Game length  1819 Max score  2048 Game score  32944
# Game #  27 Game length  1925 Max score  2048 Game score  35072
# Game #  28 Game length  2226 Max score  2048 Game score  42664
# Game #  29 Game length  1794 Max score  2048 Game score  32680
# Game #  30 Game length  1849 Max score  2048 Game score  33440
# Game #  31 Game length  1956 Max score  2048 Game score  35404
# Game #  32 Game length  1944 Max score  2048 Game score  35232
# Game #  33 Game length  2256 Max score  2048 Game score  43340
# Game #  34 Game length  2558 Max score  2048 Game score  46028
# Game #  35 Game length  1341 Max score  1024 Game score  22152
# Game #  36 Game length  3223 Max score  4096 Game score  66940
# Game #  37 Game length  2091 Max score  2048 Game score  37252
# Game #  38 Game length  2942 Max score  4096 Game score  59404
# Game #  39 Game length  1947 Max score  2048 Game score  35260
# Game #  40 Game length  2616 Max score  4096 Game score  52724
# Game #  41 Game length  1174 Max score  2048 Game score  21872
# Game #  42 Game length  2719 Max score  4096 Game score  55756
# Game #  43 Game length  1224 Max score  2048 Game score  22344
# Game #  44 Game length  1912 Max score  2048 Game score  34908
# Game #  45 Game length  1416 Max score  2048 Game score  25372
# Game #  46 Game length  3777 Max score  4096 Game score  77008
# Game #  47 Game length  3086 Max score  4096 Game score  61516
# Game #  48 Game length  1684 Max score  1024 Game score  27544
# Game #  49 Game length  3094 Max score  4096 Game score  61656
# Game #  50 Game length  2332 Max score  4096 Game score  48320
# Game #  51 Game length  2024 Max score  2048 Game score  36452
# Game #  52 Game length  1140 Max score  1024 Game score  17624
# Game #  53 Game length  2155 Max score  2048 Game score  38024
# Game #  54 Game length  1257 Max score  2048 Game score  23048
# Game #  55 Game length  1103 Max score  1024 Game score  17260
# Game #  56 Game length  3083 Max score  4096 Game score  61500
# Game #  57 Game length  1800 Max score  2048 Game score  32768
# Game #  58 Game length  2378 Max score  2048 Game score  44856
# Game #  59 Game length  3148 Max score  4096 Game score  62520
# Game #  60 Game length  1389 Max score  2048 Game score  24712
# Game #  61 Game length  3069 Max score  4096 Game score  61376
# Game #  62 Game length  3793 Max score  4096 Game score  77084
# Game #  63 Game length  3589 Max score  4096 Game score  70680
# Game #  64 Game length  1060 Max score  1024 Game score  16632
# Game #  65 Game length  3817 Max score  4096 Game score  77424
# Game #  66 Game length  3565 Max score  4096 Game score  72328
# Game #  67 Game length  1800 Max score  2048 Game score  32796
# Game #  68 Game length  1852 Max score  2048 Game score  33468
# Game #  69 Game length  2061 Max score  2048 Game score  36936
# Game #  70 Game length  1685 Max score  2048 Game score  31088
# Game #  71 Game length  3028 Max score  4096 Game score  60812
# Game #  72 Game length  2009 Max score  2048 Game score  36264
# Game #  73 Game length  1744 Max score  2048 Game score  31704
# Game #  74 Game length  2010 Max score  2048 Game score  36076
# Game #  75 Game length  1078 Max score  1024 Game score  16860
# Game #  76 Game length  1538 Max score  2048 Game score  27548
# Game #  77 Game length  1204 Max score  1024 Game score  18648
# Game #  78 Game length  3345 Max score  4096 Game score  68732
# Game #  79 Game length  1494 Max score  1024 Game score  24956
# Game #  80 Game length  3124 Max score  4096 Game score  61912
# Game #  81 Game length  1932 Max score  2048 Game score  35132
# Game #  82 Game length  2716 Max score  4096 Game score  54216
# Game #  83 Game length  1967 Max score  2048 Game score  35848
# Game #  84 Game length  1562 Max score  2048 Game score  27820
# Game #  85 Game length  1882 Max score  2048 Game score  33604
# Game #  86 Game length  3018 Max score  4096 Game score  60292
# Game #  87 Game length  1833 Max score  2048 Game score  33080
# Game #  88 Game length  3473 Max score  4096 Game score  71000
# Game #  89 Game length  2147 Max score  2048 Game score  37972
# Game #  90 Game length  2049 Max score  2048 Game score  36728
# Game #  91 Game length  2997 Max score  4096 Game score  60240
# Game #  92 Game length  1715 Max score  2048 Game score  31392
# Game #  93 Game length  838 Max score  1024 Game score  13744
# Game #  94 Game length  2271 Max score  2048 Game score  43468
# Game #  95 Game length  1542 Max score  2048 Game score  27620
# Game #  96 Game length  2009 Max score  2048 Game score  36072
# Game #  97 Game length  2023 Max score  2048 Game score  36444
# Game #  98 Game length  1075 Max score  1024 Game score  16844
# Game #  99 Game length  2336 Max score  4096 Game score  48396
# Game #  100 Game length  1785 Max score  2048 Game score  32584
# model # 11
# Game #  1 Game length  3090 Max score  4096 Game score  61576
# Game #  2 Game length  2126 Max score  2048 Game score  37740
# Game #  3 Game length  1941 Max score  2048 Game score  35192
# Game #  4 Game length  627 Max score  512 Game score  8216
# Game #  5 Game length  1092 Max score  1024 Game score  16984
# Game #  6 Game length  1724 Max score  2048 Game score  30596
# Game #  7 Game length  2079 Max score  2048 Game score  37140
# Game #  8 Game length  1980 Max score  2048 Game score  35592
# Game #  9 Game length  3054 Max score  4096 Game score  61192
# Game #  10 Game length  1678 Max score  2048 Game score  29516
# Game #  11 Game length  1563 Max score  2048 Game score  27836
# Game #  12 Game length  1797 Max score  2048 Game score  32600
# Game #  13 Game length  3485 Max score  4096 Game score  71112
# Game #  14 Game length  1426 Max score  2048 Game score  25932
# Game #  15 Game length  1984 Max score  2048 Game score  35640
# Game #  16 Game length  1658 Max score  2048 Game score  28932
# Game #  17 Game length  3308 Max score  4096 Game score  65928
# Game #  18 Game length  1054 Max score  1024 Game score  16588
# Game #  19 Game length  2069 Max score  2048 Game score  36904
# Game #  20 Game length  1554 Max score  2048 Game score  27740
# Game #  21 Game length  2096 Max score  2048 Game score  37288
# Game #  22 Game length  1515 Max score  2048 Game score  27004
# Game #  23 Game length  3118 Max score  4096 Game score  61844
# Game #  24 Game length  1506 Max score  1024 Game score  25068
# Game #  25 Game length  1364 Max score  2048 Game score  25180
# Game #  26 Game length  1993 Max score  2048 Game score  36128
# Game #  27 Game length  2043 Max score  2048 Game score  36780
# Game #  28 Game length  822 Max score  1024 Game score  12760
# Game #  29 Game length  1708 Max score  2048 Game score  29832
# Game #  30 Game length  1295 Max score  1024 Game score  20560
# Game #  31 Game length  1077 Max score  1024 Game score  16856
# Game #  32 Game length  1847 Max score  2048 Game score  33348
# Game #  33 Game length  1519 Max score  2048 Game score  27400
# Game #  34 Game length  3086 Max score  4096 Game score  61516
# Game #  35 Game length  1167 Max score  1024 Game score  18764
# Game #  36 Game length  1627 Max score  2048 Game score  28612
# Game #  37 Game length  730 Max score  512 Game score  9916
# Game #  38 Game length  2058 Max score  2048 Game score  36908
# Game #  39 Game length  1900 Max score  2048 Game score  33928
# Game #  40 Game length  1851 Max score  2048 Game score  33032
# Game #  41 Game length  2309 Max score  2048 Game score  40956
# Game #  42 Game length  1703 Max score  2048 Game score  29736
# Game #  43 Game length  1069 Max score  1024 Game score  16896
# Game #  44 Game length  1091 Max score  1024 Game score  16952
# Game #  45 Game length  3238 Max score  4096 Game score  63708
# Game #  46 Game length  1597 Max score  2048 Game score  28172
# Game #  47 Game length  3130 Max score  4096 Game score  61956
# Game #  48 Game length  1558 Max score  2048 Game score  27772
# Game #  49 Game length  2015 Max score  2048 Game score  36304
# Game #  50 Game length  1823 Max score  2048 Game score  33036
# Game #  51 Game length  1062 Max score  1024 Game score  16668
# Game #  52 Game length  2031 Max score  2048 Game score  36524
# Game #  53 Game length  3853 Max score  4096 Game score  77896
# Game #  54 Game length  1598 Max score  2048 Game score  28180
# Game #  55 Game length  1207 Max score  2048 Game score  22148
# Game #  56 Game length  2170 Max score  2048 Game score  38516
# Game #  57 Game length  2045 Max score  2048 Game score  36744
# Game #  58 Game length  2007 Max score  2048 Game score  36252
# Game #  59 Game length  1828 Max score  2048 Game score  33016
# Game #  60 Game length  1807 Max score  2048 Game score  32844
# Game #  61 Game length  1203 Max score  1024 Game score  18616
# Game #  62 Game length  1622 Max score  2048 Game score  30312
# Game #  63 Game length  944 Max score  1024 Game score  14936
# Game #  64 Game length  3626 Max score  4096 Game score  73028
# Game #  65 Game length  2003 Max score  2048 Game score  35860
# Game #  66 Game length  1953 Max score  2048 Game score  35376
# Game #  67 Game length  1890 Max score  2048 Game score  34524
# Game #  68 Game length  2945 Max score  4096 Game score  58760
# Game #  69 Game length  3441 Max score  4096 Game score  70576
# Game #  70 Game length  1756 Max score  2048 Game score  31816
# Game #  71 Game length  2054 Max score  2048 Game score  36888
# Game #  72 Game length  2936 Max score  4096 Game score  58616
# Game #  73 Game length  2078 Max score  2048 Game score  37132
# Game #  74 Game length  1905 Max score  2048 Game score  34048
# Game #  75 Game length  2660 Max score  4096 Game score  53272
# Game #  76 Game length  2546 Max score  4096 Game score  51868
# Game #  77 Game length  1936 Max score  2048 Game score  35152
# Game #  78 Game length  2168 Max score  2048 Game score  38168
# Game #  79 Game length  1647 Max score  2048 Game score  28824
# Game #  80 Game length  1456 Max score  1024 Game score  24240
# Game #  81 Game length  1945 Max score  2048 Game score  35240
# Game #  82 Game length  1489 Max score  2048 Game score  26960
# Game #  83 Game length  2025 Max score  2048 Game score  36216
# Game #  84 Game length  1659 Max score  2048 Game score  28936
# Game #  85 Game length  2045 Max score  2048 Game score  36624
# Game #  86 Game length  588 Max score  512 Game score  7996
# Game #  87 Game length  2984 Max score  4096 Game score  60000
# Game #  88 Game length  2856 Max score  4096 Game score  57820
# Game #  89 Game length  1685 Max score  2048 Game score  29592
# Game #  90 Game length  3482 Max score  4096 Game score  71096
# Game #  91 Game length  1805 Max score  2048 Game score  32832
# Game #  92 Game length  2198 Max score  2048 Game score  40344
# Game #  93 Game length  1948 Max score  2048 Game score  34568
# Game #  94 Game length  3469 Max score  4096 Game score  70916
# Game #  95 Game length  1685 Max score  2048 Game score  29592
# Game #  96 Game length  2200 Max score  2048 Game score  42384
# Game #  97 Game length  1711 Max score  2048 Game score  31372
# Game #  98 Game length  1590 Max score  2048 Game score  28248
# Game #  99 Game length  1999 Max score  2048 Game score  36172
# Game #  100 Game length  1684 Max score  2048 Game score  29644

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-602fb1d83a07> in <module>
#       1 best_model, optimizer, epoch, running_mean = load_model(model, optimizer, "model9_0.pth.tar")
#       2
# ----> 3 test(best_model)
#
# NameError: name 'test' is not defined
