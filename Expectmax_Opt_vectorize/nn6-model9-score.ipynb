# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=128, filter2=512, filter3=1024, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)

        self.conv_aaa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_aab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_aba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_abb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)

        self.conv_baa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_bba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bbb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_x = nn.Linear(input_size * 16, 1)
        self.W_a = nn.Linear(filter1 * 12, 1)
        self.W_b = nn.Linear(filter1 * 12, 1)

        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)

        self.W_aaa = nn.Linear(filter3 * 4, 1)
        self.W_aab = nn.Linear(filter3 * 6, 1)
        self.W_aba = nn.Linear(filter3 * 6, 1)
        self.W_abb = nn.Linear(filter3 * 6, 1)
        self.W_baa = nn.Linear(filter3 * 6, 1)
        self.W_bab = nn.Linear(filter3 * 6, 1)
        self.W_bba = nn.Linear(filter3 * 6, 1)
        self.W_bbb = nn.Linear(filter3 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        aa = self.relu(self.conv_aa(a))
        ab = self.relu(self.conv_ab(a))
        ba = self.relu(self.conv_ba(b))
        bb = self.relu(self.conv_bb(b))

        aaa = self.flatten(self.relu(self.conv_aaa(aa)))
        aab = self.flatten(self.relu(self.conv_aab(aa)))
        aba = self.flatten(self.relu(self.conv_aba(ab)))
        abb = self.flatten(self.relu(self.conv_abb(ab)))
        baa = self.flatten(self.relu(self.conv_baa(ba)))
        bab = self.flatten(self.relu(self.conv_bab(ba)))
        bba = self.flatten(self.relu(self.conv_bba(bb)))
        bbb = self.flatten(self.relu(self.conv_bbb(bb)))
        x = self.flatten(x)
        a = self.flatten(a)
        b = self.flatten(b)
        aa = self.flatten(aa)
        ab = self.flatten(ab)
        ba = self.flatten(ba)
        bb = self.flatten(bb)

        out = self.W_x(x) + self.W_a(a) + self.W_b(b) \
              + self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) \
              +  self.W_aaa(aaa) + self.W_aab(aab) + self.W_aba(aba) + self.W_abb(abb) \
              + self.W_baa(baa) + self.W_bab(bab) + self.W_bba(bba) + self.W_bbb(bbb)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y)
            last_loss = loss.item()
            loss.backward()
            optimizer.step()
            model.eval()
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 5e-4
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)
    
def load_model(model, optimizer, filename, model_only = False):
    checkpoint_path = os.path.join(experiment_dir, filename)
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    if not model_only:
        optimizer.load_state_dict(ckpt_dict['optimizer'])
        epoch = ckpt_dict['epoch']
        running_mean = ckpt_dict['running_mean']
    else:
        epoch = None
        running_mean = None
    return model, optimizer, epoch, running_mean

model.cuda()
# Out:
# NN2048(
#   (conv_a): Conv2d(16, 128, kernel_size=(2, 1), stride=(1, 1))
#   (conv_b): Conv2d(16, 128, kernel_size=(1, 2), stride=(1, 1))
#   (conv_aa): Conv2d(128, 512, kernel_size=(2, 1), stride=(1, 1))
#   (conv_ab): Conv2d(128, 512, kernel_size=(1, 2), stride=(1, 1))
#   (conv_ba): Conv2d(128, 512, kernel_size=(2, 1), stride=(1, 1))
#   (conv_bb): Conv2d(128, 512, kernel_size=(1, 2), stride=(1, 1))
#   (conv_aaa): Conv2d(512, 1024, kernel_size=(2, 1), stride=(1, 1))
#   (conv_aab): Conv2d(512, 1024, kernel_size=(1, 2), stride=(1, 1))
#   (conv_aba): Conv2d(512, 1024, kernel_size=(2, 1), stride=(1, 1))
#   (conv_abb): Conv2d(512, 1024, kernel_size=(1, 2), stride=(1, 1))
#   (conv_baa): Conv2d(512, 1024, kernel_size=(2, 1), stride=(1, 1))
#   (conv_bab): Conv2d(512, 1024, kernel_size=(1, 2), stride=(1, 1))
#   (conv_bba): Conv2d(512, 1024, kernel_size=(2, 1), stride=(1, 1))
#   (conv_bbb): Conv2d(512, 1024, kernel_size=(1, 2), stride=(1, 1))
#   (relu): ReLU()
#   (W_x): Linear(in_features=256, out_features=1, bias=True)
#   (W_a): Linear(in_features=1536, out_features=1, bias=True)
#   (W_b): Linear(in_features=1536, out_features=1, bias=True)
#   (W_aa): Linear(in_features=4096, out_features=1, bias=True)
#   (W_ab): Linear(in_features=4608, out_features=1, bias=True)
#   (W_ba): Linear(in_features=4608, out_features=1, bias=True)
#   (W_bb): Linear(in_features=4096, out_features=1, bias=True)
#   (W_aaa): Linear(in_features=4096, out_features=1, bias=True)
#   (W_aab): Linear(in_features=6144, out_features=1, bias=True)
#   (W_aba): Linear(in_features=6144, out_features=1, bias=True)
#   (W_abb): Linear(in_features=6144, out_features=1, bias=True)
#   (W_baa): Linear(in_features=6144, out_features=1, bias=True)
#   (W_bab): Linear(in_features=6144, out_features=1, bias=True)
#   (W_bba): Linear(in_features=6144, out_features=1, bias=True)
#   (W_bbb): Linear(in_features=4096, out_features=1, bias=True)
# )

# %%
num_epochs = 1500
best_model = None

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
    ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean:
            running_mean = sum(ls) / 10
            filename = "model2_score_"+str(epoch // 100)+".pth.tar"
            save_model({
                'epoch': epoch,
                'running_mean': running_mean,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            best_model, _, _, _ = load_model(model, optimizer, filename, True)
            model.cuda()
            
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  98 Max score  64 Game score  688
# Game #  2 Game length  347 Max score  256 Game score  3876
# Game #  3 Game length  201 Max score  128 Game score  1948
# Game #  4 Game length  185 Max score  128 Game score  1672
# Game #  5 Game length  307 Max score  256 Game score  3508
# Game #  6 Game length  229 Max score  256 Game score  2500
# Game #  7 Game length  297 Max score  256 Game score  3392
# Game #  8 Game length  164 Max score  128 Game score  1500
# Game #  9 Game length  135 Max score  128 Game score  1188
# Game #  10 Game length  244 Max score  128 Game score  2416
# Game #  11 Game length  328 Max score  256 Game score  3656
# Game #  12 Game length  237 Max score  128 Game score  2360
# Game #  13 Game length  307 Max score  256 Game score  3484
# Game #  14 Game length  441 Max score  512 Game score  5832
# Game #  15 Game length  196 Max score  128 Game score  1836
# Game #  16 Game length  233 Max score  128 Game score  2200
# Game #  17 Game length  419 Max score  512 Game score  5680
# Game #  18 Game length  445 Max score  256 Game score  5384
# Game #  19 Game length  239 Max score  128 Game score  2436
# Game #  20 Game length  371 Max score  256 Game score  4260
# Game #  21 Game length  373 Max score  512 Game score  4976
# Game #  22 Game length  319 Max score  256 Game score  3596
# Game #  23 Game length  447 Max score  512 Game score  6012
# Game #  24 Game length  229 Max score  128 Game score  2280
# Game #  25 Game length  258 Max score  256 Game score  2864
# Game #  26 Game length  498 Max score  512 Game score  6556
# Game #  27 Game length  549 Max score  512 Game score  7248
# Game #  28 Game length  263 Max score  256 Game score  2876
# Game #  29 Game length  375 Max score  256 Game score  4192
# Game #  30 Game length  669 Max score  1024 Game score  10648
# Game #  31 Game length  249 Max score  128 Game score  2472
# Game #  32 Game length  342 Max score  256 Game score  3836
# Game #  33 Game length  213 Max score  128 Game score  2156
# Game #  34 Game length  323 Max score  256 Game score  3628
# Game #  35 Game length  686 Max score  512 Game score  9356
# Game #  36 Game length  266 Max score  256 Game score  2892
# Game #  37 Game length  367 Max score  256 Game score  4476
# Game #  38 Game length  621 Max score  512 Game score  8328
# Game #  39 Game length  573 Max score  512 Game score  7812
# Game #  40 Game length  325 Max score  256 Game score  3664
# Game #  41 Game length  700 Max score  1024 Game score  11004
# Game #  42 Game length  287 Max score  256 Game score  3260
# Game #  43 Game length  461 Max score  512 Game score  6084
# Game #  44 Game length  570 Max score  512 Game score  7660
# Game #  45 Game length  761 Max score  1024 Game score  11976
# Game #  46 Game length  300 Max score  256 Game score  3436
# Game #  47 Game length  543 Max score  512 Game score  7372
# Game #  48 Game length  553 Max score  512 Game score  7520
# Game #  49 Game length  1015 Max score  1024 Game score  16188
# Game #  50 Game length  471 Max score  512 Game score  6544
# Game #  51 Game length  563 Max score  512 Game score  7968
# Game #  52 Game length  235 Max score  256 Game score  2572
# Game #  53 Game length  934 Max score  1024 Game score  14844
# Game #  54 Game length  301 Max score  256 Game score  3440
# Game #  55 Game length  590 Max score  512 Game score  8004
# Game #  56 Game length  654 Max score  512 Game score  9020
# Game #  57 Game length  537 Max score  512 Game score  7328
# Game #  58 Game length  599 Max score  512 Game score  8148
# Game #  59 Game length  489 Max score  512 Game score  6664
# Game #  60 Game length  523 Max score  512 Game score  7036
# Game #  61 Game length  546 Max score  512 Game score  7472
# Game #  62 Game length  934 Max score  1024 Game score  14892
# Game #  63 Game length  366 Max score  256 Game score  4424
# Game #  64 Game length  441 Max score  512 Game score  5856
# Game #  65 Game length  519 Max score  512 Game score  7100
# Game #  66 Game length  422 Max score  512 Game score  5648
# Game #  67 Game length  315 Max score  256 Game score  3564
# Game #  68 Game length  321 Max score  256 Game score  3608
# Game #  69 Game length  563 Max score  512 Game score  7588
# Game #  70 Game length  829 Max score  1024 Game score  12808
# Game #  71 Game length  905 Max score  1024 Game score  14112
# Game #  72 Game length  845 Max score  1024 Game score  13120
# Game #  73 Game length  156 Max score  128 Game score  1420
# Game #  74 Game length  359 Max score  256 Game score  4184
# Game #  75 Game length  863 Max score  1024 Game score  13576
# Game #  76 Game length  528 Max score  512 Game score  7244
# Game #  77 Game length  308 Max score  256 Game score  3528
# Game #  78 Game length  475 Max score  512 Game score  6568
# Game #  79 Game length  860 Max score  1024 Game score  13432
# Game #  80 Game length  544 Max score  512 Game score  7388
# Game #  81 Game length  843 Max score  1024 Game score  13112
# Game #  82 Game length  938 Max score  1024 Game score  14892
# Game #  83 Game length  282 Max score  256 Game score  3232
# Game #  84 Game length  809 Max score  1024 Game score  12640
# Game #  85 Game length  279 Max score  256 Game score  3180
# Game #  86 Game length  996 Max score  1024 Game score  15692
# Game #  87 Game length  562 Max score  512 Game score  7580
# Game #  88 Game length  579 Max score  512 Game score  7900
# Game #  89 Game length  914 Max score  1024 Game score  14172
# Game #  90 Game length  300 Max score  256 Game score  3436
# Game #  91 Game length  537 Max score  512 Game score  7328
# Game #  92 Game length  923 Max score  1024 Game score  14256
# Game #  93 Game length  372 Max score  256 Game score  4636
# Game #  94 Game length  529 Max score  512 Game score  7252
# Game #  95 Game length  633 Max score  512 Game score  8800
# Game #  96 Game length  286 Max score  256 Game score  3264
# Game #  97 Game length  679 Max score  1024 Game score  10832
# Game #  98 Game length  353 Max score  256 Game score  4124
# Game #  99 Game length  472 Max score  512 Game score  6300
# Game #  100 Game length  538 Max score  512 Game score  7336
# Game #  101 Game length  541 Max score  512 Game score  7408
# Game #  102 Game length  505 Max score  512 Game score  6976
# Game #  103 Game length  879 Max score  1024 Game score  14216
# Game #  104 Game length  290 Max score  256 Game score  3288
# Game #  105 Game length  817 Max score  1024 Game score  12816
# Game #  106 Game length  892 Max score  1024 Game score  14444
# Game #  107 Game length  815 Max score  1024 Game score  12684
# Game #  108 Game length  536 Max score  512 Game score  7324
# Game #  109 Game length  532 Max score  512 Game score  7264
# Game #  110 Game length  373 Max score  256 Game score  4280
# Game #  111 Game length  301 Max score  256 Game score  3440
# Game #  112 Game length  1432 Max score  1024 Game score  23968
# Game #  113 Game length  909 Max score  1024 Game score  14640
# Game #  114 Game length  968 Max score  1024 Game score  15628
# Game #  115 Game length  1034 Max score  1024 Game score  16420
# Game #  116 Game length  781 Max score  1024 Game score  12336
# Game #  117 Game length  792 Max score  1024 Game score  12444
# Game #  118 Game length  510 Max score  512 Game score  7040
# Game #  119 Game length  583 Max score  512 Game score  7960
# Game #  120 Game length  1297 Max score  2048 Game score  23632
# Game #  121 Game length  545 Max score  512 Game score  7384
# Game #  122 Game length  847 Max score  1024 Game score  13132
# Game #  123 Game length  709 Max score  1024 Game score  11232
# Game #  124 Game length  1005 Max score  1024 Game score  16124
# Game #  125 Game length  1026 Max score  1024 Game score  16344
# Game #  126 Game length  524 Max score  512 Game score  7184
# Game #  127 Game length  1494 Max score  2048 Game score  27024
# Game #  128 Game length  283 Max score  256 Game score  3212
# Game #  129 Game length  533 Max score  512 Game score  7272
# Game #  130 Game length  497 Max score  512 Game score  6924
# Game #  131 Game length  512 Max score  512 Game score  6956
# Game #  132 Game length  807 Max score  1024 Game score  12572
# Game #  133 Game length  503 Max score  512 Game score  6956
# Game #  134 Game length  560 Max score  512 Game score  7692
# Game #  135 Game length  1163 Max score  1024 Game score  18732
# Game #  136 Game length  937 Max score  1024 Game score  14944
# Game #  137 Game length  1020 Max score  1024 Game score  16300
# Game #  138 Game length  1374 Max score  2048 Game score  24776
# Game #  139 Game length  593 Max score  512 Game score  8272
# Game #  140 Game length  544 Max score  512 Game score  7376
# Game #  141 Game length  1457 Max score  2048 Game score  26384
# Game #  142 Game length  518 Max score  512 Game score  7096
# Game #  143 Game length  912 Max score  1024 Game score  14668
# Game #  144 Game length  528 Max score  512 Game score  7244
# Game #  145 Game length  770 Max score  1024 Game score  12240
# Game #  146 Game length  1053 Max score  1024 Game score  16584
# Game #  147 Game length  1535 Max score  2048 Game score  27580
# Game #  148 Game length  801 Max score  1024 Game score  12512
# Game #  149 Game length  1040 Max score  1024 Game score  16492
# Game #  150 Game length  654 Max score  512 Game score  9032
# Game #  151 Game length  1292 Max score  2048 Game score  23596
# Game #  152 Game length  556 Max score  512 Game score  7480
# Game #  153 Game length  780 Max score  1024 Game score  12332
# Game #  154 Game length  534 Max score  512 Game score  7312
# Game #  155 Game length  507 Max score  512 Game score  6892
# Game #  156 Game length  584 Max score  512 Game score  7964
# Game #  157 Game length  549 Max score  512 Game score  7416
# Game #  158 Game length  569 Max score  512 Game score  7752
# Game #  159 Game length  1056 Max score  1024 Game score  16600
# Game #  160 Game length  587 Max score  512 Game score  7992
# Game #  161 Game length  788 Max score  1024 Game score  12384
# Game #  162 Game length  1153 Max score  2048 Game score  21520
# Game #  163 Game length  1356 Max score  2048 Game score  25100
# Game #  164 Game length  528 Max score  512 Game score  7244
# Game #  165 Game length  551 Max score  512 Game score  7424
# Game #  166 Game length  1039 Max score  1024 Game score  16460
# Game #  167 Game length  899 Max score  1024 Game score  14044
# Game #  168 Game length  857 Max score  1024 Game score  13448
# Game #  169 Game length  521 Max score  512 Game score  7196
# Game #  170 Game length  684 Max score  1024 Game score  10860
# Game #  171 Game length  915 Max score  1024 Game score  14684
# Game #  172 Game length  550 Max score  512 Game score  7504
# Game #  173 Game length  854 Max score  1024 Game score  13180

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

# %%
test(model)

# %%
test(best_model)
