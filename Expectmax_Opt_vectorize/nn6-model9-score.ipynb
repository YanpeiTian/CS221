# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=256, filter2=1024, filter3=2048, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)

        self.conv_aaa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_aab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_aba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_abb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)

        self.conv_baa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_bba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bbb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_x = nn.Linear(input_size * 16, 1)
        self.W_a = nn.Linear(filter1 * 12, 1)
        self.W_b = nn.Linear(filter1 * 12, 1)

        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)

        self.W_aaa = nn.Linear(filter3 * 4, 1)
        self.W_aab = nn.Linear(filter3 * 6, 1)
        self.W_aba = nn.Linear(filter3 * 6, 1)
        self.W_abb = nn.Linear(filter3 * 6, 1)
        self.W_baa = nn.Linear(filter3 * 6, 1)
        self.W_bab = nn.Linear(filter3 * 6, 1)
        self.W_bba = nn.Linear(filter3 * 6, 1)
        self.W_bbb = nn.Linear(filter3 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        aa = self.relu(self.conv_aa(a))
        ab = self.relu(self.conv_ab(a))
        ba = self.relu(self.conv_ba(b))
        bb = self.relu(self.conv_bb(b))

        aaa = self.flatten(self.relu(self.conv_aaa(aa)))
        aab = self.flatten(self.relu(self.conv_aab(aa)))
        aba = self.flatten(self.relu(self.conv_aba(ab)))
        abb = self.flatten(self.relu(self.conv_abb(ab)))
        baa = self.flatten(self.relu(self.conv_baa(ba)))
        bab = self.flatten(self.relu(self.conv_bab(ba)))
        bba = self.flatten(self.relu(self.conv_bba(bb)))
        bbb = self.flatten(self.relu(self.conv_bbb(bb)))
        x = self.flatten(x)
        a = self.flatten(a)
        b = self.flatten(b)
        aa = self.flatten(aa)
        ab = self.flatten(ab)
        ba = self.flatten(ba)
        bb = self.flatten(bb)

        out = self.W_x(x) + self.W_a(a) + self.W_b(b) \
              + self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) \
              +  self.W_aaa(aaa) + self.W_aab(aab) + self.W_aba(aba) + self.W_abb(abb) \
              + self.W_baa(baa) + self.W_bab(bab) + self.W_bba(bba) + self.W_bbb(bbb)
        return out / 3

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y) / 2
            last_loss = loss.item()
            loss.backward()
            optimizer.step()
            model.eval()
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 1e-3
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)
    
def load_model(model, optimizer, filename, model_only = False):
    checkpoint_path = os.path.join(experiment_dir, filename)
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    if not model_only:
        optimizer.load_state_dict(ckpt_dict['optimizer'])
        epoch = ckpt_dict['epoch']
        running_mean = ckpt_dict['running_mean']
    else:
        epoch = None
        running_mean = None
    return model, optimizer, epoch, running_mean

# %%
num_epochs = 1000
best_model = None

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
    ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean or epoch % 500 == 0:
            running_mean = sum(ls) / 10
            name = epoch if epoch % 500 == 0 else epoch // 100
            filename = "model2_score_"+str(epoch // 100)+".pth.tar"
            save_model({
                'epoch': epoch,
                'running_mean': running_mean,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            best_model, _, _, _ = load_model(model, optimizer, filename, True)
            model.cuda()
            
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  155 Max score  128 Game score  1440
# Game #  2 Game length  239 Max score  256 Game score  2660
# Game #  3 Game length  154 Max score  128 Game score  1408
# Game #  4 Game length  157 Max score  128 Game score  1424
# Game #  5 Game length  163 Max score  128 Game score  1468
# Game #  6 Game length  117 Max score  128 Game score  1016
# Game #  7 Game length  159 Max score  128 Game score  1436
# Game #  8 Game length  408 Max score  256 Game score  4992
# Game #  9 Game length  277 Max score  256 Game score  3168
# Game #  10 Game length  206 Max score  128 Game score  2096
# Game #  11 Game length  237 Max score  128 Game score  2344
# Game #  12 Game length  597 Max score  512 Game score  8800
# Game #  13 Game length  311 Max score  256 Game score  3640
# Game #  14 Game length  270 Max score  256 Game score  3120
# Game #  15 Game length  421 Max score  512 Game score  5608
# Game #  16 Game length  675 Max score  1024 Game score  10728
# Game #  17 Game length  192 Max score  128 Game score  1804
# Game #  18 Game length  292 Max score  256 Game score  3296
# Game #  19 Game length  256 Max score  256 Game score  2744
# Game #  20 Game length  260 Max score  256 Game score  2860
# Game #  21 Game length  394 Max score  512 Game score  5280
# Game #  22 Game length  360 Max score  512 Game score  4860
# Game #  23 Game length  272 Max score  256 Game score  3132
# Game #  24 Game length  395 Max score  512 Game score  5352
# Game #  25 Game length  310 Max score  256 Game score  3500
# Game #  26 Game length  204 Max score  128 Game score  1904
# Game #  27 Game length  298 Max score  256 Game score  3340
# Game #  28 Game length  283 Max score  256 Game score  3212
# Game #  29 Game length  599 Max score  512 Game score  8092
# Game #  30 Game length  567 Max score  512 Game score  7644
# Game #  31 Game length  484 Max score  512 Game score  6708
# Game #  32 Game length  440 Max score  512 Game score  5852
# Game #  33 Game length  261 Max score  256 Game score  2892
# Game #  34 Game length  475 Max score  512 Game score  6564
# Game #  35 Game length  500 Max score  512 Game score  6816
# Game #  36 Game length  155 Max score  128 Game score  1416
# Game #  37 Game length  214 Max score  128 Game score  1980
# Game #  38 Game length  316 Max score  256 Game score  3568
# Game #  39 Game length  487 Max score  512 Game score  6652
# Game #  40 Game length  428 Max score  512 Game score  5692
# Game #  41 Game length  542 Max score  512 Game score  7368
# Game #  42 Game length  574 Max score  512 Game score  7692
# Game #  43 Game length  695 Max score  1024 Game score  10940
# Game #  44 Game length  1003 Max score  1024 Game score  15980
# Game #  45 Game length  552 Max score  512 Game score  7456
# Game #  46 Game length  544 Max score  512 Game score  7436
# Game #  47 Game length  920 Max score  1024 Game score  14748
# Game #  48 Game length  408 Max score  512 Game score  5500
# Game #  49 Game length  578 Max score  512 Game score  7772
# Game #  50 Game length  983 Max score  1024 Game score  15728
# Game #  51 Game length  292 Max score  256 Game score  3296
# Game #  52 Game length  555 Max score  512 Game score  7472
# Game #  53 Game length  516 Max score  512 Game score  7084
# Game #  54 Game length  317 Max score  256 Game score  3708
# Game #  55 Game length  431 Max score  512 Game score  5708
# Game #  56 Game length  296 Max score  256 Game score  3404
# Game #  57 Game length  946 Max score  1024 Game score  15376
# Game #  58 Game length  531 Max score  512 Game score  7260
# Game #  59 Game length  525 Max score  512 Game score  7216
# Game #  60 Game length  650 Max score  512 Game score  9504
# Game #  61 Game length  607 Max score  512 Game score  8396
# Game #  62 Game length  543 Max score  512 Game score  7372
# Game #  63 Game length  544 Max score  512 Game score  7376
# Game #  64 Game length  559 Max score  512 Game score  7564
# Game #  65 Game length  530 Max score  512 Game score  7256
# Game #  66 Game length  661 Max score  1024 Game score  10592
# Game #  67 Game length  714 Max score  1024 Game score  11464
# Game #  68 Game length  437 Max score  512 Game score  5752
# Game #  69 Game length  559 Max score  512 Game score  7564
# Game #  70 Game length  595 Max score  512 Game score  8284
# Game #  71 Game length  1088 Max score  1024 Game score  18820
# Game #  72 Game length  1078 Max score  1024 Game score  16956
# Game #  73 Game length  530 Max score  512 Game score  7256
# Game #  74 Game length  794 Max score  1024 Game score  12456
# Game #  75 Game length  594 Max score  512 Game score  8028
# Game #  76 Game length  975 Max score  1024 Game score  15436
# Game #  77 Game length  537 Max score  512 Game score  7328
# Game #  78 Game length  985 Max score  1024 Game score  15776
# Game #  79 Game length  356 Max score  256 Game score  4108
# Game #  80 Game length  528 Max score  512 Game score  7232
# Game #  81 Game length  809 Max score  1024 Game score  12644
# Game #  82 Game length  315 Max score  256 Game score  3564
# Game #  83 Game length  929 Max score  1024 Game score  14864
# Game #  84 Game length  532 Max score  512 Game score  7292
# Game #  85 Game length  1021 Max score  1024 Game score  16256
# Game #  86 Game length  1009 Max score  1024 Game score  16144
# Game #  87 Game length  515 Max score  512 Game score  6956
# Game #  88 Game length  597 Max score  512 Game score  8056
# Game #  89 Game length  1039 Max score  1024 Game score  16460
# Game #  90 Game length  693 Max score  1024 Game score  10956
# Game #  91 Game length  1035 Max score  1024 Game score  16412
# Game #  92 Game length  1195 Max score  1024 Game score  18684
# Game #  93 Game length  982 Max score  1024 Game score  15736
# Game #  94 Game length  867 Max score  1024 Game score  14044
# Game #  95 Game length  839 Max score  1024 Game score  12908
# Game #  96 Game length  971 Max score  1024 Game score  15404
# Game #  97 Game length  547 Max score  512 Game score  7452
# Game #  98 Game length  998 Max score  1024 Game score  15868
# Game #  99 Game length  1034 Max score  1024 Game score  16424
# Game #  100 Game length  981 Max score  1024 Game score  15744
# Game #  101 Game length  785 Max score  1024 Game score  12368
# Game #  102 Game length  1069 Max score  1024 Game score  16776
# Game #  103 Game length  348 Max score  256 Game score  4000
# Game #  104 Game length  602 Max score  512 Game score  8360
# Game #  105 Game length  967 Max score  1024 Game score  15632
# Game #  106 Game length  982 Max score  1024 Game score  15724
# Game #  107 Game length  483 Max score  512 Game score  6620
# Game #  108 Game length  547 Max score  512 Game score  7452
# Game #  109 Game length  545 Max score  512 Game score  7384
# Game #  110 Game length  1033 Max score  1024 Game score  16416
# Game #  111 Game length  1569 Max score  2048 Game score  28076
# Game #  112 Game length  478 Max score  512 Game score  6332
# Game #  113 Game length  806 Max score  1024 Game score  12540
# Game #  114 Game length  986 Max score  1024 Game score  15784
# Game #  115 Game length  655 Max score  512 Game score  9036
# Game #  116 Game length  546 Max score  512 Game score  7388
# Game #  117 Game length  733 Max score  1024 Game score  11672
# Game #  118 Game length  1088 Max score  1024 Game score  17104
# Game #  119 Game length  922 Max score  1024 Game score  14760
# Game #  120 Game length  1583 Max score  2048 Game score  28048
# Game #  121 Game length  1004 Max score  1024 Game score  16108
# Game #  122 Game length  543 Max score  512 Game score  7372
# Game #  123 Game length  1069 Max score  1024 Game score  16776
# Game #  124 Game length  1045 Max score  1024 Game score  16492
# Game #  125 Game length  1089 Max score  1024 Game score  17120
# Game #  126 Game length  773 Max score  1024 Game score  12260
# Game #  127 Game length  1054 Max score  1024 Game score  16588
# Game #  128 Game length  775 Max score  512 Game score  11260
# Game #  129 Game length  569 Max score  512 Game score  8000
# Game #  130 Game length  1483 Max score  2048 Game score  26920
# Game #  131 Game length  1048 Max score  1024 Game score  16520
# Game #  132 Game length  291 Max score  256 Game score  3292
# Game #  135 Game length  1411 Max score  2048 Game score  25756
# Game #  136 Game length  431 Max score  512 Game score  5708
# Game #  137 Game length  720 Max score  1024 Game score  11340
# Game #  138 Game length  1077 Max score  1024 Game score  17192
# Game #  139 Game length  1049 Max score  1024 Game score  16608
# Game #  140 Game length  292 Max score  256 Game score  3308
# Game #  141 Game length  809 Max score  1024 Game score  12640
# Game #  142 Game length  933 Max score  1024 Game score  14864
# Game #  143 Game length  1073 Max score  1024 Game score  16920
# Game #  144 Game length  2052 Max score  2048 Game score  36876
# Game #  145 Game length  638 Max score  512 Game score  8888
# Game #  146 Game length  517 Max score  512 Game score  7088
# Game #  147 Game length  534 Max score  512 Game score  7288
# Game #  148 Game length  804 Max score  1024 Game score  12520
# Game #  149 Game length  926 Max score  1024 Game score  14780
# Game #  150 Game length  454 Max score  512 Game score  5948
# Game #  151 Game length  1617 Max score  2048 Game score  29264
# Game #  152 Game length  978 Max score  1024 Game score  15704
# Game #  153 Game length  1435 Max score  2048 Game score  26028
# Game #  154 Game length  454 Max score  512 Game score  5948
# Game #  155 Game length  809 Max score  1024 Game score  12652
# Game #  156 Game length  1578 Max score  2048 Game score  28012
# Game #  157 Game length  1039 Max score  1024 Game score  16460
# Game #  158 Game length  1042 Max score  1024 Game score  16476
# Game #  159 Game length  1036 Max score  1024 Game score  16432
# Game #  160 Game length  1040 Max score  1024 Game score  16464
# Game #  161 Game length  1559 Max score  2048 Game score  27804
# Game #  162 Game length  1047 Max score  1024 Game score  16540
# Game #  163 Game length  1045 Max score  1024 Game score  16504
# Game #  164 Game length  1071 Max score  1024 Game score  16908
# Game #  165 Game length  1177 Max score  1024 Game score  19872
# Game #  166 Game length  1102 Max score  1024 Game score  17480
# Game #  167 Game length  1581 Max score  2048 Game score  28040
# Game #  168 Game length  570 Max score  512 Game score  7660
# Game #  169 Game length  1543 Max score  2048 Game score  27660
# Game #  170 Game length  866 Max score  1024 Game score  14040
# Game #  171 Game length  1047 Max score  1024 Game score  16540
# Game #  172 Game length  1545 Max score  2048 Game score  27680
# Game #  173 Game length  1031 Max score  1024 Game score  16380
# Game #  174 Game length  1051 Max score  1024 Game score  16572
# Game #  175 Game length  809 Max score  1024 Game score  12556
# Game #  176 Game length  573 Max score  512 Game score  7800
# Game #  177 Game length  1046 Max score  1024 Game score  16532
# Game #  178 Game length  1552 Max score  2048 Game score  27728
# Game #  179 Game length  1378 Max score  2048 Game score  24976
# Game #  180 Game length  546 Max score  512 Game score  7388
# Game #  181 Game length  1052 Max score  1024 Game score  16576
# Game #  182 Game length  798 Max score  1024 Game score  12488
# Game #  183 Game length  1071 Max score  1024 Game score  16908
# Game #  184 Game length  1033 Max score  1024 Game score  16416
# Game #  185 Game length  992 Max score  1024 Game score  15824
# Game #  186 Game length  926 Max score  1024 Game score  14780
# Game #  187 Game length  540 Max score  512 Game score  7356
# Game #  188 Game length  991 Max score  1024 Game score  15820
# Game #  189 Game length  1679 Max score  2048 Game score  30028
# Game #  190 Game length  303 Max score  256 Game score  3452
# Game #  191 Game length  1024 Max score  1024 Game score  16272
# Game #  192 Game length  531 Max score  512 Game score  7260
# Game #  193 Game length  814 Max score  1024 Game score  12680
# Game #  194 Game length  1051 Max score  1024 Game score  16548
# Game #  195 Game length  912 Max score  1024 Game score  14668
# Game #  196 Game length  1033 Max score  1024 Game score  16416
# Game #  197 Game length  1042 Max score  1024 Game score  16504
# Game #  198 Game length  1045 Max score  1024 Game score  16504
# Game #  199 Game length  1323 Max score  2048 Game score  23916
# Game #  200 Game length  805 Max score  1024 Game score  12536
# Game #  201 Game length  976 Max score  1024 Game score  15668
# Game #  202 Game length  1012 Max score  1024 Game score  16160
# Game #  203 Game length  1529 Max score  2048 Game score  27340
# Game #  204 Game length  544 Max score  512 Game score  7380
# Game #  205 Game length  1496 Max score  2048 Game score  27036
# Game #  206 Game length  1565 Max score  2048 Game score  27848
# Game #  207 Game length  1037 Max score  1024 Game score  16448
# Game #  208 Game length  1307 Max score  2048 Game score  23724
# Game #  209 Game length  1827 Max score  2048 Game score  33012
# Game #  210 Game length  979 Max score  1024 Game score  15708
# Game #  211 Game length  532 Max score  512 Game score  7264
# Game #  212 Game length  816 Max score  1024 Game score  12692
# Game #  213 Game length  1680 Max score  2048 Game score  31076
# Game #  214 Game length  913 Max score  1024 Game score  14672
# Game #  215 Game length  1097 Max score  1024 Game score  17192
# Game #  216 Game length  670 Max score  1024 Game score  10652
# Game #  217 Game length  914 Max score  1024 Game score  14680
# Game #  218 Game length  1049 Max score  1024 Game score  16552
# Game #  219 Game length  1044 Max score  1024 Game score  16524
# Game #  220 Game length  1433 Max score  2048 Game score  26016
# Game #  221 Game length  1042 Max score  1024 Game score  16476
# Game #  222 Game length  1027 Max score  1024 Game score  16348
# Game #  223 Game length  533 Max score  512 Game score  7280
# Game #  224 Game length  985 Max score  1024 Game score  15776
# Game #  225 Game length  1238 Max score  1024 Game score  20880
# Game #  226 Game length  1019 Max score  1024 Game score  16124
# Game #  227 Game length  1850 Max score  2048 Game score  33276
# Game #  228 Game length  2051 Max score  2048 Game score  36844
# Game #  229 Game length  844 Max score  1024 Game score  13108
# Game #  230 Game length  1011 Max score  1024 Game score  16156
# Game #  231 Game length  537 Max score  512 Game score  7388
# Game #  232 Game length  1043 Max score  1024 Game score  16480
# Game #  233 Game length  1049 Max score  1024 Game score  16552
# Game #  234 Game length  567 Max score  512 Game score  7644
# Game #  235 Game length  1283 Max score  2048 Game score  23452
# Game #  236 Game length  932 Max score  1024 Game score  14824
# Game #  237 Game length  1047 Max score  1024 Game score  16512
# Game #  238 Game length  1054 Max score  1024 Game score  16588
# Game #  239 Game length  1094 Max score  1024 Game score  17176
# Game #  240 Game length  540 Max score  512 Game score  7356
# Game #  241 Game length  1017 Max score  1024 Game score  16104
# Game #  242 Game length  1066 Max score  1024 Game score  16692
# Game #  243 Game length  998 Max score  1024 Game score  15868
# Game #  244 Game length  993 Max score  1024 Game score  15832
# Game #  245 Game length  1038 Max score  1024 Game score  16456
# Game #  246 Game length  1527 Max score  2048 Game score  27452
# Game #  247 Game length  1042 Max score  1024 Game score  16476
# Game #  248 Game length  1776 Max score  2048 Game score  32524
# Game #  249 Game length  1031 Max score  1024 Game score  16408
# Game #  250 Game length  882 Max score  1024 Game score  14172
# Game #  251 Game length  537 Max score  512 Game score  7328
# Game #  252 Game length  1070 Max score  1024 Game score  16808
# Game #  253 Game length  1020 Max score  1024 Game score  16176
# Game #  254 Game length  533 Max score  512 Game score  7308
# Game #  255 Game length  536 Max score  512 Game score  7296
# Game #  256 Game length  1505 Max score  2048 Game score  27096
# Game #  257 Game length  1039 Max score  1024 Game score  16460
# Game #  258 Game length  1534 Max score  2048 Game score  27576
# Game #  259 Game length  1987 Max score  2048 Game score  36060
# Game #  260 Game length  1515 Max score  2048 Game score  27244
# Game #  261 Game length  1198 Max score  1024 Game score  18580
# Game #  262 Game length  1889 Max score  2048 Game score  34520
# Game #  263 Game length  808 Max score  1024 Game score  12552
# Game #  264 Game length  546 Max score  512 Game score  7388
# Game #  265 Game length  1004 Max score  1024 Game score  15996
# Game #  266 Game length  1544 Max score  2048 Game score  27676
# Game #  267 Game length  803 Max score  1024 Game score  12540
# Game #  268 Game length  1540 Max score  2048 Game score  27568
# Game #  269 Game length  1100 Max score  1024 Game score  17456
# Game #  270 Game length  921 Max score  1024 Game score  14728
# Game #  271 Game length  778 Max score  1024 Game score  12236
# Game #  272 Game length  923 Max score  1024 Game score  14764
# Game #  273 Game length  789 Max score  1024 Game score  12400
# Game #  274 Game length  1041 Max score  1024 Game score  16472
# Game #  275 Game length  1355 Max score  2048 Game score  24364
# Game #  276 Game length  1027 Max score  1024 Game score  16376
# Game #  277 Game length  944 Max score  1024 Game score  15004
# Game #  278 Game length  1434 Max score  2048 Game score  25996
# Game #  279 Game length  1830 Max score  2048 Game score  33052
# Game #  280 Game length  1039 Max score  1024 Game score  16460
# Game #  281 Game length  1565 Max score  2048 Game score  27848
# Game #  282 Game length  1813 Max score  2048 Game score  32912
# Game #  283 Game length  276 Max score  256 Game score  3164
# Game #  284 Game length  786 Max score  1024 Game score  12376
# Game #  285 Game length  902 Max score  1024 Game score  14592
# Game #  286 Game length  1469 Max score  2048 Game score  26376
# Game #  287 Game length  986 Max score  1024 Game score  15784
# Game #  288 Game length  1562 Max score  2048 Game score  27832
# Game #  289 Game length  1683 Max score  2048 Game score  31068
# Game #  290 Game length  1550 Max score  2048 Game score  27720
# Game #  291 Game length  1597 Max score  2048 Game score  28296
# Game #  292 Game length  820 Max score  1024 Game score  12844
# Game #  293 Game length  1806 Max score  2048 Game score  32792
# Game #  294 Game length  1040 Max score  1024 Game score  16468
# Game #  295 Game length  1219 Max score  2048 Game score  22428
# Game #  296 Game length  982 Max score  1024 Game score  15724
# Game #  297 Game length  1043 Max score  1024 Game score  16492
# Game #  298 Game length  1045 Max score  1024 Game score  16504
# Game #  299 Game length  1441 Max score  2048 Game score  26072
# Game #  300 Game length  1070 Max score  1024 Game score  16780
# Game #  301 Game length  1070 Max score  1024 Game score  16780
# Game #  302 Game length  1039 Max score  1024 Game score  16460
# Game #  303 Game length  1697 Max score  2048 Game score  29676
# Game #  304 Game length  1977 Max score  2048 Game score  35996
# Game #  305 Game length  1018 Max score  1024 Game score  16232
# Game #  306 Game length  1880 Max score  2048 Game score  34460
# Game #  307 Game length  1030 Max score  1024 Game score  16400
# Game #  308 Game length  1040 Max score  1024 Game score  16464
# Game #  309 Game length  1043 Max score  1024 Game score  16492
# Game #  310 Game length  284 Max score  256 Game score  3228
# Game #  311 Game length  1075 Max score  1024 Game score  16844
# Game #  312 Game length  419 Max score  512 Game score  5596
# Game #  313 Game length  1545 Max score  2048 Game score  27680
# Game #  314 Game length  528 Max score  512 Game score  7244
# Game #  315 Game length  1052 Max score  1024 Game score  16576
# Game #  316 Game length  1527 Max score  2048 Game score  27452
# Game #  317 Game length  1042 Max score  1024 Game score  16476
# Game #  318 Game length  1563 Max score  2048 Game score  27864
# Game #  319 Game length  2025 Max score  2048 Game score  36456
# Game #  320 Game length  1809 Max score  2048 Game score  31864
# Game #  321 Game length  1544 Max score  2048 Game score  27676
# Game #  322 Game length  1424 Max score  2048 Game score  25932
# Game #  323 Game length  600 Max score  512 Game score  8156
# Game #  324 Game length  549 Max score  512 Game score  7404
# Game #  325 Game length  996 Max score  1024 Game score  15860
# Game #  326 Game length  1053 Max score  1024 Game score  16584
# Game #  327 Game length  1030 Max score  1024 Game score  16400
# Game #  328 Game length  541 Max score  512 Game score  7336
# Game #  329 Game length  775 Max score  1024 Game score  12100
# Game #  330 Game length  814 Max score  1024 Game score  12676
# Game #  331 Game length  1016 Max score  1024 Game score  16192
# Game #  332 Game length  1851 Max score  2048 Game score  34124
# Game #  333 Game length  1042 Max score  1024 Game score  16476
# Game #  334 Game length  781 Max score  1024 Game score  12336
# Game #  335 Game length  1593 Max score  2048 Game score  28152
# Game #  336 Game length  549 Max score  512 Game score  7416
# Game #  337 Game length  1598 Max score  2048 Game score  28300
# Game #  338 Game length  1318 Max score  2048 Game score  23804
# Game #  339 Game length  1934 Max score  2048 Game score  35144
# Game #  340 Game length  837 Max score  1024 Game score  13728
# Game #  341 Game length  1552 Max score  2048 Game score  27756
# Game #  342 Game length  1068 Max score  1024 Game score  16772
# Game #  343 Game length  1895 Max score  2048 Game score  34644
# Game #  344 Game length  1670 Max score  2048 Game score  30988
# Game #  345 Game length  1045 Max score  1024 Game score  16504
# Game #  346 Game length  1056 Max score  1024 Game score  16656
# Game #  347 Game length  1038 Max score  1024 Game score  16456
# Game #  348 Game length  406 Max score  512 Game score  5480
# Game #  349 Game length  579 Max score  512 Game score  7844
# Game #  350 Game length  1545 Max score  2048 Game score  27680
# Game #  351 Game length  1017 Max score  1024 Game score  16236
# Game #  352 Game length  534 Max score  512 Game score  7276
# Game #  353 Game length  1445 Max score  2048 Game score  26104
# Game #  354 Game length  1929 Max score  2048 Game score  35108
# Game #  355 Game length  1050 Max score  1024 Game score  16568
# Game #  356 Game length  799 Max score  1024 Game score  12492
# Game #  357 Game length  1791 Max score  2048 Game score  32652
# Game #  358 Game length  1040 Max score  1024 Game score  16464
# Game #  359 Game length  808 Max score  1024 Game score  12552
# Game #  360 Game length  1060 Max score  1024 Game score  16800
# Game #  361 Game length  2730 Max score  4096 Game score  55864
# Game #  362 Game length  1562 Max score  2048 Game score  27820
# Game #  363 Game length  1815 Max score  2048 Game score  32924
# Game #  364 Game length  1544 Max score  2048 Game score  27676
# Game #  365 Game length  1018 Max score  1024 Game score  16240
# Game #  366 Game length  1046 Max score  1024 Game score  16508
# Game #  367 Game length  994 Max score  1024 Game score  15896
# Game #  368 Game length  1448 Max score  2048 Game score  26204
# Game #  369 Game length  1544 Max score  2048 Game score  27676
# Game #  370 Game length  917 Max score  1024 Game score  14704
# Game #  371 Game length  1070 Max score  1024 Game score  16780
# Game #  372 Game length  1615 Max score  2048 Game score  28496
# Game #  373 Game length  867 Max score  1024 Game score  14044
# Game #  374 Game length  1054 Max score  1024 Game score  16588
# Game #  375 Game length  1595 Max score  2048 Game score  28284
# Game #  376 Game length  807 Max score  1024 Game score  12572
# Game #  377 Game length  814 Max score  1024 Game score  12680
# Game #  378 Game length  1447 Max score  2048 Game score  26196
# Game #  379 Game length  530 Max score  512 Game score  7256
# Game #  380 Game length  1023 Max score  1024 Game score  16268
# Game #  381 Game length  2051 Max score  2048 Game score  36836
# Game #  382 Game length  1035 Max score  1024 Game score  16428
# Game #  383 Game length  1571 Max score  2048 Game score  27976
# Game #  384 Game length  1355 Max score  2048 Game score  24364
# Game #  385 Game length  1036 Max score  1024 Game score  16432
# Game #  386 Game length  1527 Max score  2048 Game score  27480
# Game #  387 Game length  1614 Max score  2048 Game score  28492
# Game #  388 Game length  1795 Max score  2048 Game score  32684
# Game #  389 Game length  575 Max score  512 Game score  7880
# Game #  390 Game length  1430 Max score  2048 Game score  26000
# Game #  391 Game length  926 Max score  1024 Game score  14792
# Game #  392 Game length  1280 Max score  2048 Game score  23484
# Game #  393 Game length  1060 Max score  1024 Game score  16632
# Game #  394 Game length  284 Max score  256 Game score  3244
# Game #  395 Game length  1056 Max score  1024 Game score  16600
# Game #  396 Game length  1947 Max score  2048 Game score  35260
# Game #  397 Game length  1931 Max score  2048 Game score  35116
# Game #  398 Game length  1039 Max score  1024 Game score  16460
# Game #  399 Game length  1492 Max score  2048 Game score  26976
# Game #  400 Game length  524 Max score  512 Game score  7212
# Game #  401 Game length  1752 Max score  2048 Game score  32156
# Game #  402 Game length  1066 Max score  1024 Game score  16732
# Game #  403 Game length  979 Max score  1024 Game score  15720
# Game #  404 Game length  1063 Max score  1024 Game score  16732
# Game #  405 Game length  2037 Max score  2048 Game score  36664
# Game #  406 Game length  1099 Max score  1024 Game score  17452
# Game #  407 Game length  570 Max score  512 Game score  7672
# Game #  410 Game length  543 Max score  512 Game score  7372
# Game #  411 Game length  1060 Max score  1024 Game score  16632
# Game #  412 Game length  1076 Max score  1024 Game score  16824
# Game #  413 Game length  1949 Max score  2048 Game score  35272
# Game #  414 Game length  1697 Max score  2048 Game score  31192
# Game #  415 Game length  1496 Max score  2048 Game score  27008
# Game #  416 Game length  287 Max score  256 Game score  3260
# Game #  417 Game length  1029 Max score  1024 Game score  16336
# Game #  418 Game length  1297 Max score  2048 Game score  23644
# Game #  419 Game length  832 Max score  1024 Game score  12824
# Game #  420 Game length  538 Max score  512 Game score  7308
# Game #  421 Game length  801 Max score  1024 Game score  12512
# Game #  422 Game length  1049 Max score  1024 Game score  16552
# Game #  423 Game length  1627 Max score  2048 Game score  28860
# Game #  424 Game length  1034 Max score  1024 Game score  16420
# Game #  425 Game length  1386 Max score  2048 Game score  25056
# Game #  426 Game length  931 Max score  1024 Game score  14876
# Game #  427 Game length  1537 Max score  2048 Game score  27624
# Game #  428 Game length  1746 Max score  2048 Game score  32028
# Game #  429 Game length  193 Max score  128 Game score  1808
# Game #  430 Game length  1038 Max score  1024 Game score  16332
# Game #  431 Game length  1051 Max score  1024 Game score  16572
# Game #  432 Game length  836 Max score  1024 Game score  12856
# Game #  433 Game length  991 Max score  1024 Game score  15820
# Game #  434 Game length  1048 Max score  1024 Game score  16604
# Game #  435 Game length  2048 Max score  2048 Game score  36820
# Game #  436 Game length  1562 Max score  2048 Game score  27820
# Game #  437 Game length  1809 Max score  2048 Game score  32856
# Game #  438 Game length  1305 Max score  2048 Game score  23712
# Game #  439 Game length  1025 Max score  1024 Game score  16364
# Game #  440 Game length  936 Max score  1024 Game score  14940
# Game #  441 Game length  1816 Max score  2048 Game score  32988
# Game #  442 Game length  530 Max score  512 Game score  7252
# Game #  443 Game length  1045 Max score  1024 Game score  16504
# Game #  444 Game length  1701 Max score  2048 Game score  29784
# Game #  445 Game length  1432 Max score  2048 Game score  26012
# Game #  446 Game length  1068 Max score  1024 Game score  16760
# Game #  447 Game length  1480 Max score  2048 Game score  26876
# Game #  448 Game length  1573 Max score  2048 Game score  27988
# Game #  449 Game length  1436 Max score  2048 Game score  26044
# Game #  450 Game length  1877 Max score  2048 Game score  34444
# Game #  451 Game length  1069 Max score  1024 Game score  16764
# Game #  452 Game length  2074 Max score  2048 Game score  37100
# Game #  453 Game length  2064 Max score  2048 Game score  36952
# Game #  454 Game length  1994 Max score  2048 Game score  36136
# Game #  455 Game length  529 Max score  512 Game score  7248
# Game #  456 Game length  784 Max score  1024 Game score  12364
# Game #  457 Game length  1790 Max score  2048 Game score  32620
# Game #  458 Game length  1534 Max score  2048 Game score  27584
# Game #  459 Game length  945 Max score  1024 Game score  15000
# Game #  460 Game length  1947 Max score  2048 Game score  35260
# Game #  461 Game length  531 Max score  512 Game score  7260
# Game #  462 Game length  1526 Max score  2048 Game score  27472
# Game #  463 Game length  2031 Max score  2048 Game score  36620
# Game #  464 Game length  1822 Max score  2048 Game score  32972
# Game #  465 Game length  1992 Max score  2048 Game score  36124
# Game #  466 Game length  799 Max score  1024 Game score  12492
# Game #  467 Game length  1937 Max score  2048 Game score  35160
# Game #  468 Game length  1029 Max score  1024 Game score  16368
# Game #  469 Game length  1295 Max score  1024 Game score  21580
# Game #  470 Game length  1628 Max score  2048 Game score  28616
# Game #  471 Game length  568 Max score  512 Game score  7744
# Game #  472 Game length  1570 Max score  2048 Game score  27884
# Game #  473 Game length  2048 Max score  2048 Game score  36816
# Game #  474 Game length  1758 Max score  2048 Game score  32368
# Game #  475 Game length  1529 Max score  2048 Game score  27492
# Game #  476 Game length  1308 Max score  2048 Game score  23740
# Game #  477 Game length  1050 Max score  1024 Game score  16568
# Game #  478 Game length  1055 Max score  1024 Game score  16592
# Game #  479 Game length  1549 Max score  2048 Game score  27712
# Game #  480 Game length  622 Max score  512 Game score  8332
# Game #  481 Game length  2212 Max score  2048 Game score  40620
# Game #  482 Game length  1037 Max score  1024 Game score  16476
# Game #  483 Game length  2298 Max score  2048 Game score  41896
# Game #  484 Game length  1522 Max score  2048 Game score  27416
# Game #  485 Game length  1053 Max score  1024 Game score  16584
# Game #  486 Game length  1126 Max score  1024 Game score  17500
# Game #  487 Game length  1594 Max score  2048 Game score  28516
# Game #  488 Game length  840 Max score  1024 Game score  12960

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

# %%
test(model)

# %%
best_model.cuda()

test(best_model)
