# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=512, filter2=4096, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        self.conv_c = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_cc = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)
        self.W_cc = nn.Linear(filter2 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        c = self.relu(self.conv_c(x))
        aa = self.flatten(self.relu(self.conv_aa(a)))
        ab = self.flatten(self.relu(self.conv_ab(a)))
        ba = self.flatten(self.relu(self.conv_ba(b)))
        bb = self.flatten(self.relu(self.conv_bb(b)))
        cc = self.flatten(self.relu(self.conv_cc(c)))
        out = self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) + self.W_cc(cc)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y) / 2
            last_loss = loss.item()
            loss.backward()
            optimizer.step()
            model.eval()
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 5e-4
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)
    
def load_model(model, optimizer, checkpoint_path, model_only = False):
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    if not model_only:
        optimizer.load_state_dict(ckpt_dict['optimizer'])
        epoch = ckpt_dict['epoch']
        running_mean = ckpt_dict['running_mean']
    else:
        epoch = None
        running_mean = None
    return model, optimizer, epoch, running_mean

model.cuda()
# Out:
# NN2048(
#   (conv_a): Conv2d(16, 512, kernel_size=(2, 1), stride=(1, 1))
#   (conv_b): Conv2d(16, 512, kernel_size=(1, 2), stride=(1, 1))
#   (conv_c): Conv2d(16, 512, kernel_size=(2, 2), stride=(1, 1))
#   (conv_aa): Conv2d(512, 4096, kernel_size=(2, 1), stride=(1, 1))
#   (conv_ab): Conv2d(512, 4096, kernel_size=(1, 2), stride=(1, 1))
#   (conv_ba): Conv2d(512, 4096, kernel_size=(2, 1), stride=(1, 1))
#   (conv_bb): Conv2d(512, 4096, kernel_size=(1, 2), stride=(1, 1))
#   (conv_cc): Conv2d(512, 4096, kernel_size=(2, 2), stride=(1, 1))
#   (relu): ReLU()
#   (W_aa): Linear(in_features=32768, out_features=1, bias=True)
#   (W_ab): Linear(in_features=36864, out_features=1, bias=True)
#   (W_ba): Linear(in_features=36864, out_features=1, bias=True)
#   (W_bb): Linear(in_features=32768, out_features=1, bias=True)
#   (W_cc): Linear(in_features=16384, out_features=1, bias=True)
# )

# %%
num_epochs = 1500
best_model = None

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
    ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean:
            running_mean = sum(ls) / 10
            filename = "model_score_"+str(epoch // 100)+".pth.tar"
            save_model({
                'epoch': epoch,
                'running_mean': running_mean,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            best_model, _, _, _ = load_model(model, optimizer, filename, True)
            model.cuda()
            
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  102 Max score  64 Game score  736
# Game #  2 Game length  355 Max score  256 Game score  3980
# Game #  3 Game length  200 Max score  128 Game score  1980
# Game #  4 Game length  285 Max score  256 Game score  3176
# Game #  5 Game length  243 Max score  256 Game score  2712
# Game #  6 Game length  453 Max score  512 Game score  6000
# Game #  7 Game length  469 Max score  512 Game score  6496
# Game #  8 Game length  353 Max score  256 Game score  4112
# Game #  9 Game length  219 Max score  128 Game score  2092
# Game #  10 Game length  513 Max score  512 Game score  6960
# Game #  11 Game length  474 Max score  512 Game score  6284
# Game #  12 Game length  369 Max score  256 Game score  4272
# Game #  13 Game length  1069 Max score  1024 Game score  16776
# Game #  14 Game length  596 Max score  512 Game score  8052
# Game #  15 Game length  517 Max score  512 Game score  6968
# Game #  16 Game length  532 Max score  512 Game score  7244
# Game #  17 Game length  511 Max score  512 Game score  7020
# Game #  18 Game length  584 Max score  512 Game score  7964
# Game #  19 Game length  347 Max score  256 Game score  4012
# Game #  20 Game length  546 Max score  512 Game score  7400
# Game #  21 Game length  310 Max score  256 Game score  3452
# Game #  22 Game length  343 Max score  256 Game score  3964
# Game #  23 Game length  800 Max score  512 Game score  11480
# Game #  24 Game length  573 Max score  512 Game score  7688
# Game #  25 Game length  485 Max score  512 Game score  6416
# Game #  26 Game length  551 Max score  512 Game score  7452
# Game #  27 Game length  172 Max score  128 Game score  1552
# Game #  28 Game length  550 Max score  512 Game score  7420
# Game #  29 Game length  840 Max score  1024 Game score  12916
# Game #  30 Game length  277 Max score  256 Game score  3120
# Game #  31 Game length  164 Max score  128 Game score  1472
# Game #  32 Game length  452 Max score  512 Game score  6108
# Game #  33 Game length  733 Max score  1024 Game score  11336
# Game #  34 Game length  320 Max score  256 Game score  3600
# Game #  35 Game length  486 Max score  512 Game score  6396
# Game #  36 Game length  392 Max score  512 Game score  5308
# Game #  37 Game length  168 Max score  128 Game score  1532
# Game #  38 Game length  759 Max score  1024 Game score  11740
# Game #  39 Game length  291 Max score  256 Game score  3292
# Game #  40 Game length  547 Max score  512 Game score  7432
# Game #  41 Game length  350 Max score  256 Game score  4028
# Game #  42 Game length  546 Max score  512 Game score  7364
# Game #  43 Game length  835 Max score  1024 Game score  12972
# Game #  44 Game length  591 Max score  512 Game score  8012
# Game #  45 Game length  584 Max score  512 Game score  7844
# Game #  46 Game length  533 Max score  512 Game score  7280
# Game #  47 Game length  383 Max score  512 Game score  5128
# Game #  48 Game length  1203 Max score  2048 Game score  22200
# Game #  49 Game length  795 Max score  1024 Game score  12460
# Game #  50 Game length  1036 Max score  1024 Game score  16408
# Game #  51 Game length  566 Max score  512 Game score  7612
# Game #  52 Game length  531 Max score  512 Game score  7260
# Game #  53 Game length  508 Max score  512 Game score  6908
# Game #  54 Game length  738 Max score  1024 Game score  11792
# Game #  55 Game length  1038 Max score  1024 Game score  16456
# Game #  56 Game length  1032 Max score  1024 Game score  16412
# Game #  57 Game length  356 Max score  256 Game score  4140
# Game #  58 Game length  543 Max score  512 Game score  7372
# Game #  59 Game length  1554 Max score  2048 Game score  27740
# Game #  60 Game length  531 Max score  512 Game score  7260
# Game #  61 Game length  809 Max score  1024 Game score  12616
# Game #  62 Game length  558 Max score  512 Game score  7560
# Game #  63 Game length  1011 Max score  1024 Game score  16156
# Game #  64 Game length  847 Max score  1024 Game score  13372
# Game #  65 Game length  1058 Max score  1024 Game score  16704
# Game #  66 Game length  541 Max score  512 Game score  7360
# Game #  67 Game length  607 Max score  512 Game score  8396
# Game #  68 Game length  786 Max score  1024 Game score  12376
# Game #  69 Game length  1007 Max score  1024 Game score  16012
# Game #  70 Game length  1039 Max score  1024 Game score  16460
# Game #  71 Game length  566 Max score  512 Game score  7612
# Game #  72 Game length  570 Max score  512 Game score  7660
# Game #  73 Game length  847 Max score  1024 Game score  13888
# Game #  74 Game length  779 Max score  1024 Game score  12328
# Game #  75 Game length  551 Max score  512 Game score  7508
# Game #  76 Game length  538 Max score  512 Game score  7308
# Game #  77 Game length  806 Max score  1024 Game score  12624
# Game #  78 Game length  930 Max score  1024 Game score  14812
# Game #  79 Game length  981 Max score  1024 Game score  15744
# Game #  80 Game length  468 Max score  512 Game score  6492
# Game #  81 Game length  1053 Max score  1024 Game score  16584
# Game #  82 Game length  860 Max score  1024 Game score  13488
# Game #  83 Game length  795 Max score  1024 Game score  12460
# Game #  84 Game length  786 Max score  1024 Game score  12400
# Game #  85 Game length  853 Max score  1024 Game score  13440
# Game #  86 Game length  941 Max score  1024 Game score  14976
# Game #  87 Game length  926 Max score  1024 Game score  14780
# Game #  88 Game length  1038 Max score  1024 Game score  16456
# Game #  89 Game length  1417 Max score  2048 Game score  25856
# Game #  90 Game length  540 Max score  512 Game score  7356
# Game #  91 Game length  537 Max score  512 Game score  7328
# Game #  92 Game length  538 Max score  512 Game score  7336
# Game #  93 Game length  1044 Max score  1024 Game score  16524
# Game #  94 Game length  1114 Max score  1024 Game score  17388
# Game #  95 Game length  1147 Max score  1024 Game score  18044
# Game #  96 Game length  1208 Max score  1024 Game score  20556
# Game #  97 Game length  537 Max score  512 Game score  7328
# Game #  98 Game length  1023 Max score  1024 Game score  16268
# Game #  99 Game length  1056 Max score  1024 Game score  16600
# Game #  100 Game length  406 Max score  512 Game score  5480
# Game #  101 Game length  913 Max score  1024 Game score  14672
# Game #  102 Game length  858 Max score  1024 Game score  13960
# Game #  103 Game length  528 Max score  512 Game score  7244
# Game #  104 Game length  540 Max score  512 Game score  7356
# Game #  105 Game length  1001 Max score  1024 Game score  16092
# Game #  106 Game length  851 Max score  1024 Game score  13432
# Game #  107 Game length  558 Max score  512 Game score  7560
# Game #  108 Game length  926 Max score  1024 Game score  14792
# Game #  109 Game length  1887 Max score  2048 Game score  34508
# Game #  110 Game length  778 Max score  1024 Game score  12320
# Game #  111 Game length  1074 Max score  1024 Game score  16812
# Game #  112 Game length  1070 Max score  1024 Game score  16780
# Game #  113 Game length  1033 Max score  1024 Game score  16416
# Game #  114 Game length  469 Max score  512 Game score  6496
# Game #  115 Game length  1548 Max score  2048 Game score  27696
# Game #  116 Game length  526 Max score  512 Game score  7232
# Game #  117 Game length  295 Max score  256 Game score  3324
# Game #  118 Game length  982 Max score  1024 Game score  15484
# Game #  119 Game length  1559 Max score  2048 Game score  27804
# Game #  120 Game length  1024 Max score  1024 Game score  16332
# Game #  121 Game length  536 Max score  512 Game score  7296
# Game #  122 Game length  668 Max score  1024 Game score  10668
# Game #  123 Game length  1540 Max score  2048 Game score  27656
# Game #  124 Game length  522 Max score  512 Game score  7116
# Game #  125 Game length  1571 Max score  2048 Game score  27936
# Game #  126 Game length  909 Max score  1024 Game score  14652
# Game #  127 Game length  989 Max score  1024 Game score  15808
# Game #  128 Game length  1089 Max score  1024 Game score  17136
# Game #  129 Game length  901 Max score  1024 Game score  14080
# Game #  130 Game length  1067 Max score  1024 Game score  16764
# Game #  131 Game length  1163 Max score  1024 Game score  18236
# Game #  132 Game length  893 Max score  1024 Game score  14336
# Game #  133 Game length  1055 Max score  1024 Game score  16596
# Game #  134 Game length  1016 Max score  1024 Game score  16192
# Game #  135 Game length  1041 Max score  1024 Game score  16472
# Game #  136 Game length  2000 Max score  2048 Game score  36176
# Game #  137 Game length  1055 Max score  1024 Game score  16652
# Game #  138 Game length  1034 Max score  1024 Game score  16424
# Game #  139 Game length  1094 Max score  1024 Game score  17424
# Game #  140 Game length  521 Max score  512 Game score  7196
# Game #  141 Game length  534 Max score  512 Game score  7288
# Game #  142 Game length  1792 Max score  2048 Game score  32716
# Game #  143 Game length  298 Max score  256 Game score  3340

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

# %%
test(model)

# %%
test(best_model)
