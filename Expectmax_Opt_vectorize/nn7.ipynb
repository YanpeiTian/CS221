# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=256, filter2=2048, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        self.conv_c = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_cc = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)
        self.W_cc = nn.Linear(filter2 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        c = self.relu(self.conv_c(x))
        aa = self.flatten(self.relu(self.conv_aa(a)))
        ab = self.flatten(self.relu(self.conv_ab(a)))
        ba = self.flatten(self.relu(self.conv_ba(b)))
        bb = self.flatten(self.relu(self.conv_bb(b)))
        cc = self.flatten(self.relu(self.conv_cc(c)))
        out = self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) + self.W_cc(cc)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y) / 2
            last_loss = loss.item()
            loss.backward()
#             nn.utils.clip_grad_norm_(model.parameters(), 10.0) #
            optimizer.step()
            model.eval()
#             if game_len % 50 == 0:
#                 print (game_len, last_loss)
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 1e-4
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)

# %%
def load_model(model, optimizer, checkpoint_path):
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    optimizer.load_state_dict(ckpt_dict['optimizer'])
    epoch = ckpt_dict['epoch']
    return model, optimizer, epoch

# model, optimizer, epoch = load_model(model, optimizer, "model/model7_500.pth.tar")

# %%
num_epochs = 5000

def train(model, optimizer, loss):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        if epoch % 500 == 0:
            filename = "model8_"+str(epoch)+".pth.tar"
            save_model({
                'epoch': epoch,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            model.cuda()
    
    
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  98 Max score  32 Game score  632
# Game #  2 Game length  161 Max score  128 Game score  1484
# Game #  3 Game length  219 Max score  256 Game score  2464
# Game #  4 Game length  122 Max score  64 Game score  984
# Game #  5 Game length  227 Max score  128 Game score  2248
# Game #  6 Game length  454 Max score  512 Game score  6060
# Game #  7 Game length  410 Max score  512 Game score  5512
# Game #  8 Game length  184 Max score  128 Game score  1676
# Game #  9 Game length  269 Max score  256 Game score  2944
# Game #  10 Game length  281 Max score  256 Game score  3200
# Game #  11 Game length  270 Max score  256 Game score  2976
# Game #  12 Game length  347 Max score  256 Game score  3924
# Game #  13 Game length  279 Max score  256 Game score  3180
# Game #  14 Game length  177 Max score  128 Game score  1616
# Game #  15 Game length  288 Max score  256 Game score  3276
# Game #  16 Game length  347 Max score  256 Game score  4236
# Game #  17 Game length  205 Max score  256 Game score  2256
# Game #  18 Game length  310 Max score  256 Game score  3452
# Game #  19 Game length  233 Max score  256 Game score  2560
# Game #  20 Game length  377 Max score  256 Game score  4688
# Game #  21 Game length  235 Max score  256 Game score  2572
# Game #  22 Game length  343 Max score  256 Game score  3812
# Game #  23 Game length  283 Max score  256 Game score  3236
# Game #  24 Game length  314 Max score  256 Game score  3532
# Game #  25 Game length  154 Max score  128 Game score  1352
# Game #  26 Game length  297 Max score  256 Game score  3420
# Game #  27 Game length  288 Max score  256 Game score  3276
# Game #  28 Game length  544 Max score  512 Game score  7380
# Game #  29 Game length  702 Max score  512 Game score  9548
# Game #  30 Game length  338 Max score  256 Game score  3928
# Game #  31 Game length  379 Max score  256 Game score  4348
# Game #  32 Game length  578 Max score  512 Game score  7808
# Game #  33 Game length  942 Max score  1024 Game score  15096
# Game #  34 Game length  518 Max score  512 Game score  6748
# Game #  35 Game length  612 Max score  512 Game score  8268
# Game #  36 Game length  669 Max score  1024 Game score  10660
# Game #  37 Game length  371 Max score  256 Game score  4292
# Game #  38 Game length  343 Max score  256 Game score  3868
# Game #  39 Game length  387 Max score  256 Game score  4404
# Game #  40 Game length  413 Max score  256 Game score  5056
# Game #  41 Game length  1164 Max score  1024 Game score  18628
# Game #  42 Game length  301 Max score  256 Game score  3440
# Game #  43 Game length  413 Max score  256 Game score  5048
# Game #  44 Game length  707 Max score  512 Game score  9612
# Game #  45 Game length  510 Max score  512 Game score  6668
# Game #  46 Game length  438 Max score  256 Game score  5336
# Game #  47 Game length  598 Max score  512 Game score  7964
# Game #  48 Game length  462 Max score  256 Game score  5704
# Game #  49 Game length  338 Max score  256 Game score  3928
# Game #  50 Game length  791 Max score  512 Game score  10972
# Game #  51 Game length  1084 Max score  1024 Game score  16904
# Game #  52 Game length  540 Max score  512 Game score  6984
# Game #  53 Game length  818 Max score  1024 Game score  12700
# Game #  54 Game length  267 Max score  256 Game score  2908
# Game #  55 Game length  207 Max score  128 Game score  1932
# Game #  56 Game length  1181 Max score  1024 Game score  18440
# Game #  57 Game length  490 Max score  512 Game score  6456
# Game #  58 Game length  764 Max score  1024 Game score  11824
# Game #  59 Game length  354 Max score  256 Game score  4060
# Game #  60 Game length  858 Max score  512 Game score  12460
# Game #  61 Game length  619 Max score  512 Game score  8316
# Game #  62 Game length  282 Max score  256 Game score  3208
# Game #  63 Game length  1013 Max score  1024 Game score  15952
# Game #  64 Game length  387 Max score  256 Game score  4572
# Game #  65 Game length  593 Max score  512 Game score  8024
# Game #  66 Game length  385 Max score  256 Game score  4392
# Game #  67 Game length  904 Max score  1024 Game score  14108
# Game #  68 Game length  648 Max score  512 Game score  8988
# Game #  69 Game length  523 Max score  512 Game score  7148
# Game #  70 Game length  528 Max score  512 Game score  7232
# Game #  71 Game length  327 Max score  256 Game score  3708
# Game #  72 Game length  431 Max score  256 Game score  5260
# Game #  73 Game length  549 Max score  512 Game score  7416
# Game #  74 Game length  573 Max score  512 Game score  7744
# Game #  75 Game length  419 Max score  512 Game score  5596
# Game #  76 Game length  1253 Max score  1024 Game score  19800
# Game #  77 Game length  886 Max score  1024 Game score  13840
# Game #  78 Game length  315 Max score  256 Game score  3564
# Game #  79 Game length  551 Max score  512 Game score  7512
# Game #  80 Game length  427 Max score  256 Game score  4808
# Game #  81 Game length  377 Max score  256 Game score  4328
# Game #  82 Game length  616 Max score  512 Game score  8264
# Game #  83 Game length  526 Max score  512 Game score  6860
# Game #  84 Game length  349 Max score  256 Game score  4032
# Game #  85 Game length  601 Max score  512 Game score  8076
# Game #  86 Game length  581 Max score  512 Game score  7936
# Game #  87 Game length  710 Max score  512 Game score  9752
# Game #  88 Game length  341 Max score  256 Game score  3944
# Game #  89 Game length  774 Max score  512 Game score  10524
# Game #  90 Game length  610 Max score  512 Game score  8920
# Game #  91 Game length  358 Max score  256 Game score  4092
# Game #  92 Game length  850 Max score  1024 Game score  13400
# Game #  93 Game length  899 Max score  1024 Game score  13996
# Game #  94 Game length  405 Max score  256 Game score  4696
# Game #  95 Game length  633 Max score  512 Game score  8772
# Game #  96 Game length  868 Max score  1024 Game score  14048
# Game #  97 Game length  1854 Max score  2048 Game score  33420
# Game #  98 Game length  769 Max score  1024 Game score  11984
# Game #  99 Game length  491 Max score  512 Game score  6508
# Game #  100 Game length  1077 Max score  1024 Game score  16952
# Game #  101 Game length  780 Max score  512 Game score  11324
# Game #  102 Game length  801 Max score  1024 Game score  12504
# Game #  103 Game length  575 Max score  512 Game score  7708
# Game #  104 Game length  213 Max score  128 Game score  2144
# Game #  105 Game length  760 Max score  1024 Game score  11968
# Game #  106 Game length  274 Max score  256 Game score  3152
# Game #  107 Game length  753 Max score  1024 Game score  11920
# Game #  108 Game length  321 Max score  256 Game score  3608
# Game #  109 Game length  588 Max score  512 Game score  8236
# Game #  110 Game length  608 Max score  512 Game score  8152
# Game #  111 Game length  279 Max score  256 Game score  3192
# Game #  112 Game length  805 Max score  1024 Game score  12592
# Game #  113 Game length  683 Max score  512 Game score  9464
# Game #  114 Game length  512 Max score  512 Game score  6680
# Game #  115 Game length  813 Max score  1024 Game score  12676
# Game #  116 Game length  605 Max score  512 Game score  8184
# Game #  117 Game length  656 Max score  512 Game score  9040
# Game #  118 Game length  583 Max score  512 Game score  7836
# Game #  119 Game length  664 Max score  512 Game score  8884
# Game #  120 Game length  446 Max score  256 Game score  5388
# Game #  121 Game length  744 Max score  1024 Game score  11612
# Game #  122 Game length  588 Max score  512 Game score  7984
# Game #  123 Game length  570 Max score  512 Game score  7784
# Game #  124 Game length  779 Max score  512 Game score  11308
# Game #  125 Game length  293 Max score  256 Game score  3388
# Game #  126 Game length  1110 Max score  1024 Game score  18064
# Game #  127 Game length  983 Max score  1024 Game score  15768
# Game #  128 Game length  615 Max score  512 Game score  8284
# Game #  129 Game length  951 Max score  1024 Game score  15164
# Game #  130 Game length  841 Max score  1024 Game score  12920
# Game #  131 Game length  1603 Max score  2048 Game score  28300
# Game #  132 Game length  532 Max score  512 Game score  7264
# Game #  133 Game length  657 Max score  512 Game score  9048
# Game #  134 Game length  1020 Max score  1024 Game score  16300
# Game #  135 Game length  813 Max score  1024 Game score  12784
# Game #  136 Game length  429 Max score  512 Game score  5696
# Game #  137 Game length  376 Max score  256 Game score  4572
# Game #  138 Game length  765 Max score  1024 Game score  12144
# Game #  139 Game length  813 Max score  1024 Game score  12784
# Game #  140 Game length  656 Max score  512 Game score  9040
# Game #  141 Game length  590 Max score  512 Game score  8032
# Game #  142 Game length  750 Max score  1024 Game score  11848
# Game #  143 Game length  1029 Max score  1024 Game score  16396
# Game #  144 Game length  784 Max score  1024 Game score  12364
# Game #  145 Game length  650 Max score  512 Game score  8828
# Game #  146 Game length  310 Max score  256 Game score  3512
# Game #  147 Game length  622 Max score  512 Game score  8524
# Game #  148 Game length  542 Max score  512 Game score  7368
# Game #  149 Game length  608 Max score  512 Game score  8400
# Game #  150 Game length  896 Max score  1024 Game score  14016
# Game #  151 Game length  307 Max score  256 Game score  3436
# Game #  152 Game length  755 Max score  1024 Game score  11932
# Game #  153 Game length  564 Max score  512 Game score  7600
# Game #  154 Game length  541 Max score  512 Game score  7352
# Game #  155 Game length  643 Max score  512 Game score  8876
# Game #  156 Game length  848 Max score  1024 Game score  13136
# Game #  157 Game length  581 Max score  512 Game score  7920
# Game #  158 Game length  598 Max score  512 Game score  8328
# Game #  159 Game length  876 Max score  1024 Game score  13556
# Game #  160 Game length  936 Max score  1024 Game score  14940
# Game #  161 Game length  539 Max score  512 Game score  7340
# Game #  162 Game length  930 Max score  1024 Game score  14812
# Game #  163 Game length  529 Max score  512 Game score  7248
# Game #  164 Game length  1078 Max score  1024 Game score  16860
# Game #  165 Game length  256 Max score  256 Game score  2940
# Game #  166 Game length  627 Max score  512 Game score  9116
# Game #  167 Game length  821 Max score  1024 Game score  12752
# Game #  168 Game length  528 Max score  512 Game score  7232
# Game #  169 Game length  544 Max score  512 Game score  7404
# Game #  170 Game length  946 Max score  1024 Game score  15016
# Game #  171 Game length  316 Max score  256 Game score  3636
# Game #  172 Game length  1084 Max score  1024 Game score  16904
# Game #  173 Game length  543 Max score  512 Game score  7372
# Game #  174 Game length  656 Max score  512 Game score  9040
# Game #  175 Game length  556 Max score  512 Game score  7548
# Game #  176 Game length  768 Max score  1024 Game score  12220
# Game #  177 Game length  345 Max score  256 Game score  4000
# Game #  178 Game length  601 Max score  512 Game score  8104
# Game #  179 Game length  631 Max score  512 Game score  8668
# Game #  180 Game length  340 Max score  256 Game score  3964
# Game #  181 Game length  974 Max score  1024 Game score  15432
# Game #  182 Game length  372 Max score  256 Game score  4636
# Game #  183 Game length  382 Max score  512 Game score  5120
# Game #  184 Game length  388 Max score  512 Game score  5276
# Game #  185 Game length  512 Max score  512 Game score  7052
# Game #  186 Game length  478 Max score  512 Game score  6344
# Game #  187 Game length  1034 Max score  1024 Game score  16396
# Game #  188 Game length  574 Max score  512 Game score  7752
# Game #  189 Game length  796 Max score  1024 Game score  12476
# Game #  190 Game length  783 Max score  1024 Game score  12356
# Game #  191 Game length  879 Max score  1024 Game score  14216
# Game #  192 Game length  876 Max score  1024 Game score  14188
# Game #  193 Game length  1004 Max score  1024 Game score  15988
# Game #  194 Game length  599 Max score  512 Game score  8092
# Game #  195 Game length  983 Max score  1024 Game score  15740
# Game #  196 Game length  351 Max score  256 Game score  4044
# Game #  197 Game length  252 Max score  256 Game score  2892
# Game #  198 Game length  995 Max score  1024 Game score  15900
# Game #  199 Game length  478 Max score  512 Game score  6344
# Game #  200 Game length  942 Max score  1024 Game score  14984
# Game #  201 Game length  1010 Max score  1024 Game score  16036
# Game #  202 Game length  734 Max score  512 Game score  10696
# Game #  203 Game length  846 Max score  1024 Game score  13004
# Game #  204 Game length  534 Max score  512 Game score  7312
# Game #  205 Game length  314 Max score  256 Game score  3560
# Game #  206 Game length  556 Max score  512 Game score  7548
# Game #  207 Game length  349 Max score  256 Game score  4032
# Game #  208 Game length  964 Max score  1024 Game score  15328
# Game #  209 Game length  786 Max score  1024 Game score  12400
# Game #  210 Game length  979 Max score  1024 Game score  15708
# Game #  211 Game length  646 Max score  512 Game score  8844
# Game #  212 Game length  345 Max score  256 Game score  4000
# Game #  213 Game length  564 Max score  512 Game score  7616
# Game #  214 Game length  1042 Max score  1024 Game score  16476
# Game #  215 Game length  295 Max score  256 Game score  3324
# Game #  216 Game length  257 Max score  256 Game score  2956
# Game #  217 Game length  543 Max score  512 Game score  7372
# Game #  218 Game length  553 Max score  512 Game score  7496
# Game #  219 Game length  550 Max score  512 Game score  7420
# Game #  220 Game length  315 Max score  256 Game score  3684
# Game #  221 Game length  605 Max score  512 Game score  8136
# Game #  222 Game length  876 Max score  1024 Game score  14188
# Game #  223 Game length  842 Max score  1024 Game score  13096
# Game #  224 Game length  787 Max score  1024 Game score  12380
# Game #  225 Game length  559 Max score  512 Game score  7564
# Game #  226 Game length  574 Max score  512 Game score  8064
# Game #  227 Game length  636 Max score  512 Game score  8708
# Game #  228 Game length  429 Max score  256 Game score  5248
# Game #  229 Game length  684 Max score  1024 Game score  10860
# Game #  230 Game length  319 Max score  256 Game score  3596
# Game #  231 Game length  547 Max score  512 Game score  7476
# Game #  232 Game length  559 Max score  512 Game score  7564
# Game #  233 Game length  413 Max score  512 Game score  5552
# Game #  234 Game length  544 Max score  512 Game score  7436
# Game #  235 Game length  1081 Max score  1024 Game score  17000
# Game #  236 Game length  764 Max score  1024 Game score  12140
# Game #  237 Game length  535 Max score  512 Game score  7292
# Game #  238 Game length  748 Max score  1024 Game score  11884
# Game #  239 Game length  808 Max score  1024 Game score  12636
# Game #  240 Game length  570 Max score  512 Game score  7672
# Game #  241 Game length  886 Max score  1024 Game score  13880
# Game #  242 Game length  432 Max score  512 Game score  5772
# Game #  243 Game length  509 Max score  512 Game score  7084
# Game #  244 Game length  590 Max score  512 Game score  7884
# Game #  245 Game length  531 Max score  512 Game score  7260
# Game #  246 Game length  445 Max score  512 Game score  5888
# Game #  247 Game length  494 Max score  512 Game score  6784
# Game #  248 Game length  289 Max score  256 Game score  3280
# Game #  249 Game length  879 Max score  1024 Game score  13708
# Game #  250 Game length  557 Max score  512 Game score  7552
# Game #  251 Game length  1050 Max score  1024 Game score  16616
# Game #  252 Game length  561 Max score  512 Game score  7516
# Game #  253 Game length  1071 Max score  1024 Game score  16812
# Game #  254 Game length  494 Max score  512 Game score  6772
# Game #  255 Game length  1385 Max score  2048 Game score  24872
# Game #  256 Game length  649 Max score  512 Game score  8992
# Game #  257 Game length  745 Max score  1024 Game score  11808
# Game #  258 Game length  1029 Max score  1024 Game score  16312
# Game #  259 Game length  426 Max score  512 Game score  5644
# Game #  260 Game length  473 Max score  512 Game score  6280
# Game #  261 Game length  550 Max score  512 Game score  7480
# Game #  262 Game length  533 Max score  512 Game score  7272
# Game #  263 Game length  450 Max score  512 Game score  6096
# Game #  264 Game length  214 Max score  128 Game score  2152
# Game #  265 Game length  784 Max score  1024 Game score  12364
# Game #  266 Game length  805 Max score  1024 Game score  12584
# Game #  267 Game length  808 Max score  1024 Game score  12552
# Game #  268 Game length  895 Max score  1024 Game score  14348
# Game #  269 Game length  811 Max score  1024 Game score  12652
# Game #  270 Game length  511 Max score  512 Game score  6924
# Game #  271 Game length  821 Max score  1024 Game score  12728
# Game #  272 Game length  550 Max score  512 Game score  7448
# Game #  273 Game length  597 Max score  512 Game score  8080
# Game #  274 Game length  1558 Max score  2048 Game score  27772
# Game #  275 Game length  756 Max score  1024 Game score  12060
# Game #  276 Game length  831 Max score  1024 Game score  12940
# Game #  277 Game length  553 Max score  512 Game score  7532
# Game #  278 Game length  780 Max score  1024 Game score  12332
# Game #  279 Game length  543 Max score  512 Game score  7372
# Game #  280 Game length  1047 Max score  1024 Game score  16540
# Game #  281 Game length  1026 Max score  1024 Game score  16344
# Game #  282 Game length  865 Max score  1024 Game score  13556
# Game #  283 Game length  891 Max score  1024 Game score  14436
# Game #  284 Game length  542 Max score  512 Game score  7368
# Game #  285 Game length  506 Max score  512 Game score  6888
# Game #  286 Game length  532 Max score  512 Game score  7264
# Game #  287 Game length  792 Max score  1024 Game score  12444
# Game #  288 Game length  1054 Max score  1024 Game score  16588
# Game #  289 Game length  403 Max score  512 Game score  5460
# Game #  290 Game length  919 Max score  1024 Game score  14744
# Game #  291 Game length  538 Max score  512 Game score  7348
# Game #  292 Game length  1007 Max score  1024 Game score  16012
# Game #  293 Game length  752 Max score  1024 Game score  11916
# Game #  294 Game length  543 Max score  512 Game score  7372
# Game #  295 Game length  545 Max score  512 Game score  7384
# Game #  296 Game length  936 Max score  1024 Game score  14940
# Game #  297 Game length  486 Max score  512 Game score  6396
# Game #  298 Game length  537 Max score  512 Game score  7328
# Game #  299 Game length  562 Max score  512 Game score  7704
# Game #  300 Game length  653 Max score  512 Game score  9520
# Game #  301 Game length  830 Max score  1024 Game score  12812
# Game #  302 Game length  530 Max score  512 Game score  7256
# Game #  303 Game length  826 Max score  1024 Game score  12904
# Game #  304 Game length  912 Max score  1024 Game score  14668
# Game #  305 Game length  1239 Max score  2048 Game score  22892
# Game #  306 Game length  788 Max score  1024 Game score  12384
# Game #  307 Game length  347 Max score  256 Game score  4012
# Game #  308 Game length  866 Max score  1024 Game score  14036
# Game #  309 Game length  973 Max score  1024 Game score  15664
# Game #  310 Game length  756 Max score  1024 Game score  12060
# Game #  311 Game length  919 Max score  1024 Game score  14716
# Game #  312 Game length  761 Max score  1024 Game score  12088
# Game #  313 Game length  1049 Max score  1024 Game score  16552
# Game #  314 Game length  555 Max score  512 Game score  7532
# Game #  315 Game length  1068 Max score  1024 Game score  16892
# Game #  316 Game length  731 Max score  1024 Game score  11688
# Game #  317 Game length  319 Max score  256 Game score  3596
# Game #  318 Game length  808 Max score  1024 Game score  12636
# Game #  319 Game length  784 Max score  1024 Game score  12364
# Game #  320 Game length  537 Max score  512 Game score  7304
# Game #  321 Game length  763 Max score  1024 Game score  12136
# Game #  322 Game length  473 Max score  512 Game score  6528
# Game #  323 Game length  559 Max score  512 Game score  7564
# Game #  324 Game length  786 Max score  1024 Game score  12376
# Game #  325 Game length  1014 Max score  1024 Game score  16060
# Game #  326 Game length  505 Max score  512 Game score  7004
# Game #  327 Game length  289 Max score  256 Game score  3280
# Game #  328 Game length  543 Max score  512 Game score  7420
# Game #  329 Game length  730 Max score  1024 Game score  11404
# Game #  330 Game length  501 Max score  512 Game score  6944
# Game #  331 Game length  730 Max score  1024 Game score  11680
# Game #  332 Game length  535 Max score  512 Game score  7292
# Game #  333 Game length  542 Max score  512 Game score  7368
# Game #  334 Game length  592 Max score  512 Game score  8268
# Game #  335 Game length  1026 Max score  1024 Game score  16344
# Game #  336 Game length  529 Max score  512 Game score  7248
# Game #  337 Game length  1008 Max score  1024 Game score  16140
# Game #  338 Game length  965 Max score  1024 Game score  15584
# Game #  339 Game length  543 Max score  512 Game score  7372
# Game #  340 Game length  435 Max score  512 Game score  5788
# Game #  341 Game length  965 Max score  1024 Game score  15528
# Game #  342 Game length  1025 Max score  1024 Game score  16336
# Game #  343 Game length  795 Max score  1024 Game score  12460
# Game #  344 Game length  936 Max score  1024 Game score  14940
# Game #  345 Game length  1267 Max score  2048 Game score  23320
# Game #  346 Game length  606 Max score  512 Game score  8392
# Game #  347 Game length  927 Max score  1024 Game score  14796
# Game #  348 Game length  298 Max score  256 Game score  3424
# Game #  349 Game length  767 Max score  1024 Game score  12156
# Game #  350 Game length  814 Max score  1024 Game score  12680
# Game #  351 Game length  1039 Max score  1024 Game score  16488
# Game #  352 Game length  1045 Max score  1024 Game score  16528
# Game #  353 Game length  784 Max score  1024 Game score  12364
# Game #  354 Game length  542 Max score  512 Game score  7356
# Game #  355 Game length  860 Max score  1024 Game score  13996
# Game #  356 Game length  1052 Max score  1024 Game score  16624
# Game #  357 Game length  542 Max score  512 Game score  7368
# Game #  358 Game length  862 Max score  1024 Game score  14064
# Game #  359 Game length  785 Max score  1024 Game score  12368
# Game #  360 Game length  913 Max score  1024 Game score  14672
# Game #  361 Game length  524 Max score  512 Game score  7212
# Game #  362 Game length  801 Max score  1024 Game score  12504
# Game #  363 Game length  567 Max score  512 Game score  7644
# Game #  364 Game length  667 Max score  512 Game score  9644
# Game #  365 Game length  544 Max score  512 Game score  7404
# Game #  366 Game length  529 Max score  512 Game score  7248
# Game #  367 Game length  1006 Max score  1024 Game score  16128
# Game #  368 Game length  590 Max score  512 Game score  8008
# Game #  369 Game length  544 Max score  512 Game score  7380
# Game #  370 Game length  468 Max score  512 Game score  6492
# Game #  371 Game length  700 Max score  512 Game score  9984
# Game #  372 Game length  912 Max score  1024 Game score  14668
# Game #  373 Game length  785 Max score  512 Game score  11388
# Game #  374 Game length  798 Max score  1024 Game score  12488
# Game #  375 Game length  1044 Max score  1024 Game score  16512
# Game #  376 Game length  1030 Max score  1024 Game score  16364
# Game #  377 Game length  991 Max score  1024 Game score  15820
# Game #  378 Game length  1044 Max score  1024 Game score  16524
# Game #  379 Game length  1048 Max score  1024 Game score  16472
# Game #  380 Game length  1780 Max score  2048 Game score  32436
# Game #  381 Game length  937 Max score  1024 Game score  14872
# Game #  382 Game length  1030 Max score  1024 Game score  16400
# Game #  383 Game length  924 Max score  1024 Game score  14780
# Game #  384 Game length  535 Max score  512 Game score  7320
# Game #  385 Game length  546 Max score  512 Game score  7388
# Game #  386 Game length  549 Max score  512 Game score  7404
# Game #  387 Game length  553 Max score  512 Game score  7520
# Game #  388 Game length  891 Max score  1024 Game score  14412
# Game #  389 Game length  505 Max score  512 Game score  6976
# Game #  390 Game length  1010 Max score  1024 Game score  16028
# Game #  391 Game length  531 Max score  512 Game score  7260
# Game #  392 Game length  983 Max score  1024 Game score  15768
# Game #  393 Game length  1058 Max score  1024 Game score  16620
# Game #  394 Game length  1525 Max score  2048 Game score  27404
# Game #  395 Game length  544 Max score  512 Game score  7376
# Game #  396 Game length  353 Max score  256 Game score  4056
# Game #  397 Game length  851 Max score  1024 Game score  13404
# Game #  398 Game length  1296 Max score  2048 Game score  23628
# Game #  399 Game length  743 Max score  1024 Game score  11760
# Game #  400 Game length  1030 Max score  1024 Game score  16400
# Game #  401 Game length  1013 Max score  1024 Game score  16180
# Game #  402 Game length  951 Max score  1024 Game score  15068
# Game #  403 Game length  600 Max score  512 Game score  8336
# Game #  404 Game length  914 Max score  1024 Game score  14652
# Game #  405 Game length  762 Max score  1024 Game score  12104
# Game #  406 Game length  795 Max score  1024 Game score  12460
# Game #  407 Game length  535 Max score  512 Game score  7292
# Game #  408 Game length  1043 Max score  1024 Game score  16492
# Game #  409 Game length  1123 Max score  1024 Game score  18328
# Game #  410 Game length  531 Max score  512 Game score  7260
# Game #  411 Game length  528 Max score  512 Game score  7244
# Game #  412 Game length  803 Max score  1024 Game score  12512
# Game #  413 Game length  924 Max score  1024 Game score  14780
# Game #  414 Game length  1748 Max score  2048 Game score  32108
# Game #  415 Game length  528 Max score  512 Game score  7244
# Game #  416 Game length  767 Max score  1024 Game score  12168
# Game #  417 Game length  552 Max score  512 Game score  7432
# Game #  418 Game length  756 Max score  1024 Game score  11936
# Game #  419 Game length  435 Max score  512 Game score  5788
# Game #  420 Game length  1022 Max score  1024 Game score  16308
# Game #  421 Game length  551 Max score  512 Game score  7452
# Game #  422 Game length  582 Max score  512 Game score  7952
# Game #  423 Game length  563 Max score  512 Game score  7708
# Game #  424 Game length  1058 Max score  1024 Game score  16636
# Game #  425 Game length  1031 Max score  1024 Game score  16408
# Game #  426 Game length  1017 Max score  1024 Game score  16224
# Game #  427 Game length  1115 Max score  1024 Game score  17768
# Game #  428 Game length  1572 Max score  2048 Game score  28316
# Game #  429 Game length  743 Max score  1024 Game score  11772
# Game #  430 Game length  562 Max score  512 Game score  7580
# Game #  431 Game length  874 Max score  1024 Game score  14092
# Game #  432 Game length  978 Max score  1024 Game score  15704
# Game #  433 Game length  1138 Max score  1024 Game score  17960
# Game #  434 Game length  1300 Max score  1024 Game score  21608
# Game #  435 Game length  300 Max score  256 Game score  3388
# Game #  436 Game length  545 Max score  512 Game score  7384
# Game #  437 Game length  978 Max score  1024 Game score  15704
# Game #  438 Game length  428 Max score  512 Game score  5656
# Game #  439 Game length  1539 Max score  2048 Game score  27612
# Game #  440 Game length  545 Max score  512 Game score  7384
# Game #  441 Game length  861 Max score  1024 Game score  13504
# Game #  442 Game length  1087 Max score  1024 Game score  17292
# Game #  443 Game length  815 Max score  1024 Game score  12684
# Game #  444 Game length  539 Max score  512 Game score  7316
# Game #  445 Game length  842 Max score  1024 Game score  13092
# Game #  446 Game length  607 Max score  512 Game score  8396
# Game #  447 Game length  532 Max score  512 Game score  7264
# Game #  448 Game length  1036 Max score  1024 Game score  16432
# Game #  449 Game length  1553 Max score  2048 Game score  27736
# Game #  450 Game length  543 Max score  512 Game score  7456
# Game #  451 Game length  1000 Max score  1024 Game score  15964
# Game #  452 Game length  1015 Max score  1024 Game score  16188
# Game #  453 Game length  414 Max score  512 Game score  5568
# Game #  454 Game length  537 Max score  512 Game score  7328
# Game #  455 Game length  1359 Max score  2048 Game score  24396
# Game #  456 Game length  659 Max score  512 Game score  9564
# Game #  457 Game length  915 Max score  1024 Game score  14684
# Game #  458 Game length  920 Max score  1024 Game score  14748
# Game #  459 Game length  1045 Max score  1024 Game score  16504
# Game #  460 Game length  532 Max score  512 Game score  7276
# Game #  461 Game length  517 Max score  512 Game score  7080
# Game #  462 Game length  806 Max score  1024 Game score  12540
# Game #  463 Game length  1019 Max score  1024 Game score  16236
# Game #  464 Game length  1045 Max score  1024 Game score  16504
# Game #  465 Game length  1039 Max score  1024 Game score  16460
# Game #  466 Game length  555 Max score  512 Game score  7656
# Game #  467 Game length  912 Max score  1024 Game score  14668
# Game #  468 Game length  319 Max score  256 Game score  3708
# Game #  469 Game length  1040 Max score  1024 Game score  16464
# Game #  470 Game length  1556 Max score  2048 Game score  27788
# Game #  471 Game length  567 Max score  512 Game score  7644
# Game #  472 Game length  463 Max score  512 Game score  6464
# Game #  473 Game length  1091 Max score  1024 Game score  17372
# Game #  474 Game length  972 Max score  1024 Game score  15660
# Game #  475 Game length  997 Max score  1024 Game score  15936
# Game #  476 Game length  1534 Max score  2048 Game score  27584
# Game #  477 Game length  790 Max score  1024 Game score  12420
# Game #  478 Game length  465 Max score  512 Game score  6224
# Game #  479 Game length  874 Max score  1024 Game score  14176
# Game #  480 Game length  530 Max score  512 Game score  7256
# Game #  481 Game length  1026 Max score  1024 Game score  16296
# Game #  482 Game length  1143 Max score  1024 Game score  18068
# Game #  483 Game length  1046 Max score  1024 Game score  16536
# Game #  484 Game length  1047 Max score  1024 Game score  16552
# Game #  485 Game length  415 Max score  512 Game score  5572
# Game #  486 Game length  810 Max score  1024 Game score  12768
# Game #  487 Game length  1056 Max score  1024 Game score  16608
# Game #  488 Game length  1008 Max score  1024 Game score  16140
# Game #  489 Game length  803 Max score  1024 Game score  12524
# Game #  490 Game length  1004 Max score  1024 Game score  16108
# Game #  491 Game length  870 Max score  1024 Game score  14240
# Game #  492 Game length  535 Max score  512 Game score  7292
# Game #  493 Game length  906 Max score  1024 Game score  14120
# Game #  494 Game length  543 Max score  512 Game score  7372
# Game #  495 Game length  932 Max score  1024 Game score  15004
# Game #  496 Game length  972 Max score  1024 Game score  15660
# Game #  497 Game length  560 Max score  512 Game score  7596
# Game #  498 Game length  458 Max score  512 Game score  6176
# Game #  499 Game length  1035 Max score  1024 Game score  16428
# Game #  500 Game length  431 Max score  512 Game score  5792
# Game #  501 Game length  1323 Max score  2048 Game score  23916
# Game #  502 Game length  994 Max score  1024 Game score  15836
# Game #  503 Game length  1029 Max score  1024 Game score  16360
# Game #  504 Game length  1082 Max score  1024 Game score  16940
# Game #  505 Game length  530 Max score  512 Game score  7256
# Game #  506 Game length  916 Max score  1024 Game score  14184
# Game #  507 Game length  652 Max score  512 Game score  9020
# Game #  508 Game length  552 Max score  512 Game score  7432
# Game #  509 Game length  1566 Max score  2048 Game score  27852
# Game #  510 Game length  1055 Max score  1024 Game score  16764
# Game #  511 Game length  970 Max score  1024 Game score  15648
# Game #  512 Game length  986 Max score  1024 Game score  15840
# Game #  513 Game length  591 Max score  512 Game score  8012
# Game #  514 Game length  818 Max score  1024 Game score  12700
# Game #  515 Game length  578 Max score  512 Game score  7896
# Game #  516 Game length  941 Max score  1024 Game score  14976
# Game #  517 Game length  546 Max score  512 Game score  7400
# Game #  518 Game length  596 Max score  512 Game score  8076
# Game #  519 Game length  939 Max score  1024 Game score  14460
# Game #  520 Game length  1556 Max score  2048 Game score  27788
# Game #  521 Game length  1580 Max score  2048 Game score  27976
# Game #  522 Game length  867 Max score  1024 Game score  13356
# Game #  523 Game length  301 Max score  256 Game score  3440
# Game #  524 Game length  622 Max score  512 Game score  8584
# Game #  525 Game length  524 Max score  512 Game score  7212
# Game #  526 Game length  1045 Max score  1024 Game score  16528
# Game #  527 Game length  799 Max score  1024 Game score  12492
# Game #  528 Game length  1073 Max score  1024 Game score  16808
# Game #  529 Game length  785 Max score  1024 Game score  12368
# Game #  530 Game length  780 Max score  1024 Game score  12344
# Game #  531 Game length  1025 Max score  1024 Game score  16336
# Game #  532 Game length  1049 Max score  1024 Game score  16552
# Game #  533 Game length  1239 Max score  1024 Game score  20848
# Game #  534 Game length  790 Max score  1024 Game score  12408
# Game #  535 Game length  1060 Max score  1024 Game score  16660
# Game #  536 Game length  1054 Max score  1024 Game score  16588
# Game #  537 Game length  528 Max score  512 Game score  7244
# Game #  538 Game length  567 Max score  512 Game score  7644
# Game #  539 Game length  543 Max score  512 Game score  7372
# Game #  540 Game length  1041 Max score  1024 Game score  16472
# Game #  541 Game length  594 Max score  512 Game score  8028
# Game #  542 Game length  1053 Max score  1024 Game score  16640
# Game #  543 Game length  1539 Max score  2048 Game score  27556
# Game #  544 Game length  571 Max score  512 Game score  7676
# Game #  545 Game length  945 Max score  1024 Game score  15120
# Game #  546 Game length  860 Max score  1024 Game score  13996
# Game #  547 Game length  394 Max score  256 Game score  4896
# Game #  548 Game length  725 Max score  1024 Game score  11628
# Game #  549 Game length  544 Max score  512 Game score  7436
# Game #  550 Game length  1063 Max score  1024 Game score  16732
# Game #  551 Game length  428 Max score  512 Game score  5740
# Game #  552 Game length  1553 Max score  2048 Game score  27736
# Game #  553 Game length  532 Max score  512 Game score  7276
# Game #  554 Game length  825 Max score  1024 Game score  12776
# Game #  555 Game length  787 Max score  1024 Game score  12380
# Game #  556 Game length  531 Max score  512 Game score  7260
# Game #  557 Game length  1043 Max score  1024 Game score  16480
# Game #  558 Game length  665 Max score  512 Game score  9608
# Game #  559 Game length  1322 Max score  2048 Game score  23912
# Game #  560 Game length  1116 Max score  1024 Game score  17600
# Game #  561 Game length  846 Max score  1024 Game score  13128
# Game #  562 Game length  913 Max score  1024 Game score  14672
# Game #  563 Game length  789 Max score  1024 Game score  12400
# Game #  564 Game length  1050 Max score  1024 Game score  16568
# Game #  565 Game length  785 Max score  1024 Game score  12368
# Game #  566 Game length  807 Max score  1024 Game score  12632
# Game #  567 Game length  815 Max score  1024 Game score  12684
# Game #  568 Game length  894 Max score  1024 Game score  14344
# Game #  569 Game length  726 Max score  1024 Game score  11456
# Game #  570 Game length  1039 Max score  1024 Game score  16460
# Game #  571 Game length  1443 Max score  2048 Game score  26080
# Game #  572 Game length  984 Max score  1024 Game score  15772
# Game #  573 Game length  539 Max score  512 Game score  7340
# Game #  574 Game length  808 Max score  1024 Game score  12636
# Game #  575 Game length  768 Max score  1024 Game score  12172
# Game #  576 Game length  790 Max score  1024 Game score  12396
# Game #  577 Game length  489 Max score  512 Game score  6664
# Game #  578 Game length  907 Max score  1024 Game score  14628
# Game #  579 Game length  1039 Max score  1024 Game score  16460
# Game #  580 Game length  805 Max score  1024 Game score  12536
# Game #  581 Game length  978 Max score  1024 Game score  15692
# Game #  582 Game length  287 Max score  256 Game score  3260
# Game #  583 Game length  1036 Max score  1024 Game score  16432
# Game #  584 Game length  926 Max score  1024 Game score  14816
# Game #  585 Game length  1015 Max score  1024 Game score  16216
# Game #  586 Game length  552 Max score  512 Game score  7516
# Game #  587 Game length  1016 Max score  1024 Game score  16220
# Game #  588 Game length  1499 Max score  2048 Game score  27232
# Game #  589 Game length  915 Max score  1024 Game score  14684
# Game #  590 Game length  1283 Max score  2048 Game score  23452
# Game #  591 Game length  1046 Max score  1024 Game score  16508
# Game #  592 Game length  1012 Max score  1024 Game score  16160
# Game #  593 Game length  1463 Max score  2048 Game score  26668
# Game #  594 Game length  650 Max score  1024 Game score  10488
# Game #  595 Game length  1500 Max score  2048 Game score  27068
# Game #  596 Game length  1122 Max score  1024 Game score  18224
# Game #  597 Game length  897 Max score  1024 Game score  14540
# Game #  598 Game length  1533 Max score  2048 Game score  27520
# Game #  599 Game length  1025 Max score  1024 Game score  16336
# Game #  600 Game length  534 Max score  512 Game score  7288
# Game #  601 Game length  1094 Max score  1024 Game score  17176
# Game #  602 Game length  642 Max score  512 Game score  8920
# Game #  603 Game length  442 Max score  512 Game score  5836
# Game #  604 Game length  899 Max score  1024 Game score  14540
# Game #  605 Game length  546 Max score  512 Game score  7400
# Game #  606 Game length  548 Max score  512 Game score  7484
# Game #  607 Game length  280 Max score  256 Game score  3184
# Game #  608 Game length  819 Max score  1024 Game score  12716
# Game #  609 Game length  801 Max score  1024 Game score  12560
# Game #  610 Game length  502 Max score  512 Game score  6864
# Game #  611 Game length  1032 Max score  1024 Game score  16412
# Game #  612 Game length  550 Max score  512 Game score  7420
# Game #  613 Game length  436 Max score  512 Game score  5792
# Game #  614 Game length  1065 Max score  1024 Game score  16744
# Game #  615 Game length  1030 Max score  1024 Game score  16400
# Game #  616 Game length  974 Max score  1024 Game score  15680
# Game #  617 Game length  1652 Max score  2048 Game score  29560
# Game #  618 Game length  1459 Max score  2048 Game score  26300
# Game #  619 Game length  505 Max score  512 Game score  6992
# Game #  620 Game length  521 Max score  512 Game score  7196
# Game #  621 Game length  1024 Max score  1024 Game score  16272
# Game #  622 Game length  939 Max score  1024 Game score  14956
# Game #  623 Game length  528 Max score  512 Game score  7244
# Game #  624 Game length  1078 Max score  1024 Game score  16860
# Game #  625 Game length  1035 Max score  1024 Game score  16428
# Game #  626 Game length  573 Max score  512 Game score  7688
# Game #  627 Game length  1756 Max score  2048 Game score  32188
# Game #  628 Game length  775 Max score  512 Game score  11288
# Game #  629 Game length  1808 Max score  2048 Game score  32848
# Game #  630 Game length  932 Max score  1024 Game score  14860
# Game #  631 Game length  1048 Max score  1024 Game score  16528
# Game #  632 Game length  1023 Max score  1024 Game score  16316
# Game #  633 Game length  540 Max score  512 Game score  7356
# Game #  634 Game length  474 Max score  512 Game score  6560
# Game #  635 Game length  916 Max score  1024 Game score  14688
# Game #  636 Game length  1071 Max score  1024 Game score  16812
# Game #  637 Game length  704 Max score  1024 Game score  11024
# Game #  638 Game length  988 Max score  1024 Game score  15804
# Game #  639 Game length  523 Max score  512 Game score  7208
# Game #  640 Game length  540 Max score  512 Game score  7404
# Game #  641 Game length  962 Max score  1024 Game score  15272
# Game #  642 Game length  615 Max score  512 Game score  8656
# Game #  643 Game length  1520 Max score  2048 Game score  27280
# Game #  644 Game length  684 Max score  1024 Game score  10860
# Game #  645 Game length  1035 Max score  1024 Game score  16428
# Game #  646 Game length  1998 Max score  2048 Game score  36168
# Game #  647 Game length  984 Max score  1024 Game score  15744
# Game #  648 Game length  676 Max score  1024 Game score  10780
# Game #  649 Game length  529 Max score  512 Game score  7248
# Game #  650 Game length  1084 Max score  1024 Game score  17264
# Game #  651 Game length  1051 Max score  1024 Game score  16572
# Game #  652 Game length  1071 Max score  1024 Game score  16908
# Game #  653 Game length  269 Max score  256 Game score  3116
# Game #  654 Game length  1550 Max score  2048 Game score  27720
# Game #  655 Game length  1083 Max score  1024 Game score  17260
# Game #  656 Game length  1544 Max score  2048 Game score  27676
# Game #  657 Game length  1058 Max score  1024 Game score  16648
# Game #  658 Game length  277 Max score  256 Game score  3168
# Game #  659 Game length  1016 Max score  1024 Game score  16220
# Game #  660 Game length  593 Max score  512 Game score  8024
# Game #  661 Game length  1096 Max score  1024 Game score  17436
# Game #  662 Game length  542 Max score  512 Game score  7368
# Game #  663 Game length  991 Max score  1024 Game score  15820
# Game #  664 Game length  979 Max score  1024 Game score  15708
# Game #  665 Game length  977 Max score  1024 Game score  15696
# Game #  666 Game length  1287 Max score  1024 Game score  21500
# Game #  667 Game length  548 Max score  512 Game score  7408
# Game #  668 Game length  1076 Max score  1024 Game score  16848
# Game #  669 Game length  1907 Max score  2048 Game score  34844
# Game #  670 Game length  1076 Max score  1024 Game score  17692
# Game #  671 Game length  432 Max score  512 Game score  5760
# Game #  672 Game length  1687 Max score  2048 Game score  31100
# Game #  673 Game length  788 Max score  1024 Game score  12396
# Game #  674 Game length  930 Max score  1024 Game score  14824
# Game #  675 Game length  772 Max score  1024 Game score  12192
# Game #  676 Game length  529 Max score  512 Game score  7248
# Game #  677 Game length  1041 Max score  1024 Game score  16472
# Game #  678 Game length  898 Max score  1024 Game score  14488
# Game #  679 Game length  1114 Max score  1024 Game score  17592
# Game #  680 Game length  538 Max score  512 Game score  7308
# Game #  681 Game length  786 Max score  1024 Game score  12376
# Game #  682 Game length  541 Max score  512 Game score  7360
# Game #  683 Game length  1060 Max score  1024 Game score  16704
# Game #  684 Game length  911 Max score  1024 Game score  14652
# Game #  685 Game length  1220 Max score  1024 Game score  19680
# Game #  686 Game length  1158 Max score  1024 Game score  18200
# Game #  687 Game length  476 Max score  512 Game score  6572
# Game #  688 Game length  1557 Max score  2048 Game score  27852
# Game #  689 Game length  2102 Max score  2048 Game score  38224
# Game #  690 Game length  563 Max score  512 Game score  7960
# Game #  691 Game length  1051 Max score  1024 Game score  16572
# Game #  692 Game length  801 Max score  1024 Game score  12504
# Game #  693 Game length  1044 Max score  1024 Game score  16524
# Game #  694 Game length  407 Max score  512 Game score  5484
# Game #  695 Game length  498 Max score  512 Game score  6928
# Game #  696 Game length  927 Max score  1024 Game score  14796
# Game #  697 Game length  510 Max score  512 Game score  7040
# Game #  698 Game length  1561 Max score  2048 Game score  27816
# Game #  699 Game length  793 Max score  1024 Game score  12448
# Game #  700 Game length  1468 Max score  2048 Game score  26732
# Game #  701 Game length  518 Max score  512 Game score  7144
# Game #  702 Game length  1431 Max score  2048 Game score  25472
# Game #  703 Game length  1564 Max score  2048 Game score  27840
# Game #  704 Game length  1051 Max score  1024 Game score  16572
# Game #  705 Game length  1367 Max score  2048 Game score  24476
# Game #  706 Game length  1264 Max score  1024 Game score  20240
# Game #  707 Game length  979 Max score  1024 Game score  15708
# Game #  708 Game length  1040 Max score  1024 Game score  16464
# Game #  709 Game length  1554 Max score  2048 Game score  27740
# Game #  710 Game length  1004 Max score  1024 Game score  16108
# Game #  711 Game length  1004 Max score  1024 Game score  16108
# Game #  712 Game length  1234 Max score  1024 Game score  19832
# Game #  713 Game length  1041 Max score  1024 Game score  16472
# Game #  714 Game length  1024 Max score  1024 Game score  16332
# Game #  715 Game length  559 Max score  512 Game score  7564
# Game #  716 Game length  816 Max score  1024 Game score  12644
# Game #  717 Game length  820 Max score  1024 Game score  12832
# Game #  718 Game length  950 Max score  1024 Game score  15064
# Game #  719 Game length  967 Max score  1024 Game score  15608
# Game #  720 Game length  1953 Max score  2048 Game score  35352
# Game #  721 Game length  684 Max score  512 Game score  9852
# Game #  722 Game length  1549 Max score  2048 Game score  27704
# Game #  723 Game length  1977 Max score  2048 Game score  35940
# Game #  724 Game length  550 Max score  512 Game score  7504
# Game #  725 Game length  778 Max score  1024 Game score  12320
# Game #  726 Game length  1543 Max score  2048 Game score  27660
# Game #  727 Game length  828 Max score  1024 Game score  12804
# Game #  728 Game length  797 Max score  1024 Game score  12484
# Game #  729 Game length  991 Max score  1024 Game score  15820
# Game #  730 Game length  775 Max score  1024 Game score  12220
# Game #  731 Game length  797 Max score  1024 Game score  12472
# Game #  732 Game length  1747 Max score  2048 Game score  32092
# Game #  733 Game length  971 Max score  1024 Game score  15656
# Game #  734 Game length  915 Max score  1024 Game score  14684
# Game #  735 Game length  1050 Max score  1024 Game score  16556
# Game #  736 Game length  543 Max score  512 Game score  7372
# Game #  737 Game length  1739 Max score  2048 Game score  32036
# Game #  738 Game length  621 Max score  512 Game score  8700
# Game #  739 Game length  675 Max score  1024 Game score  10716
# Game #  740 Game length  913 Max score  1024 Game score  14672
# Game #  741 Game length  1296 Max score  2048 Game score  23628
# Game #  742 Game length  509 Max score  512 Game score  7024
# Game #  743 Game length  991 Max score  1024 Game score  15820
# Game #  744 Game length  977 Max score  1024 Game score  15696
# Game #  745 Game length  1042 Max score  1024 Game score  16476
# Game #  746 Game length  1025 Max score  1024 Game score  16336
# Game #  747 Game length  672 Max score  1024 Game score  10676
# Game #  748 Game length  962 Max score  1024 Game score  15512
# Game #  749 Game length  918 Max score  1024 Game score  14736
# Game #  750 Game length  840 Max score  1024 Game score  13072
# Game #  751 Game length  1785 Max score  2048 Game score  32668
# Game #  752 Game length  589 Max score  512 Game score  8252
# Game #  753 Game length  1022 Max score  1024 Game score  16264
# Game #  754 Game length  1813 Max score  2048 Game score  32888
# Game #  755 Game length  607 Max score  512 Game score  8396
# Game #  756 Game length  1041 Max score  1024 Game score  16472
# Game #  757 Game length  1071 Max score  1024 Game score  16796
# Game #  758 Game length  972 Max score  1024 Game score  15412
# Game #  759 Game length  1298 Max score  2048 Game score  23640
# Game #  760 Game length  1108 Max score  1024 Game score  17524
# Game #  761 Game length  787 Max score  1024 Game score  12380
# Game #  762 Game length  791 Max score  1024 Game score  12412
# Game #  763 Game length  287 Max score  256 Game score  3260
# Game #  764 Game length  1461 Max score  2048 Game score  26320
# Game #  765 Game length  1077 Max score  1024 Game score  17036
# Game #  766 Game length  298 Max score  256 Game score  3424
# Game #  767 Game length  542 Max score  512 Game score  7424
# Game #  768 Game length  530 Max score  512 Game score  7256
# Game #  769 Game length  926 Max score  1024 Game score  14792
# Game #  770 Game length  854 Max score  1024 Game score  13180
# Game #  771 Game length  1540 Max score  2048 Game score  27644
# ...
# Game #  1382 Game length  2354 Max score  2048 Game score  42420
# Game #  1383 Game length  2782 Max score  4096 Game score  56764
# Game #  1384 Game length  1102 Max score  1024 Game score  17476
# Game #  1385 Game length  1463 Max score  2048 Game score  26332
# Game #  1386 Game length  1529 Max score  2048 Game score  27548
# Game #  1387 Game length  562 Max score  512 Game score  7580
# Game #  1388 Game length  1423 Max score  2048 Game score  25928
# Game #  1389 Game length  1017 Max score  1024 Game score  16200
# Game #  1390 Game length  529 Max score  512 Game score  7248
# Game #  1391 Game length  2001 Max score  2048 Game score  36184
# Game #  1392 Game length  2061 Max score  2048 Game score  36936
# Game #  1393 Game length  1870 Max score  2048 Game score  33612
# Game #  1394 Game length  784 Max score  1024 Game score  12364
# Game #  1395 Game length  1978 Max score  2048 Game score  36000
# Game #  1396 Game length  1214 Max score  2048 Game score  22460
# Game #  1397 Game length  724 Max score  1024 Game score  11612
# Game #  1398 Game length  1001 Max score  1024 Game score  16080
# Game #  1399 Game length  982 Max score  1024 Game score  15760
# Game #  1400 Game length  806 Max score  1024 Game score  12588
# Game #  1401 Game length  1426 Max score  2048 Game score  25952
# Game #  1402 Game length  1059 Max score  1024 Game score  16672
# Game #  1403 Game length  1975 Max score  2048 Game score  35900
# Game #  1404 Game length  998 Max score  1024 Game score  15868
# Game #  1405 Game length  1498 Max score  2048 Game score  27048
# Game #  1406 Game length  562 Max score  512 Game score  7604
# Game #  1407 Game length  1036 Max score  1024 Game score  16436
# Game #  1408 Game length  1859 Max score  2048 Game score  34264
# Game #  1409 Game length  1084 Max score  1024 Game score  17024
# Game #  1410 Game length  1194 Max score  1024 Game score  18980
# Game #  1411 Game length  2449 Max score  2048 Game score  44380
# Game #  1412 Game length  1824 Max score  2048 Game score  32984
# Game #  1413 Game length  923 Max score  1024 Game score  14776
# Game #  1414 Game length  1579 Max score  2048 Game score  28868
# Game #  1415 Game length  2058 Max score  2048 Game score  36908
# Game #  1416 Game length  1007 Max score  1024 Game score  16136
# Game #  1417 Game length  1307 Max score  2048 Game score  23724
# Game #  1418 Game length  1448 Max score  2048 Game score  26120
# Game #  1419 Game length  478 Max score  512 Game score  6568
# Game #  1420 Game length  2201 Max score  2048 Game score  40416
# Game #  1421 Game length  2040 Max score  2048 Game score  36764
# Game #  1422 Game length  806 Max score  1024 Game score  12540
# Game #  1423 Game length  487 Max score  512 Game score  6820
# Game #  1424 Game length  779 Max score  1024 Game score  12324
# Game #  1425 Game length  2111 Max score  2048 Game score  37836
# Game #  1426 Game length  1037 Max score  1024 Game score  16420
# Game #  1427 Game length  2069 Max score  2048 Game score  37016
# Game #  1428 Game length  839 Max score  1024 Game score  12896
# Game #  1429 Game length  973 Max score  1024 Game score  15424
# Game #  1430 Game length  1052 Max score  1024 Game score  16568
# Game #  1431 Game length  2552 Max score  2048 Game score  47944
# Game #  1432 Game length  1427 Max score  2048 Game score  25948
# Game #  1433 Game length  1531 Max score  2048 Game score  27560
# Game #  1434 Game length  1544 Max score  2048 Game score  27676
# Game #  1435 Game length  1041 Max score  1024 Game score  16472
# Game #  1436 Game length  935 Max score  1024 Game score  14908
# Game #  1437 Game length  1566 Max score  2048 Game score  27852
# Game #  1438 Game length  972 Max score  1024 Game score  15420
# Game #  1439 Game length  1799 Max score  2048 Game score  32764
# Game #  1440 Game length  1536 Max score  2048 Game score  27536
# Game #  1441 Game length  519 Max score  512 Game score  7148
# Game #  1442 Game length  1051 Max score  1024 Game score  16572
# Game #  1443 Game length  2029 Max score  2048 Game score  36488
# Game #  1444 Game length  1313 Max score  2048 Game score  23740
# Game #  1445 Game length  943 Max score  1024 Game score  14988
# Game #  1446 Game length  1255 Max score  1024 Game score  19316
# Game #  1447 Game length  1048 Max score  1024 Game score  16544
# Game #  1448 Game length  2163 Max score  2048 Game score  38956
# Game #  1449 Game length  1020 Max score  1024 Game score  16240
# Game #  1450 Game length  2884 Max score  4096 Game score  58796
# Game #  1451 Game length  1049 Max score  1024 Game score  16552
# Game #  1452 Game length  1512 Max score  2048 Game score  27228
# Game #  1453 Game length  1024 Max score  1024 Game score  16332
# Game #  1454 Game length  1716 Max score  2048 Game score  31772
# Game #  1455 Game length  835 Max score  1024 Game score  12876
# Game #  1456 Game length  1919 Max score  2048 Game score  34956
# Game #  1457 Game length  2078 Max score  2048 Game score  37076
# Game #  1458 Game length  2104 Max score  2048 Game score  37368
# Game #  1459 Game length  1367 Max score  2048 Game score  25196
# Game #  1460 Game length  951 Max score  1024 Game score  15068
# Game #  1461 Game length  1030 Max score  1024 Game score  16028
# Game #  1462 Game length  556 Max score  512 Game score  7536
# Game #  1463 Game length  1526 Max score  2048 Game score  27324
# Game #  1464 Game length  890 Max score  1024 Game score  14432
# Game #  1465 Game length  1598 Max score  2048 Game score  28180
# Game #  1466 Game length  1319 Max score  2048 Game score  23808
# Game #  1467 Game length  1075 Max score  1024 Game score  16820
# Game #  1468 Game length  1288 Max score  1024 Game score  20456
# Game #  1469 Game length  1063 Max score  1024 Game score  16732
# Game #  1470 Game length  1051 Max score  1024 Game score  16572
# Game #  1471 Game length  1257 Max score  1024 Game score  20072
# Game #  1472 Game length  2013 Max score  2048 Game score  36296
# Game #  1473 Game length  2009 Max score  2048 Game score  36264
# Game #  1474 Game length  1116 Max score  1024 Game score  17600
# Game #  1475 Game length  1550 Max score  2048 Game score  27716
# Game #  1476 Game length  1763 Max score  2048 Game score  32408
# Game #  1477 Game length  1044 Max score  1024 Game score  16524
# Game #  1478 Game length  1037 Max score  1024 Game score  16412
# Game #  1479 Game length  512 Max score  512 Game score  7100
# Game #  1480 Game length  604 Max score  512 Game score  8128
# Game #  1481 Game length  1054 Max score  1024 Game score  16588
# Game #  1482 Game length  571 Max score  512 Game score  7664
# Game #  1483 Game length  1937 Max score  2048 Game score  35168
# Game #  1484 Game length  1967 Max score  2048 Game score  34156
# Game #  1485 Game length  673 Max score  1024 Game score  10752
# Game #  1486 Game length  1489 Max score  2048 Game score  26712
# Game #  1487 Game length  2220 Max score  2048 Game score  39080
# Game #  1488 Game length  1046 Max score  1024 Game score  16536
# Game #  1489 Game length  1939 Max score  2048 Game score  35168
# Game #  1490 Game length  961 Max score  1024 Game score  15504
# Game #  1491 Game length  3005 Max score  4096 Game score  60172
# Game #  1492 Game length  1053 Max score  1024 Game score  16580
# Game #  1493 Game length  569 Max score  512 Game score  7656
# Game #  1494 Game length  986 Max score  1024 Game score  15756
# Game #  1495 Game length  1308 Max score  1024 Game score  20680
# Game #  1496 Game length  785 Max score  1024 Game score  12396
# Game #  1497 Game length  571 Max score  512 Game score  7788
# Game #  1498 Game length  1045 Max score  1024 Game score  16504
# Game #  1499 Game length  1070 Max score  1024 Game score  16792
# Game #  1500 Game length  1047 Max score  1024 Game score  16512
# Game #  1501 Game length  2364 Max score  2048 Game score  42520
# Game #  1502 Game length  1454 Max score  2048 Game score  25740
# Game #  1503 Game length  2011 Max score  2048 Game score  36024
# Game #  1504 Game length  1836 Max score  2048 Game score  33096
# Game #  1505 Game length  2023 Max score  2048 Game score  36444
# Game #  1506 Game length  2025 Max score  2048 Game score  36576
# Game #  1507 Game length  651 Max score  512 Game score  9004
# Game #  1508 Game length  615 Max score  512 Game score  8228
# Game #  1509 Game length  278 Max score  256 Game score  3176
# Game #  1510 Game length  1553 Max score  2048 Game score  27760
# Game #  1511 Game length  1488 Max score  2048 Game score  26956
# Game #  1512 Game length  551 Max score  512 Game score  7428
# Game #  1513 Game length  1893 Max score  2048 Game score  34044
# Game #  1514 Game length  1320 Max score  1024 Game score  20792
# Game #  1515 Game length  468 Max score  512 Game score  6492
# Game #  1516 Game length  1791 Max score  2048 Game score  32700
# Game #  1517 Game length  558 Max score  512 Game score  7560
# Game #  1518 Game length  1567 Max score  2048 Game score  27856
# Game #  1519 Game length  944 Max score  1024 Game score  14936
# Game #  1520 Game length  1063 Max score  1024 Game score  16732
# Game #  1521 Game length  1133 Max score  1024 Game score  17920
# Game #  1522 Game length  1435 Max score  2048 Game score  26028
# Game #  1523 Game length  2158 Max score  2048 Game score  38412
# Game #  1524 Game length  1619 Max score  2048 Game score  28556
# Game #  1525 Game length  2310 Max score  2048 Game score  42008
# Game #  1526 Game length  1500 Max score  2048 Game score  26820
# Game #  1527 Game length  675 Max score  1024 Game score  10716
# Game #  1528 Game length  979 Max score  1024 Game score  15708
# Game #  1529 Game length  1043 Max score  1024 Game score  16520
# Game #  1530 Game length  1161 Max score  1024 Game score  18216
# Game #  1531 Game length  1075 Max score  1024 Game score  16844
# Game #  1532 Game length  1305 Max score  2048 Game score  23688
# Game #  1533 Game length  1684 Max score  2048 Game score  29560
# Game #  1534 Game length  924 Max score  1024 Game score  14768
# Game #  1535 Game length  1015 Max score  1024 Game score  16092
# Game #  1536 Game length  2170 Max score  2048 Game score  38584
# Game #  1537 Game length  2831 Max score  4096 Game score  57420
# Game #  1538 Game length  1017 Max score  1024 Game score  16224
# Game #  1539 Game length  1060 Max score  1024 Game score  16632
# Game #  1540 Game length  775 Max score  1024 Game score  12292
# Game #  1541 Game length  1308 Max score  2048 Game score  23740
# Game #  1542 Game length  563 Max score  512 Game score  7596
# Game #  1543 Game length  1021 Max score  1024 Game score  16136
# Game #  1544 Game length  566 Max score  512 Game score  7612
# Game #  1545 Game length  665 Max score  1024 Game score  10628
# Game #  1546 Game length  545 Max score  512 Game score  7384
# Game #  1547 Game length  2205 Max score  2048 Game score  39372
# Game #  1548 Game length  1116 Max score  1024 Game score  17352
# Game #  1549 Game length  2067 Max score  2048 Game score  37004
# Game #  1550 Game length  1027 Max score  1024 Game score  16288
# Game #  1551 Game length  592 Max score  512 Game score  8268
# Game #  1552 Game length  1558 Max score  2048 Game score  27800
# Game #  1553 Game length  2538 Max score  2048 Game score  47736
# Game #  1554 Game length  1423 Max score  2048 Game score  25924
# Game #  1555 Game length  1608 Max score  1024 Game score  27164
# Game #  1556 Game length  712 Max score  1024 Game score  11080
# Game #  1557 Game length  1547 Max score  1024 Game score  25660
# Game #  1558 Game length  1613 Max score  2048 Game score  28736
# Game #  1559 Game length  1039 Max score  1024 Game score  16460
# Game #  1560 Game length  1810 Max score  2048 Game score  32860
# Game #  1561 Game length  1025 Max score  1024 Game score  16336
# Game #  1562 Game length  1543 Max score  2048 Game score  27644
# Game #  1563 Game length  1035 Max score  1024 Game score  16428
# Game #  1564 Game length  339 Max score  256 Game score  3932
# Game #  1565 Game length  1161 Max score  2048 Game score  21756
# Game #  1566 Game length  540 Max score  512 Game score  7356
# Game #  1567 Game length  1110 Max score  1024 Game score  17308
# Game #  1568 Game length  547 Max score  512 Game score  7464
# Game #  1569 Game length  1094 Max score  1024 Game score  17148
# Game #  1570 Game length  1823 Max score  2048 Game score  32980
# Game #  1571 Game length  1039 Max score  1024 Game score  16460
# Game #  1572 Game length  3090 Max score  4096 Game score  61576
# Game #  1573 Game length  2104 Max score  2048 Game score  37368
# Game #  1574 Game length  1077 Max score  1024 Game score  17036
# Game #  1575 Game length  1877 Max score  2048 Game score  33564
# Game #  1576 Game length  1039 Max score  1024 Game score  16460
# Game #  1577 Game length  1571 Max score  2048 Game score  27976
# Game #  1578 Game length  401 Max score  512 Game score  5452
# Game #  1579 Game length  1413 Max score  2048 Game score  25644
# Game #  1580 Game length  1032 Max score  1024 Game score  16412
# Game #  1581 Game length  2053 Max score  2048 Game score  36712
# Game #  1582 Game length  1822 Max score  2048 Game score  32972
# Game #  1583 Game length  1004 Max score  1024 Game score  15996
# Game #  1584 Game length  483 Max score  512 Game score  6620
# Game #  1585 Game length  568 Max score  512 Game score  7592
# Game #  1586 Game length  1897 Max score  2048 Game score  34600
# Game #  1587 Game length  2194 Max score  2048 Game score  39292
# Game #  1588 Game length  1098 Max score  1024 Game score  17084
# Game #  1589 Game length  1312 Max score  2048 Game score  23760
# Game #  1590 Game length  1557 Max score  1024 Game score  25752
# Game #  1591 Game length  1782 Max score  2048 Game score  32556
# Game #  1592 Game length  1174 Max score  1024 Game score  18332
# Game #  1593 Game length  1683 Max score  2048 Game score  31068
# Game #  1594 Game length  1044 Max score  1024 Game score  16488
# Game #  1595 Game length  1550 Max score  2048 Game score  27708
# Game #  1596 Game length  2189 Max score  2048 Game score  39240
# Game #  1597 Game length  1791 Max score  2048 Game score  32712
# Game #  1598 Game length  1071 Max score  1024 Game score  16908
# Game #  1599 Game length  988 Max score  1024 Game score  15792
# Game #  1600 Game length  2070 Max score  2048 Game score  37004
# Game #  1601 Game length  1547 Max score  2048 Game score  27692
# Game #  1602 Game length  790 Max score  1024 Game score  12396
# Game #  1603 Game length  934 Max score  1024 Game score  14376
# Game #  1604 Game length  1621 Max score  2048 Game score  30316
# Game #  1605 Game length  1051 Max score  1024 Game score  16632
# Game #  1606 Game length  2020 Max score  2048 Game score  36344
# Game #  1607 Game length  2062 Max score  2048 Game score  36940
# Game #  1608 Game length  1691 Max score  2048 Game score  31132
# Game #  1609 Game length  986 Max score  1024 Game score  15792
# Game #  1610 Game length  523 Max score  512 Game score  7208
# Game #  1611 Game length  936 Max score  1024 Game score  14856
# Game #  1612 Game length  991 Max score  1024 Game score  15820
# Game #  1613 Game length  1491 Max score  2048 Game score  26972
# Game #  1614 Game length  1319 Max score  2048 Game score  23808
# Game #  1615 Game length  1041 Max score  1024 Game score  16496
# Game #  1616 Game length  1073 Max score  1024 Game score  16832
# Game #  1617 Game length  2008 Max score  2048 Game score  36256
# Game #  1618 Game length  1939 Max score  2048 Game score  35180
# Game #  1619 Game length  2055 Max score  2048 Game score  36892
# Game #  1620 Game length  2090 Max score  2048 Game score  37244
# Game #  1621 Game length  1032 Max score  1024 Game score  16412
# Game #  1622 Game length  915 Max score  1024 Game score  14684
# Game #  1623 Game length  1554 Max score  2048 Game score  27708
# Game #  1624 Game length  792 Max score  1024 Game score  12416
# Game #  1625 Game length  574 Max score  512 Game score  7692
# Game #  1626 Game length  2121 Max score  2048 Game score  37688
# Game #  1627 Game length  1003 Max score  1024 Game score  15980
# Game #  1628 Game length  584 Max score  512 Game score  7784
# Game #  1629 Game length  1998 Max score  2048 Game score  35820

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

test(model)
# Out:
# epoch 1 2026 2048 36412 0
# epoch 2 2040 2048 36680 0
# epoch 3 1060 1024 16660 0
# epoch 4 801 1024 12488 0
# epoch 5 727 1024 11628 0
# epoch 6 1042 1024 16476 0
# epoch 7 796 1024 12476 0
# epoch 8 925 1024 14280 0
# epoch 9 1552 2048 27728 0
# epoch 10 1801 2048 32800 0
# epoch 11 1547 2048 27692 0
# epoch 12 1054 1024 16588 0
# epoch 13 1038 1024 16456 0
# epoch 14 1031 1024 16408 0
# epoch 15 1864 2048 33568 0
# epoch 16 1809 2048 32856 0
# epoch 17 1822 2048 32972 0
# epoch 18 1553 2048 27736 0
# epoch 19 1823 2048 32980 0
# epoch 20 569 512 7628 0
# epoch 21 1617 2048 29264 0
# epoch 22 2048 2048 36760 0
# epoch 23 1042 1024 16476 0
# epoch 24 1044 1024 16488 0
# epoch 25 1553 2048 27760 0
# epoch 26 1004 1024 15984 0
# epoch 27 1972 2048 35884 0
# epoch 28 1041 1024 16472 0
# epoch 29 2080 2048 37264 0
# epoch 30 1559 2048 27804 0
# epoch 31 1488 2048 26956 0
# epoch 32 1813 2048 32888 0
# epoch 33 1914 2048 34892 0
# epoch 34 1544 2048 27648 0
# epoch 35 1058 1024 16620 0
# epoch 36 975 1024 15676 0
# epoch 37 1054 1024 16588 0
# epoch 38 980 1024 15716 0
# epoch 39 1149 1024 18056 0
# epoch 40 604 512 8120 0
# epoch 41 1683 2048 29580 0
# epoch 42 1879 2048 33672 0
# epoch 43 1547 2048 27692 0
# epoch 44 574 512 7692 0
# epoch 45 1027 1024 16348 0
# epoch 46 1819 2048 32944 0
# epoch 47 2030 2048 36492 0
# epoch 48 1577 2048 28008 0
# epoch 49 1022 1024 16140 0
# epoch 50 1033 1024 16392 0
# epoch 51 1846 2048 33244 0
# epoch 52 1895 2048 34732 0
# epoch 53 1048 1024 16544 0
# epoch 54 2011 2048 36284 0
# epoch 55 1039 1024 16460 0
# epoch 56 1315 2048 23788 0
# epoch 57 992 1024 15800 0
# epoch 58 1882 2048 34472 0
# epoch 59 2798 4096 56908 0
# epoch 60 1561 2048 27872 0
# epoch 61 878 1024 13692 0
# epoch 62 795 512 11440 0
# epoch 63 1042 1024 16476 0
# epoch 64 1961 2048 35552 0
# epoch 65 1593 2048 28140 0
# epoch 66 1047 1024 16540 0
# epoch 67 1814 2048 32892 0
# epoch 68 1527 2048 27452 0
# epoch 69 1860 2048 33772 0
# epoch 70 2774 4096 56712 0
# epoch 71 1747 2048 32092 0
# epoch 72 1063 1024 16732 0
# epoch 73 1721 2048 31464 0
# epoch 74 1109 1024 17288 0
# epoch 75 1126 1024 17872 0
# epoch 76 1381 2048 25320 0
# epoch 77 1140 1024 17624 0
# epoch 78 1045 1024 16504 0
# epoch 79 2906 4096 58540 0
# epoch 80 2061 2048 36936 0
# epoch 81 1765 2048 32444 0
# epoch 82 1775 2048 31500 0
# epoch 83 1822 2048 32948 0
# epoch 84 1606 2048 28676 0
# epoch 85 1936 2048 35152 0
# epoch 86 861 1024 13256 0
# epoch 87 2057 2048 36904 0
# epoch 88 2088 2048 37224 0
# epoch 89 1011 1024 16156 0
# epoch 90 925 1024 14776 0
# epoch 91 1987 2048 36012 0
# epoch 92 538 512 7308 0
# epoch 93 1053 1024 16572 0
# epoch 94 1040 1024 16464 0
# epoch 95 1582 2048 28044 0
# epoch 96 1042 1024 16476 0
# epoch 97 1292 1024 20544 0
# epoch 98 1053 1024 16640 0
# epoch 99 1023 1024 16268 0
# epoch 100 1620 2048 28536 0
