# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np
import random

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=256, filter2=2048, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        self.conv_c = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_cc = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)
        self.W_cc = nn.Linear(filter2 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        c = self.relu(self.conv_c(x))
        aa = self.flatten(self.relu(self.conv_aa(a)))
        ab = self.flatten(self.relu(self.conv_ab(a)))
        ba = self.flatten(self.relu(self.conv_ba(b)))
        bb = self.flatten(self.relu(self.conv_bb(b)))
        cc = self.flatten(self.relu(self.conv_cc(c)))
        out = self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) + self.W_cc(cc)
        return out

# %%
def make_input(grid):
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            r[grid[i, j],i, j]=1
    return r

def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 1
    return mat

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = False, explorationProb=0.1):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    last_loss = 0

    while True:
        grid_array = add_two(last_grid1)
        board_list = getMove(grid_array)
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len += 1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
                v = (s - game_score) + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_score = s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y) / 2
            last_loss = loss.item()
            loss.backward()
#             nn.utils.clip_grad_norm_(model.parameters(), 10.0) #
            optimizer.step()
            model.eval()
#             if game_len % 50 == 0:
#                 print (game_len, last_loss)
                
        if not board_list:
            break
            
        # gibbs sampling or espilon-greedy
        if is_train and random.random() < explorationProb:
            idx = random.randint(0, len(board_list) - 1)
            game_score = board_list[idx][2]
            last_grid1 = board_list[idx][0]
            last_grid2 = boards[idx]
        else:
            game_score = best_score
            last_grid1 = best_grid1
            last_grid2 = best_grid2
        
    return game_len, 2**grid_array.max(), game_score, last_loss

# %%
lr = 1e-4
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = "model"

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)

# %%
def load_model(model, optimizer, checkpoint_path):
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    optimizer.load_state_dict(ckpt_dict['optimizer'])
    epoch = ckpt_dict['epoch']
    return model, optimizer, epoch

model, optimizer, epoch = load_model(model, optimizer, "model/model8_1500.pth.tar")

# %%
num_epochs = 5000

def train(model, optimizer, loss, epoch = 0):
    ls = [1024] * 10
    running_mean = 2048
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, optimizer, loss, True, 0)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean:
            running_mean = sum(ls) / 10
            filename = "model8_"+str(epoch // 100)+".pth.tar"
            save_model({
                'epoch': epoch,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            model.cuda()
    
    
train(model, optimizer, loss, epoch)
# Out:
# Game #  1501 Game length  1057 Max score  1024 Game score  16616
# Game #  1502 Game length  1929 Max score  2048 Game score  34600
# Game #  1503 Game length  1751 Max score  2048 Game score  32124
# Game #  1504 Game length  1262 Max score  1024 Game score  20108
# Game #  1505 Game length  1513 Max score  2048 Game score  27356
# Game #  1506 Game length  1057 Max score  1024 Game score  16616
# Game #  1507 Game length  1979 Max score  2048 Game score  35948
# Game #  1508 Game length  559 Max score  512 Game score  7564
# Game #  1509 Game length  1039 Max score  1024 Game score  16460
# Game #  1510 Game length  1573 Max score  2048 Game score  27984
# Game #  1511 Game length  1833 Max score  2048 Game score  33128
# Game #  1512 Game length  1627 Max score  1024 Game score  26568
# Game #  1513 Game length  1998 Max score  2048 Game score  35412
# Game #  1514 Game length  2774 Max score  4096 Game score  56696
# Game #  1515 Game length  1072 Max score  1024 Game score  16912
# Game #  1516 Game length  982 Max score  1024 Game score  15760
# Game #  1517 Game length  1250 Max score  2048 Game score  23000
# Game #  1518 Game length  1100 Max score  1024 Game score  17456
# Game #  1519 Game length  1535 Max score  2048 Game score  27592
# Game #  1520 Game length  1109 Max score  1024 Game score  17528
# Game #  1521 Game length  1941 Max score  2048 Game score  35220
# Game #  1522 Game length  1792 Max score  2048 Game score  32656
# Game #  1523 Game length  1028 Max score  1024 Game score  16352
# Game #  1524 Game length  2812 Max score  4096 Game score  57260
# Game #  1525 Game length  1227 Max score  2048 Game score  22540
# Game #  1526 Game length  803 Max score  1024 Game score  12512
# Game #  1527 Game length  801 Max score  1024 Game score  12504
# Game #  1528 Game length  1803 Max score  2048 Game score  32812
# Game #  1529 Game length  951 Max score  1024 Game score  15068
# Game #  1530 Game length  1012 Max score  1024 Game score  15992
# Game #  1531 Game length  1037 Max score  1024 Game score  16448
# Game #  1532 Game length  1616 Max score  2048 Game score  28588
# Game #  1533 Game length  554 Max score  512 Game score  7500
# Game #  1534 Game length  1464 Max score  1024 Game score  22904
# Game #  1535 Game length  2796 Max score  4096 Game score  57068
# Game #  1536 Game length  943 Max score  1024 Game score  15112
# Game #  1537 Game length  1514 Max score  2048 Game score  27360
# Game #  1538 Game length  1484 Max score  2048 Game score  26924
# Game #  1539 Game length  1818 Max score  2048 Game score  32940
# Game #  1540 Game length  867 Max score  1024 Game score  13300
# Game #  1541 Game length  1071 Max score  1024 Game score  16880
# Game #  1542 Game length  1699 Max score  2048 Game score  31200
# Game #  1543 Game length  617 Max score  512 Game score  8488
# Game #  1544 Game length  1031 Max score  1024 Game score  16404
# Game #  1545 Game length  1080 Max score  1024 Game score  16884
# Game #  1546 Game length  1076 Max score  1024 Game score  16824
# Game #  1547 Game length  1904 Max score  2048 Game score  34704
# Game #  1548 Game length  2323 Max score  2048 Game score  42124
# Game #  1549 Game length  1053 Max score  1024 Game score  16584
# Game #  1550 Game length  1951 Max score  2048 Game score  35284
# Game #  1551 Game length  1819 Max score  2048 Game score  33004
# Game #  1552 Game length  1964 Max score  2048 Game score  35820
# Game #  1553 Game length  1560 Max score  2048 Game score  27868
# Game #  1554 Game length  2825 Max score  4096 Game score  57376
# Game #  1555 Game length  1791 Max score  2048 Game score  32652
# Game #  1556 Game length  726 Max score  512 Game score  10616
# Game #  1557 Game length  1020 Max score  1024 Game score  16244
# Game #  1558 Game length  608 Max score  512 Game score  8152
# Game #  1559 Game length  2346 Max score  2048 Game score  44408
# Game #  1560 Game length  2034 Max score  2048 Game score  36348
# Game #  1561 Game length  1592 Max score  2048 Game score  28508
# Game #  1562 Game length  984 Max score  1024 Game score  15832
# Game #  1563 Game length  1631 Max score  2048 Game score  29388
# Game #  1564 Game length  1812 Max score  2048 Game score  32908
# Game #  1565 Game length  565 Max score  512 Game score  7596
# Game #  1566 Game length  791 Max score  1024 Game score  12412
# Game #  1567 Game length  1038 Max score  1024 Game score  16456
# Game #  1568 Game length  1428 Max score  2048 Game score  25964
# Game #  1569 Game length  985 Max score  1024 Game score  15776
# Game #  1570 Game length  1084 Max score  1024 Game score  16904
# Game #  1571 Game length  1702 Max score  2048 Game score  31256
# Game #  1572 Game length  930 Max score  1024 Game score  14812
# Game #  1573 Game length  1189 Max score  1024 Game score  19000
# Game #  1574 Game length  921 Max score  1024 Game score  14728
# Game #  1575 Game length  2032 Max score  2048 Game score  36504
# Game #  1576 Game length  1157 Max score  1024 Game score  17820
# Game #  1577 Game length  1849 Max score  2048 Game score  33272
# Game #  1578 Game length  1680 Max score  2048 Game score  31052
# Game #  1579 Game length  1030 Max score  1024 Game score  16400
# Game #  1580 Game length  1075 Max score  1024 Game score  16760
# Game #  1581 Game length  1291 Max score  2048 Game score  23592
# Game #  1582 Game length  1876 Max score  2048 Game score  33680
# Game #  1583 Game length  2062 Max score  2048 Game score  36940
# Game #  1584 Game length  793 Max score  1024 Game score  12424
# Game #  1585 Game length  2981 Max score  4096 Game score  59900
# Game #  1586 Game length  1048 Max score  1024 Game score  16520
# Game #  1587 Game length  2776 Max score  2048 Game score  52280
# Game #  1588 Game length  2028 Max score  2048 Game score  36592
# Game #  1589 Game length  1798 Max score  2048 Game score  32784
# Game #  1590 Game length  411 Max score  512 Game score  5516
# Game #  1591 Game length  1027 Max score  1024 Game score  16300
# Game #  1592 Game length  1441 Max score  2048 Game score  26072
# Game #  1593 Game length  1548 Max score  2048 Game score  27696
# Game #  1594 Game length  1266 Max score  2048 Game score  23312
# Game #  1595 Game length  1093 Max score  1024 Game score  17384
# Game #  1596 Game length  544 Max score  512 Game score  7376
# Game #  1597 Game length  818 Max score  1024 Game score  12652
# Game #  1598 Game length  1055 Max score  1024 Game score  16596
# Game #  1599 Game length  1539 Max score  2048 Game score  27612
# Game #  1600 Game length  1077 Max score  1024 Game score  16856
# Game #  1601 Game length  915 Max score  1024 Game score  14684
# Game #  1602 Game length  1540 Max score  2048 Game score  27616
# Game #  1603 Game length  3535 Max score  4096 Game score  72012
# Game #  1604 Game length  1922 Max score  2048 Game score  34972
# Game #  1605 Game length  774 Max score  1024 Game score  12288
# Game #  1606 Game length  1573 Max score  2048 Game score  27928
# Game #  1607 Game length  2055 Max score  2048 Game score  36868
# Game #  1608 Game length  1269 Max score  2048 Game score  23328
# Game #  1609 Game length  1114 Max score  1024 Game score  17340
# Game #  1610 Game length  1301 Max score  2048 Game score  23656
# Game #  1611 Game length  1032 Max score  1024 Game score  16412
# Game #  1612 Game length  1808 Max score  2048 Game score  32848
# Game #  1613 Game length  3013 Max score  4096 Game score  60600
# Game #  1614 Game length  917 Max score  1024 Game score  14696
# Game #  1615 Game length  969 Max score  1024 Game score  15368
# Game #  1616 Game length  1530 Max score  2048 Game score  27496
# Game #  1617 Game length  1078 Max score  1024 Game score  16860
# Game #  1618 Game length  1205 Max score  1024 Game score  20152
# Game #  1619 Game length  1660 Max score  2048 Game score  30800
# Game #  1620 Game length  1013 Max score  1024 Game score  16080
# Game #  1621 Game length  509 Max score  512 Game score  6664
# Game #  1622 Game length  1047 Max score  1024 Game score  16516
# Game #  1623 Game length  1056 Max score  1024 Game score  16600
# Game #  1624 Game length  993 Max score  1024 Game score  15832
# Game #  1625 Game length  1574 Max score  2048 Game score  27908
# Game #  1626 Game length  1875 Max score  2048 Game score  33676
# Game #  1627 Game length  1561 Max score  2048 Game score  27812
# Game #  1630 Game length  2512 Max score  4096 Game score  51532
# Game #  1631 Game length  1003 Max score  1024 Game score  15932
# Game #  1632 Game length  1992 Max score  2048 Game score  36124
# Game #  1633 Game length  1810 Max score  2048 Game score  32896
# Game #  1634 Game length  2852 Max score  4096 Game score  57652
# Game #  1637 Game length  1850 Max score  2048 Game score  33276
# Game #  1638 Game length  2046 Max score  2048 Game score  36748
# Game #  1639 Game length  1751 Max score  2048 Game score  32124
# Game #  1640 Game length  1933 Max score  2048 Game score  35128
# Game #  1641 Game length  802 Max score  1024 Game score  12508
# Game #  1642 Game length  1048 Max score  1024 Game score  16556
# Game #  1643 Game length  571 Max score  512 Game score  7592
# Game #  1644 Game length  2127 Max score  2048 Game score  37756
# Game #  1645 Game length  1064 Max score  1024 Game score  16740
# Game #  1646 Game length  820 Max score  1024 Game score  12664
# Game #  1647 Game length  2892 Max score  4096 Game score  58176
# Game #  1648 Game length  1800 Max score  2048 Game score  32772
# Game #  1649 Game length  1068 Max score  1024 Game score  16892
# Game #  1650 Game length  1072 Max score  1024 Game score  16792
# Game #  1651 Game length  2078 Max score  2048 Game score  37100
# Game #  1652 Game length  967 Max score  1024 Game score  15356
# Game #  1653 Game length  1502 Max score  1024 Game score  25036
# Game #  1657 Game length  1067 Max score  1024 Game score  16764
# Game #  1658 Game length  1848 Max score  2048 Game score  33256
# Game #  1659 Game length  1289 Max score  1024 Game score  21368
# Game #  1660 Game length  1041 Max score  1024 Game score  16472
# Game #  1661 Game length  524 Max score  512 Game score  7164
# Game #  1662 Game length  1774 Max score  2048 Game score  31400
# Game #  1663 Game length  2200 Max score  2048 Game score  38840
# Game #  1664 Game length  511 Max score  512 Game score  7036
# Game #  1665 Game length  1594 Max score  2048 Game score  28156
# Game #  1666 Game length  1000 Max score  1024 Game score  16088
# Game #  1667 Game length  2179 Max score  2048 Game score  38668
# Game #  1668 Game length  1874 Max score  2048 Game score  34400
# Game #  1669 Game length  1684 Max score  2048 Game score  31072
# Game #  1670 Game length  1038 Max score  1024 Game score  16452
# Game #  1671 Game length  672 Max score  512 Game score  9176
# Game #  1672 Game length  3040 Max score  4096 Game score  60924
# Game #  1673 Game length  1301 Max score  2048 Game score  23664
# Game #  1674 Game length  2008 Max score  2048 Game score  36064
# Game #  1675 Game length  477 Max score  512 Game score  6636
# Game #  1676 Game length  2285 Max score  2048 Game score  41720
# Game #  1677 Game length  1041 Max score  1024 Game score  16472
# Game #  1678 Game length  1911 Max score  2048 Game score  34780
# Game #  1679 Game length  1862 Max score  2048 Game score  33436
# Game #  1680 Game length  1826 Max score  2048 Game score  33032
# Game #  1681 Game length  1563 Max score  2048 Game score  27836
# Game #  1682 Game length  2066 Max score  2048 Game score  36988
# Game #  1683 Game length  1038 Max score  1024 Game score  16480
# Game #  1684 Game length  1031 Max score  1024 Game score  16200
# Game #  1685 Game length  2905 Max score  4096 Game score  59040
# Game #  1686 Game length  1550 Max score  2048 Game score  27720
# Game #  1687 Game length  542 Max score  512 Game score  7368
# Game #  1688 Game length  1048 Max score  1024 Game score  16548
# Game #  1689 Game length  1470 Max score  2048 Game score  26380
# Game #  1690 Game length  2542 Max score  4096 Game score  51816
# Game #  1691 Game length  1604 Max score  2048 Game score  28400
# Game #  1692 Game length  942 Max score  1024 Game score  14924
# Game #  1693 Game length  1696 Max score  2048 Game score  31184
# Game #  1694 Game length  1365 Max score  2048 Game score  24464
# Game #  1695 Game length  1464 Max score  2048 Game score  26340
# Game #  1698 Game length  1831 Max score  2048 Game score  33452
# Game #  1699 Game length  1581 Max score  2048 Game score  28160
# Game #  1700 Game length  3168 Max score  4096 Game score  64220
# Game #  1701 Game length  1056 Max score  1024 Game score  16600
# Game #  1702 Game length  1526 Max score  2048 Game score  27472
# Game #  1703 Game length  1042 Max score  1024 Game score  16488
# Game #  1704 Game length  2052 Max score  2048 Game score  36840
# Game #  1705 Game length  1586 Max score  2048 Game score  28104
# Game #  1706 Game length  1717 Max score  2048 Game score  31440
# Game #  1707 Game length  832 Max score  1024 Game score  12808
# Game #  1708 Game length  2085 Max score  2048 Game score  37208
# Game #  1709 Game length  1032 Max score  1024 Game score  16412
# Game #  1710 Game length  1063 Max score  1024 Game score  16732
# Game #  1711 Game length  637 Max score  512 Game score  8712
# Game #  1712 Game length  1038 Max score  1024 Game score  16444
# Game #  1713 Game length  487 Max score  512 Game score  6652
# Game #  1714 Game length  1313 Max score  2048 Game score  23768
# Game #  1715 Game length  1096 Max score  1024 Game score  17160
# Game #  1716 Game length  1125 Max score  1024 Game score  17496
# Game #  1717 Game length  1300 Max score  1024 Game score  20600
# Game #  1718 Game length  1659 Max score  2048 Game score  29284
# Game #  1719 Game length  2570 Max score  4096 Game score  52260
# Game #  1720 Game length  2001 Max score  2048 Game score  35848
# Game #  1721 Game length  1797 Max score  2048 Game score  32780
# Game #  1722 Game length  1968 Max score  2048 Game score  35840
# Game #  1723 Game length  1781 Max score  2048 Game score  32576
# Game #  1724 Game length  1039 Max score  1024 Game score  16460
# Game #  1725 Game length  1561 Max score  2048 Game score  27872
# Game #  1726 Game length  1062 Max score  1024 Game score  16700
# Game #  1727 Game length  937 Max score  1024 Game score  14944
# Game #  1728 Game length  1957 Max score  2048 Game score  35408
# Game #  1729 Game length  1999 Max score  2048 Game score  36172
# Game #  1730 Game length  1044 Max score  1024 Game score  16572
# Game #  1731 Game length  1608 Max score  2048 Game score  28280
# Game #  1732 Game length  952 Max score  1024 Game score  15048
# Game #  1733 Game length  2062 Max score  2048 Game score  36940
# Game #  1734 Game length  1445 Max score  2048 Game score  26104
# Game #  1735 Game length  1871 Max score  2048 Game score  33560
# Game #  1736 Game length  1746 Max score  2048 Game score  32088
# Game #  1737 Game length  2295 Max score  2048 Game score  43740
# Game #  1738 Game length  1036 Max score  1024 Game score  16444
# Game #  1739 Game length  1575 Max score  2048 Game score  27996
# Game #  1740 Game length  1853 Max score  2048 Game score  33664
# Game #  1741 Game length  964 Max score  1024 Game score  15580
# Game #  1742 Game length  2111 Max score  2048 Game score  37564
# Game #  1743 Game length  2858 Max score  4096 Game score  57708
# Game #  1744 Game length  1157 Max score  1024 Game score  18124
# Game #  1745 Game length  1046 Max score  1024 Game score  16508
# Game #  1746 Game length  1846 Max score  2048 Game score  33236
# Game #  1747 Game length  1824 Max score  2048 Game score  33068
# Game #  1748 Game length  1054 Max score  1024 Game score  16588
# Game #  1749 Game length  1823 Max score  2048 Game score  32980
# Game #  1750 Game length  2897 Max score  4096 Game score  58120
# Game #  1751 Game length  2012 Max score  2048 Game score  36264
# Game #  1752 Game length  1040 Max score  1024 Game score  16464
# Game #  1753 Game length  1319 Max score  1024 Game score  21852
# Game #  1754 Game length  2046 Max score  2048 Game score  36748
# Game #  1755 Game length  1576 Max score  2048 Game score  28000
# Game #  1756 Game length  1592 Max score  2048 Game score  28316
# Game #  1757 Game length  2144 Max score  2048 Game score  37956
# Game #  1758 Game length  1869 Max score  2048 Game score  33608
# Game #  1759 Game length  2024 Max score  2048 Game score  36572
# Game #  1760 Game length  1085 Max score  1024 Game score  17080
# Game #  1761 Game length  994 Max score  1024 Game score  15836
# Game #  1762 Game length  1839 Max score  2048 Game score  33196
# Game #  1763 Game length  885 Max score  1024 Game score  13500
# Game #  1764 Game length  1070 Max score  1024 Game score  16780
# Game #  1765 Game length  812 Max score  512 Game score  11676
# Game #  1766 Game length  1862 Max score  2048 Game score  33436
# Game #  1767 Game length  1387 Max score  2048 Game score  24668
# Game #  1768 Game length  1107 Max score  1024 Game score  17144
# Game #  1769 Game length  944 Max score  1024 Game score  14440
# Game #  1770 Game length  1965 Max score  2048 Game score  35612
# Game #  1771 Game length  1038 Max score  1024 Game score  16456
# Game #  1772 Game length  548 Max score  512 Game score  7400
# Game #  1773 Game length  753 Max score  1024 Game score  11864
# Game #  1774 Game length  1032 Max score  1024 Game score  16328
# Game #  1775 Game length  1116 Max score  1024 Game score  17352
# Game #  1776 Game length  1056 Max score  1024 Game score  16600
# Game #  1777 Game length  1887 Max score  2048 Game score  33752
# Game #  1778 Game length  1112 Max score  1024 Game score  17552
# Game #  1779 Game length  2119 Max score  2048 Game score  37676
# Game #  1780 Game length  2334 Max score  4096 Game score  48328
# Game #  1781 Game length  1149 Max score  1024 Game score  18056
# Game #  1782 Game length  1700 Max score  2048 Game score  31220
# Game #  1783 Game length  1269 Max score  1024 Game score  20184
# Game #  1784 Game length  1194 Max score  1024 Game score  20012
# Game #  1785 Game length  956 Max score  1024 Game score  15080
# Game #  1786 Game length  1051 Max score  1024 Game score  16572
# Game #  1787 Game length  687 Max score  512 Game score  9372
# Game #  1788 Game length  1853 Max score  2048 Game score  33416
# Game #  1789 Game length  1389 Max score  2048 Game score  24712
# Game #  1790 Game length  915 Max score  1024 Game score  14684
# Game #  1791 Game length  1850 Max score  2048 Game score  33276
# Game #  1792 Game length  1048 Max score  1024 Game score  16544
# Game #  1793 Game length  2614 Max score  2048 Game score  47000
# Game #  1794 Game length  1052 Max score  1024 Game score  16576
# Game #  1795 Game length  1789 Max score  2048 Game score  32640
# Game #  1796 Game length  2203 Max score  2048 Game score  38856
# Game #  1797 Game length  1539 Max score  2048 Game score  27640
# Game #  1800 Game length  1550 Max score  2048 Game score  27720
# Game #  1801 Game length  913 Max score  1024 Game score  14168
# Game #  1802 Game length  1572 Max score  2048 Game score  27968
# Game #  1803 Game length  1852 Max score  2048 Game score  33288
# Game #  1804 Game length  2349 Max score  4096 Game score  48500
# Game #  1805 Game length  2951 Max score  4096 Game score  59644
# Game #  1806 Game length  1078 Max score  1024 Game score  16860
# Game #  1807 Game length  1079 Max score  1024 Game score  17240
# Game #  1808 Game length  1311 Max score  2048 Game score  23816
# Game #  1809 Game length  1982 Max score  2048 Game score  35976
# Game #  1810 Game length  2091 Max score  2048 Game score  37252
# Game #  1811 Game length  2068 Max score  2048 Game score  37008
# Game #  1812 Game length  1036 Max score  1024 Game score  16416
# Game #  1813 Game length  1919 Max score  2048 Game score  34508
# Game #  1814 Game length  938 Max score  1024 Game score  14924
# Game #  1815 Game length  1553 Max score  2048 Game score  27736
# Game #  1816 Game length  1054 Max score  1024 Game score  16588
# Game #  1817 Game length  1982 Max score  2048 Game score  35724
# Game #  1818 Game length  928 Max score  1024 Game score  14804
# Game #  1819 Game length  520 Max score  512 Game score  7104
# Game #  1820 Game length  1042 Max score  1024 Game score  16488
# Game #  1821 Game length  1076 Max score  1024 Game score  16824
# Game #  1822 Game length  1607 Max score  2048 Game score  28332
# Game #  1823 Game length  2852 Max score  4096 Game score  57676
# Game #  1824 Game length  1138 Max score  1024 Game score  17948
# Game #  1825 Game length  1877 Max score  2048 Game score  34408
# Game #  1826 Game length  3591 Max score  4096 Game score  72732
# Game #  1827 Game length  1904 Max score  2048 Game score  34828
# Game #  1828 Game length  1292 Max score  1024 Game score  21556
# Game #  1829 Game length  1744 Max score  2048 Game score  32076
# Game #  1830 Game length  1036 Max score  1024 Game score  16436
# Game #  1831 Game length  1084 Max score  1024 Game score  16904
# Game #  1832 Game length  1831 Max score  2048 Game score  33116
# Game #  1833 Game length  2061 Max score  2048 Game score  36936
# Game #  1834 Game length  933 Max score  1024 Game score  14828
# Game #  1835 Game length  1625 Max score  2048 Game score  29344
# Game #  1836 Game length  1545 Max score  2048 Game score  27680
# Game #  1837 Game length  1994 Max score  2048 Game score  35716
# Game #  1838 Game length  1059 Max score  1024 Game score  16684
# Game #  1839 Game length  1302 Max score  2048 Game score  23660
# Game #  1840 Game length  1850 Max score  2048 Game score  33276
# Game #  1841 Game length  2041 Max score  2048 Game score  36712
# Game #  1842 Game length  1120 Max score  1024 Game score  18128
# Game #  1843 Game length  2033 Max score  2048 Game score  36632
# Game #  1844 Game length  798 Max score  1024 Game score  12476
# Game #  1845 Game length  1926 Max score  2048 Game score  35088
# Game #  1846 Game length  1494 Max score  2048 Game score  26776
# Game #  1847 Game length  1042 Max score  1024 Game score  16476
# Game #  1848 Game length  1728 Max score  2048 Game score  31512
# Game #  1849 Game length  2768 Max score  4096 Game score  56652
# Game #  1850 Game length  2838 Max score  4096 Game score  57496
# Game #  1851 Game length  1055 Max score  1024 Game score  16620
# Game #  1852 Game length  1075 Max score  1024 Game score  16844
# Game #  1853 Game length  2047 Max score  2048 Game score  36812
# Game #  1854 Game length  1780 Max score  2048 Game score  32460
# Game #  1855 Game length  1039 Max score  1024 Game score  16460
# Game #  1856 Game length  951 Max score  1024 Game score  15068
# Game #  1857 Game length  1788 Max score  2048 Game score  32456
# Game #  1858 Game length  1134 Max score  1024 Game score  17676
# Game #  1859 Game length  1554 Max score  2048 Game score  27740
# Game #  1860 Game length  1193 Max score  1024 Game score  18552
# Game #  1861 Game length  1328 Max score  1024 Game score  21864
# Game #  1862 Game length  1586 Max score  2048 Game score  28036
# Game #  1863 Game length  2048 Max score  2048 Game score  36816
# Game #  1864 Game length  947 Max score  1024 Game score  15048
# Game #  1865 Game length  3075 Max score  4096 Game score  61436
# Game #  1866 Game length  2819 Max score  4096 Game score  57260
# Game #  1867 Game length  1012 Max score  1024 Game score  16160
# Game #  1868 Game length  800 Max score  1024 Game score  12500
# Game #  1869 Game length  1101 Max score  1024 Game score  17968
# Game #  1870 Game length  2938 Max score  4096 Game score  59552
# Game #  1871 Game length  1846 Max score  2048 Game score  33244
# Game #  1872 Game length  3073 Max score  4096 Game score  61256
# Game #  1873 Game length  2083 Max score  2048 Game score  37196
# Game #  1874 Game length  1096 Max score  1024 Game score  17016
# Game #  1875 Game length  1026 Max score  1024 Game score  16284
# Game #  1876 Game length  1934 Max score  2048 Game score  34636
# Game #  1877 Game length  1033 Max score  1024 Game score  16420
# Game #  1878 Game length  1801 Max score  2048 Game score  32800
# Game #  1879 Game length  824 Max score  1024 Game score  12772
# Game #  1881 Game length  2121 Max score  2048 Game score  37688
# Game #  1882 Game length  1550 Max score  1024 Game score  25676
# Game #  1883 Game length  1642 Max score  2048 Game score  29516
# Game #  1884 Game length  1029 Max score  1024 Game score  16216
# Game #  1885 Game length  1552 Max score  2048 Game score  27728
# Game #  1886 Game length  2729 Max score  4096 Game score  55832
# Game #  1887 Game length  1084 Max score  1024 Game score  16904
# Game #  1888 Game length  1560 Max score  2048 Game score  27784
# Game #  1889 Game length  1595 Max score  2048 Game score  28152
# Game #  1890 Game length  1061 Max score  1024 Game score  16664
# Game #  1891 Game length  1316 Max score  2048 Game score  23792
# Game #  1892 Game length  1049 Max score  1024 Game score  16564
# Game #  1893 Game length  2896 Max score  4096 Game score  58956
# Game #  1894 Game length  1574 Max score  2048 Game score  27932
# Game #  1895 Game length  1056 Max score  1024 Game score  16656
# Game #  1896 Game length  2111 Max score  2048 Game score  37444
# Game #  1897 Game length  2060 Max score  2048 Game score  36928
# Game #  1898 Game length  2379 Max score  4096 Game score  49200
# Game #  1899 Game length  1554 Max score  2048 Game score  27740
# Game #  1900 Game length  818 Max score  1024 Game score  12824
# Game #  1901 Game length  1058 Max score  1024 Game score  16620
# Game #  1902 Game length  2062 Max score  2048 Game score  36940
# Game #  1903 Game length  2051 Max score  2048 Game score  36864
# Game #  1904 Game length  1384 Max score  1024 Game score  22644
# Game #  1905 Game length  592 Max score  512 Game score  7960
# Game #  1906 Game length  1848 Max score  2048 Game score  33436
# Game #  1907 Game length  1045 Max score  1024 Game score  16504
# Game #  1908 Game length  1002 Max score  1024 Game score  15708
# Game #  1909 Game length  2276 Max score  2048 Game score  41464
# Game #  1910 Game length  919 Max score  1024 Game score  14716
# Game #  1911 Game length  1133 Max score  1024 Game score  17576
# Game #  1912 Game length  599 Max score  512 Game score  7944
# Game #  1913 Game length  1851 Max score  2048 Game score  33404
# Game #  1914 Game length  1529 Max score  2048 Game score  27488
# Game #  1915 Game length  1452 Max score  2048 Game score  26152
# Game #  1916 Game length  1299 Max score  2048 Game score  23644
# Game #  1917 Game length  1020 Max score  1024 Game score  16120
# Game #  1918 Game length  959 Max score  1024 Game score  15096
# Game #  1919 Game length  2460 Max score  4096 Game score  50668
# Game #  1920 Game length  1098 Max score  1024 Game score  17028
# Game #  1921 Game length  1945 Max score  2048 Game score  34744
# Game #  1922 Game length  1464 Max score  2048 Game score  26684
# Game #  1923 Game length  1082 Max score  1024 Game score  17064
# Game #  1924 Game length  1472 Max score  2048 Game score  26420
# Game #  1925 Game length  1002 Max score  1024 Game score  15676
# Game #  1926 Game length  1890 Max score  2048 Game score  34112
# Game #  1927 Game length  2594 Max score  4096 Game score  52508
# Game #  1928 Game length  1049 Max score  1024 Game score  16552
# Game #  1929 Game length  844 Max score  1024 Game score  13104
# Game #  1930 Game length  1960 Max score  2048 Game score  35424
# Game #  1931 Game length  1073 Max score  1024 Game score  16808
# Game #  1932 Game length  1446 Max score  2048 Game score  26136
# Game #  1933 Game length  1943 Max score  2048 Game score  35228
# Game #  1934 Game length  1608 Max score  2048 Game score  28280
# Game #  1935 Game length  2083 Max score  2048 Game score  37112
# Game #  1936 Game length  2073 Max score  2048 Game score  37048
# Game #  1937 Game length  2057 Max score  2048 Game score  36904
# Game #  1938 Game length  1770 Max score  2048 Game score  31292
# Game #  1939 Game length  1160 Max score  1024 Game score  18716
# Game #  1940 Game length  1740 Max score  2048 Game score  30664
# Game #  1941 Game length  1213 Max score  1024 Game score  18888
# Game #  1942 Game length  1367 Max score  2048 Game score  24476
# Game #  1943 Game length  1115 Max score  1024 Game score  17396
# Game #  1944 Game length  1980 Max score  2048 Game score  36024
# Game #  1945 Game length  2062 Max score  2048 Game score  36964
# Game #  1946 Game length  1326 Max score  2048 Game score  23884
# Game #  1947 Game length  927 Max score  1024 Game score  14796
# Game #  1948 Game length  1590 Max score  2048 Game score  28544
# Game #  1949 Game length  1049 Max score  1024 Game score  16524
# Game #  1950 Game length  2062 Max score  2048 Game score  36940
# Game #  1951 Game length  1026 Max score  1024 Game score  16356
# Game #  1952 Game length  886 Max score  1024 Game score  13532
# Game #  1953 Game length  2582 Max score  4096 Game score  52348
# Game #  1954 Game length  1425 Max score  2048 Game score  25936
# Game #  1955 Game length  2617 Max score  4096 Game score  52728
# Game #  1956 Game length  1983 Max score  2048 Game score  35732
# Game #  1957 Game length  1862 Max score  2048 Game score  33560
# Game #  1958 Game length  2080 Max score  2048 Game score  37168
# Game #  1959 Game length  487 Max score  512 Game score  6428
# Game #  1960 Game length  2044 Max score  2048 Game score  36616
# Game #  1961 Game length  1421 Max score  2048 Game score  25904
# Game #  1962 Game length  1638 Max score  2048 Game score  28708
# Game #  1963 Game length  2008 Max score  2048 Game score  36232
# Game #  1964 Game length  1596 Max score  2048 Game score  28168
# Game #  1965 Game length  810 Max score  1024 Game score  12588
# Game #  1966 Game length  3128 Max score  4096 Game score  63804
# Game #  1967 Game length  644 Max score  512 Game score  8536
# Game #  1968 Game length  1197 Max score  1024 Game score  19440
# Game #  1969 Game length  1050 Max score  1024 Game score  16568
# Game #  1970 Game length  1494 Max score  2048 Game score  26748
# Game #  1972 Game length  2456 Max score  4096 Game score  50560
# Game #  1973 Game length  1336 Max score  2048 Game score  24092
# Game #  1974 Game length  1773 Max score  2048 Game score  32376
# Game #  1975 Game length  758 Max score  1024 Game score  11900
# Game #  1976 Game length  1019 Max score  1024 Game score  16296
# Game #  1977 Game length  1238 Max score  1024 Game score  19836
# Game #  1978 Game length  1744 Max score  2048 Game score  32076
# Game #  1979 Game length  1555 Max score  2048 Game score  27756
# Game #  1980 Game length  1541 Max score  2048 Game score  27632
# Game #  1981 Game length  1085 Max score  1024 Game score  17032
# Game #  1982 Game length  1036 Max score  1024 Game score  16360
# Game #  1983 Game length  636 Max score  512 Game score  8456
# Game #  1984 Game length  574 Max score  512 Game score  7692
# Game #  1985 Game length  1009 Max score  1024 Game score  16144
# Game #  1986 Game length  1126 Max score  1024 Game score  17500
# Game #  1987 Game length  1455 Max score  2048 Game score  26252
# Game #  1988 Game length  3091 Max score  4096 Game score  61580
# Game #  1989 Game length  1578 Max score  2048 Game score  27964
# Game #  1990 Game length  896 Max score  1024 Game score  13608
# Game #  1991 Game length  2832 Max score  4096 Game score  56436
# Game #  1992 Game length  2977 Max score  4096 Game score  59880
# Game #  1993 Game length  1942 Max score  2048 Game score  35224
# Game #  1994 Game length  1931 Max score  2048 Game score  35116
# Game #  1995 Game length  1549 Max score  2048 Game score  27712
# Game #  1996 Game length  1022 Max score  1024 Game score  16140
# Game #  1997 Game length  1036 Max score  1024 Game score  16432
# Game #  1998 Game length  3004 Max score  4096 Game score  60168
# Game #  1999 Game length  1551 Max score  2048 Game score  27724
# Game #  2000 Game length  2568 Max score  4096 Game score  52252
# Game #  2001 Game length  922 Max score  1024 Game score  14760
# Game #  2002 Game length  964 Max score  1024 Game score  15160
# Game #  2003 Game length  297 Max score  256 Game score  3336
# Game #  2004 Game length  1342 Max score  2048 Game score  24076
# Game #  2005 Game length  1082 Max score  1024 Game score  17064
# Game #  2006 Game length  1944 Max score  2048 Game score  35208
# Game #  2007 Game length  1938 Max score  2048 Game score  35164
# Game #  2008 Game length  1828 Max score  2048 Game score  33040
# Game #  2009 Game length  1096 Max score  1024 Game score  17184
# Game #  2010 Game length  1075 Max score  1024 Game score  16820
# Game #  2011 Game length  1928 Max score  2048 Game score  35016
# Game #  2012 Game length  1747 Max score  2048 Game score  32092
# Game #  2013 Game length  1952 Max score  2048 Game score  35288
# Game #  2014 Game length  1820 Max score  2048 Game score  32960
# Game #  2015 Game length  1949 Max score  2048 Game score  35272
# Game #  2016 Game length  1017 Max score  1024 Game score  16200
# Game #  2017 Game length  2057 Max score  2048 Game score  36904
# Game #  2018 Game length  993 Max score  1024 Game score  15832
# Game #  2019 Game length  984 Max score  1024 Game score  15748
# Game #  2020 Game length  958 Max score  1024 Game score  15116
# Game #  2021 Game length  1875 Max score  2048 Game score  33676
# Game #  2022 Game length  1981 Max score  2048 Game score  36016
# Game #  2023 Game length  1127 Max score  1024 Game score  17460
# Game #  2024 Game length  1053 Max score  1024 Game score  16584
# Game #  2025 Game length  2034 Max score  2048 Game score  36540
# Game #  2026 Game length  2633 Max score  4096 Game score  53760
# Game #  2027 Game length  2976 Max score  4096 Game score  59864
# Game #  2028 Game length  1778 Max score  2048 Game score  32544
# Game #  2029 Game length  1031 Max score  1024 Game score  16368
# Game #  2030 Game length  827 Max score  1024 Game score  12796
# Game #  2031 Game length  1063 Max score  1024 Game score  16684
# Game #  2032 Game length  583 Max score  512 Game score  7872
# Game #  2033 Game length  1869 Max score  2048 Game score  33608
# Game #  2034 Game length  636 Max score  512 Game score  8456
# Game #  2035 Game length  2344 Max score  4096 Game score  48416
# Game #  2036 Game length  1180 Max score  1024 Game score  18376
# Game #  2037 Game length  1570 Max score  2048 Game score  27884
# Game #  2038 Game length  1972 Max score  2048 Game score  35540
# Game #  2039 Game length  1323 Max score  1024 Game score  20808
# Game #  2040 Game length  2954 Max score  4096 Game score  59688
# Game #  2041 Game length  2476 Max score  2048 Game score  47084
# Game #  2042 Game length  1047 Max score  1024 Game score  16540
# Game #  2043 Game length  825 Max score  1024 Game score  12872
# Game #  2044 Game length  2544 Max score  4096 Game score  51980
# Game #  2045 Game length  2034 Max score  2048 Game score  36648
# Game #  2046 Game length  1085 Max score  1024 Game score  16908
# Game #  2047 Game length  1047 Max score  1024 Game score  16540
# Game #  2048 Game length  1908 Max score  2048 Game score  34848
# Game #  2049 Game length  1106 Max score  1024 Game score  17276
# Game #  2050 Game length  1446 Max score  2048 Game score  26160
# Game #  2051 Game length  1088 Max score  1024 Game score  16936
# Game #  2052 Game length  1335 Max score  2048 Game score  24028
# Game #  2053 Game length  1074 Max score  1024 Game score  16812
# Game #  2054 Game length  1583 Max score  2048 Game score  28172
# Game #  2055 Game length  1848 Max score  2048 Game score  33256
# Game #  2056 Game length  1440 Max score  2048 Game score  26064
# Game #  2057 Game length  3409 Max score  4096 Game score  69480
# Game #  2058 Game length  1019 Max score  1024 Game score  16236
# Game #  2059 Game length  1840 Max score  2048 Game score  33128
# Game #  2060 Game length  2024 Max score  2048 Game score  36548
# Game #  2061 Game length  626 Max score  512 Game score  8388
# Game #  2062 Game length  606 Max score  512 Game score  8392
# Game #  2063 Game length  990 Max score  1024 Game score  15984
# Game #  2064 Game length  1586 Max score  2048 Game score  28044
# Game #  2065 Game length  3290 Max score  2048 Game score  61884
# Game #  2066 Game length  2037 Max score  2048 Game score  36688
# Game #  2067 Game length  2092 Max score  2048 Game score  37380
# Game #  2068 Game length  1141 Max score  1024 Game score  18480
# Game #  2069 Game length  1620 Max score  2048 Game score  28440
# Game #  2070 Game length  922 Max score  1024 Game score  14732
# Game #  2071 Game length  2100 Max score  2048 Game score  37684
# Game #  2072 Game length  3009 Max score  4096 Game score  60232
# Game #  2073 Game length  3078 Max score  2048 Game score  57372
# Game #  2074 Game length  558 Max score  512 Game score  7560
# Game #  2075 Game length  2010 Max score  2048 Game score  36244
# Game #  2076 Game length  2378 Max score  2048 Game score  45516
# Game #  2077 Game length  2375 Max score  2048 Game score  45080
# Game #  2078 Game length  951 Max score  1024 Game score  15068
# Game #  2079 Game length  1596 Max score  2048 Game score  28168
# Game #  2080 Game length  1042 Max score  1024 Game score  16476
# Game #  2081 Game length  952 Max score  1024 Game score  15196
# Game #  2082 Game length  2021 Max score  2048 Game score  36544
# Game #  2083 Game length  2843 Max score  4096 Game score  57496
# Game #  2084 Game length  1854 Max score  2048 Game score  33480
# Game #  2085 Game length  1037 Max score  1024 Game score  16056
# Game #  2086 Game length  1479 Max score  2048 Game score  26812
# Game #  2087 Game length  1040 Max score  1024 Game score  16464
# Game #  2088 Game length  1111 Max score  1024 Game score  17288
# Game #  2089 Game length  983 Max score  1024 Game score  15516
# Game #  2090 Game length  2119 Max score  2048 Game score  37916
# Game #  2091 Game length  1039 Max score  1024 Game score  16460
# Game #  2092 Game length  872 Max score  1024 Game score  13364
# Game #  2093 Game length  1012 Max score  1024 Game score  16052
# Game #  2094 Game length  1094 Max score  1024 Game score  17052
# Game #  2095 Game length  1562 Max score  2048 Game score  27820
# Game #  2096 Game length  1084 Max score  1024 Game score  16904
# Game #  2097 Game length  2054 Max score  2048 Game score  36804
# Game #  2098 Game length  1583 Max score  2048 Game score  27992
# Game #  2099 Game length  1565 Max score  2048 Game score  27848
# Game #  2100 Game length  2048 Max score  2048 Game score  36760
# Game #  2101 Game length  1052 Max score  1024 Game score  16580
# Game #  2102 Game length  983 Max score  1024 Game score  15764
# Game #  2103 Game length  778 Max score  1024 Game score  12320
# Game #  2104 Game length  1027 Max score  1024 Game score  16348
# Game #  2105 Game length  1005 Max score  1024 Game score  16112
# Game #  2106 Game length  1076 Max score  1024 Game score  16824
# Game #  2107 Game length  1584 Max score  2048 Game score  28056
# Game #  2108 Game length  1580 Max score  2048 Game score  28008
# Game #  2109 Game length  2333 Max score  2048 Game score  44316
# Game #  2110 Game length  2073 Max score  2048 Game score  37048
# Game #  2111 Game length  1581 Max score  2048 Game score  28040
# Game #  2112 Game length  2138 Max score  2048 Game score  38572
# Game #  2113 Game length  1254 Max score  1024 Game score  20028
# Game #  2114 Game length  1660 Max score  2048 Game score  29820
# Game #  2115 Game length  1088 Max score  1024 Game score  17048
# Game #  2116 Game length  1042 Max score  1024 Game score  16476
# Game #  2117 Game length  2058 Max score  2048 Game score  36920
# Game #  2118 Game length  1781 Max score  2048 Game score  32440
# Game #  2119 Game length  2312 Max score  4096 Game score  47720
# Game #  2120 Game length  1030 Max score  1024 Game score  16316
# Game #  2121 Game length  3116 Max score  4096 Game score  61832
# Game #  2122 Game length  2042 Max score  2048 Game score  36776
# Game #  2123 Game length  293 Max score  256 Game score  3312
# Game #  2124 Game length  1803 Max score  2048 Game score  32812
# Game #  2125 Game length  1074 Max score  1024 Game score  16828
# Game #  2126 Game length  2052 Max score  2048 Game score  36792
# Game #  2127 Game length  3094 Max score  4096 Game score  61596
# Game #  2128 Game length  3097 Max score  4096 Game score  61624
# Game #  2129 Game length  502 Max score  512 Game score  6780
# Game #  2130 Game length  1854 Max score  2048 Game score  34176
# Game #  2131 Game length  764 Max score  1024 Game score  12140
# Game #  2132 Game length  2639 Max score  2048 Game score  50748
# Game #  2133 Game length  1039 Max score  1024 Game score  16460
# Game #  2134 Game length  1949 Max score  2048 Game score  35272
# Game #  2135 Game length  1007 Max score  1024 Game score  16136
# Game #  2136 Game length  2486 Max score  4096 Game score  50960
# Game #  2137 Game length  1422 Max score  1024 Game score  23868
# Game #  2138 Game length  993 Max score  1024 Game score  15592
# Game #  2139 Game length  636 Max score  512 Game score  8456
# Game #  2140 Game length  1959 Max score  2048 Game score  35372
# Game #  2141 Game length  1523 Max score  2048 Game score  27420
# Game #  2142 Game length  1105 Max score  1024 Game score  17160
# Game #  2143 Game length  1124 Max score  1024 Game score  17432
# Game #  2144 Game length  985 Max score  1024 Game score  15584
# Game #  2145 Game length  1109 Max score  1024 Game score  17304
# Game #  2146 Game length  1050 Max score  1024 Game score  16556
# Game #  2147 Game length  1053 Max score  1024 Game score  16584
# Game #  2148 Game length  2252 Max score  2048 Game score  41268
# Game #  2149 Game length  1293 Max score  2048 Game score  23600
# Game #  2150 Game length  1604 Max score  2048 Game score  28248
# Game #  2151 Game length  1936 Max score  2048 Game score  35180
# Game #  2152 Game length  2953 Max score  4096 Game score  59680
# Game #  2153 Game length  1819 Max score  1024 Game score  29896
# Game #  2154 Game length  1036 Max score  1024 Game score  16408
# Game #  2155 Game length  3636 Max score  4096 Game score  73176
# Game #  2156 Game length  1807 Max score  2048 Game score  32844
# Game #  2157 Game length  708 Max score  512 Game score  9560
# Game #  2158 Game length  1591 Max score  2048 Game score  28188
# Game #  2159 Game length  2001 Max score  2048 Game score  36184
# Game #  2160 Game length  848 Max score  1024 Game score  12968
# Game #  2161 Game length  1017 Max score  1024 Game score  16236
# Game #  2162 Game length  3529 Max score  4096 Game score  71968
# Game #  2163 Game length  1936 Max score  2048 Game score  35152
# Game #  2164 Game length  2330 Max score  2048 Game score  44188
# Game #  2165 Game length  1081 Max score  1024 Game score  16888
# Game #  2166 Game length  581 Max score  512 Game score  7800
# Game #  2167 Game length  2005 Max score  2048 Game score  36216
# Game #  2168 Game length  1804 Max score  2048 Game score  32828
# Game #  2169 Game length  957 Max score  1024 Game score  15064
# Game #  2170 Game length  1152 Max score  1024 Game score  18128
# Game #  2171 Game length  2061 Max score  2048 Game score  36936
# Game #  2172 Game length  2003 Max score  2048 Game score  36220
# Game #  2173 Game length  1161 Max score  1024 Game score  18552
# Game #  2174 Game length  2224 Max score  2048 Game score  42668
# Game #  2175 Game length  1078 Max score  1024 Game score  16860
# Game #  2176 Game length  1166 Max score  1024 Game score  19764
# Game #  2177 Game length  1588 Max score  2048 Game score  28112
# Game #  2178 Game length  1715 Max score  2048 Game score  29880
# Game #  2179 Game length  2065 Max score  2048 Game score  36956
# Game #  2180 Game length  1438 Max score  2048 Game score  25560
# Game #  2181 Game length  1046 Max score  1024 Game score  16508
# Game #  2182 Game length  509 Max score  512 Game score  6996
# Game #  2183 Game length  914 Max score  1024 Game score  14680
# Game #  2184 Game length  1126 Max score  1024 Game score  17692
# Game #  2185 Game length  3076 Max score  4096 Game score  61368
# Game #  2186 Game length  1114 Max score  1024 Game score  17220
# Game #  2187 Game length  1813 Max score  2048 Game score  32912
# Game #  2188 Game length  1537 Max score  2048 Game score  27544
# Game #  2189 Game length  3116 Max score  4096 Game score  61832
# Game #  2190 Game length  2056 Max score  2048 Game score  36896
# Game #  2191 Game length  992 Max score  1024 Game score  15576
# Game #  2192 Game length  2034 Max score  2048 Game score  36636
# Game #  2193 Game length  1512 Max score  2048 Game score  27144
# Game #  2194 Game length  2623 Max score  2048 Game score  46808
# Game #  2195 Game length  930 Max score  1024 Game score  14812
# Game #  2196 Game length  1337 Max score  2048 Game score  24040
# Game #  2197 Game length  3132 Max score  4096 Game score  62088
# Game #  2198 Game length  1843 Max score  2048 Game score  33228
# Game #  2199 Game length  1489 Max score  2048 Game score  26964
# Game #  2200 Game length  1998 Max score  2048 Game score  36168
# Game #  2201 Game length  1923 Max score  2048 Game score  35036
# Game #  2202 Game length  1998 Max score  2048 Game score  36156
# Game #  2203 Game length  1042 Max score  1024 Game score  16428
# Game #  2204 Game length  1337 Max score  2048 Game score  24160
# Game #  2205 Game length  1039 Max score  1024 Game score  16460
# Game #  2206 Game length  1958 Max score  2048 Game score  35500
# Game #  2207 Game length  2101 Max score  2048 Game score  37352
# Game #  2208 Game length  1481 Max score  2048 Game score  26908
# Game #  2209 Game length  2148 Max score  2048 Game score  37976
# Game #  2210 Game length  1612 Max score  2048 Game score  28312
# Game #  2211 Game length  1158 Max score  1024 Game score  17948
# Game #  2212 Game length  2060 Max score  2048 Game score  36928
# Game #  2213 Game length  1055 Max score  1024 Game score  16608
# Game #  2214 Game length  2355 Max score  2048 Game score  41528
# Game #  2215 Game length  2085 Max score  2048 Game score  37208
# Game #  2216 Game length  1492 Max score  2048 Game score  26988
# Game #  2217 Game length  3089 Max score  2048 Game score  57480
# Game #  2218 Game length  1419 Max score  2048 Game score  25896
# Game #  2219 Game length  1092 Max score  1024 Game score  16984
# Game #  2220 Game length  1024 Max score  1024 Game score  16248
# Game #  2221 Game length  1046 Max score  1024 Game score  16508
# Game #  2222 Game length  751 Max score  1024 Game score  11900
# Game #  2223 Game length  1889 Max score  2048 Game score  34576
# Game #  2224 Game length  829 Max score  1024 Game score  12808
# Game #  2225 Game length  815 Max score  1024 Game score  12684
# Game #  2226 Game length  1090 Max score  1024 Game score  17116
# Game #  2227 Game length  1810 Max score  2048 Game score  32860
# Game #  2228 Game length  996 Max score  1024 Game score  15848
# Game #  2229 Game length  1643 Max score  2048 Game score  28744
# Game #  2230 Game length  1582 Max score  2048 Game score  28044
# Game #  2231 Game length  1867 Max score  2048 Game score  33416
# Game #  2232 Game length  1961 Max score  2048 Game score  35384
# Game #  2233 Game length  832 Max score  1024 Game score  12824
# Game #  2234 Game length  1025 Max score  1024 Game score  16292
# Game #  2235 Game length  2754 Max score  2048 Game score  50700
# Game #  2236 Game length  1705 Max score  2048 Game score  29816

# %%
num_epochs = 100

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score, last_loss = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

test(model)
# Out:
# epoch 1 2026 2048 36412 0
# epoch 2 2040 2048 36680 0
# epoch 3 1060 1024 16660 0
# epoch 4 801 1024 12488 0
# epoch 5 727 1024 11628 0
# epoch 6 1042 1024 16476 0
# epoch 7 796 1024 12476 0
# epoch 8 925 1024 14280 0
# epoch 9 1552 2048 27728 0
# epoch 10 1801 2048 32800 0
# epoch 11 1547 2048 27692 0
# epoch 12 1054 1024 16588 0
# epoch 13 1038 1024 16456 0
# epoch 14 1031 1024 16408 0
# epoch 15 1864 2048 33568 0
# epoch 16 1809 2048 32856 0
# epoch 17 1822 2048 32972 0
# epoch 18 1553 2048 27736 0
# epoch 19 1823 2048 32980 0
# epoch 20 569 512 7628 0
# epoch 21 1617 2048 29264 0
# epoch 22 2048 2048 36760 0
# epoch 23 1042 1024 16476 0
# epoch 24 1044 1024 16488 0
# epoch 25 1553 2048 27760 0
# epoch 26 1004 1024 15984 0
# epoch 27 1972 2048 35884 0
# epoch 28 1041 1024 16472 0
# epoch 29 2080 2048 37264 0
# epoch 30 1559 2048 27804 0
# epoch 31 1488 2048 26956 0
# epoch 32 1813 2048 32888 0
# epoch 33 1914 2048 34892 0
# epoch 34 1544 2048 27648 0
# epoch 35 1058 1024 16620 0
# epoch 36 975 1024 15676 0
# epoch 37 1054 1024 16588 0
# epoch 38 980 1024 15716 0
# epoch 39 1149 1024 18056 0
# epoch 40 604 512 8120 0
# epoch 41 1683 2048 29580 0
# epoch 42 1879 2048 33672 0
# epoch 43 1547 2048 27692 0
# epoch 44 574 512 7692 0
# epoch 45 1027 1024 16348 0
# epoch 46 1819 2048 32944 0
# epoch 47 2030 2048 36492 0
# epoch 48 1577 2048 28008 0
# epoch 49 1022 1024 16140 0
# epoch 50 1033 1024 16392 0
# epoch 51 1846 2048 33244 0
# epoch 52 1895 2048 34732 0
# epoch 53 1048 1024 16544 0
# epoch 54 2011 2048 36284 0
# epoch 55 1039 1024 16460 0
# epoch 56 1315 2048 23788 0
# epoch 57 992 1024 15800 0
# epoch 58 1882 2048 34472 0
# epoch 59 2798 4096 56908 0
# epoch 60 1561 2048 27872 0
# epoch 61 878 1024 13692 0
# epoch 62 795 512 11440 0
# epoch 63 1042 1024 16476 0
# epoch 64 1961 2048 35552 0
# epoch 65 1593 2048 28140 0
# epoch 66 1047 1024 16540 0
# epoch 67 1814 2048 32892 0
# epoch 68 1527 2048 27452 0
# epoch 69 1860 2048 33772 0
# epoch 70 2774 4096 56712 0
# epoch 71 1747 2048 32092 0
# epoch 72 1063 1024 16732 0
# epoch 73 1721 2048 31464 0
# epoch 74 1109 1024 17288 0
# epoch 75 1126 1024 17872 0
# epoch 76 1381 2048 25320 0
# epoch 77 1140 1024 17624 0
# epoch 78 1045 1024 16504 0
# epoch 79 2906 4096 58540 0
# epoch 80 2061 2048 36936 0
# epoch 81 1765 2048 32444 0
# epoch 82 1775 2048 31500 0
# epoch 83 1822 2048 32948 0
# epoch 84 1606 2048 28676 0
# epoch 85 1936 2048 35152 0
# epoch 86 861 1024 13256 0
# epoch 87 2057 2048 36904 0
# epoch 88 2088 2048 37224 0
# epoch 89 1011 1024 16156 0
# epoch 90 925 1024 14776 0
# epoch 91 1987 2048 36012 0
# epoch 92 538 512 7308 0
# epoch 93 1053 1024 16572 0
# epoch 94 1040 1024 16464 0
# epoch 95 1582 2048 28044 0
# epoch 96 1042 1024 16476 0
# epoch 97 1292 1024 20544 0
# epoch 98 1053 1024 16640 0
# epoch 99 1023 1024 16268 0
# epoch 100 1620 2048 28536 0
