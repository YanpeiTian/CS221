# %%
from c2048log import Game, push

# %%
import torch
from torch import nn
import torch.optim as optim
import numpy as np

# %%
class NN2048(nn.Module):
    def __init__(self, input_size=16, filter1=128, filter2=512, filter3=1024, drop_prob=0.):
        super(NN2048, self).__init__()
        self.conv_a = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(2,1), padding=0)
        self.conv_b = nn.Conv2d(in_channels=input_size, out_channels=filter1, kernel_size=(1,2), padding=0)
        
        self.conv_aa = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_ab = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)
        self.conv_ba = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(2,1), padding=0)
        self.conv_bb = nn.Conv2d(in_channels=filter1, out_channels=filter2, kernel_size=(1,2), padding=0)

        self.conv_aaa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_aab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_aba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_abb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)

        self.conv_baa = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bab = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        self.conv_bba = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(2,1), padding=0)
        self.conv_bbb = nn.Conv2d(in_channels=filter2, out_channels=filter3, kernel_size=(1,2), padding=0)
        
        self.relu = nn.ReLU()
        self.W_x = nn.Linear(input_size * 16, 1)
        self.W_a = nn.Linear(filter1 * 12, 1)
        self.W_b = nn.Linear(filter1 * 12, 1)

        self.W_aa = nn.Linear(filter2 * 8, 1)
        self.W_ab = nn.Linear(filter2 * 9, 1)
        self.W_ba = nn.Linear(filter2 * 9, 1)
        self.W_bb = nn.Linear(filter2 * 8, 1)

        self.W_aaa = nn.Linear(filter3 * 4, 1)
        self.W_aab = nn.Linear(filter3 * 6, 1)
        self.W_aba = nn.Linear(filter3 * 6, 1)
        self.W_abb = nn.Linear(filter3 * 6, 1)
        self.W_baa = nn.Linear(filter3 * 6, 1)
        self.W_bab = nn.Linear(filter3 * 6, 1)
        self.W_bba = nn.Linear(filter3 * 6, 1)
        self.W_bbb = nn.Linear(filter3 * 4, 1)

    def flatten(self, x):
        N = x.size()[0]
        return x.view(N, -1)
        
    def forward(self, x):
        x = x.float()
        a = self.relu(self.conv_a(x))
        b = self.relu(self.conv_b(x))
        aa = self.relu(self.conv_aa(a))
        ab = self.relu(self.conv_ab(a))
        ba = self.relu(self.conv_ba(b))
        bb = self.relu(self.conv_bb(b))

        aaa = self.flatten(self.relu(self.conv_aaa(aa)))
        aab = self.flatten(self.relu(self.conv_aab(aa)))
        aba = self.flatten(self.relu(self.conv_aba(ab)))
        abb = self.flatten(self.relu(self.conv_abb(ab)))
        baa = self.flatten(self.relu(self.conv_baa(ba)))
        bab = self.flatten(self.relu(self.conv_bab(ba)))
        bba = self.flatten(self.relu(self.conv_bba(bb)))
        bbb = self.flatten(self.relu(self.conv_bbb(bb)))
        x = self.flatten(x)
        a = self.flatten(a)
        b = self.flatten(b)
        aa = self.flatten(aa)
        ab = self.flatten(ab)
        ba = self.flatten(ba)
        bb = self.flatten(bb)

        out = self.W_x(x) + self.W_a(a) + self.W_b(b) \
              + self.W_aa(aa) + self.W_ab(ab) + self.W_ba(ba) + self.W_bb(bb) \
              +  self.W_aaa(aaa) + self.W_aab(aab) + self.W_aba(aba) + self.W_abb(abb) \
              + self.W_baa(baa) + self.W_bab(bab) + self.W_bba(bba) + self.W_bbb(bbb)
        return out

# %%
singleScore=[0,0,4,16,48,128,320,768,1792,4096,9216,20480,45056,98304,212992,458752,983040]
moveDict=np.load('move.npy')

def move(list):
    return moveDict[list[0],list[1],list[2],list[3],:]

def lookup(x):
    return singleScore[x]

lookup = np.vectorize(lookup)

def getScore(matrix):
    return np.sum(lookup(matrix))

def getMove(grid):
    board_list = []
    for i in range(4):
        newGrid=moveGrid(grid, i)
        if not isSame(grid,newGrid):
            board_list.append((newGrid, i, getScore(newGrid)))
    return board_list
        
def moveGrid(grid,i):
    # new=np.zeros((4,4),dtype=np.int)
    new = None
    if i==0:
        # move up
        grid=np.transpose(grid)
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int).T
    elif i==1:
        # move left
        new = np.stack([move(grid[row,:]) for row in range(4)], axis = 0).astype(int)
    elif i==2:
        # move down
        grid=np.transpose(grid)
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int).T
    elif i==3:
        # move right
        new = np.stack([np.flip(move(np.flip(grid[row,:]))) for row in range(4)], axis = 0).astype(int)
    return new

def isSame(grid1,grid2):
    return np.all(grid1==grid2)

# %%
table ={2**i:i for i in range(1,16)}
table[0]=0
def make_input(grid):
    g0 = grid
    r = np.zeros(shape=(16, 4, 4))
    for i in range(4):
        for j in range(4):
            v = g0[i, j]
            r[table[v],i, j]=1
    return r

# %%
def add_two(mat):
    indexs=np.argwhere(mat==0)
    index=np.random.randint(0,len(indexs))
    mat[tuple(indexs[index])] = 2
    return mat

# %%
def Vchange(grid, v):
    g0 = grid
    g1 = g0[:,::-1,:]
    g2 = g0[:,:,::-1]
    g3 = g2[:,::-1,:]
    r0 = grid.swapaxes(1,2)
    r1 = r0[:,::-1,:]
    r2 = r0[:,:,::-1]
    r3 = r2[:,::-1,:]
    xtrain = np.array([g0,g1,g2,g3,r0,r1,r2,r3])
    ytrain = np.array([v]*8)
    return xtrain, ytrain

def gen_sample_and_learn(model, optimizer, loss_fn, is_train = True):
    model.eval()
    game_len = 0
    game_score = 0
    last_grid1 = np.zeros((4,4),dtype=np.int)
    last_grid1 = add_two(last_grid1)
    last_grid2 = make_input(last_grid1)
    while True:
        grid_array = add_two(last_grid1)
        board_list = []
        for m in range(4):
            g = grid_array.copy()
            s = push(g, m%4)
            if s >= 0:
                board_list.append( (g, m, s) )
        if board_list:
            boards = np.array([make_input(g) for g,m,s in board_list])
            p = model(torch.from_numpy(boards).cuda()).flatten().detach()        
            game_len+=1
            best_move = -1
            best_v = None
            for i, (g,m,s) in enumerate(board_list):
#                 print (s)
                v = 2 * s + p[i].item()
                if best_v is None or v > best_v:
                    best_v = v
                    best_move = m
                    best_score = 2 * s
                    best_grid1 = board_list[i][0]
                    best_grid2 = boards[i]
                    
            game_score += best_score
        else:
            best_v = 0
            best_grid1 = None
            best_grid2 = None
            
        if is_train:
            x, y = Vchange(last_grid2, best_v)
            x = torch.from_numpy(x).cuda()
            y = torch.from_numpy(y).unsqueeze(dim=1).cuda().float()
            model.train()
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y)
            last_loss = loss.item()
            loss.backward()
#             nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            optimizer.step()
            model.eval()
#             if game_len % 50 == 0:
#                 print (game_len, last_loss)
                
        if not board_list:
            break
        last_grid2 = best_grid2
        last_grid1 = best_grid1
        
    return game_len, grid_array.max(), game_score

# %%
lr = 5e-4
weight_decay = 0
beta1 = 0.9

model = NN2048().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, 0.999))
loss=nn.MSELoss()

# %%
import os
experiment_dir = ""

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)

def load_model(model, optimizer, checkpoint_path, model_only = False):
    ckpt_dict = torch.load(checkpoint_path, map_location="cuda:0")

    model.load_state_dict(ckpt_dict['state_dict'])
    if not model_only:
        optimizer.load_state_dict(ckpt_dict['optimizer'])
        epoch = ckpt_dict['epoch']
        running_mean = ckpt_dict['running_mean']
    else:
        epoch = None
        running_mean = None
    return model, optimizer, epoch, running_mean

# %%
num_epochs = 500
best_model = None

def train(model, optimizer, loss, epoch = 0, running_mean = 2048):
    ls = [1024] * 10
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score = gen_sample_and_learn(model, optimizer, loss, True)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
        ls.pop(0)
        ls.append(max_score)
        if sum(ls) / 10 > running_mean:
            running_mean = sum(ls) / 10
            filename = "model9_"+str(epoch // 100)+".pth.tar"
            save_model({
                'epoch': epoch,
                'running_mean': running_mean,
                'state_dict': model.cpu().state_dict(),
                'optimizer': optimizer.state_dict(),
            }, filename)
            best_model, _, _, _ = load_model(model, optimizer, filename, True)
            model.cuda()
            
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  91 Max score  64 Game score  258.0
# Game #  2 Game length  187 Max score  128 Game score  620.0
# Game #  3 Game length  122 Max score  128 Game score  380.0
# Game #  4 Game length  130 Max score  128 Game score  406.0
# Game #  5 Game length  284 Max score  256 Game score  998.0
# Game #  6 Game length  106 Max score  64 Game score  312.0
# Game #  7 Game length  128 Max score  128 Game score  400.0
# Game #  8 Game length  377 Max score  256 Game score  1362.0
# Game #  9 Game length  244 Max score  256 Game score  856.0
# Game #  10 Game length  95 Max score  64 Game score  266.0
# Game #  11 Game length  145 Max score  128 Game score  456.0
# Game #  12 Game length  259 Max score  128 Game score  898.0
# Game #  13 Game length  170 Max score  128 Game score  556.0
# Game #  14 Game length  189 Max score  128 Game score  630.0
# Game #  15 Game length  301 Max score  256 Game score  1074.0
# Game #  16 Game length  252 Max score  256 Game score  886.0
# Game #  17 Game length  253 Max score  256 Game score  878.0
# Game #  18 Game length  252 Max score  128 Game score  866.0
# Game #  19 Game length  427 Max score  256 Game score  1564.0
# Game #  20 Game length  328 Max score  256 Game score  1176.0
# Game #  21 Game length  290 Max score  256 Game score  1024.0
# Game #  22 Game length  684 Max score  512 Game score  2566.0
# Game #  23 Game length  465 Max score  512 Game score  1718.0
# Game #  24 Game length  635 Max score  512 Game score  2388.0
# Game #  25 Game length  696 Max score  512 Game score  2606.0
# Game #  26 Game length  354 Max score  256 Game score  1276.0
# Game #  27 Game length  502 Max score  512 Game score  1852.0
# Game #  28 Game length  783 Max score  1024 Game score  2986.0
# Game #  29 Game length  647 Max score  512 Game score  2440.0
# Game #  30 Game length  683 Max score  512 Game score  2570.0
# Game #  31 Game length  681 Max score  512 Game score  2562.0
# Game #  32 Game length  342 Max score  256 Game score  1230.0
# Game #  33 Game length  785 Max score  512 Game score  2980.0
# Game #  34 Game length  940 Max score  1024 Game score  3600.0
# Game #  35 Game length  276 Max score  256 Game score  974.0
# Game #  36 Game length  659 Max score  512 Game score  2464.0
# Game #  37 Game length  904 Max score  1024 Game score  3464.0
# Game #  38 Game length  988 Max score  1024 Game score  3800.0
# Game #  39 Game length  768 Max score  1024 Game score  2904.0
# Game #  40 Game length  338 Max score  256 Game score  1212.0
# Game #  41 Game length  687 Max score  512 Game score  2598.0
# Game #  42 Game length  1320 Max score  2048 Game score  5130.0
# Game #  43 Game length  583 Max score  512 Game score  2178.0
# Game #  44 Game length  466 Max score  512 Game score  1732.0
# Game #  45 Game length  531 Max score  512 Game score  1978.0
# Game #  46 Game length  508 Max score  512 Game score  1892.0
# Game #  47 Game length  443 Max score  512 Game score  1628.0
# Game #  48 Game length  620 Max score  512 Game score  2324.0
# Game #  49 Game length  371 Max score  256 Game score  1342.0
# Game #  50 Game length  551 Max score  512 Game score  2052.0
# Game #  51 Game length  655 Max score  512 Game score  2464.0
# Game #  52 Game length  656 Max score  512 Game score  2466.0
# Game #  53 Game length  729 Max score  512 Game score  2746.0
# Game #  54 Game length  973 Max score  1024 Game score  3736.0
# Game #  55 Game length  1073 Max score  1024 Game score  4134.0
# Game #  56 Game length  1257 Max score  1024 Game score  4866.0
# Game #  57 Game length  502 Max score  512 Game score  1874.0
# Game #  58 Game length  291 Max score  256 Game score  1026.0
# Game #  59 Game length  1085 Max score  1024 Game score  4162.0
# Game #  61 Game length  1582 Max score  2048 Game score  6166.0
# Game #  62 Game length  1548 Max score  1024 Game score  6002.0
# Game #  63 Game length  940 Max score  1024 Game score  3604.0
# Game #  64 Game length  619 Max score  512 Game score  2320.0
# Game #  65 Game length  658 Max score  512 Game score  2486.0
# Game #  66 Game length  905 Max score  1024 Game score  3466.0
# Game #  67 Game length  469 Max score  512 Game score  1740.0
# Game #  68 Game length  1131 Max score  1024 Game score  4376.0
# Game #  69 Game length  973 Max score  1024 Game score  3724.0
# Game #  70 Game length  1412 Max score  2048 Game score  5500.0
# Game #  71 Game length  906 Max score  1024 Game score  3472.0
# Game #  72 Game length  1251 Max score  2048 Game score  4854.0
# Game #  73 Game length  942 Max score  1024 Game score  3590.0
# Game #  74 Game length  1143 Max score  1024 Game score  4422.0
# Game #  75 Game length  538 Max score  512 Game score  2000.0
# Game #  76 Game length  1149 Max score  1024 Game score  4426.0
# Game #  77 Game length  1294 Max score  2048 Game score  5032.0
# Game #  78 Game length  885 Max score  1024 Game score  3390.0
# Game #  79 Game length  1205 Max score  1024 Game score  4656.0
# Game #  80 Game length  549 Max score  512 Game score  2054.0
# Game #  81 Game length  1080 Max score  1024 Game score  4162.0
# Game #  82 Game length  596 Max score  512 Game score  2232.0
# Game #  83 Game length  1065 Max score  1024 Game score  4092.0
# Game #  84 Game length  612 Max score  512 Game score  2302.0
# Game #  85 Game length  1554 Max score  2048 Game score  6050.0
# Game #  86 Game length  1275 Max score  1024 Game score  4942.0
# Game #  87 Game length  858 Max score  1024 Game score  3266.0
# Game #  88 Game length  656 Max score  512 Game score  2480.0
# Game #  89 Game length  935 Max score  1024 Game score  3582.0
# Game #  90 Game length  1132 Max score  1024 Game score  4368.0
# Game #  91 Game length  815 Max score  1024 Game score  3116.0
# Game #  92 Game length  1561 Max score  2048 Game score  6078.0
# Game #  93 Game length  888 Max score  1024 Game score  3392.0
# Game #  94 Game length  840 Max score  1024 Game score  3198.0
# Game #  95 Game length  413 Max score  512 Game score  1516.0
# Game #  96 Game length  887 Max score  1024 Game score  3382.0
# Game #  97 Game length  1212 Max score  1024 Game score  4702.0
# Game #  98 Game length  331 Max score  256 Game score  1176.0
# Game #  99 Game length  688 Max score  512 Game score  2580.0
# Game #  100 Game length  1137 Max score  1024 Game score  4382.0
# Game #  101 Game length  920 Max score  1024 Game score  3532.0
# Game #  102 Game length  573 Max score  512 Game score  2134.0
# Game #  103 Game length  791 Max score  1024 Game score  3014.0
# Game #  104 Game length  1040 Max score  1024 Game score  3998.0
# Game #  105 Game length  576 Max score  512 Game score  2142.0
# Game #  106 Game length  618 Max score  512 Game score  2314.0
# Game #  107 Game length  1305 Max score  1024 Game score  5042.0
# Game #  108 Game length  1059 Max score  1024 Game score  4070.0
# Game #  109 Game length  1678 Max score  2048 Game score  6536.0
# Game #  110 Game length  987 Max score  1024 Game score  3794.0
# Game #  111 Game length  1058 Max score  1024 Game score  4062.0
# Game #  112 Game length  1654 Max score  2048 Game score  6470.0
# Game #  115 Game length  1263 Max score  1024 Game score  4886.0
# Game #  116 Game length  1797 Max score  2048 Game score  7018.0
# Game #  117 Game length  1309 Max score  1024 Game score  5068.0
# Game #  118 Game length  1412 Max score  1024 Game score  5458.0
# Game #  119 Game length  1675 Max score  2048 Game score  6538.0
# Game #  120 Game length  565 Max score  512 Game score  2110.0
# Game #  121 Game length  682 Max score  512 Game score  2564.0
# Game #  122 Game length  1044 Max score  1024 Game score  4012.0
# Game #  123 Game length  588 Max score  512 Game score  2198.0
# Game #  124 Game length  753 Max score  512 Game score  2838.0
# Game #  125 Game length  1032 Max score  1024 Game score  3974.0
# Game #  126 Game length  1044 Max score  1024 Game score  4018.0
# Game #  127 Game length  674 Max score  512 Game score  2530.0
# Game #  128 Game length  1462 Max score  2048 Game score  5694.0
# Game #  129 Game length  1035 Max score  1024 Game score  3982.0
# Game #  130 Game length  1266 Max score  1024 Game score  4882.0
# Game #  131 Game length  2002 Max score  2048 Game score  7840.0
# Game #  132 Game length  576 Max score  512 Game score  2158.0
# Game #  133 Game length  2039 Max score  2048 Game score  7984.0
# Game #  134 Game length  1424 Max score  2048 Game score  5548.0
# Game #  135 Game length  1539 Max score  2048 Game score  5998.0
# Game #  136 Game length  1900 Max score  2048 Game score  7436.0
# Game #  137 Game length  1250 Max score  1024 Game score  4828.0
# Game #  138 Game length  1208 Max score  1024 Game score  4652.0
# Game #  139 Game length  523 Max score  512 Game score  1940.0
# Game #  140 Game length  1037 Max score  1024 Game score  3988.0
# Game #  141 Game length  830 Max score  1024 Game score  3170.0
# Game #  142 Game length  1321 Max score  2048 Game score  5126.0
# Game #  143 Game length  987 Max score  1024 Game score  3778.0
# Game #  144 Game length  1716 Max score  2048 Game score  6678.0
# Game #  145 Game length  907 Max score  1024 Game score  3480.0
# Game #  146 Game length  1566 Max score  2048 Game score  6102.0
# Game #  147 Game length  1778 Max score  2048 Game score  6946.0
# Game #  148 Game length  807 Max score  1024 Game score  3078.0
# Game #  149 Game length  999 Max score  1024 Game score  3850.0
# Game #  150 Game length  1271 Max score  1024 Game score  4916.0
# Game #  151 Game length  297 Max score  256 Game score  1046.0
# Game #  152 Game length  602 Max score  512 Game score  2252.0
# Game #  153 Game length  1091 Max score  1024 Game score  4182.0
# Game #  155 Game length  2042 Max score  2048 Game score  7996.0
# Game #  156 Game length  1156 Max score  1024 Game score  4456.0
# Game #  157 Game length  2030 Max score  2048 Game score  7942.0
# Game #  158 Game length  870 Max score  1024 Game score  3326.0
# Game #  159 Game length  1046 Max score  1024 Game score  4018.0
# Game #  160 Game length  1342 Max score  2048 Game score  5204.0
# Game #  161 Game length  1384 Max score  2048 Game score  5390.0
# Game #  162 Game length  1894 Max score  2048 Game score  7408.0
# Game #  163 Game length  667 Max score  512 Game score  2502.0
# Game #  164 Game length  898 Max score  1024 Game score  3432.0
# Game #  165 Game length  714 Max score  512 Game score  2684.0
# Game #  166 Game length  1567 Max score  2048 Game score  6098.0
# Game #  167 Game length  1068 Max score  1024 Game score  4104.0
# Game #  168 Game length  1522 Max score  2048 Game score  5934.0
# Game #  169 Game length  930 Max score  1024 Game score  3562.0
# Game #  170 Game length  1001 Max score  1024 Game score  3844.0
# Game #  171 Game length  1771 Max score  2048 Game score  6924.0
# Game #  172 Game length  584 Max score  512 Game score  2194.0
# Game #  173 Game length  1493 Max score  1024 Game score  5802.0
# Game #  174 Game length  1298 Max score  2048 Game score  5044.0
# Game #  175 Game length  1019 Max score  1024 Game score  3920.0
# Game #  176 Game length  582 Max score  512 Game score  2162.0
# Game #  177 Game length  1428 Max score  2048 Game score  5558.0
# Game #  178 Game length  1078 Max score  1024 Game score  4150.0
# Game #  179 Game length  984 Max score  1024 Game score  3786.0
# Game #  180 Game length  537 Max score  512 Game score  1998.0
# Game #  181 Game length  930 Max score  1024 Game score  3562.0
# Game #  182 Game length  2025 Max score  2048 Game score  7922.0
# Game #  183 Game length  1599 Max score  2048 Game score  6230.0
# Game #  184 Game length  1656 Max score  2048 Game score  6474.0
# Game #  185 Game length  1240 Max score  2048 Game score  4820.0
# Game #  186 Game length  1101 Max score  1024 Game score  4234.0
# Game #  187 Game length  1103 Max score  1024 Game score  4250.0
# Game #  188 Game length  1029 Max score  1024 Game score  3954.0
# Game #  189 Game length  969 Max score  1024 Game score  3734.0
# Game #  190 Game length  594 Max score  512 Game score  2202.0
# Game #  191 Game length  1130 Max score  1024 Game score  4346.0
# Game #  192 Game length  1115 Max score  1024 Game score  4290.0
# Game #  193 Game length  588 Max score  512 Game score  2186.0
# Game #  194 Game length  1116 Max score  1024 Game score  4286.0
# Game #  195 Game length  804 Max score  1024 Game score  3074.0
# Game #  196 Game length  907 Max score  1024 Game score  3486.0
# Game #  197 Game length  969 Max score  1024 Game score  3734.0
# Game #  198 Game length  1348 Max score  2048 Game score  5224.0
# Game #  200 Game length  1552 Max score  2048 Game score  6050.0
# Game #  201 Game length  912 Max score  1024 Game score  3502.0
# Game #  202 Game length  545 Max score  512 Game score  2028.0
# Game #  203 Game length  1310 Max score  2048 Game score  5082.0
# Game #  204 Game length  1080 Max score  1024 Game score  4146.0
# Game #  205 Game length  1394 Max score  2048 Game score  5406.0
# Game #  206 Game length  1491 Max score  2048 Game score  5810.0
# Game #  207 Game length  1826 Max score  2048 Game score  7148.0
# Game #  208 Game length  979 Max score  1024 Game score  3764.0
# Game #  209 Game length  1037 Max score  1024 Game score  3990.0
# Game #  210 Game length  1990 Max score  2048 Game score  7784.0
# Game #  211 Game length  528 Max score  512 Game score  1970.0
# Game #  212 Game length  920 Max score  1024 Game score  3526.0
# Game #  213 Game length  874 Max score  1024 Game score  3328.0
# Game #  214 Game length  1681 Max score  2048 Game score  6572.0
# Game #  215 Game length  586 Max score  512 Game score  2192.0
# Game #  216 Game length  2008 Max score  2048 Game score  7860.0
# Game #  217 Game length  1565 Max score  2048 Game score  6092.0
# Game #  218 Game length  2714 Max score  4096 Game score  10700.0
# Game #  219 Game length  931 Max score  1024 Game score  3570.0
# Game #  220 Game length  579 Max score  512 Game score  2170.0
# Game #  221 Game length  949 Max score  1024 Game score  3652.0
# Game #  222 Game length  781 Max score  1024 Game score  2980.0
# Game #  223 Game length  1028 Max score  1024 Game score  3942.0
# Game #  224 Game length  956 Max score  1024 Game score  3660.0
# Game #  225 Game length  1814 Max score  2048 Game score  7076.0
# Game #  226 Game length  1046 Max score  1024 Game score  4024.0
# Game #  227 Game length  1327 Max score  2048 Game score  5152.0
# Game #  228 Game length  1447 Max score  2048 Game score  5626.0
# Game #  229 Game length  1030 Max score  1024 Game score  3968.0
# Game #  230 Game length  1053 Max score  1024 Game score  4046.0
# Game #  231 Game length  1561 Max score  2048 Game score  6080.0
# Game #  232 Game length  1032 Max score  1024 Game score  3974.0
# Game #  233 Game length  930 Max score  1024 Game score  3562.0
# Game #  234 Game length  1965 Max score  2048 Game score  7686.0
# Game #  235 Game length  887 Max score  1024 Game score  3404.0
# Game #  236 Game length  1819 Max score  2048 Game score  7108.0
# Game #  237 Game length  1464 Max score  1024 Game score  5692.0
# Game #  238 Game length  996 Max score  1024 Game score  3826.0
# Game #  239 Game length  1801 Max score  2048 Game score  7044.0
# Game #  240 Game length  1464 Max score  2048 Game score  5704.0
# Game #  241 Game length  425 Max score  512 Game score  1568.0
# Game #  242 Game length  528 Max score  512 Game score  1970.0
# Game #  243 Game length  1039 Max score  1024 Game score  3996.0
# Game #  244 Game length  714 Max score  512 Game score  2678.0
# Game #  245 Game length  1042 Max score  1024 Game score  4008.0
# Game #  246 Game length  1015 Max score  1024 Game score  3904.0
# Game #  247 Game length  1554 Max score  2048 Game score  6050.0
# Game #  248 Game length  1855 Max score  2048 Game score  7252.0
# Game #  249 Game length  1042 Max score  1024 Game score  4004.0
# Game #  250 Game length  1831 Max score  2048 Game score  7158.0
# Game #  251 Game length  1121 Max score  1024 Game score  4314.0
# Game #  253 Game length  1117 Max score  1024 Game score  4288.0
# Game #  254 Game length  1820 Max score  2048 Game score  7110.0
# Game #  255 Game length  565 Max score  512 Game score  2104.0
# Game #  256 Game length  1062 Max score  1024 Game score  4078.0
# Game #  257 Game length  842 Max score  1024 Game score  3226.0
# Game #  258 Game length  1047 Max score  1024 Game score  4026.0
# Game #  259 Game length  852 Max score  1024 Game score  3270.0
# Game #  260 Game length  1025 Max score  1024 Game score  3940.0
# Game #  261 Game length  1503 Max score  2048 Game score  5868.0
# Game #  262 Game length  1010 Max score  1024 Game score  3892.0
# Game #  263 Game length  800 Max score  1024 Game score  3046.0
# Game #  264 Game length  1012 Max score  1024 Game score  3898.0
# Game #  265 Game length  1871 Max score  2048 Game score  7328.0
# Game #  266 Game length  509 Max score  512 Game score  1896.0
# Game #  267 Game length  1330 Max score  2048 Game score  5160.0
# Game #  268 Game length  865 Max score  1024 Game score  3304.0
# Game #  269 Game length  1449 Max score  2048 Game score  5662.0
# Game #  270 Game length  810 Max score  1024 Game score  3080.0
# Game #  271 Game length  504 Max score  512 Game score  1878.0
# Game #  272 Game length  512 Max score  512 Game score  1908.0
# Game #  273 Game length  1017 Max score  1024 Game score  3910.0
# Game #  274 Game length  1563 Max score  2048 Game score  6086.0
# Game #  275 Game length  1955 Max score  2048 Game score  7644.0
# Game #  276 Game length  1483 Max score  2048 Game score  5774.0
# Game #  277 Game length  1956 Max score  2048 Game score  7630.0
# Game #  278 Game length  752 Max score  1024 Game score  2866.0
# Game #  279 Game length  905 Max score  1024 Game score  3466.0
# Game #  280 Game length  1095 Max score  1024 Game score  4210.0
# Game #  281 Game length  994 Max score  1024 Game score  3816.0
# Game #  282 Game length  1852 Max score  2048 Game score  7228.0
# Game #  283 Game length  1046 Max score  1024 Game score  4018.0
# Game #  284 Game length  1791 Max score  2048 Game score  6988.0
# Game #  285 Game length  1088 Max score  1024 Game score  4176.0
# Game #  286 Game length  1256 Max score  1024 Game score  4864.0
# Game #  287 Game length  1999 Max score  2048 Game score  7828.0
# Game #  288 Game length  2052 Max score  2048 Game score  8026.0
# Game #  289 Game length  1172 Max score  1024 Game score  4510.0
# Game #  290 Game length  1044 Max score  1024 Game score  4012.0
# Game #  291 Game length  1111 Max score  1024 Game score  4276.0
# Game #  292 Game length  1491 Max score  2048 Game score  5810.0
# Game #  293 Game length  1804 Max score  2048 Game score  7056.0
# Game #  294 Game length  991 Max score  1024 Game score  3808.0
# Game #  295 Game length  647 Max score  512 Game score  2434.0
# Game #  296 Game length  527 Max score  512 Game score  1964.0
# Game #  297 Game length  1048 Max score  1024 Game score  4024.0
# Game #  298 Game length  556 Max score  512 Game score  2072.0
# Game #  299 Game length  1580 Max score  2048 Game score  6156.0
# Game #  300 Game length  1512 Max score  2048 Game score  5882.0
# Game #  301 Game length  981 Max score  1024 Game score  3770.0
# Game #  302 Game length  1533 Max score  2048 Game score  5982.0
# Game #  303 Game length  1059 Max score  1024 Game score  4066.0
# Game #  304 Game length  1538 Max score  2048 Game score  5996.0
# Game #  305 Game length  1064 Max score  1024 Game score  4090.0
# Game #  306 Game length  1314 Max score  2048 Game score  5098.0
# Game #  307 Game length  932 Max score  1024 Game score  3570.0
# Game #  308 Game length  1613 Max score  2048 Game score  6280.0
# Game #  309 Game length  1454 Max score  2048 Game score  5652.0
# Game #  310 Game length  1127 Max score  1024 Game score  4344.0
# Game #  311 Game length  631 Max score  512 Game score  2364.0
# Game #  312 Game length  1025 Max score  1024 Game score  3940.0
# Game #  313 Game length  1484 Max score  2048 Game score  5764.0
# Game #  314 Game length  1791 Max score  2048 Game score  7002.0
# Game #  315 Game length  935 Max score  1024 Game score  3584.0
# Game #  316 Game length  1033 Max score  1024 Game score  3976.0
# Game #  317 Game length  1021 Max score  1024 Game score  3932.0
# Game #  318 Game length  1052 Max score  1024 Game score  4042.0
# Game #  319 Game length  1565 Max score  2048 Game score  6092.0
# Game #  320 Game length  1050 Max score  1024 Game score  4030.0
# Game #  321 Game length  994 Max score  1024 Game score  3820.0
# Game #  322 Game length  1448 Max score  2048 Game score  5640.0
# Game #  323 Game length  1027 Max score  1024 Game score  3958.0
# Game #  324 Game length  1042 Max score  1024 Game score  4004.0
# Game #  325 Game length  1032 Max score  1024 Game score  3962.0
# Game #  326 Game length  1789 Max score  2048 Game score  7004.0
# Game #  327 Game length  1122 Max score  1024 Game score  4342.0
# Game #  328 Game length  936 Max score  1024 Game score  3582.0
# Game #  329 Game length  1601 Max score  2048 Game score  6228.0
# Game #  330 Game length  1052 Max score  1024 Game score  4050.0
# Game #  331 Game length  1604 Max score  2048 Game score  6254.0
# Game #  332 Game length  1946 Max score  2048 Game score  7612.0
# Game #  333 Game length  540 Max score  512 Game score  2010.0
# Game #  334 Game length  1809 Max score  2048 Game score  7070.0
# Game #  335 Game length  1027 Max score  1024 Game score  3952.0
# Game #  336 Game length  2060 Max score  2048 Game score  8062.0
# Game #  337 Game length  963 Max score  1024 Game score  3698.0
# Game #  338 Game length  1054 Max score  1024 Game score  4048.0
# Game #  339 Game length  1768 Max score  2048 Game score  6904.0
# Game #  340 Game length  963 Max score  1024 Game score  3698.0
# Game #  341 Game length  2028 Max score  2048 Game score  7942.0
# Game #  342 Game length  537 Max score  512 Game score  2002.0
# Game #  343 Game length  927 Max score  1024 Game score  3562.0
# Game #  344 Game length  1715 Max score  2048 Game score  6698.0
# Game #  345 Game length  993 Max score  1024 Game score  3806.0
# Game #  346 Game length  1045 Max score  1024 Game score  4016.0
# Game #  347 Game length  817 Max score  1024 Game score  3112.0
# Game #  348 Game length  844 Max score  1024 Game score  3220.0
# Game #  349 Game length  951 Max score  1024 Game score  3646.0
# Game #  350 Game length  991 Max score  1024 Game score  3812.0
# Game #  351 Game length  562 Max score  512 Game score  2092.0
# Game #  352 Game length  1749 Max score  2048 Game score  6830.0
# Game #  353 Game length  452 Max score  512 Game score  1672.0
# Game #  354 Game length  2776 Max score  4096 Game score  10948.0
# Game #  355 Game length  913 Max score  1024 Game score  3504.0
# Game #  356 Game length  799 Max score  1024 Game score  3044.0
# Game #  357 Game length  1448 Max score  2048 Game score  5640.0
# Game #  358 Game length  1042 Max score  1024 Game score  4004.0
# Game #  359 Game length  1819 Max score  2048 Game score  7108.0
# Game #  360 Game length  1022 Max score  1024 Game score  3932.0
# Game #  361 Game length  1035 Max score  1024 Game score  3982.0
# Game #  362 Game length  1057 Max score  1024 Game score  4056.0
# Game #  363 Game length  1803 Max score  2048 Game score  7050.0
# Game #  364 Game length  1715 Max score  2048 Game score  6676.0
# Game #  365 Game length  1549 Max score  2048 Game score  6038.0
# Game #  366 Game length  1375 Max score  2048 Game score  5332.0
# Game #  367 Game length  802 Max score  1024 Game score  3052.0
# Game #  368 Game length  1550 Max score  2048 Game score  6040.0
# Game #  369 Game length  1007 Max score  1024 Game score  3870.0
# Game #  370 Game length  1184 Max score  2048 Game score  4596.0
# Game #  371 Game length  1712 Max score  2048 Game score  6686.0
# Game #  372 Game length  1565 Max score  2048 Game score  6092.0
# Game #  373 Game length  1335 Max score  2048 Game score  5182.0
# Game #  374 Game length  744 Max score  1024 Game score  2828.0
# Game #  375 Game length  1297 Max score  2048 Game score  5046.0
# Game #  376 Game length  1152 Max score  1024 Game score  4424.0
# Game #  377 Game length  1099 Max score  1024 Game score  4222.0
# Game #  378 Game length  1312 Max score  2048 Game score  5092.0
# Game #  379 Game length  1573 Max score  2048 Game score  6128.0
# Game #  380 Game length  2059 Max score  2048 Game score  8062.0
# Game #  382 Game length  1531 Max score  2048 Game score  5970.0
# Game #  383 Game length  2076 Max score  2048 Game score  8118.0
# Game #  384 Game length  1488 Max score  2048 Game score  5792.0
# Game #  385 Game length  1757 Max score  2048 Game score  6866.0
# Game #  386 Game length  2046 Max score  2048 Game score  8018.0
# Game #  387 Game length  1971 Max score  2048 Game score  7722.0
# Game #  388 Game length  449 Max score  512 Game score  1648.0
# Game #  389 Game length  1547 Max score  2048 Game score  6028.0
# Game #  390 Game length  1527 Max score  2048 Game score  5950.0
# Game #  391 Game length  1566 Max score  2048 Game score  6094.0
# Game #  392 Game length  1035 Max score  1024 Game score  3982.0
# Game #  393 Game length  1812 Max score  2048 Game score  7080.0
# Game #  394 Game length  1442 Max score  2048 Game score  5608.0
# Game #  395 Game length  1297 Max score  2048 Game score  5040.0
# Game #  396 Game length  1193 Max score  2048 Game score  4624.0
# Game #  397 Game length  416 Max score  512 Game score  1528.0
# Game #  398 Game length  940 Max score  1024 Game score  3604.0
# Game #  399 Game length  1053 Max score  1024 Game score  4046.0
# Game #  400 Game length  1510 Max score  2048 Game score  5876.0
# Game #  401 Game length  1618 Max score  2048 Game score  6304.0
# Game #  402 Game length  2061 Max score  2048 Game score  8066.0
# Game #  403 Game length  1575 Max score  2048 Game score  6122.0
# Game #  404 Game length  1020 Max score  1024 Game score  3922.0
# Game #  405 Game length  1082 Max score  1024 Game score  4154.0
# Game #  406 Game length  810 Max score  1024 Game score  3098.0
# Game #  407 Game length  1698 Max score  2048 Game score  6606.0
# Game #  408 Game length  1048 Max score  1024 Game score  4024.0
# Game #  409 Game length  1336 Max score  2048 Game score  5186.0
# Game #  410 Game length  1919 Max score  2048 Game score  7520.0
# Game #  411 Game length  1512 Max score  2048 Game score  5900.0
# Game #  412 Game length  787 Max score  1024 Game score  3000.0
# Game #  413 Game length  1033 Max score  1024 Game score  3970.0
# Game #  414 Game length  1033 Max score  1024 Game score  3976.0
# Game #  415 Game length  1048 Max score  1024 Game score  4028.0
# Game #  416 Game length  2441 Max score  2048 Game score  9600.0
# Game #  417 Game length  1625 Max score  2048 Game score  6324.0
# Game #  418 Game length  2601 Max score  4096 Game score  10234.0
# Game #  419 Game length  1809 Max score  2048 Game score  7070.0
# Game #  420 Game length  1086 Max score  1024 Game score  4166.0
# Game #  421 Game length  1055 Max score  1024 Game score  4050.0
# Game #  422 Game length  1039 Max score  1024 Game score  4000.0
# Game #  423 Game length  1555 Max score  2048 Game score  6058.0
# Game #  424 Game length  1042 Max score  1024 Game score  4004.0
# Game #  425 Game length  915 Max score  1024 Game score  3510.0
# Game #  426 Game length  1033 Max score  1024 Game score  3976.0
# Game #  427 Game length  1690 Max score  2048 Game score  6600.0
# Game #  428 Game length  2212 Max score  2048 Game score  8652.0
# Game #  429 Game length  1803 Max score  2048 Game score  7050.0
# Game #  430 Game length  1074 Max score  1024 Game score  4130.0
# Game #  431 Game length  2771 Max score  4096 Game score  10926.0
# Game #  432 Game length  928 Max score  1024 Game score  3564.0
# Game #  433 Game length  1112 Max score  1024 Game score  4266.0
# Game #  434 Game length  2846 Max score  4096 Game score  11210.0
# Game #  435 Game length  724 Max score  1024 Game score  2760.0
# Game #  436 Game length  1687 Max score  2048 Game score  6592.0
# Game #  437 Game length  1064 Max score  1024 Game score  4088.0
# Game #  438 Game length  893 Max score  1024 Game score  3410.0
# Game #  439 Game length  1061 Max score  1024 Game score  4076.0
# Game #  440 Game length  1626 Max score  2048 Game score  6326.0
# Game #  441 Game length  1938 Max score  2048 Game score  7582.0
# Game #  442 Game length  2043 Max score  2048 Game score  7998.0
# Game #  443 Game length  1816 Max score  2048 Game score  7098.0
# Game #  444 Game length  1992 Max score  2048 Game score  7806.0
# Game #  445 Game length  2016 Max score  2048 Game score  7886.0
# Game #  446 Game length  1058 Max score  1024 Game score  4062.0
# Game #  447 Game length  1833 Max score  2048 Game score  7164.0
# Game #  448 Game length  1908 Max score  2048 Game score  7472.0
# Game #  449 Game length  927 Max score  1024 Game score  3554.0
# Game #  450 Game length  1887 Max score  2048 Game score  7386.0
# Game #  451 Game length  1044 Max score  1024 Game score  4014.0
# Game #  452 Game length  2046 Max score  2048 Game score  8010.0
# Game #  453 Game length  1056 Max score  1024 Game score  4054.0
# Game #  454 Game length  2088 Max score  2048 Game score  8162.0
# Game #  455 Game length  1787 Max score  2048 Game score  6988.0
# Game #  456 Game length  878 Max score  1024 Game score  3334.0
# Game #  457 Game length  1506 Max score  1024 Game score  5852.0
# Game #  458 Game length  1074 Max score  1024 Game score  4130.0
# Game #  459 Game length  1804 Max score  2048 Game score  7056.0
# Game #  460 Game length  2003 Max score  2048 Game score  7842.0
# Game #  461 Game length  1430 Max score  2048 Game score  5564.0
# Game #  462 Game length  1775 Max score  2048 Game score  6944.0
# Game #  463 Game length  565 Max score  512 Game score  2104.0
# Game #  464 Game length  1556 Max score  2048 Game score  6060.0
# Game #  465 Game length  1025 Max score  1024 Game score  3940.0
# Game #  466 Game length  659 Max score  1024 Game score  2504.0
# Game #  467 Game length  1004 Max score  1024 Game score  3868.0
# Game #  468 Game length  1838 Max score  2048 Game score  7184.0
# Game #  469 Game length  1999 Max score  2048 Game score  7824.0
# Game #  470 Game length  1548 Max score  2048 Game score  6034.0
# Game #  471 Game length  1045 Max score  1024 Game score  4020.0
# Game #  472 Game length  2321 Max score  4096 Game score  9134.0
# Game #  473 Game length  2070 Max score  2048 Game score  8098.0
# Game #  474 Game length  929 Max score  1024 Game score  3560.0
# Game #  475 Game length  1144 Max score  1024 Game score  4408.0
# Game #  476 Game length  1688 Max score  2048 Game score  6584.0
# Game #  477 Game length  1064 Max score  1024 Game score  4082.0
# Game #  478 Game length  1534 Max score  2048 Game score  5978.0
# Game #  479 Game length  2341 Max score  4096 Game score  9200.0
# Game #  480 Game length  1564 Max score  2048 Game score  6090.0
# Game #  481 Game length  537 Max score  512 Game score  2002.0
# Game #  482 Game length  2048 Max score  2048 Game score  8024.0
# Game #  483 Game length  1543 Max score  2048 Game score  6014.0
# Game #  484 Game length  2046 Max score  2048 Game score  8014.0
# Game #  485 Game length  1567 Max score  2048 Game score  6104.0
# Game #  486 Game length  986 Max score  1024 Game score  3786.0
# Game #  487 Game length  1076 Max score  1024 Game score  4136.0
# Game #  488 Game length  2062 Max score  2048 Game score  8068.0
# Game #  489 Game length  1618 Max score  2048 Game score  6310.0
# Game #  490 Game length  810 Max score  1024 Game score  3082.0
# Game #  491 Game length  2008 Max score  2048 Game score  7864.0
# Game #  492 Game length  1032 Max score  1024 Game score  3974.0
# Game #  493 Game length  2025 Max score  2048 Game score  7926.0
# Game #  494 Game length  1111 Max score  1024 Game score  4264.0
# Game #  495 Game length  2041 Max score  2048 Game score  7984.0
# Game #  496 Game length  2027 Max score  2048 Game score  7934.0
# Game #  497 Game length  1540 Max score  2048 Game score  5996.0
# Game #  498 Game length  1007 Max score  1024 Game score  3870.0
# Game #  499 Game length  2027 Max score  2048 Game score  7944.0
# Game #  500 Game length  1593 Max score  2048 Game score  6198.0

# %%
num_epochs = 100
model.cuda()
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  1831 Max score  2048 Game score  7156.0
# Game #  2 Game length  1938 Max score  2048 Game score  7582.0
# Game #  3 Game length  1053 Max score  1024 Game score  4046.0
# Game #  4 Game length  2592 Max score  4096 Game score  10194.0
# Game #  5 Game length  1823 Max score  2048 Game score  7120.0
# Game #  6 Game length  1814 Max score  2048 Game score  7092.0
# Game #  7 Game length  1964 Max score  2048 Game score  7676.0
# Game #  8 Game length  1871 Max score  2048 Game score  7332.0
# Game #  9 Game length  1799 Max score  2048 Game score  7034.0
# Game #  10 Game length  2070 Max score  2048 Game score  8098.0
# Game #  11 Game length  1739 Max score  2048 Game score  6796.0
# Game #  12 Game length  2188 Max score  2048 Game score  8560.0
# Game #  13 Game length  2062 Max score  2048 Game score  8068.0
# Game #  14 Game length  2072 Max score  2048 Game score  8104.0
# Game #  15 Game length  1335 Max score  1024 Game score  5156.0
# Game #  16 Game length  2568 Max score  4096 Game score  10114.0
# Game #  17 Game length  2016 Max score  2048 Game score  7902.0
# Game #  18 Game length  2222 Max score  2048 Game score  8710.0
# Game #  19 Game length  2059 Max score  2048 Game score  8058.0
# Game #  20 Game length  1800 Max score  2048 Game score  7026.0
# Game #  21 Game length  2794 Max score  4096 Game score  11024.0
# Game #  22 Game length  1454 Max score  2048 Game score  5676.0
# Game #  23 Game length  789 Max score  1024 Game score  3014.0
# Game #  24 Game length  1483 Max score  2048 Game score  5784.0
# Game #  25 Game length  636 Max score  512 Game score  2374.0
# Game #  26 Game length  1056 Max score  1024 Game score  4054.0
# Game #  27 Game length  1546 Max score  2048 Game score  6026.0
# Game #  28 Game length  2060 Max score  2048 Game score  8068.0
# Game #  29 Game length  791 Max score  1024 Game score  3014.0
# Game #  30 Game length  1971 Max score  2048 Game score  7722.0
# Game #  31 Game length  2026 Max score  2048 Game score  7938.0
# Game #  32 Game length  1773 Max score  2048 Game score  6926.0
# Game #  33 Game length  1539 Max score  2048 Game score  5998.0
# Game #  34 Game length  2072 Max score  2048 Game score  8104.0
# Game #  35 Game length  1817 Max score  2048 Game score  7100.0
# Game #  36 Game length  1309 Max score  2048 Game score  5076.0
# Game #  37 Game length  1049 Max score  1024 Game score  4032.0
# Game #  38 Game length  2077 Max score  2048 Game score  8120.0
# Game #  39 Game length  1475 Max score  2048 Game score  5744.0
# Game #  40 Game length  2323 Max score  4096 Game score  9140.0
# Game #  41 Game length  1767 Max score  2048 Game score  6902.0
# Game #  42 Game length  1919 Max score  2048 Game score  7512.0
# Game #  43 Game length  3442 Max score  4096 Game score  13596.0
# Game #  44 Game length  1348 Max score  1024 Game score  5214.0
# Game #  45 Game length  635 Max score  1024 Game score  2402.0
# Game #  46 Game length  1089 Max score  1024 Game score  4200.0
# Game #  47 Game length  2067 Max score  2048 Game score  8090.0
# Game #  48 Game length  2066 Max score  2048 Game score  8082.0
# Game #  49 Game length  1962 Max score  2048 Game score  7678.0
# Game #  50 Game length  1548 Max score  2048 Game score  6034.0
# Game #  51 Game length  1074 Max score  1024 Game score  4124.0
# Game #  52 Game length  538 Max score  512 Game score  2000.0
# Game #  53 Game length  2523 Max score  4096 Game score  9934.0
# Game #  54 Game length  1809 Max score  2048 Game score  7070.0
# Game #  55 Game length  1733 Max score  2048 Game score  6752.0
# Game #  56 Game length  1558 Max score  2048 Game score  6070.0
# Game #  57 Game length  1059 Max score  1024 Game score  4078.0
# Game #  58 Game length  554 Max score  512 Game score  2068.0
# Game #  59 Game length  897 Max score  1024 Game score  3450.0
# Game #  60 Game length  1598 Max score  2048 Game score  6220.0
# Game #  61 Game length  1999 Max score  2048 Game score  7828.0
# Game #  62 Game length  993 Max score  1024 Game score  3814.0
# Game #  63 Game length  928 Max score  1024 Game score  3556.0
# Game #  64 Game length  1604 Max score  2048 Game score  6236.0
# Game #  65 Game length  1042 Max score  1024 Game score  4004.0
# Game #  66 Game length  1024 Max score  1024 Game score  3928.0
# Game #  67 Game length  1043 Max score  1024 Game score  4010.0
# Game #  68 Game length  1954 Max score  2048 Game score  7650.0
# Game #  69 Game length  3023 Max score  4096 Game score  11922.0
# Game #  70 Game length  2836 Max score  4096 Game score  11174.0
# Game #  71 Game length  1610 Max score  2048 Game score  6256.0
# Game #  72 Game length  2337 Max score  4096 Game score  9190.0
# Game #  73 Game length  2150 Max score  2048 Game score  8424.0
# Game #  74 Game length  978 Max score  1024 Game score  3760.0
# Game #  75 Game length  2840 Max score  4096 Game score  11186.0
# Game #  76 Game length  988 Max score  1024 Game score  3800.0
# Game #  77 Game length  1091 Max score  1024 Game score  4212.0
# Game #  78 Game length  1838 Max score  2048 Game score  7178.0
# Game #  79 Game length  1307 Max score  2048 Game score  5076.0
# Game #  80 Game length  2898 Max score  4096 Game score  11438.0
# Game #  81 Game length  1064 Max score  1024 Game score  4090.0
# Game #  82 Game length  1557 Max score  2048 Game score  6062.0
# Game #  83 Game length  1037 Max score  1024 Game score  3980.0
# Game #  84 Game length  1911 Max score  2048 Game score  7478.0
# Game #  85 Game length  1447 Max score  2048 Game score  5624.0
# Game #  86 Game length  1799 Max score  2048 Game score  7040.0
# Game #  87 Game length  2062 Max score  2048 Game score  8072.0
# Game #  88 Game length  3055 Max score  4096 Game score  12048.0
# Game #  89 Game length  1751 Max score  2048 Game score  6846.0
# Game #  90 Game length  1053 Max score  1024 Game score  4050.0
# Game #  91 Game length  3559 Max score  4096 Game score  14060.0
# Game #  92 Game length  1584 Max score  2048 Game score  6170.0
# Game #  93 Game length  1821 Max score  2048 Game score  7114.0
# Game #  94 Game length  1912 Max score  2048 Game score  7486.0
# Game #  95 Game length  1551 Max score  2048 Game score  6042.0
# Game #  96 Game length  1947 Max score  2048 Game score  7606.0
# Game #  97 Game length  1512 Max score  2048 Game score  5894.0
# Game #  98 Game length  1565 Max score  2048 Game score  6092.0
# Game #  99 Game length  1049 Max score  1024 Game score  4026.0
# Game #  100 Game length  1552 Max score  2048 Game score  6050.0

# %%
num_epochs = 1000
train(model, optimizer, loss)
# Out:
# Game #  1 Game length  1055 Max score  1024 Game score  4050.0
# Game #  2 Game length  1581 Max score  2048 Game score  6154.0
# Game #  3 Game length  2077 Max score  2048 Game score  8128.0
# Game #  4 Game length  1807 Max score  2048 Game score  7064.0
# Game #  5 Game length  2859 Max score  4096 Game score  11264.0
# Game #  6 Game length  1941 Max score  2048 Game score  7594.0
# Game #  7 Game length  1558 Max score  2048 Game score  6070.0
# Game #  8 Game length  1296 Max score  2048 Game score  5038.0
# Game #  9 Game length  2067 Max score  2048 Game score  8090.0
# Game #  10 Game length  1143 Max score  1024 Game score  4406.0
# Game #  11 Game length  1829 Max score  2048 Game score  7144.0
# Game #  12 Game length  2957 Max score  4096 Game score  11656.0
# Game #  13 Game length  914 Max score  1024 Game score  3512.0
# Game #  14 Game length  2339 Max score  4096 Game score  9198.0
# Game #  15 Game length  1804 Max score  2048 Game score  7052.0
# Game #  16 Game length  1906 Max score  2048 Game score  7466.0
# Game #  17 Game length  2076 Max score  2048 Game score  8118.0
# Game #  18 Game length  2073 Max score  2048 Game score  8106.0
# Game #  19 Game length  1348 Max score  2048 Game score  5224.0
# Game #  20 Game length  2696 Max score  4096 Game score  10634.0
# Game #  21 Game length  1561 Max score  2048 Game score  6078.0
# Game #  22 Game length  1049 Max score  1024 Game score  4032.0
# Game #  23 Game length  3110 Max score  4096 Game score  12254.0
# Game #  24 Game length  1445 Max score  2048 Game score  5632.0
# Game #  25 Game length  1801 Max score  2048 Game score  7044.0
# Game #  26 Game length  913 Max score  1024 Game score  3504.0
# Game #  27 Game length  1000 Max score  1024 Game score  3836.0
# Game #  28 Game length  829 Max score  1024 Game score  3156.0
# Game #  29 Game length  1701 Max score  2048 Game score  6642.0
# Game #  30 Game length  987 Max score  1024 Game score  3794.0
# Game #  31 Game length  2937 Max score  4096 Game score  11578.0
# Game #  32 Game length  2151 Max score  2048 Game score  8426.0
# Game #  33 Game length  1305 Max score  2048 Game score  5070.0
# Game #  34 Game length  3054 Max score  4096 Game score  12038.0
# Game #  35 Game length  1052 Max score  1024 Game score  4044.0
# Game #  36 Game length  1934 Max score  2048 Game score  7572.0
# Game #  37 Game length  1565 Max score  2048 Game score  6092.0
# Game #  38 Game length  575 Max score  512 Game score  2140.0
# Game #  39 Game length  1562 Max score  2048 Game score  6084.0
# Game #  40 Game length  1581 Max score  2048 Game score  6150.0
# Game #  41 Game length  1083 Max score  1024 Game score  4150.0
# Game #  42 Game length  944 Max score  1024 Game score  3618.0
# Game #  43 Game length  1589 Max score  2048 Game score  6184.0
# Game #  44 Game length  1932 Max score  2048 Game score  7554.0
# Game #  45 Game length  964 Max score  1024 Game score  3704.0
# Game #  46 Game length  544 Max score  512 Game score  2024.0
# Game #  47 Game length  1805 Max score  2048 Game score  7058.0
# Game #  48 Game length  2036 Max score  2048 Game score  7962.0
# Game #  49 Game length  1556 Max score  2048 Game score  6060.0
# Game #  50 Game length  1040 Max score  1024 Game score  3998.0
# Game #  51 Game length  2047 Max score  2048 Game score  8016.0
# Game #  52 Game length  2444 Max score  4096 Game score  9628.0
# Game #  53 Game length  1086 Max score  1024 Game score  4168.0
# Game #  54 Game length  1523 Max score  2048 Game score  5936.0
# Game #  55 Game length  2054 Max score  2048 Game score  8044.0
# Game #  56 Game length  2045 Max score  2048 Game score  8012.0
# Game #  57 Game length  2959 Max score  4096 Game score  11668.0
# Game #  58 Game length  740 Max score  1024 Game score  2814.0
# Game #  59 Game length  1906 Max score  2048 Game score  7466.0
# Game #  60 Game length  3073 Max score  4096 Game score  12120.0
# Game #  61 Game length  2323 Max score  4096 Game score  9148.0
# Game #  62 Game length  2092 Max score  2048 Game score  8180.0
# Game #  63 Game length  2067 Max score  2048 Game score  8090.0
# Game #  64 Game length  1554 Max score  2048 Game score  6054.0
# Game #  65 Game length  1878 Max score  2048 Game score  7346.0
# Game #  66 Game length  2091 Max score  2048 Game score  8178.0
# Game #  67 Game length  1584 Max score  2048 Game score  6170.0
# Game #  68 Game length  918 Max score  1024 Game score  3522.0
# Game #  69 Game length  1779 Max score  2048 Game score  6952.0
# Game #  70 Game length  1046 Max score  1024 Game score  4018.0
# Game #  71 Game length  2088 Max score  2048 Game score  8176.0
# Game #  72 Game length  1033 Max score  1024 Game score  3976.0
# Game #  73 Game length  1568 Max score  2048 Game score  6100.0
# Game #  74 Game length  1804 Max score  2048 Game score  7056.0
# Game #  75 Game length  1722 Max score  2048 Game score  6698.0
# Game #  76 Game length  1522 Max score  2048 Game score  5932.0
# Game #  77 Game length  1024 Max score  1024 Game score  3944.0
# Game #  78 Game length  1804 Max score  2048 Game score  7052.0
# Game #  79 Game length  1658 Max score  2048 Game score  6460.0
# Game #  80 Game length  1011 Max score  1024 Game score  3884.0
# Game #  81 Game length  2833 Max score  4096 Game score  11164.0
# Game #  82 Game length  1917 Max score  2048 Game score  7502.0
# Game #  83 Game length  1060 Max score  1024 Game score  4076.0
# Game #  84 Game length  2019 Max score  2048 Game score  7904.0
# Game #  85 Game length  1303 Max score  1024 Game score  5048.0
# Game #  86 Game length  1540 Max score  2048 Game score  6006.0
# Game #  87 Game length  1039 Max score  1024 Game score  3996.0
# Game #  88 Game length  913 Max score  1024 Game score  3484.0
# Game #  89 Game length  1050 Max score  1024 Game score  4034.0
# Game #  90 Game length  1099 Max score  1024 Game score  4216.0
# Game #  91 Game length  927 Max score  1024 Game score  3554.0
# Game #  92 Game length  1536 Max score  2048 Game score  5986.0
# Game #  93 Game length  1809 Max score  2048 Game score  7070.0
# Game #  94 Game length  1040 Max score  1024 Game score  4000.0
# Game #  95 Game length  1584 Max score  2048 Game score  6166.0
# Game #  96 Game length  1563 Max score  2048 Game score  6086.0
# Game #  97 Game length  864 Max score  1024 Game score  3314.0
# Game #  98 Game length  930 Max score  1024 Game score  3562.0
# Game #  99 Game length  3067 Max score  4096 Game score  12096.0
# Game #  100 Game length  2088 Max score  2048 Game score  8166.0
# Game #  101 Game length  2050 Max score  2048 Game score  8024.0
# Game #  102 Game length  2448 Max score  2048 Game score  9606.0
# Game #  103 Game length  1194 Max score  1024 Game score  4614.0
# Game #  104 Game length  2009 Max score  2048 Game score  7864.0
# Game #  105 Game length  2059 Max score  2048 Game score  8060.0
# Game #  106 Game length  2041 Max score  2048 Game score  7996.0
# Game #  107 Game length  803 Max score  1024 Game score  3054.0
# Game #  108 Game length  1385 Max score  2048 Game score  5400.0
# Game #  109 Game length  933 Max score  1024 Game score  3574.0
# Game #  110 Game length  2036 Max score  2048 Game score  7976.0
# Game #  111 Game length  2049 Max score  2048 Game score  8024.0
# Game #  112 Game length  1019 Max score  1024 Game score  3914.0
# Game #  113 Game length  1833 Max score  2048 Game score  7162.0
# Game #  114 Game length  861 Max score  1024 Game score  3282.0
# Game #  115 Game length  1106 Max score  1024 Game score  4258.0
# Game #  116 Game length  1565 Max score  2048 Game score  6092.0
# Game #  117 Game length  1042 Max score  1024 Game score  4012.0
# Game #  118 Game length  1950 Max score  2048 Game score  7626.0
# Game #  119 Game length  1087 Max score  1024 Game score  4180.0
# Game #  120 Game length  2058 Max score  2048 Game score  8054.0
# Game #  121 Game length  1774 Max score  2048 Game score  6928.0
# Game #  122 Game length  2827 Max score  4096 Game score  11144.0
# Game #  123 Game length  1806 Max score  2048 Game score  7062.0
# Game #  124 Game length  1564 Max score  2048 Game score  6102.0
# Game #  125 Game length  1951 Max score  2048 Game score  7636.0
# Game #  126 Game length  2057 Max score  2048 Game score  8052.0
# Game #  127 Game length  2001 Max score  2048 Game score  7834.0
# Game #  128 Game length  1423 Max score  2048 Game score  5542.0
# Game #  129 Game length  916 Max score  1024 Game score  3512.0
# Game #  130 Game length  1876 Max score  2048 Game score  7324.0
# Game #  131 Game length  1056 Max score  1024 Game score  4054.0
# Game #  132 Game length  1061 Max score  1024 Game score  4076.0
# Game #  133 Game length  1522 Max score  2048 Game score  5914.0
# Game #  134 Game length  1997 Max score  2048 Game score  7820.0
# Game #  135 Game length  1091 Max score  1024 Game score  4234.0
# Game #  136 Game length  1067 Max score  1024 Game score  4102.0
# Game #  137 Game length  1956 Max score  2048 Game score  7676.0
# Game #  138 Game length  1843 Max score  2048 Game score  7200.0
# Game #  139 Game length  495 Max score  512 Game score  1834.0
# Game #  140 Game length  1521 Max score  1024 Game score  5914.0
# Game #  141 Game length  983 Max score  1024 Game score  3778.0
# Game #  142 Game length  2572 Max score  4096 Game score  10128.0
# Game #  143 Game length  951 Max score  1024 Game score  3646.0
# Game #  144 Game length  1754 Max score  2048 Game score  6860.0
# Game #  145 Game length  991 Max score  1024 Game score  3808.0
# Game #  146 Game length  1310 Max score  2048 Game score  5082.0
# Game #  147 Game length  1952 Max score  2048 Game score  7640.0
# Game #  148 Game length  1064 Max score  1024 Game score  4084.0
# Game #  149 Game length  2929 Max score  4096 Game score  11552.0
# Game #  150 Game length  1515 Max score  2048 Game score  5894.0
# Game #  151 Game length  1522 Max score  2048 Game score  5934.0
# Game #  152 Game length  2541 Max score  4096 Game score  10010.0
# Game #  153 Game length  2057 Max score  2048 Game score  8052.0
# Game #  154 Game length  1307 Max score  2048 Game score  5074.0
# Game #  155 Game length  970 Max score  1024 Game score  3736.0
# Game #  156 Game length  796 Max score  1024 Game score  3032.0
# Game #  157 Game length  1053 Max score  1024 Game score  4044.0
# Game #  158 Game length  1032 Max score  1024 Game score  3974.0
# Game #  159 Game length  1036 Max score  1024 Game score  3984.0
# Game #  160 Game length  2936 Max score  4096 Game score  11584.0
# Game #  161 Game length  1911 Max score  2048 Game score  7482.0
# Game #  162 Game length  1045 Max score  1024 Game score  4016.0
# Game #  163 Game length  2053 Max score  2048 Game score  8040.0
# Game #  164 Game length  2060 Max score  2048 Game score  8062.0
# Game #  165 Game length  1932 Max score  2048 Game score  7562.0
# Game #  166 Game length  1548 Max score  2048 Game score  6030.0
# Game #  167 Game length  2723 Max score  4096 Game score  10730.0
# Game #  168 Game length  1070 Max score  1024 Game score  4110.0
# Game #  169 Game length  1079 Max score  1024 Game score  4144.0
# Game #  170 Game length  1544 Max score  2048 Game score  6016.0
# Game #  171 Game length  1039 Max score  1024 Game score  3990.0
# Game #  172 Game length  1950 Max score  2048 Game score  7634.0
# Game #  173 Game length  2007 Max score  2048 Game score  7858.0
# Game #  174 Game length  1817 Max score  2048 Game score  7094.0
# Game #  175 Game length  1438 Max score  2048 Game score  5598.0
# Game #  176 Game length  1497 Max score  2048 Game score  5834.0
# Game #  177 Game length  2059 Max score  2048 Game score  8060.0
# Game #  178 Game length  1537 Max score  2048 Game score  5992.0
# Game #  179 Game length  915 Max score  1024 Game score  3510.0
# Game #  180 Game length  1053 Max score  1024 Game score  4046.0
# Game #  181 Game length  1571 Max score  2048 Game score  6108.0
# Game #  182 Game length  2054 Max score  2048 Game score  8036.0
# Game #  183 Game length  2048 Max score  2048 Game score  8018.0
# Game #  184 Game length  2037 Max score  2048 Game score  7978.0
# Game #  185 Game length  2201 Max score  2048 Game score  8626.0
# Game #  186 Game length  1551 Max score  2048 Game score  6042.0
# Game #  187 Game length  1592 Max score  2048 Game score  6202.0
# Game #  188 Game length  2014 Max score  2048 Game score  7892.0
# Game #  189 Game length  2057 Max score  2048 Game score  8054.0
# Game #  190 Game length  1529 Max score  2048 Game score  5960.0
# Game #  191 Game length  1581 Max score  2048 Game score  6154.0
# Game #  192 Game length  855 Max score  1024 Game score  3262.0
# Game #  193 Game length  695 Max score  1024 Game score  2634.0
# Game #  194 Game length  934 Max score  1024 Game score  3576.0
# Game #  195 Game length  1024 Max score  1024 Game score  3944.0
# Game #  196 Game length  1952 Max score  2048 Game score  7634.0
# Game #  197 Game length  1801 Max score  2048 Game score  7044.0
# Game #  198 Game length  1069 Max score  1024 Game score  4108.0
# Game #  199 Game length  1551 Max score  2048 Game score  6042.0
# Game #  202 Game length  1531 Max score  2048 Game score  5960.0
# Game #  203 Game length  1531 Max score  2048 Game score  5960.0
# Game #  204 Game length  2025 Max score  2048 Game score  7922.0
# Game #  205 Game length  1578 Max score  2048 Game score  6142.0
# Game #  206 Game length  1941 Max score  2048 Game score  7594.0
# Game #  207 Game length  1039 Max score  1024 Game score  3996.0
# Game #  208 Game length  2102 Max score  2048 Game score  8232.0
# Game #  209 Game length  1593 Max score  2048 Game score  6198.0
# Game #  210 Game length  1564 Max score  2048 Game score  6092.0
# Game #  211 Game length  1036 Max score  1024 Game score  3984.0
# Game #  212 Game length  2321 Max score  2048 Game score  9098.0
# Game #  213 Game length  1750 Max score  2048 Game score  6844.0
# Game #  214 Game length  1042 Max score  1024 Game score  4004.0
# Game #  215 Game length  911 Max score  1024 Game score  3500.0
# Game #  216 Game length  1036 Max score  1024 Game score  3988.0
# Game #  217 Game length  1851 Max score  2048 Game score  7222.0
# Game #  218 Game length  1855 Max score  2048 Game score  7236.0
# Game #  219 Game length  1044 Max score  1024 Game score  4012.0
# Game #  220 Game length  778 Max score  1024 Game score  2972.0
# Game #  221 Game length  1048 Max score  1024 Game score  4028.0
# Game #  222 Game length  1719 Max score  2048 Game score  6714.0
# Game #  223 Game length  2008 Max score  2048 Game score  7856.0
# Game #  224 Game length  1556 Max score  2048 Game score  6052.0
# Game #  225 Game length  1988 Max score  2048 Game score  7786.0
# Game #  226 Game length  2132 Max score  2048 Game score  8346.0
# Game #  227 Game length  2518 Max score  4096 Game score  9912.0
# Game #  228 Game length  1791 Max score  2048 Game score  7002.0
# Game #  229 Game length  1499 Max score  2048 Game score  5840.0
# Game #  230 Game length  1064 Max score  1024 Game score  4092.0
# Game #  231 Game length  1865 Max score  2048 Game score  7282.0
# Game #  232 Game length  1525 Max score  2048 Game score  5936.0
# Game #  233 Game length  1906 Max score  2048 Game score  7456.0
# Game #  234 Game length  1531 Max score  2048 Game score  5966.0
# Game #  235 Game length  1763 Max score  2048 Game score  6890.0
# Game #  236 Game length  988 Max score  1024 Game score  3800.0
# Game #  237 Game length  1875 Max score  2048 Game score  7342.0
# Game #  238 Game length  1080 Max score  1024 Game score  4146.0
# Game #  239 Game length  1074 Max score  1024 Game score  4130.0
# Game #  240 Game length  2944 Max score  4096 Game score  11616.0
# Game #  241 Game length  1608 Max score  2048 Game score  6266.0
# Game #  242 Game length  1993 Max score  2048 Game score  7804.0
# Game #  243 Game length  936 Max score  1024 Game score  3582.0
# Game #  244 Game length  1798 Max score  2048 Game score  7036.0
# Game #  245 Game length  1042 Max score  1024 Game score  4004.0
# Game #  246 Game length  1046 Max score  1024 Game score  4024.0
# Game #  247 Game length  2047 Max score  2048 Game score  8008.0
# Game #  248 Game length  889 Max score  1024 Game score  3418.0
# Game #  249 Game length  2834 Max score  4096 Game score  11166.0
# Game #  250 Game length  1009 Max score  1024 Game score  3884.0
# Game #  251 Game length  1624 Max score  2048 Game score  6318.0
# Game #  252 Game length  1616 Max score  2048 Game score  6288.0
# Game #  253 Game length  1114 Max score  1024 Game score  4280.0
# Game #  254 Game length  1449 Max score  2048 Game score  5644.0
# Game #  255 Game length  1942 Max score  2048 Game score  7602.0
# Game #  256 Game length  1942 Max score  2048 Game score  7596.0
# Game #  257 Game length  1047 Max score  1024 Game score  4026.0
# Game #  258 Game length  2298 Max score  4096 Game score  9036.0
# Game #  259 Game length  2064 Max score  2048 Game score  8074.0
# Game #  260 Game length  1565 Max score  2048 Game score  6092.0
# Game #  261 Game length  1369 Max score  1024 Game score  5300.0
# Game #  262 Game length  1868 Max score  2048 Game score  7316.0
# Game #  263 Game length  1427 Max score  2048 Game score  5556.0
# Game #  264 Game length  2011 Max score  2048 Game score  7872.0
# Game #  265 Game length  856 Max score  1024 Game score  3284.0
# Game #  266 Game length  1833 Max score  2048 Game score  7162.0
# Game #  267 Game length  540 Max score  512 Game score  2014.0
# Game #  268 Game length  1038 Max score  1024 Game score  3994.0
# Game #  269 Game length  2049 Max score  2048 Game score  8014.0
# Game #  270 Game length  2520 Max score  4096 Game score  9926.0
# Game #  271 Game length  1544 Max score  2048 Game score  6020.0
# Game #  272 Game length  1540 Max score  2048 Game score  5988.0
# Game #  273 Game length  1554 Max score  2048 Game score  6050.0
# Game #  274 Game length  1919 Max score  2048 Game score  7514.0
# Game #  275 Game length  3269 Max score  4096 Game score  12922.0
# Game #  276 Game length  1634 Max score  2048 Game score  6388.0
# Game #  277 Game length  527 Max score  512 Game score  1968.0
# Game #  278 Game length  1033 Max score  1024 Game score  3978.0
# Game #  279 Game length  1065 Max score  1024 Game score  4094.0
# Game #  280 Game length  1970 Max score  2048 Game score  7720.0
# Game #  281 Game length  1037 Max score  1024 Game score  3990.0
# Game #  282 Game length  3102 Max score  4096 Game score  12218.0
# Game #  283 Game length  1839 Max score  2048 Game score  7186.0
# Game #  284 Game length  1199 Max score  1024 Game score  4638.0
# Game #  285 Game length  551 Max score  512 Game score  2054.0
# Game #  286 Game length  1880 Max score  2048 Game score  7364.0
# Game #  288 Game length  3415 Max score  4096 Game score  13498.0
# Game #  289 Game length  2088 Max score  2048 Game score  8170.0
# Game #  290 Game length  1469 Max score  2048 Game score  5728.0
# Game #  291 Game length  1900 Max score  2048 Game score  7438.0
# Game #  292 Game length  993 Max score  1024 Game score  3814.0
# Game #  293 Game length  1573 Max score  2048 Game score  6122.0
# Game #  294 Game length  1848 Max score  2048 Game score  7218.0
# Game #  295 Game length  1965 Max score  2048 Game score  7678.0
# Game #  296 Game length  1061 Max score  1024 Game score  4076.0
# Game #  297 Game length  917 Max score  1024 Game score  3506.0
# Game #  298 Game length  799 Max score  1024 Game score  3044.0
# Game #  299 Game length  999 Max score  1024 Game score  3846.0
# Game #  300 Game length  2029 Max score  2048 Game score  7940.0
# Game #  301 Game length  1984 Max score  2048 Game score  7752.0
# Game #  302 Game length  1577 Max score  2048 Game score  6140.0
# Game #  303 Game length  1842 Max score  2048 Game score  7198.0
# Game #  304 Game length  2035 Max score  2048 Game score  7968.0
# Game #  305 Game length  1009 Max score  1024 Game score  3876.0
# Game #  306 Game length  1136 Max score  1024 Game score  4378.0
# Game #  308 Game length  1563 Max score  2048 Game score  6086.0
# Game #  309 Game length  1057 Max score  1024 Game score  4060.0
# Game #  310 Game length  2503 Max score  4096 Game score  9868.0
# Game #  313 Game length  1505 Max score  2048 Game score  5860.0
# Game #  314 Game length  1032 Max score  1024 Game score  3974.0
# Game #  315 Game length  1567 Max score  2048 Game score  6098.0
# Game #  316 Game length  2013 Max score  2048 Game score  7874.0
# Game #  317 Game length  1179 Max score  2048 Game score  4574.0
# Game #  318 Game length  1069 Max score  1024 Game score  4108.0
# Game #  319 Game length  2022 Max score  2048 Game score  7918.0
# Game #  320 Game length  1015 Max score  1024 Game score  3904.0
# Game #  321 Game length  1999 Max score  2048 Game score  7828.0
# Game #  322 Game length  2058 Max score  2048 Game score  8058.0
# Game #  323 Game length  1715 Max score  2048 Game score  6700.0
# Game #  324 Game length  1427 Max score  2048 Game score  5556.0
# Game #  325 Game length  794 Max score  1024 Game score  3022.0
# Game #  326 Game length  612 Max score  512 Game score  2282.0
# Game #  327 Game length  1326 Max score  1024 Game score  5132.0
# Game #  328 Game length  1936 Max score  2048 Game score  7576.0
# Game #  329 Game length  1553 Max score  2048 Game score  6050.0
# Game #  330 Game length  1548 Max score  2048 Game score  6034.0
# Game #  331 Game length  1033 Max score  1024 Game score  3964.0
# Game #  332 Game length  1965 Max score  2048 Game score  7686.0
# Game #  333 Game length  1573 Max score  2048 Game score  6122.0
# Game #  334 Game length  1816 Max score  2048 Game score  7096.0
# Game #  335 Game length  1487 Max score  1024 Game score  5782.0
# Game #  336 Game length  2060 Max score  2048 Game score  8064.0
# Game #  337 Game length  947 Max score  1024 Game score  3636.0
# Game #  338 Game length  2403 Max score  4096 Game score  9462.0
# Game #  339 Game length  938 Max score  1024 Game score  3600.0
# Game #  340 Game length  1558 Max score  2048 Game score  6062.0
# Game #  341 Game length  2001 Max score  2048 Game score  7834.0
# Game #  342 Game length  2304 Max score  4096 Game score  9070.0
# Game #  343 Game length  1058 Max score  1024 Game score  4068.0
# Game #  344 Game length  973 Max score  1024 Game score  3744.0
# Game #  345 Game length  1041 Max score  1024 Game score  4002.0
# Game #  346 Game length  1790 Max score  2048 Game score  7006.0
# Game #  347 Game length  2503 Max score  4096 Game score  9858.0
# Game #  348 Game length  552 Max score  512 Game score  2062.0
# Game #  349 Game length  1512 Max score  2048 Game score  5894.0
# Game #  350 Game length  928 Max score  1024 Game score  3556.0
# Game #  351 Game length  2058 Max score  2048 Game score  8054.0
# Game #  352 Game length  1550 Max score  2048 Game score  6038.0
# Game #  353 Game length  1008 Max score  1024 Game score  3882.0
# Game #  354 Game length  1830 Max score  2048 Game score  7154.0
# Game #  355 Game length  1963 Max score  2048 Game score  7672.0
# Game #  356 Game length  1991 Max score  2048 Game score  7802.0
# Game #  357 Game length  1077 Max score  1024 Game score  4132.0
# Game #  358 Game length  1704 Max score  2048 Game score  6630.0
# Game #  359 Game length  1023 Max score  1024 Game score  3934.0
# Game #  360 Game length  1830 Max score  2048 Game score  7154.0
# Game #  361 Game length  1046 Max score  1024 Game score  4020.0
# Game #  362 Game length  1394 Max score  2048 Game score  5436.0
# Game #  363 Game length  2613 Max score  4096 Game score  10272.0
# Game #  364 Game length  1648 Max score  2048 Game score  6414.0
# Game #  365 Game length  1041 Max score  1024 Game score  4002.0
# Game #  366 Game length  1671 Max score  2048 Game score  6514.0
# Game #  367 Game length  883 Max score  1024 Game score  3368.0
# Game #  368 Game length  2031 Max score  2048 Game score  7954.0
# Game #  369 Game length  975 Max score  1024 Game score  3754.0
# Game #  370 Game length  982 Max score  1024 Game score  3772.0
# Game #  371 Game length  1928 Max score  2048 Game score  7546.0
# Game #  372 Game length  2032 Max score  2048 Game score  7956.0
# Game #  373 Game length  1117 Max score  1024 Game score  4300.0
# Game #  374 Game length  2068 Max score  2048 Game score  8092.0
# Game #  375 Game length  1998 Max score  2048 Game score  7826.0
# Game #  376 Game length  1212 Max score  1024 Game score  4690.0
# Game #  377 Game length  2064 Max score  2048 Game score  8074.0
# Game #  378 Game length  2498 Max score  4096 Game score  9850.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-d06c3f612c3d> in <module>
#       1 num_epochs = 1000
# ----> 2 train(model, optimizer, loss)
#
# <ipython-input-10-bef355e9577f> in train(model, optimizer, loss, epoch, running_mean)
#       6     while epoch != num_epochs:
#       7         epoch += 1
# ----> 8         game_len, max_score, game_score = gen_sample_and_learn(model, optimizer, loss, True)
#       9         print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)
#      10         ls.pop(0)
#
# <ipython-input-7-7edeab58cb8a> in gen_sample_and_learn(model, optimizer, loss_fn, is_train)
#      56             optimizer.zero_grad()
#      57             pred = model(x)
# ---> 58             loss = loss_fn(pred, y)
#      59             last_loss = loss.item()
#      60             loss.backward()
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     429
#     430     def forward(self, input, target):
# --> 431         return F.mse_loss(input, target, reduction=self.reduction)
#     432
#     433
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in mse_loss(input, target, size_average, reduce, reduction)
#    2188     else:
#    2189         expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 2190         ret = torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#    2191     return ret
#    2192
#
# KeyboardInterrupt:

# %%
num_epochs = 100

print (best_model)

def test(model):
    epoch = 0
    while epoch != num_epochs:
        epoch += 1
        game_len, max_score, game_score = gen_sample_and_learn(model, None, None, False)
        print ('Game # ', epoch, 'Game length ', game_len, 'Max score ', max_score, 'Game score ', game_score, flush=True)

test(model)
# Out:
# None
# Game #  1 Game length  1935 Max score  2048 Game score  7574.0
# Game #  2 Game length  1192 Max score  1024 Game score  4596.0
# Game #  3 Game length  2824 Max score  4096 Game score  11136.0
# Game #  4 Game length  2042 Max score  2048 Game score  8000.0
# Game #  5 Game length  1047 Max score  1024 Game score  4026.0
# Game #  6 Game length  1819 Max score  2048 Game score  7108.0
# Game #  7 Game length  1574 Max score  2048 Game score  6124.0
# Game #  8 Game length  1796 Max score  2048 Game score  7026.0
# Game #  9 Game length  737 Max score  1024 Game score  2796.0
# Game #  10 Game length  498 Max score  512 Game score  1858.0
# Game #  11 Game length  906 Max score  1024 Game score  3482.0
# Game #  12 Game length  1575 Max score  2048 Game score  6134.0
# Game #  13 Game length  1736 Max score  2048 Game score  6786.0
# Game #  14 Game length  1563 Max score  2048 Game score  6086.0
# Game #  15 Game length  814 Max score  1024 Game score  3108.0
# Game #  16 Game length  1038 Max score  1024 Game score  3998.0
# Game #  17 Game length  2058 Max score  2048 Game score  8054.0
# Game #  18 Game length  1886 Max score  2048 Game score  7362.0
# Game #  19 Game length  1038 Max score  1024 Game score  3994.0
# Game #  20 Game length  1515 Max score  2048 Game score  5910.0
# Game #  21 Game length  1551 Max score  2048 Game score  6042.0
# Game #  22 Game length  1531 Max score  2048 Game score  5960.0
# Game #  23 Game length  1544 Max score  2048 Game score  6020.0
# Game #  24 Game length  1490 Max score  2048 Game score  5808.0
# Game #  25 Game length  1822 Max score  2048 Game score  7116.0
# Game #  26 Game length  2048 Max score  2048 Game score  8018.0
# Game #  27 Game length  1057 Max score  1024 Game score  4056.0
# Game #  28 Game length  1075 Max score  1024 Game score  4132.0
# Game #  29 Game length  1922 Max score  2048 Game score  7524.0
# Game #  30 Game length  1234 Max score  2048 Game score  4800.0
# Game #  31 Game length  1531 Max score  2048 Game score  5974.0
# Game #  32 Game length  1177 Max score  2048 Game score  4574.0
# Game #  33 Game length  1562 Max score  2048 Game score  6084.0
# Game #  34 Game length  1803 Max score  2048 Game score  7054.0
# Game #  35 Game length  1787 Max score  2048 Game score  6988.0
# Game #  36 Game length  1314 Max score  2048 Game score  5098.0
# Game #  37 Game length  1991 Max score  2048 Game score  7792.0
# Game #  38 Game length  1545 Max score  2048 Game score  6022.0
# Game #  39 Game length  841 Max score  1024 Game score  3212.0
# Game #  40 Game length  1821 Max score  2048 Game score  7114.0
# Game #  41 Game length  1039 Max score  1024 Game score  3996.0
# Game #  42 Game length  1498 Max score  2048 Game score  5824.0
# Game #  43 Game length  2072 Max score  2048 Game score  8104.0
# Game #  44 Game length  1562 Max score  2048 Game score  6080.0
# Game #  45 Game length  1813 Max score  2048 Game score  7084.0
# Game #  46 Game length  1544 Max score  2048 Game score  6020.0
# Game #  47 Game length  935 Max score  1024 Game score  3586.0
# Game #  48 Game length  1032 Max score  1024 Game score  3974.0
# Game #  49 Game length  1956 Max score  2048 Game score  7652.0
# Game #  50 Game length  2220 Max score  2048 Game score  8706.0
# Game #  51 Game length  1538 Max score  2048 Game score  5988.0
# Game #  52 Game length  1794 Max score  2048 Game score  7010.0
# Game #  53 Game length  1548 Max score  2048 Game score  6034.0
# Game #  54 Game length  1477 Max score  2048 Game score  5760.0
# Game #  55 Game length  601 Max score  512 Game score  2246.0
# Game #  56 Game length  924 Max score  1024 Game score  3542.0
# Game #  57 Game length  834 Max score  1024 Game score  3172.0
# Game #  58 Game length  1020 Max score  1024 Game score  3926.0
# Game #  59 Game length  2072 Max score  2048 Game score  8104.0
# Game #  60 Game length  844 Max score  1024 Game score  3224.0
# Game #  61 Game length  1124 Max score  1024 Game score  4336.0
# Game #  62 Game length  584 Max score  512 Game score  2182.0
# Game #  63 Game length  2062 Max score  2048 Game score  8068.0
# Game #  64 Game length  1843 Max score  2048 Game score  7200.0
# Game #  65 Game length  1028 Max score  1024 Game score  3954.0
# Game #  66 Game length  1795 Max score  2048 Game score  7020.0
# Game #  67 Game length  1324 Max score  1024 Game score  5126.0
# Game #  68 Game length  786 Max score  1024 Game score  2994.0
# Game #  69 Game length  2824 Max score  4096 Game score  11136.0
# Game #  70 Game length  1822 Max score  2048 Game score  7124.0
# Game #  71 Game length  988 Max score  1024 Game score  3792.0
# Game #  72 Game length  1971 Max score  2048 Game score  7710.0
# Game #  73 Game length  2016 Max score  2048 Game score  7902.0
# Game #  74 Game length  1023 Max score  1024 Game score  3934.0
# Game #  75 Game length  916 Max score  1024 Game score  3512.0
# Game #  76 Game length  1994 Max score  2048 Game score  7810.0
# Game #  77 Game length  1188 Max score  1024 Game score  4590.0
# Game #  78 Game length  3091 Max score  4096 Game score  12184.0
# Game #  79 Game length  1575 Max score  2048 Game score  6134.0
# Game #  80 Game length  1179 Max score  2048 Game score  4580.0
# Game #  81 Game length  544 Max score  512 Game score  2024.0
# Game #  82 Game length  1048 Max score  1024 Game score  4032.0
# Game #  83 Game length  1369 Max score  2048 Game score  5338.0
# Game #  84 Game length  1560 Max score  2048 Game score  6074.0
# Game #  85 Game length  1046 Max score  1024 Game score  4022.0
# Game #  86 Game length  1790 Max score  2048 Game score  6994.0
# Game #  87 Game length  2053 Max score  2048 Game score  8040.0
# Game #  88 Game length  1853 Max score  2048 Game score  7234.0
# Game #  89 Game length  1550 Max score  2048 Game score  6040.0
# Game #  90 Game length  1938 Max score  2048 Game score  7582.0
# Game #  91 Game length  1300 Max score  2048 Game score  5048.0
# Game #  92 Game length  1769 Max score  2048 Game score  6906.0
# Game #  93 Game length  994 Max score  1024 Game score  3820.0
# Game #  94 Game length  419 Max score  512 Game score  1536.0
# Game #  95 Game length  1043 Max score  1024 Game score  4010.0
# Game #  96 Game length  1041 Max score  1024 Game score  4002.0
# Game #  97 Game length  1050 Max score  1024 Game score  4038.0
# Game #  98 Game length  1562 Max score  2048 Game score  6080.0
# Game #  99 Game length  1040 Max score  1024 Game score  3998.0
# Game #  100 Game length  1053 Max score  1024 Game score  4046.0

# %%
import os
experiment_dir = "model"
filename = "model2.pth.tar"
num_epochs = 200

def save_model(state, filename='model.pth.tar'):
    filename = os.path.join(experiment_dir, filename)
    torch.save(state, filename)

save_model({
    'epoch': num_epochs,
    'state_dict': model.cpu().state_dict(),
    'optimizer': optimizer.state_dict(),
}, filename)

# %%
best_model, optimizer, epoch, running_mean = load_model(model, optimizer, "model9_0.pth.tar")

test(best_model)
# Out:
# Game #  1 Game length  1834 Max score  2048 Game score  7160.0
# Game #  2 Game length  2612 Max score  4096 Game score  10270.0
# Game #  3 Game length  2137 Max score  2048 Game score  8376.0
# Game #  4 Game length  2059 Max score  2048 Game score  8060.0
# Game #  5 Game length  2040 Max score  2048 Game score  7982.0
# Game #  6 Game length  2036 Max score  2048 Game score  7956.0
# Game #  7 Game length  1959 Max score  2048 Game score  7666.0
# Game #  8 Game length  975 Max score  1024 Game score  3750.0
# Game #  9 Game length  1937 Max score  2048 Game score  7572.0
# Game #  10 Game length  1424 Max score  2048 Game score  5548.0
# Game #  11 Game length  1608 Max score  2048 Game score  6262.0
# Game #  12 Game length  1035 Max score  1024 Game score  3982.0
# Game #  13 Game length  1821 Max score  2048 Game score  7114.0
# Game #  14 Game length  1596 Max score  2048 Game score  6206.0
# Game #  15 Game length  1476 Max score  2048 Game score  5740.0
# Game #  16 Game length  1560 Max score  2048 Game score  6074.0
# Game #  17 Game length  2068 Max score  2048 Game score  8088.0
# Game #  18 Game length  2070 Max score  2048 Game score  8098.0
# Game #  19 Game length  1743 Max score  2048 Game score  6818.0
# Game #  20 Game length  1036 Max score  1024 Game score  3988.0
# Game #  21 Game length  2036 Max score  2048 Game score  7962.0
# Game #  22 Game length  1040 Max score  1024 Game score  3998.0
# Game #  23 Game length  644 Max score  512 Game score  2404.0
# Game #  24 Game length  1492 Max score  2048 Game score  5814.0
# Game #  25 Game length  1534 Max score  2048 Game score  5968.0
# Game #  26 Game length  1972 Max score  2048 Game score  7724.0
# Game #  27 Game length  2145 Max score  2048 Game score  8420.0
# Game #  28 Game length  2562 Max score  4096 Game score  10082.0
# Game #  29 Game length  1057 Max score  1024 Game score  4056.0
# Game #  30 Game length  2778 Max score  4096 Game score  10948.0
# Game #  31 Game length  4058 Max score  4096 Game score  16034.0
# Game #  32 Game length  1526 Max score  2048 Game score  5938.0
# Game #  33 Game length  2961 Max score  4096 Game score  11674.0
# Game #  34 Game length  2105 Max score  2048 Game score  8236.0
# Game #  35 Game length  2066 Max score  2048 Game score  8088.0
# Game #  36 Game length  1941 Max score  2048 Game score  7594.0
# Game #  37 Game length  2588 Max score  4096 Game score  10180.0
# Game #  38 Game length  787 Max score  1024 Game score  3000.0
# Game #  39 Game length  1078 Max score  1024 Game score  4144.0
# Game #  40 Game length  1022 Max score  1024 Game score  3922.0
# Game #  41 Game length  2041 Max score  2048 Game score  7980.0
# Game #  42 Game length  1039 Max score  1024 Game score  3996.0
# Game #  43 Game length  917 Max score  1024 Game score  3516.0
# Game #  44 Game length  2099 Max score  2048 Game score  8208.0
# Game #  45 Game length  1961 Max score  2048 Game score  7672.0
# Game #  46 Game length  1318 Max score  1024 Game score  5100.0
# Game #  47 Game length  2062 Max score  2048 Game score  8068.0
# Game #  48 Game length  1567 Max score  2048 Game score  6096.0
# Game #  49 Game length  1027 Max score  1024 Game score  3932.0
# Game #  50 Game length  1081 Max score  1024 Game score  4152.0
# Game #  51 Game length  1128 Max score  1024 Game score  4338.0
# Game #  52 Game length  2841 Max score  4096 Game score  11194.0
# Game #  53 Game length  1816 Max score  2048 Game score  7092.0
# Game #  54 Game length  1563 Max score  2048 Game score  6082.0
# Game #  55 Game length  2051 Max score  2048 Game score  8030.0
# Game #  56 Game length  2097 Max score  2048 Game score  8202.0
# Game #  57 Game length  2064 Max score  2048 Game score  8074.0
# Game #  58 Game length  1041 Max score  1024 Game score  4002.0
# Game #  59 Game length  2061 Max score  2048 Game score  8066.0
# Game #  60 Game length  1581 Max score  2048 Game score  6154.0
# Game #  61 Game length  1033 Max score  1024 Game score  3976.0
# Game #  62 Game length  1917 Max score  2048 Game score  7494.0
# Game #  63 Game length  446 Max score  256 Game score  1626.0
# Game #  64 Game length  2064 Max score  2048 Game score  8074.0
# Game #  65 Game length  1677 Max score  2048 Game score  6534.0
# Game #  66 Game length  1582 Max score  2048 Game score  6162.0
# Game #  67 Game length  2075 Max score  2048 Game score  8116.0
# Game #  68 Game length  1052 Max score  1024 Game score  4042.0
# Game #  69 Game length  2094 Max score  2048 Game score  8186.0
# Game #  70 Game length  2836 Max score  4096 Game score  11172.0
# Game #  71 Game length  1529 Max score  2048 Game score  5960.0
# Game #  72 Game length  2594 Max score  4096 Game score  10202.0
# Game #  73 Game length  1561 Max score  2048 Game score  6078.0
# Game #  74 Game length  1998 Max score  2048 Game score  7822.0
# Game #  75 Game length  285 Max score  256 Game score  1006.0
# Game #  76 Game length  2516 Max score  4096 Game score  9910.0
# Game #  77 Game length  1019 Max score  1024 Game score  3920.0
# Game #  78 Game length  1146 Max score  1024 Game score  4422.0
# Game #  79 Game length  3086 Max score  4096 Game score  12162.0
# Game #  80 Game length  2570 Max score  4096 Game score  10114.0
# Game #  81 Game length  2838 Max score  4096 Game score  11180.0
# Game #  82 Game length  1056 Max score  1024 Game score  4054.0
# Game #  83 Game length  2592 Max score  4096 Game score  10194.0
# Game #  84 Game length  1436 Max score  2048 Game score  5580.0
# Game #  85 Game length  1786 Max score  2048 Game score  6992.0
# Game #  86 Game length  1048 Max score  1024 Game score  4030.0
# Game #  87 Game length  2837 Max score  4096 Game score  11178.0
# Game #  88 Game length  1935 Max score  2048 Game score  7574.0
# Game #  89 Game length  2734 Max score  4096 Game score  10774.0
# Game #  90 Game length  1948 Max score  2048 Game score  7622.0
# Game #  91 Game length  805 Max score  1024 Game score  3064.0
# Game #  92 Game length  2096 Max score  2048 Game score  8194.0
# Game #  93 Game length  1942 Max score  2048 Game score  7602.0
# Game #  94 Game length  3074 Max score  4096 Game score  12114.0
# Game #  95 Game length  2028 Max score  2048 Game score  7930.0
# Game #  96 Game length  1000 Max score  1024 Game score  3836.0
# Game #  97 Game length  2077 Max score  2048 Game score  8120.0
# Game #  98 Game length  3024 Max score  4096 Game score  11924.0
# Game #  99 Game length  516 Max score  512 Game score  1914.0
# Game #  100 Game length  2006 Max score  2048 Game score  7854.0
